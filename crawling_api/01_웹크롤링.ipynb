# %% [markdown]
# 웹크롤링

# %%
# !pip install selenium

# %%
from selenium import webdriver

driver=webdriver.Chrome('chromedriver.exe') #새 창이 뜸
# Out:
# C:\Users\SBAUser\AppData\Local\Temp\ipykernel_1804\1032076275.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome('chromedriver.exe') #새 창이 뜸

# %%
url='https://www.naver.com/'
driver.get(url)

# %% [markdown]
# 웹페이지(HTML)다운로드

# %%
html=driver.page_source
html
# Out:
# '<html lang="ko" data-dark="false" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36"><head><script async="" type="text/javascript" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-core.js"></script> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"> <meta name="robots" content="index,nofollow"> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url"
# ...

# %% [markdown]
# 멜론 노래 순위 정보 크롤링

# %%
url = 'https://www.melon.com/chart/index.htm'
driver.get(url)

# %%
# !pip install beautifulsoup4
from bs4 import BeautifulSoup

html=driver.page_source
soup=BeautifulSoup(html, 'html.parser')
soup
# Out:
# ...
# <html class="narrow-screen" lang="ko"><head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>멜론차트&gt;TOP100&gt;멜론</title>
# <meta content="음악서비스, 멜론차트, 멜론TOP100, 최신음악, 인기가요, 뮤직비디오, 앨범, 플레이어, 스트리밍, 다운로드, 아티스트플러스, 아티스트채널" name="keywords"/>
# <meta content="No.1 뮤직플랫폼 멜론! 최신 트렌드부터 나를 아는 똑똑한 음악추천까지!" name="description"/>
# <meta content="ee85ff6db1fa8f2226bcb671ecb2bcdbcffb6f8b" name="naver-site-verification"/>
# <meta content="q4tbTQhmxa4La3OdNLsNOCxrJ_WV6lUlBFrFW4-HqQc" name="google-site-verification"/>
# <meta content="357952407588971" property="fb:app_id"/>
# <meta content="Melon" property="og:title"/>
# <meta content="https://cdnimg.melon.co.kr/resource/image/web/common/logo_melon142x99.png" property="og:image"/>
# <meta content="음악이 필요한 순간, 멜론" property="og:description"/>
# <meta content="http://www.melon.com/chart/index.htm" property="og:url"/>
# ...

# %% [markdown]
# 100개 노래 태그 찾기

# %%
soup.select('tbody>tr')
# Out:
# [<tr class="lst50" data-song-no="34819473" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="사건의 지평선 곡 선택" type="checkbox" value="34819473"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">1</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10903868');" title="YOUNHA 6th Album Repackage 'END THEORY : Final Edition'">
#  <img alt="YOUNHA 6th Album Repackage 'END THEORY : Final Edition' - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/109/03/868/10903868_20220330103544_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# ...

# %%
songs = soup.select('tbody>tr')
print(len(songs))
print(type(songs))
print(songs[0])
# Out:
# 100
# <class 'bs4.element.ResultSet'>
# <tr class="lst50" data-song-no="34819473" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="사건의 지평선 곡 선택" type="checkbox" value="34819473"/></div></td>
# <td><div class="wrap t_center"><span class="rank">1</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10903868');" title="YOUNHA 6th Album Repackage 'END THEORY : Final Edition'">
# ...

# %%
songs[1:]
# Out:
# [<tr class="lst50" data-song-no="35454426" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Hype boy 곡 선택" type="checkbox" value="35454426"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">2</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11011565');" title="NewJeans 1st EP 'New Jeans'">
#  <img alt="NewJeans 1st EP 'New Jeans' - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/110/11/565/11011565_20220801102637_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
# ...

# %%
songs=soup.select('tr')[1:]
len(songs)
# Out:
# 100

# %%
song = songs[0]

title=song.select('a')
titles
# Out:
# [<a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10903868');" title="YOUNHA 6th Album Repackage 'END THEORY : Final Edition'">
#  <img alt="YOUNHA 6th Album Repackage 'END THEORY : Final Edition' - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/109/03/868/10903868_20220330103544_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('34819473');" title="사건의 지평선 곡정보"><span class="none">곡정보</span></a>,
#  <a href="javascript:melon.play.playSong('1000002721',34819473);" title="사건의 지평선 재생">사건의 지평선</a>,
#  <a href="javascript:melon.link.goArtistDetail('203912');" title="윤하 (YOUNHA) - 페이지 이동">윤하 (YOUNHA)</a>,
#  <a href="javascript:melon.link.goArtistDetail('203912');" title="윤하 (YOUNHA) - 페이지 이동">윤하 (YOUNHA)</a>,
# ...

# %%
title[2]
# Out:
# <a href="javascript:melon.play.playSong('1000002721',34819473);" title="사건의 지평선 재생">사건의 지평선</a>

# %%
title[2].text
# Out:
# '사건의 지평선'

# %% [markdown]
# 곡 제목 찾는 방법_조금은 스마트하게

# %%
title=song.select('span > a')
title
# Out:
# [<a href="javascript:melon.play.playSong('1000002721',34819473);" title="사건의 지평선 재생">사건의 지평선</a>,
#  <a href="javascript:melon.link.goArtistDetail('203912');" title="윤하 (YOUNHA) - 페이지 이동">윤하 (YOUNHA)</a>]

# %%
len(title)
# Out:
# 2

# %%
title[0].text
# Out:
# '사건의 지평선'

# %% [markdown]
# 곡 제목 찾는 방법_정말 스마트하게
# - 날로 먹기 불가능할 때
#
# 와 이거 꼬옥 ! 복습하기
# 사이트 들어가서 검사 본다음에 덮여있는거 확인 확인 해서 가장 ㄱㅊ한거 골라서 뽑아내기

# %%
title=song.select('div.ellipsis.rank01>span>a')

# %%
len(title)
# Out:
# 1

# %%
title
# Out:
# [<a href="javascript:melon.play.playSong('1000002721',34819473);" title="사건의 지평선 재생">사건의 지평선</a>]

# %%
title[0].text
# Out:
# '사건의 지평선'

# %%
singer=song.select('div.ellipsis.rank02 > a')
singer

singer[0].text
# Out:
# '윤하 (YOUNHA)'

# %%
print(len(songs))
# Out:
# 100

# %% [markdown]
# 멜론 100위 노래 순위 정보 가져오기

# %%
for song in songs:
    title=song.select('div.ellipsis.rank01>span>a')[0].text
    singer=singer=song.select('div.ellipsis.rank02 > a')[0].text
    print(title, singer, sep=' , ') #콤마가 좋음
# Out:
# 사건의 지평선 , 윤하 (YOUNHA)
# Hype boy , NewJeans
# ANTIFRAGILE , LE SSERAFIM (르세라핌)
# 마이웨이 (MY WAY) (Prod. R.Tee) , 저스디스 (JUSTHIS)
# After LIKE , IVE (아이브)
# Nxde , (여자)아이들
# 사랑은 늘 도망가 , 임영웅
# 새삥 (Prod. ZICO) (Feat. 호미들) , 지코 (ZICO)
# Attention , NewJeans
# Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound) , 정국
# 우리들의 블루스 , 임영웅
# LOVE DIVE , IVE (아이브)
# 다시 만날 수 있을까 , 임영웅
# Monologue , 테이
# Snowman , Sia
# London Boy , 임영웅
# All I Want for Christmas Is You , Mariah Carey
# Polaroid , 임영웅
# 무지개 , 임영웅
# 이제 나만 믿어요 , 임영웅
# 아버지 , 임영웅
# Rush Hour (Feat. j-hope of BTS) , Crush
# Shut Down , BLACKPINK
# A bientot , 임영웅
# 위하여 (We Higher) (Prod. GroovyRoom) , 그루비룸 (GroovyRoom)
# 손이 참 곱던 그대 , 임영웅
# 인생찬가 , 임영웅
# Pink Venom , BLACKPINK
# Santa Tell Me , Ariana Grande
# 사랑해 진짜 , 임영웅
# 잘가요 , 주호
# WHEN I MOVE , 카라
# 해요 (2022) , #안녕
# 연애편지 , 임영웅
# 자격지심 (Feat. ZICO) , BE'O (비오)
# 너의 모든 순간 , 성시경
# 딱 10CM만 , 10CM
# TOMBOY , (여자)아이들
# 사랑인가 봐 , 멜로망스
# 내가 아니라도 , 주호
# ...

# %%
#!pip install selenium
from selenium import webdriver

driver=webdriver.Chrome('chromedriver.exe') #새 창이 뜸

#html=driver.page_source
#html

url = 'https://www.melon.com/chart/index.htm'
driver.get(url)

#!pip install beautifulsoup4
from bs4 import BeautifulSoup

#html=driver.page_source
#soup=BeautifulSoup(html, 'html.parser')
#soup

for song in songs:
    title=song.select('div.ellipsis.rank01>span>a')[0].text
    singer=singer=song.select('div.ellipsis.rank02 > a')[0].text
    print(title, singer, sep=' , ') #콤마가 좋음
# Out:
# C:\Users\SBAUser\AppData\Local\Temp\ipykernel_1804\1488307831.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome('chromedriver.exe') #새 창이 뜸
# 사건의 지평선 , 윤하 (YOUNHA)
# Hype boy , NewJeans
# ANTIFRAGILE , LE SSERAFIM (르세라핌)
# 마이웨이 (MY WAY) (Prod. R.Tee) , 저스디스 (JUSTHIS)
# After LIKE , IVE (아이브)
# Nxde , (여자)아이들
# 사랑은 늘 도망가 , 임영웅
# 새삥 (Prod. ZICO) (Feat. 호미들) , 지코 (ZICO)
# Attention , NewJeans
# Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound) , 정국
# 우리들의 블루스 , 임영웅
# LOVE DIVE , IVE (아이브)
# 다시 만날 수 있을까 , 임영웅
# Monologue , 테이
# Snowman , Sia
# London Boy , 임영웅
# All I Want for Christmas Is You , Mariah Carey
# Polaroid , 임영웅
# 무지개 , 임영웅
# 이제 나만 믿어요 , 임영웅
# 아버지 , 임영웅
# Rush Hour (Feat. j-hope of BTS) , Crush
# Shut Down , BLACKPINK
# A bientot , 임영웅
# 위하여 (We Higher) (Prod. GroovyRoom) , 그루비룸 (GroovyRoom)
# 손이 참 곱던 그대 , 임영웅
# 인생찬가 , 임영웅
# Pink Venom , BLACKPINK
# ...

# %%
driver=webdriver.Chrome('./chromedriver.exe') #새 창이 뜸

url = 'https://www.melon.com/chart/index.htm'
driver.get(url)

for song in songs:
    title=song.select('div.ellipsis.rank01>span>a')[0].text
    singer=singer=song.select('div.ellipsis.rank02 > a')[0].text
    print(title, singer, sep=' , ')
# Out:
# C:\Users\SBAUser\AppData\Local\Temp\ipykernel_1804\3239972389.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome('chromedriver.exe') #새 창이 뜸
# 사건의 지평선 , 윤하 (YOUNHA)
# Hype boy , NewJeans
# ANTIFRAGILE , LE SSERAFIM (르세라핌)
# 마이웨이 (MY WAY) (Prod. R.Tee) , 저스디스 (JUSTHIS)
# After LIKE , IVE (아이브)
# Nxde , (여자)아이들
# 사랑은 늘 도망가 , 임영웅
# 새삥 (Prod. ZICO) (Feat. 호미들) , 지코 (ZICO)
# Attention , NewJeans
# Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound) , 정국
# 우리들의 블루스 , 임영웅
# LOVE DIVE , IVE (아이브)
# 다시 만날 수 있을까 , 임영웅
# Monologue , 테이
# Snowman , Sia
# London Boy , 임영웅
# All I Want for Christmas Is You , Mariah Carey
# Polaroid , 임영웅
# 무지개 , 임영웅
# 이제 나만 믿어요 , 임영웅
# 아버지 , 임영웅
# Rush Hour (Feat. j-hope of BTS) , Crush
# Shut Down , BLACKPINK
# A bientot , 임영웅
# 위하여 (We Higher) (Prod. GroovyRoom) , 그루비룸 (GroovyRoom)
# 손이 참 곱던 그대 , 임영웅
# 인생찬가 , 임영웅
# Pink Venom , BLACKPINK
# ...
