# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (4.7.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from selenium) (1.26.13)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: trio~=0.17 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: outcome in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: sortedcontainers in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: sniffio in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from bs4 import BeautifulSoup


driver=webdriver.Chrome('chromedriver.exe') #새 창이 a뜸

url = 'https://www.genie.co.kr/chart/top200'
driver.get(url)

html=driver.page_source
soup=BeautifulSoup(html, 'html.parser')



#------------------------------------------------------
song_data=[]
rank=1 #초기화

songs=soup.select('tr')[1:]

for song in songs:
    title=song.select('a.title.ellipsis')[0].text.strip()
    singer=song.select('a.artist.ellipsis')[0].text.strip()
    print(title, singer, sep=' , ')
    mylist = ['genie', rank, title, singer]
    song_data.append(mylist)
    rank += 1
# Out:
# C:\Users\SBAUser\AppData\Local\Temp\ipykernel_16656\340170478.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome('chromedriver.exe') #새 창이 a뜸
# 사건의 지평선 , 윤하 (YOUNHA)
# NOT SORRY (Feat. pH-1) (Prod. by Slom) , 이영지
# Hype boy , NewJeans
# Candy , NCT DREAM
# ANTIFRAGILE , LE SSERAFIM (르세라핌)
# After LIKE , IVE (아이브)
# Nxde , (여자)아이들
# 사랑은 늘 도망가 , 임영웅
# All I Want for Christmas Is You , Mariah Carey
# Attention , NewJeans
# 마이웨이 (MY WAY) (Prod. by R.Tee) , 저스디스 (JUSTHIS) & R.Tee & 던말릭 (DON MALIK) & 허성현 (Huh) & KHAN & 맥대디 (Mckdaddy) & Los
# 새삥 (Prod. by ZICO) (Feat. 호미들) , 지코 (ZICO)
# 우리들의 블루스 , 임영웅
# LOVE DIVE , IVE (아이브)
# 다시 만날 수 있을까 , 임영웅
# 이제 나만 믿어요 , 임영웅
# London Boy , 임영웅
# 무지개 , 임영웅
# Polaroid , 임영웅
# Dreamers (Music from the FIFA World Cup Qatar 2022 Official Soundtrack) (Feat. FIFA Sound) , 정국 & 방탄소년단
# 아버지 , 임영웅
# 눈 (EYE) (Feat. BIG Naughty & 저스디스 (JUSTHIS)) (Prod. by R.Tee) , 던말릭 (DON MALIK)
# 너의 모든 순간 , 성시경
# A bientot , 임영웅
# Santa Tell Me , Ariana Grande
# Monologue , 테이 (Tei)
# 손이 참 곱던 그대 , 임영웅
# Pink Venom , BLACKPINK
# Shut Down , BLACKPINK
# 사랑해 진짜 , 임영웅
# 연애편지 , 임영웅
# 다정히 내 이름을 부르면 , 경서예지 & 전건호
# 인생찬가 , 임영웅
# 보금자리 , 임영웅
# TOMBOY , (여자)아이들
# Rush Hour (Feat. j-hope of BTS) , Crush
# 그때 그 순간 그대로 (그그그) , WSG워너비 (가야G)
# Snowman , Sia
# 나침반 (Feat. UNEDUCATED KID & 수퍼비 (SUPERBEE)) (Prod. by R.Tee) , KHAN
# 사랑인가 봐 , 멜로망스 (MeloMance)
# That's Hilarious , Charlie Puth
# WHEN I MOVE , 카라 (KARA)
# 내가 아니라도 , 주호
# 미리 메리 크리스마스 (Feat. 천둥 of MBLAQ) , 아이유 (IU)
# ELEVEN , IVE (아이브)
# 자격지심 (Feat. ZICO) , BE'O (비오)
# 해요 (2022) , #안녕
# 취중고백 , 김민석 (멜로망스)
# 나의 X에게 , 경서
# Cookie , NewJeans

# %%
song_data
# Out:
# [['genie', 1, '사건의 지평선', '윤하 (YOUNHA)'],
#  ['genie', 2, 'NOT SORRY (Feat. pH-1) (Prod. by Slom)', '이영지'],
#  ['genie', 3, 'Hype boy', 'NewJeans'],
#  ['genie', 4, 'Candy', 'NCT DREAM'],
#  ['genie', 5, 'ANTIFRAGILE', 'LE SSERAFIM (르세라핌)'],
#  ['genie', 6, 'After LIKE', 'IVE (아이브)'],
#  ['genie', 7, 'Nxde', '(여자)아이들'],
#  ['genie', 8, '사랑은 늘 도망가', '임영웅'],
#  ['genie', 9, 'All I Want for Christmas Is You', 'Mariah Carey'],
#  ['genie', 10, 'Attention', 'NewJeans'],
#  ['genie',
#   11,
#   '마이웨이 (MY WAY) (Prod. by R.Tee)',
#   '저스디스 (JUSTHIS) & R.Tee & 던말릭 (DON MALIK) & 허성현 (Huh) & KHAN & 맥대디 (Mckdaddy) & Los'],
#  ['genie', 12, '새삥 (Prod. by ZICO) (Feat. 호미들)', '지코 (ZICO)'],
#  ['genie', 13, '우리들의 블루스', '임영웅'],
#  ['genie', 14, 'LOVE DIVE', 'IVE (아이브)'],
#  ['genie', 15, '다시 만날 수 있을까', '임영웅'],
#  ['genie', 16, '이제 나만 믿어요', '임영웅'],
#  ['genie', 17, 'London Boy', '임영웅'],
#  ['genie', 18, '무지개', '임영웅'],
#  ['genie', 19, 'Polaroid', '임영웅'],
#  ['genie',
#   20,
#   'Dreamers (Music from the FIFA World Cup Qatar 2022 Official Soundtrack) (Feat. FIFA Sound)',
#   '정국 & 방탄소년단'],
#  ['genie', 21, '아버지', '임영웅'],
#  ['genie',
#   22,
#   '눈 (EYE) (Feat. BIG Naughty & 저스디스 (JUSTHIS)) (Prod. by R.Tee)',
#   '던말릭 (DON MALIK)'],
#  ['genie', 23, '너의 모든 순간', '성시경'],
#  ['genie', 24, 'A bientot', '임영웅'],
#  ['genie', 25, 'Santa Tell Me', 'Ariana Grande'],
#  ['genie', 26, 'Monologue', '테이 (Tei)'],
#  ['genie', 27, '손이 참 곱던 그대', '임영웅'],
#  ['genie', 28, 'Pink Venom', 'BLACKPINK'],
#  ['genie', 29, 'Shut Down', 'BLACKPINK'],
#  ['genie', 30, '사랑해 진짜', '임영웅'],
#  ['genie', 31, '연애편지', '임영웅'],
#  ['genie', 32, '다정히 내 이름을 부르면', '경서예지 & 전건호'],
#  ['genie', 33, '인생찬가', '임영웅'],
#  ['genie', 34, '보금자리', '임영웅'],
#  ['genie', 35, 'TOMBOY', '(여자)아이들'],
#  ['genie', 36, 'Rush Hour (Feat. j-hope of BTS)', 'Crush'],
#  ['genie', 37, '그때 그 순간 그대로 (그그그)', 'WSG워너비 (가야G)'],
#  ['genie', 38, 'Snowman', 'Sia'],
#  ['genie',
#   39,
#   '나침반 (Feat. UNEDUCATED KID & 수퍼비 (SUPERBEE)) (Prod. by R.Tee)',
#   'KHAN'],
#  ['genie', 40, '사랑인가 봐', '멜로망스 (MeloMance)'],
#  ['genie', 41, "That's Hilarious", 'Charlie Puth'],
#  ['genie', 42, 'WHEN I MOVE', '카라 (KARA)'],
#  ['genie', 43, '내가 아니라도', '주호'],
#  ['genie', 44, '미리 메리 크리스마스 (Feat. 천둥 of MBLAQ)', '아이유 (IU)'],
#  ['genie', 45, 'ELEVEN', 'IVE (아이브)'],
#  ['genie', 46, '자격지심 (Feat. ZICO)', "BE'O (비오)"],
#  ['genie', 47, '해요 (2022)', '#안녕'],
#  ['genie', 48, '취중고백', '김민석 (멜로망스)'],
#  ['genie', 49, '나의 X에게', '경서'],
#  ['genie', 50, 'Cookie', 'NewJeans']]

# %%
import pandas as pd

df=pd.DataFrame(song_data, columns=['서비스업체', '순위', '타이틀(곡명)', '가수'])
df
# Out:
#     서비스업체  순위                                            타이틀(곡명)  \
# 0   genie   1                                            사건의 지평선
# 1   genie   2             NOT SORRY (Feat. pH-1) (Prod. by Slom)
# 2   genie   3                                           Hype boy
# 3   genie   4                                              Candy
# 4   genie   5                                        ANTIFRAGILE
# 5   genie   6                                         After LIKE
# 6   genie   7                                               Nxde
# 7   genie   8                                          사랑은 늘 도망가
# 8   genie   9                    All I Want for Christmas Is You
# 9   genie  10                                          Attention
# 10  genie  11                     마이웨이 (MY WAY) (Prod. by R.Tee)
# 11  genie  12                     새삥 (Prod. by ZICO) (Feat. 호미들)
# 12  genie  13                                           우리들의 블루스
# 13  genie  14                                          LOVE DIVE
# 14  genie  15                                        다시 만날 수 있을까
# 15  genie  16                                          이제 나만 믿어요
# 16  genie  17                                         London Boy
# 17  genie  18                                                무지개
# 18  genie  19                                           Polaroid
# 19  genie  20  Dreamers (Music from the FIFA World Cup Qatar ...
# 20  genie  21                                                아버지
# 21  genie  22  눈 (EYE) (Feat. BIG Naughty & 저스디스 (JUSTHIS)) (...
# 22  genie  23                                           너의 모든 순간
# 23  genie  24                                          A bientot
# 24  genie  25                                      Santa Tell Me
# 25  genie  26                                          Monologue
# 26  genie  27                                         손이 참 곱던 그대
# 27  genie  28                                         Pink Venom
# 28  genie  29                                          Shut Down
# 29  genie  30                                             사랑해 진짜
# 30  genie  31                                               연애편지
# 31  genie  32                                      다정히 내 이름을 부르면
# 32  genie  33                                               인생찬가
# 33  genie  34                                               보금자리
# 34  genie  35                                             TOMBOY
# 35  genie  36                    Rush Hour (Feat. j-hope of BTS)
# 36  genie  37                                  그때 그 순간 그대로 (그그그)
# 37  genie  38                                            Snowman
# 38  genie  39  나침반 (Feat. UNEDUCATED KID & 수퍼비 (SUPERBEE)) (P...
# 39  genie  40                                             사랑인가 봐
# 40  genie  41                                   That's Hilarious
# 41  genie  42                                        WHEN I MOVE
# 42  genie  43                                            내가 아니라도
# 43  genie  44                    미리 메리 크리스마스 (Feat. 천둥 of MBLAQ)
# 44  genie  45                                             ELEVEN
# 45  genie  46                                  자격지심 (Feat. ZICO)
# 46  genie  47                                          해요 (2022)
# 47  genie  48                                               취중고백
# 48  genie  49                                             나의 X에게
# 49  genie  50                                             Cookie
#
#                                                    가수
# 0                                         윤하 (YOUNHA)
# 1                                                 이영지
# 2                                            NewJeans
# 3                                           NCT DREAM
# 4                                  LE SSERAFIM (르세라핌)
# 5                                           IVE (아이브)
# 6                                             (여자)아이들
# 7                                                 임영웅
# 8                                        Mariah Carey
# 9                                            NewJeans
# 10  저스디스 (JUSTHIS) & R.Tee & 던말릭 (DON MALIK) & 허성현...
# 11                                          지코 (ZICO)
# 12                                                임영웅
# 13                                          IVE (아이브)
# 14                                                임영웅
# 15                                                임영웅
# 16                                                임영웅
# 17                                                임영웅
# 18                                                임영웅
# 19                                         정국 & 방탄소년단
# 20                                                임영웅
# 21                                    던말릭 (DON MALIK)
# 22                                                성시경
# 23                                                임영웅
# 24                                      Ariana Grande
# 25                                           테이 (Tei)
# 26                                                임영웅
# 27                                          BLACKPINK
# 28                                          BLACKPINK
# 29                                                임영웅
# 30                                                임영웅
# 31                                         경서예지 & 전건호
# 32                                                임영웅
# 33                                                임영웅
# 34                                            (여자)아이들
# 35                                              Crush
# 36                                       WSG워너비 (가야G)
# 37                                                Sia
# 38                                               KHAN
# 39                                   멜로망스 (MeloMance)
# 40                                       Charlie Puth
# 41                                          카라 (KARA)
# 42                                                 주호
# 43                                           아이유 (IU)
# 44                                          IVE (아이브)
# 45                                          BE'O (비오)
# 46                                                #안녕
# 47                                         김민석 (멜로망스)
# 48                                                 경서
# 49                                           NewJeans

# %%
df.to_excel('./gn_rank.xlsx', index=False)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame
