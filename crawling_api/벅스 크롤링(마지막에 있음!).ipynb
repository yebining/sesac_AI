# %%
driver=webdriver.Chrome('chromedriver.exe') #새 창이 뜸

url = 'https://www.melon.com/chart/index.htm'
driver.get(url)

html=driver.page_source
soup=BeautifulSoup(html, 'html.parser')



#------------------------------------------------------
#soup.select('tbody>tr')
#songs = soup.select('tbody>tr')
songs=soup.select('tr')[1:]

for song in songs:
    title=song.select('div.ellipsis.rank01>span>a')[0].text
    singer=singer=song.select('div.ellipsis.rank02 > a')[0].text
    print(title, singer, sep=' , ')
# Out:
# C:\Users\SBAUser\AppData\Local\Temp\ipykernel_5908\1014527068.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome('chromedriver.exe') #새 창이 뜸
# 사건의 지평선 , 윤하 (YOUNHA)
# Hype boy , NewJeans
# ANTIFRAGILE , LE SSERAFIM (르세라핌)
# 마이웨이 (MY WAY) (Prod. R.Tee) , 저스디스 (JUSTHIS)
# After LIKE , IVE (아이브)
# Nxde , (여자)아이들
# 사랑은 늘 도망가 , 임영웅
# 새삥 (Prod. ZICO) (Feat. 호미들) , 지코 (ZICO)
# Attention , NewJeans
# Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound) , 정국
# 우리들의 블루스 , 임영웅
# LOVE DIVE , IVE (아이브)
# 다시 만날 수 있을까 , 임영웅
# Monologue , 테이
# Snowman , Sia
# London Boy , 임영웅
# All I Want for Christmas Is You , Mariah Carey
# Polaroid , 임영웅
# 무지개 , 임영웅
# 이제 나만 믿어요 , 임영웅
# 아버지 , 임영웅
# Rush Hour (Feat. j-hope of BTS) , Crush
# Shut Down , BLACKPINK
# A bientot , 임영웅
# 위하여 (We Higher) (Prod. GroovyRoom) , 그루비룸 (GroovyRoom)
# 손이 참 곱던 그대 , 임영웅
# 인생찬가 , 임영웅
# Pink Venom , BLACKPINK
# Santa Tell Me , Ariana Grande
# 사랑해 진짜 , 임영웅
# 잘가요 , 주호
# WHEN I MOVE , 카라
# 해요 (2022) , #안녕
# 연애편지 , 임영웅
# 자격지심 (Feat. ZICO) , BE'O (비오)
# 너의 모든 순간 , 성시경
# 딱 10CM만 , 10CM
# TOMBOY , (여자)아이들
# 사랑인가 봐 , 멜로망스
# 내가 아니라도 , 주호
# 보금자리 , 임영웅
# 그때 그 순간 그대로 (그그그) , WSG워너비 (가야G)
# 첫 눈 , EXO
# Last Christmas , Ariana Grande
# 그 겨울이 잠든 거리에서 , 경서예지
# 미리 메리 크리스마스 (Feat. 천둥 Of MBLAQ) , 아이유
# Cookie , NewJeans
# 그라데이션 , 10CM
# 정이라고 하자 (Feat. 10CM) , BIG Naughty (서동현)
# FEARLESS , LE SSERAFIM (르세라핌)
# WE (Feat. 박재범) (Prod. by Slom) , 이영지
# 크리스마스니까 , 성시경
# 취중고백 , 김민석 (멜로망스)
# 우린 그렇게 사랑해서 , 강민경 (다비치)
# ELEVEN , IVE (아이브)
# 나의 X에게 , 경서
# 보고싶었어 , WSG워너비 (4FIRE)
# 떠나보낼 준비해 둘걸 그랬어 , 임한별
# Flick (Feat. BE'O (비오), 김하온 (HAON)) (Prod. GroovyRoom) , 노윤하
# 흩어지지 않게 , 엠씨더맥스 (M.C the MAX)
# That's Hilarious , Charlie Puth
# 다정히 내 이름을 부르면 , 경서예지
# Dynamite , 방탄소년단
# 그대를 알고 , 송하예
# 첫사랑 , 백아
# 모든 날, 모든 순간 (Every day, Every Moment) , 폴킴
# I Don't Think That I Like Her , Charlie Puth
# 밤하늘의 별을(2020) , 경서
# 내 기쁨은 너가 벤틀리를 끄는 거야 , 김승민
# LOVE me , BE'O (비오)
# Butter , 방탄소년단
# 봄날 , 방탄소년단
# 새벽에 걸려온 너의 전화는 , 한동근
# 주저하는 연인들을 위해 , 잔나비
# That That (prod. & feat. SUGA of BTS) , 싸이 (PSY)
# STAY , The Kid LAROI
# Permission to Dance , 방탄소년단
# FOREVER 1 , 소녀시대 (GIRLS' GENERATION)
# Yet To Come , 방탄소년단
# 봄여름가을겨울 (Still Life) , BIGBANG (빅뱅)
# 도깨비불 (Illusion) , aespa
# Love story , 볼빨간사춘기
# SNEAKERS , ITZY (있지)
# 사랑한다고 말해줘 , 탑현
# 들꽃놀이 (with 조유진) , RM
# Make It To Christmas , Alessia Cara
# Off My Face , Justin Bieber
# 아저씨 , 릴러말즈 (Leellamarz)
# 고백연습 , 경서
# 그중에 그대를 만나 , 김호중
# The Astronaut , 진
# 스티커 사진 , 21학번
# Feel My Rhythm , Red Velvet (레드벨벳)
# 오르트구름 , 윤하 (YOUNHA)
# 신호등 , 이무진
# 드라마 , 아이유
# 그날의 그대여 , 헤이즈 (Heize)
# POP! , 나연 (TWICE)
# Left and Right (Feat. Jung Kook of BTS) , Charlie Puth
# 추억때문에 , 유림

# %% [markdown]
# 멜론 인기차트 순위 크롤러

# %%
driver=webdriver.Chrome('chromedriver.exe') #새 창이 뜸

url = 'https://www.melon.com/chart/index.htm'
driver.get(url)

html=driver.page_source
soup=BeautifulSoup(html, 'html.parser')



#------------------------------------------------------
song_data=[]
rank=1 #초기화

songs=soup.select('tr')[1:]

for song in songs:
    title=song.select('div.ellipsis.rank01>span>a')[0].text
    singer=singer=song.select('div.ellipsis.rank02 > a')[0].text
    print(title, singer, sep=' , ')
    mylist = ['melon', rank, title, singer]
    song_data.append(mylist)
    rank += 1
# Out:
# C:\Users\SBAUser\AppData\Local\Temp\ipykernel_5908\1077103111.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome('chromedriver.exe') #새 창이 뜸
# 사건의 지평선 , 윤하 (YOUNHA)
# Hype boy , NewJeans
# ANTIFRAGILE , LE SSERAFIM (르세라핌)
# 마이웨이 (MY WAY) (Prod. R.Tee) , 저스디스 (JUSTHIS)
# After LIKE , IVE (아이브)
# Nxde , (여자)아이들
# 사랑은 늘 도망가 , 임영웅
# 새삥 (Prod. ZICO) (Feat. 호미들) , 지코 (ZICO)
# Attention , NewJeans
# Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound) , 정국
# 우리들의 블루스 , 임영웅
# LOVE DIVE , IVE (아이브)
# 다시 만날 수 있을까 , 임영웅
# Monologue , 테이
# Snowman , Sia
# London Boy , 임영웅
# All I Want for Christmas Is You , Mariah Carey
# Polaroid , 임영웅
# 무지개 , 임영웅
# 이제 나만 믿어요 , 임영웅
# 아버지 , 임영웅
# Rush Hour (Feat. j-hope of BTS) , Crush
# Shut Down , BLACKPINK
# A bientot , 임영웅
# 위하여 (We Higher) (Prod. GroovyRoom) , 그루비룸 (GroovyRoom)
# 손이 참 곱던 그대 , 임영웅
# 인생찬가 , 임영웅
# Pink Venom , BLACKPINK
# Santa Tell Me , Ariana Grande
# 사랑해 진짜 , 임영웅
# 잘가요 , 주호
# WHEN I MOVE , 카라
# 해요 (2022) , #안녕
# 연애편지 , 임영웅
# 자격지심 (Feat. ZICO) , BE'O (비오)
# 너의 모든 순간 , 성시경
# 딱 10CM만 , 10CM
# TOMBOY , (여자)아이들
# 사랑인가 봐 , 멜로망스
# 내가 아니라도 , 주호
# 보금자리 , 임영웅
# 그때 그 순간 그대로 (그그그) , WSG워너비 (가야G)
# 첫 눈 , EXO
# Last Christmas , Ariana Grande
# 그 겨울이 잠든 거리에서 , 경서예지
# 미리 메리 크리스마스 (Feat. 천둥 Of MBLAQ) , 아이유
# Cookie , NewJeans
# 그라데이션 , 10CM
# 정이라고 하자 (Feat. 10CM) , BIG Naughty (서동현)
# FEARLESS , LE SSERAFIM (르세라핌)
# WE (Feat. 박재범) (Prod. by Slom) , 이영지
# 크리스마스니까 , 성시경
# 취중고백 , 김민석 (멜로망스)
# 우린 그렇게 사랑해서 , 강민경 (다비치)
# ELEVEN , IVE (아이브)
# 나의 X에게 , 경서
# 보고싶었어 , WSG워너비 (4FIRE)
# 떠나보낼 준비해 둘걸 그랬어 , 임한별
# Flick (Feat. BE'O (비오), 김하온 (HAON)) (Prod. GroovyRoom) , 노윤하
# 흩어지지 않게 , 엠씨더맥스 (M.C the MAX)
# That's Hilarious , Charlie Puth
# 다정히 내 이름을 부르면 , 경서예지
# Dynamite , 방탄소년단
# 그대를 알고 , 송하예
# 첫사랑 , 백아
# 모든 날, 모든 순간 (Every day, Every Moment) , 폴킴
# I Don't Think That I Like Her , Charlie Puth
# 밤하늘의 별을(2020) , 경서
# 내 기쁨은 너가 벤틀리를 끄는 거야 , 김승민
# LOVE me , BE'O (비오)
# Butter , 방탄소년단
# 봄날 , 방탄소년단
# 새벽에 걸려온 너의 전화는 , 한동근
# 주저하는 연인들을 위해 , 잔나비
# That That (prod. & feat. SUGA of BTS) , 싸이 (PSY)
# STAY , The Kid LAROI
# Permission to Dance , 방탄소년단
# FOREVER 1 , 소녀시대 (GIRLS' GENERATION)
# Yet To Come , 방탄소년단
# 봄여름가을겨울 (Still Life) , BIGBANG (빅뱅)
# 도깨비불 (Illusion) , aespa
# Love story , 볼빨간사춘기
# SNEAKERS , ITZY (있지)
# 사랑한다고 말해줘 , 탑현
# 들꽃놀이 (with 조유진) , RM
# Make It To Christmas , Alessia Cara
# Off My Face , Justin Bieber
# 아저씨 , 릴러말즈 (Leellamarz)
# 고백연습 , 경서
# 그중에 그대를 만나 , 김호중
# The Astronaut , 진
# 스티커 사진 , 21학번
# Feel My Rhythm , Red Velvet (레드벨벳)
# 오르트구름 , 윤하 (YOUNHA)
# 신호등 , 이무진
# 드라마 , 아이유
# 그날의 그대여 , 헤이즈 (Heize)
# POP! , 나연 (TWICE)
# Left and Right (Feat. Jung Kook of BTS) , Charlie Puth
# 추억때문에 , 유림

# %%
song_data
# Out:
# [['melon', 1, '사건의 지평선', '윤하 (YOUNHA)'],
#  ['melon', 2, 'Hype boy', 'NewJeans'],
#  ['melon', 3, 'ANTIFRAGILE', 'LE SSERAFIM (르세라핌)'],
#  ['melon', 4, '마이웨이 (MY WAY) (Prod. R.Tee)', '저스디스 (JUSTHIS)'],
#  ['melon', 5, 'After LIKE', 'IVE (아이브)'],
#  ['melon', 6, 'Nxde', '(여자)아이들'],
#  ['melon', 7, '사랑은 늘 도망가', '임영웅'],
#  ['melon', 8, '새삥 (Prod. ZICO) (Feat. 호미들)', '지코 (ZICO)'],
#  ['melon', 9, 'Attention', 'NewJeans'],
#  ['melon',
#   10,
#   'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound)',
#   '정국'],
#  ['melon', 11, '우리들의 블루스', '임영웅'],
#  ['melon', 12, 'LOVE DIVE', 'IVE (아이브)'],
#  ['melon', 13, '다시 만날 수 있을까', '임영웅'],
#  ['melon', 14, 'Monologue', '테이'],
#  ['melon', 15, 'Snowman', 'Sia'],
#  ['melon', 16, 'London Boy', '임영웅'],
#  ['melon', 17, 'All I Want for Christmas Is You', 'Mariah Carey'],
#  ['melon', 18, 'Polaroid', '임영웅'],
#  ['melon', 19, '무지개', '임영웅'],
#  ['melon', 20, '이제 나만 믿어요', '임영웅'],
#  ['melon', 21, '아버지', '임영웅'],
#  ['melon', 22, 'Rush Hour (Feat. j-hope of BTS)', 'Crush'],
#  ['melon', 23, 'Shut Down', 'BLACKPINK'],
#  ['melon', 24, 'A bientot', '임영웅'],
#  ['melon', 25, '위하여 (We Higher) (Prod. GroovyRoom)', '그루비룸 (GroovyRoom)'],
#  ['melon', 26, '손이 참 곱던 그대', '임영웅'],
#  ['melon', 27, '인생찬가', '임영웅'],
#  ['melon', 28, 'Pink Venom', 'BLACKPINK'],
#  ['melon', 29, 'Santa Tell Me', 'Ariana Grande'],
#  ['melon', 30, '사랑해 진짜', '임영웅'],
#  ['melon', 31, '잘가요', '주호'],
#  ['melon', 32, 'WHEN I MOVE', '카라'],
#  ['melon', 33, '해요 (2022)', '#안녕'],
#  ['melon', 34, '연애편지', '임영웅'],
#  ['melon', 35, '자격지심 (Feat. ZICO)', "BE'O (비오)"],
#  ['melon', 36, '너의 모든 순간', '성시경'],
#  ['melon', 37, '딱 10CM만', '10CM'],
#  ['melon', 38, 'TOMBOY', '(여자)아이들'],
#  ['melon', 39, '사랑인가 봐', '멜로망스'],
#  ['melon', 40, '내가 아니라도', '주호'],
#  ['melon', 41, '보금자리', '임영웅'],
#  ['melon', 42, '그때 그 순간 그대로 (그그그)', 'WSG워너비 (가야G)'],
#  ['melon', 43, '첫 눈', 'EXO'],
#  ['melon', 44, 'Last Christmas', 'Ariana Grande'],
#  ['melon', 45, '그 겨울이 잠든 거리에서', '경서예지'],
#  ['melon', 46, '미리 메리 크리스마스 (Feat. 천둥 Of MBLAQ)', '아이유'],
#  ['melon', 47, 'Cookie', 'NewJeans'],
#  ['melon', 48, '그라데이션', '10CM'],
#  ['melon', 49, '정이라고 하자 (Feat. 10CM)', 'BIG Naughty (서동현)'],
#  ['melon', 50, 'FEARLESS', 'LE SSERAFIM (르세라핌)'],
#  ['melon', 51, 'WE (Feat. 박재범) (Prod. by Slom)', '이영지'],
#  ['melon', 52, '크리스마스니까', '성시경'],
#  ['melon', 53, '취중고백', '김민석 (멜로망스)'],
#  ['melon', 54, '우린 그렇게 사랑해서', '강민경 (다비치)'],
#  ['melon', 55, 'ELEVEN', 'IVE (아이브)'],
#  ['melon', 56, '나의 X에게', '경서'],
#  ['melon', 57, '보고싶었어', 'WSG워너비 (4FIRE)'],
#  ['melon', 58, '떠나보낼 준비해 둘걸 그랬어', '임한별'],
#  ['melon',
#   59,
#   "Flick (Feat. BE'O (비오), 김하온 (HAON)) (Prod. GroovyRoom)",
#   '노윤하'],
#  ['melon', 60, '흩어지지 않게', '엠씨더맥스 (M.C the MAX)'],
#  ['melon', 61, "That's Hilarious", 'Charlie Puth'],
#  ['melon', 62, '다정히 내 이름을 부르면', '경서예지'],
#  ['melon', 63, 'Dynamite', '방탄소년단'],
#  ['melon', 64, '그대를 알고', '송하예'],
#  ['melon', 65, '첫사랑', '백아'],
#  ['melon', 66, '모든 날, 모든 순간 (Every day, Every Moment)', '폴킴'],
#  ['melon', 67, "I Don't Think That I Like Her", 'Charlie Puth'],
#  ['melon', 68, '밤하늘의 별을(2020)', '경서'],
#  ['melon', 69, '내 기쁨은 너가 벤틀리를 끄는 거야', '김승민'],
#  ['melon', 70, 'LOVE me', "BE'O (비오)"],
#  ['melon', 71, 'Butter', '방탄소년단'],
#  ['melon', 72, '봄날', '방탄소년단'],
#  ['melon', 73, '새벽에 걸려온 너의 전화는', '한동근'],
#  ['melon', 74, '주저하는 연인들을 위해', '잔나비'],
#  ['melon', 75, 'That That (prod. & feat. SUGA of BTS)', '싸이 (PSY)'],
#  ['melon', 76, 'STAY', 'The Kid LAROI'],
#  ['melon', 77, 'Permission to Dance', '방탄소년단'],
#  ['melon', 78, 'FOREVER 1', "소녀시대 (GIRLS' GENERATION)"],
#  ['melon', 79, 'Yet To Come', '방탄소년단'],
#  ['melon', 80, '봄여름가을겨울 (Still Life)', 'BIGBANG (빅뱅)'],
#  ['melon', 81, '도깨비불 (Illusion)', 'aespa'],
#  ['melon', 82, 'Love story', '볼빨간사춘기'],
#  ['melon', 83, 'SNEAKERS', 'ITZY (있지)'],
#  ['melon', 84, '사랑한다고 말해줘', '탑현'],
#  ['melon', 85, '들꽃놀이 (with 조유진)', 'RM'],
#  ['melon', 86, 'Make It To Christmas', 'Alessia Cara'],
#  ['melon', 87, 'Off My Face', 'Justin Bieber'],
#  ['melon', 88, '아저씨', '릴러말즈 (Leellamarz)'],
#  ['melon', 89, '고백연습', '경서'],
#  ['melon', 90, '그중에 그대를 만나', '김호중'],
#  ['melon', 91, 'The Astronaut', '진'],
#  ['melon', 92, '스티커 사진', '21학번'],
#  ['melon', 93, 'Feel My Rhythm', 'Red Velvet (레드벨벳)'],
#  ['melon', 94, '오르트구름', '윤하 (YOUNHA)'],
#  ['melon', 95, '신호등', '이무진'],
#  ['melon', 96, '드라마', '아이유'],
#  ['melon', 97, '그날의 그대여', '헤이즈 (Heize)'],
#  ['melon', 98, 'POP!', '나연 (TWICE)'],
#  ['melon', 99, 'Left and Right (Feat. Jung Kook of BTS)', 'Charlie Puth'],
#  ['melon', 100, '추억때문에', '유림']]

# %%
import pandas as pd

df=pd.DataFrame(song_data, columns=['서비스업체', '순위', '타이틀(곡명)', '가수'])
df
# Out:
#     서비스업체   순위                                  타이틀(곡명)                  가수
# 0   melon    1                                  사건의 지평선         윤하 (YOUNHA)
# 1   melon    2                                 Hype boy            NewJeans
# 2   melon    3                              ANTIFRAGILE  LE SSERAFIM (르세라핌)
# 3   melon    4              마이웨이 (MY WAY) (Prod. R.Tee)      저스디스 (JUSTHIS)
# 4   melon    5                               After LIKE           IVE (아이브)
# ..    ...  ...                                      ...                 ...
# 95  melon   96                                      드라마                 아이유
# 96  melon   97                                  그날의 그대여         헤이즈 (Heize)
# 97  melon   98                                     POP!          나연 (TWICE)
# 98  melon   99  Left and Right (Feat. Jung Kook of BTS)        Charlie Puth
# 99  melon  100                                    추억때문에                  유림
#
# [100 rows x 4 columns]

# %%
df.to_excel('./melon_rank.xlsx'. index=False)
# Out:
#   File "C:\Users\SBAUser\AppData\Local\Temp\ipykernel_5908\3832209529.py", line 1
#     df.to_excel('./melon_rank.xlsx'. index=False)
#                 ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
driver=webdriver.Chrome('chromedriver.exe') #새 창이 뜸

url = 'https://music.bugs.co.kr/chart'
driver.get(url)

html=driver.page_source
soup=BeautifulSoup(html, 'html.parser')

soup.select('tbody>tr')
songs = soup.select('tbody>tr')

print(len(songs))
print(type(songs))
print(songs[0])
# Out:
# C:\Users\SBAUser\AppData\Local\Temp\ipykernel_5908\2399380576.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome('chromedriver.exe') #새 창이 뜸
# 103
# <class 'bs4.element.ResultSet'>
# <tr albumid="4073469" artistid="80010025" multiartist="N" mvid="607295" rowtype="track" trackid="6155092">
# <input name="_isStream" type="hidden" value="6155092"/>
# <input name="_isDown" type="hidden" value="6155092"/>
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="사건의 지평선" type="checkbox" value="6155092"/></td>
# <td>
# <div class="ranking">
# <strong>1</strong>
# <p class="change none"><em>0</em><span>변동없음</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4073469?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="YOUNHA 6th Album Repackage 'END THEORY : Final Edition' 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40734/4073469.jpg?version=20221116004342.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6155092?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6155092',true);
# " title="사건의 지평선">사건의 지평선</a>
# </p>
# </th>
# <td class="left">
# <p class="artist">
# <a href="https://music.bugs.co.kr/artist/80010025?wl_ref=list_tr_10_chart" onclick="
# " title="윤하(Younha/ユンナ)">윤하(Younha/ユンナ)</a>
# </p>
# </td>
# <td class="left">
# <a class="album" href="https://music.bugs.co.kr/album/4073469?wl_ref=list_tr_11_chart" onclick="
# " title="YOUNHA 6th Album Repackage 'END THEORY : Final Edition'">YOUNHA 6th Album Repackage 'END THEORY : Final Edition'</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn play" href="javascript:;" onclick="bugs.wiselog.area('list_tr_12_chart');bugs.music.listen('6155092',true);
# ">듣기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn addPlaylist" href="javascript:;" onclick="bugs.wiselog.area('list_tr_13_chart');bugs.music.listen('6155092');
# ">재생목록에 추가</a>
# </td>
# <td>
# <a class="btn addAlbum" href="javascript:;" onclick="bugs.wiselog.area('list_tr_14_chart');bugs.music.addTrackToMyAlbum(this,'6155092');
# " track_title="사건의 지평선">내 앨범에 담기</a>
# </td>
# <td>
# <a adultcheckval="1" aria-label="새창" class="btn download flac" href="javascript:;" onclick="bugs.wiselog.area('list_tr_15_chart');bugs.layermenu.down(this,'6155092','true','true','44.1','true','96', null );
# "><em class="flac">flac </em>다운로드</a>
# </td>
# <td>
# <a aria-label="새창" class="btn viewMV" href="javascript:;" onclick="bugs.wiselog.area('list_tr_16_chart');
# bugs.layermenu.mv(this,6155092, 607295, 'Y', 'Y', 'Y', 'Y', 6155092, 'N','ALL', 'Y');
# ">영상 재생</a>
# </td>
# <td>
# <a artist_disp_nm="윤하(Younha/ユンナ)" artist_id="80010025" class="btnActions" href="javascript:;" layer_type="CHART" layerpositiontarget="td" onclick="bugs.wiselog.area('list_tr_17_chart');
# bugs.layermenu.trackMoreAction(this,'6155092','0','4073469','bugs.music.listenRadioFromSeed(\'6155092\',\'track\');','N', 'Y', '_chart');
# " track_title="사건의 지평선">기타 기능</a>
# </td>
# </tr>

# %%
songs[1:]
# Out:
# [<tr class="list" songid="97582507">
#  <td class="check"><input class="select-check" title="Hype boy" type="checkbox"/></td>
#  <td class="number">2
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-none"><span class="hide">유지</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82842800');return false;"><span class="mask"></span><img alt="NewJeans 1st EP 'New Jeans'" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/842/800/82842800_1659340238924_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('97582507');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('97582507','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  Hype boy</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('81490206');return false;">NewJeans</a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('97582507');" type="button">외</button>
#  <ul class="list" id="RelationArtist_97582507"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82842800');return false;">NewJeans 1st EP 'New Jeans'</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('97582507;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('97582507;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_97582507" onclick="fnAddMyAlbumForm('#add_my_album_97582507' , '97582507' ,10, 10);return false;" songid="97582507" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('97582507');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_97582507">
#  <a alt="Hype boy" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('97582507','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('97582507');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('97582507');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="98661235">
#  <td class="check"><input class="select-check" title="ANTIFRAGILE" type="checkbox"/></td>
#  <td class="number">3
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-none"><span class="hide">유지</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('83082184');return false;"><span class="mask"></span><img alt="ANTIFRAGILE" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/083/082/184/83082184_1665969939180_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('98661235');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('98661235','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  ANTIFRAGILE</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('81397289');return false;">LE SSERAFIM (르세라핌)</a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('98661235');" type="button">외</button>
#  <ul class="list" id="RelationArtist_98661235"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('83082184');return false;">ANTIFRAGILE</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('98661235;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('98661235;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_98661235" onclick="fnAddMyAlbumForm('#add_my_album_98661235' , '98661235' ,10, 10);return false;" songid="98661235" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('98661235');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_98661235">
#  <a alt="ANTIFRAGILE" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('98661235','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('98661235');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('98661235');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="97976355">
#  <td class="check"><input class="select-check" title="After LIKE" type="checkbox"/></td>
#  <td class="number">4
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-none"><span class="hide">유지</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82912984');return false;"><span class="mask"></span><img alt="After LIKE" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/912/984/82912984_1661135567760_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('97976355');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('97976355','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  After LIKE</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('81271496');return false;">IVE (아이브)</a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('97976355');" type="button">외</button>
#  <ul class="list" id="RelationArtist_97976355"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82912984');return false;">After LIKE</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('97976355;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('97976355;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_97976355" onclick="fnAddMyAlbumForm('#add_my_album_97976355' , '97976355' ,10, 10);return false;" songid="97976355" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('97976355');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_97976355">
#  <a alt="After LIKE" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('97976355','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('97976355');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('97976355');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="98633640">
#  <td class="check"><input class="select-check" title="Nxde" type="checkbox"/></td>
#  <td class="number">5
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-up">2<span class="hide">상승</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('83072254');return false;"><span class="mask"></span><img alt="I love" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/083/072/254/83072254_1665976983718_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('98633640');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('98633640','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  Nxde</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('80632010');return false;">(여자)아이들</a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('98633640');" type="button">외</button>
#  <ul class="list" id="RelationArtist_98633640"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('83072254');return false;">I love</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('98633640;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('98633640;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_98633640" onclick="fnAddMyAlbumForm('#add_my_album_98633640' , '98633640' ,10, 10);return false;" songid="98633640" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('98633640');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_98633640">
#  <a alt="Nxde" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('98633640','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('98633640');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('98633640');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="99266256">
#  <td class="check"><input class="select-check" title="마이웨이 (MY WAY) (Prod. by R.Tee)" type="checkbox"/></td>
#  <td class="number">6
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-none"><span class="hide">유지</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('83243377');return false;"><span class="mask"></span><img alt="쇼미더머니 11 Episode 1" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/083/243/377/83243377_1669883362558_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('99266256');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('99266256','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  마이웨이 (MY WAY) (Prod. by R.Tee)</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('81651809');return false;">저스디스 (JUSTHIS) &amp; R.Tee &amp; 던말릭 (DON MALIK) &amp; 허성현 (Huh) &amp; KHAN &amp; 맥대디 (Mckdaddy) &amp; Los</a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('99266256');" type="button">외</button>
#  <ul class="list" id="RelationArtist_99266256"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('83243377');return false;">쇼미더머니 11 Episode 1</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('99266256;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('99266256;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_99266256" onclick="fnAddMyAlbumForm('#add_my_album_99266256' , '99266256' ,10, 10);return false;" songid="99266256" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('99266256');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_99266256">
#  <a alt="마이웨이 (MY WAY) (Prod. by R.Tee)" class="btn btn-basic btn-mv disabled" href="#" onclick="return false;" style="pointer-events: none;" title="재생 불가">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('99266256');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('99266256');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="94535712">
#  <td class="check"><input class="select-check" title="사랑은 늘 도망가" type="checkbox"/></td>
#  <td class="number">7
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-down">2<span class="hide">하강</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82322594');return false;"><span class="mask"></span><img alt="신사와 아가씨 OST Part.2" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/322/594/82322594_1633671778123_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('94535712');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('94535712','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  사랑은 늘 도망가</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('80539618');return false;">임영웅</a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('94535712');" type="button">외</button>
#  <ul class="list" id="RelationArtist_94535712"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82322594');return false;">신사와 아가씨 OST Part.2</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('94535712;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('94535712;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_94535712" onclick="fnAddMyAlbumForm('#add_my_album_94535712' , '94535712' ,10, 10);return false;" songid="94535712" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('94535712');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_94535712">
#  <a alt="사랑은 늘 도망가" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('94535712','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('94535712');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('94535712');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="98133352">
#  <td class="check"><input class="select-check" title="새삥 (Prod. by ZICO) (Feat. 호미들)" type="checkbox"/></td>
#  <td class="number">8
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-up">1<span class="hide">상승</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82941007');return false;"><span class="mask"></span><img alt="스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/941/007/82941007_1662445894361_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('98133352');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('98133352','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  새삥 (Prod. by ZICO) (Feat. 호미들)</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('80291985');return false;">지코 (ZICO)</a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('98133352');" type="button">외</button>
#  <ul class="list" id="RelationArtist_98133352"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82941007');return false;">스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('98133352;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('98133352;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_98133352" onclick="fnAddMyAlbumForm('#add_my_album_98133352' , '98133352' ,10, 10);return false;" songid="98133352" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('98133352');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_98133352">
#  <a alt="새삥 (Prod. by ZICO) (Feat. 호미들)" class="btn btn-basic btn-mv disabled" href="#" onclick="return false;" style="pointer-events: none;" title="재생 불가">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('98133352');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('98133352');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="96549502">
#  <td class="check"><input class="select-check" title="우리들의 블루스" type="checkbox"/></td>
#  <td class="number">9
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-down">1<span class="hide">하강</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82638032');return false;"><span class="mask"></span><img alt="IM HERO" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/638/032/82638032_1651479062721_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('96549502');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('96549502','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  우리들의 블루스</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('80539618');return false;">임영웅</a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('96549502');" type="button">외</button>
#  <ul class="list" id="RelationArtist_96549502"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82638032');return false;">IM HERO</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('96549502;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('96549502;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_96549502" onclick="fnAddMyAlbumForm('#add_my_album_96549502' , '96549502' ,10, 10);return false;" songid="96549502" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('96549502');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_96549502">
#  <a alt="우리들의 블루스" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('96549502','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('96549502');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('96549502');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="97582506">
#  <td class="check"><input class="select-check" title="Attention" type="checkbox"/></td>
#  <td class="number">10
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-none"><span class="hide">유지</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82842800');return false;"><span class="mask"></span><img alt="NewJeans 1st EP 'New Jeans'" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/842/800/82842800_1659340238924_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('97582506');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('97582506','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  Attention</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('81490206');return false;">NewJeans</a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('97582506');" type="button">외</button>
#  <ul class="list" id="RelationArtist_97582506"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82842800');return false;">NewJeans 1st EP 'New Jeans'</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('97582506;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('97582506;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_97582506" onclick="fnAddMyAlbumForm('#add_my_album_97582506' , '97582506' ,10, 10);return false;" songid="97582506" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('97582506');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_97582506">
#  <a alt="Attention" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('97582506','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('97582506');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('97582506');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="96480048">
#  <td class="check"><input class="select-check" title="LOVE DIVE" type="checkbox"/></td>
#  <td class="number">11
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-up">3<span class="hide">상승</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82624363');return false;"><span class="mask"></span><img alt="LOVE DIVE" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/624/363/82624363_1649123068092_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('96480048');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('96480048','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  LOVE DIVE</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('81271496');return false;">IVE (아이브)</a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('96480048');" type="button">외</button>
#  <ul class="list" id="RelationArtist_96480048"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82624363');return false;">LOVE DIVE</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('96480048;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('96480048;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_96480048" onclick="fnAddMyAlbumForm('#add_my_album_96480048' , '96480048' ,10, 10);return false;" songid="96480048" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('96480048');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_96480048">
#  <a alt="LOVE DIVE" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('96480048','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('96480048');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('96480048');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="96696809">
#  <td class="check"><input class="select-check" title="다시 만날 수 있을까" type="checkbox"/></td>
#  <td class="number">12
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-down">1<span class="hide">하강</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82638032');return false;"><span class="mask"></span><img alt="IM HERO" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/638/032/82638032_1651479062721_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('96696809');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('96696809','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  다시 만날 수 있을까</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('80539618');return false;">임영웅</a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('96696809');" type="button">외</button>
#  <ul class="list" id="RelationArtist_96696809"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82638032');return false;">IM HERO</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('96696809;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('96696809;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_96696809" onclick="fnAddMyAlbumForm('#add_my_album_96696809' , '96696809' ,10, 10);return false;" songid="96696809" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('96696809');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_96696809">
#  <a alt="다시 만날 수 있을까" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('96696809','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('96696809');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('96696809');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="90077755">
#  <td class="check"><input class="select-check" title="이제 나만 믿어요" type="checkbox"/></td>
#  <td class="number">13
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-down">1<span class="hide">하강</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('81410156');return false;"><span class="mask"></span><img alt="내일은 미스터트롯 우승자 특전곡" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/081/410/156/81410156_1585878705990_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('90077755');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('90077755','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  이제 나만 믿어요</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('80539618');return false;">임영웅</a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('90077755');" type="button">외</button>
#  <ul class="list" id="RelationArtist_90077755"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('81410156');return false;">내일은 미스터트롯 우승자 특전곡</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('90077755;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('90077755;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_90077755" onclick="fnAddMyAlbumForm('#add_my_album_90077755' , '90077755' ,10, 10);return false;" songid="90077755" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('90077755');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_90077755">
#  <a alt="이제 나만 믿어요" class="btn btn-basic btn-mv disabled" href="#" onclick="return false;" style="pointer-events: none;" title="재생 불가">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('90077755');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('90077755');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="99014221">
#  <td class="check"><input class="select-check" title="London Boy" type="checkbox"/></td>
#  <td class="number">14
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-up">1<span class="hide">상승</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('83180213');return false;"><span class="mask"></span><img alt="Polaroid" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/083/180/213/83180213_1668490985544_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('99014221');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('99014221','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  London Boy</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('80539618');return false;">임영웅</a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('99014221');" type="button">외</button>
#  <ul class="list" id="RelationArtist_99014221"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('83180213');return false;">Polaroid</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('99014221;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('99014221;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_99014221" onclick="fnAddMyAlbumForm('#add_my_album_99014221' , '99014221' ,10, 10);return false;" songid="99014221" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('99014221');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_99014221">
#  <a alt="London Boy" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('99014221','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('99014221');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('99014221');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="96696807">
#  <td class="check"><input class="select-check" title="무지개" type="checkbox"/></td>
#  <td class="number">15
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-up">1<span class="hide">상승</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82638032');return false;"><span class="mask"></span><img alt="IM HERO" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/638/032/82638032_1651479062721_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('96696807');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('96696807','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  무지개</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('80539618');return false;">임영웅</a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('96696807');" type="button">외</button>
#  <ul class="list" id="RelationArtist_96696807"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82638032');return false;">IM HERO</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('96696807;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('96696807;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_96696807" onclick="fnAddMyAlbumForm('#add_my_album_96696807' , '96696807' ,10, 10);return false;" songid="96696807" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('96696807');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_96696807">
#  <a alt="무지개" class="btn btn-basic btn-mv disabled" href="#" onclick="return false;" style="pointer-events: none;" title="재생 불가">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('96696807');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('96696807');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="99014222">
#  <td class="check"><input class="select-check" title="Polaroid" type="checkbox"/></td>
#  <td class="number">16
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-up">1<span class="hide">상승</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('83180213');return false;"><span class="mask"></span><img alt="Polaroid" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/083/180/213/83180213_1668490985544_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('99014222');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('99014222','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  Polaroid</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('80539618');return false;">임영웅</a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('99014222');" type="button">외</button>
#  <ul class="list" id="RelationArtist_99014222"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('83180213');return false;">Polaroid</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('99014222;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('99014222;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_99014222" onclick="fnAddMyAlbumForm('#add_my_album_99014222' , '99014222' ,10, 10);return false;" songid="99014222" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('99014222');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_99014222">
#  <a alt="Polaroid" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('99014222','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('99014222');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('99014222');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="82146674">
#  <td class="check"><input class="select-check" title="All I Want for Christmas Is You" type="checkbox"/></td>
#  <td class="number">17
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-down">4<span class="hide">하강</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('80384589');return false;"><span class="mask"></span><img alt="Merry Christmas (Deluxe Anniversary Edition)" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/080/384/589/80384589_1572569104266_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('82146674');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('82146674','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  All I Want for Christmas Is You</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14937308');return false;">Mariah Carey</a>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('80384589');return false;">Merry Christmas (Deluxe Anniversary Edition)</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('82146674;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('82146674;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_82146674" onclick="fnAddMyAlbumForm('#add_my_album_82146674' , '82146674' ,10, 10);return false;" songid="82146674" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('82146674');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_82146674">
#  <a alt="All I Want for Christmas Is You" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('82146674','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('82146674');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('82146674');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="99084793">
#  <td class="check"><input class="select-check" title="Dreamers (Music from the FIFA World Cup Qatar 2022 Official Soundtrack) (Feat. FIFA Sound)" type="checkbox"/></td>
#  <td class="number">18
#
#                                      <span class="rank">
# ...
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('95376934;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('95376934;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_95376934" onclick="fnAddMyAlbumForm('#add_my_album_95376934' , '95376934' ,10, 10);return false;" songid="95376934" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('95376934');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_95376934">
#  <a alt="취중고백" class="btn btn-basic btn-mv disabled" href="#" onclick="return false;" style="pointer-events: none;" title="재생 불가">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('95376934');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('95376934');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="97404331">
#  <td class="check"><input class="select-check" title="보고싶었어" type="checkbox"/></td>
#  <td class="number">46
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-up">2<span class="hide">상승</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82814458');return false;"><span class="mask"></span><img alt="WSG워너비 1집" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/814/458/82814458_1657270030475_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('97404331');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('97404331','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  보고싶었어</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('81475829');return false;">WSG워너비 (4FIRE)</a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('97404331');" type="button">외</button>
#  <ul class="list" id="RelationArtist_97404331"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82814458');return false;">WSG워너비 1집</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('97404331;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('97404331;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_97404331" onclick="fnAddMyAlbumForm('#add_my_album_97404331' , '97404331' ,10, 10);return false;" songid="97404331" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('97404331');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_97404331">
#  <a alt="보고싶었어" class="btn btn-basic btn-mv disabled" href="#" onclick="return false;" style="pointer-events: none;" title="재생 불가">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('97404331');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('97404331');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="97728588">
#  <td class="check"><input class="select-check" title="Cookie" type="checkbox"/></td>
#  <td class="number">47
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-up">6<span class="hide">상승</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82842800');return false;"><span class="mask"></span><img alt="NewJeans 1st EP 'New Jeans'" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/842/800/82842800_1659340238924_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('97728588');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('97728588','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  Cookie</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('81490206');return false;">NewJeans</a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('97728588');" type="button">외</button>
#  <ul class="list" id="RelationArtist_97728588"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82842800');return false;">NewJeans 1st EP 'New Jeans'</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('97728588;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('97728588;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_97728588" onclick="fnAddMyAlbumForm('#add_my_album_97728588' , '97728588' ,10, 10);return false;" songid="97728588" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('97728588');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_97728588">
#  <a alt="Cookie" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('97728588','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('97728588');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('97728588');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="89557918">
#  <td class="check"><input class="select-check" title="Last Christmas" type="checkbox"/></td>
#  <td class="number">48
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-up">17<span class="hide">상승</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('81302648');return false;"><span class="mask"></span><img alt="George Michael &amp; Wham! Last Christmas : The Original Motion Picture Soundtrack" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/081/302/648/81302648_1573092053705_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('89557918');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('89557918','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  Last Christmas</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14942662');return false;">Wham!</a>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('81302648');return false;">George Michael &amp; Wham! Last Christmas : The Original Motion Picture Soundtrack</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('89557918;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('89557918;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_89557918" onclick="fnAddMyAlbumForm('#add_my_album_89557918' , '89557918' ,10, 10);return false;" songid="89557918" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down disabled" href="#" title="다운 불가">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_89557918">
#  <a alt="Last Christmas" class="btn btn-basic btn-mv disabled" href="#" onclick="return false;" style="pointer-events: none;" title="재생 불가">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('89557918');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item disabled" href="#" title="선물 불가">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="97313940">
#  <td class="check"><input class="select-check" title="그라데이션" type="checkbox"/></td>
#  <td class="number">49
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-none"><span class="hide">유지</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82798875');return false;"><span class="mask"></span><img alt="5.3" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/798/875/82798875_1656663217923_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('97313940');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('97313940','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  그라데이션</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('80044692');return false;">10CM</a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('97313940');" type="button">외</button>
#  <ul class="list" id="RelationArtist_97313940"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82798875');return false;">5.3</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('97313940;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('97313940;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_97313940" onclick="fnAddMyAlbumForm('#add_my_album_97313940' , '97313940' ,10, 10);return false;" songid="97313940" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('97313940');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_97313940">
#  <a alt="그라데이션" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('97313940','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('97313940');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('97313940');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="80897960">
#  <td class="check"><input class="select-check" title="미리 메리 크리스마스 (Feat. 천둥 of MBLAQ)" type="checkbox"/></td>
#  <td class="number">50
#
#                                      <span class="rank">
#  <span class="rank"><span class="rank-none"><span class="hide">유지</span></span></span>
#  </span>
#  </td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('80218361');return false;"><span class="mask"></span><img alt="REAL" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/080/218/361/80218361_1378798829373_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('80897960');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('80897960','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                  미리 메리 크리스마스 (Feat. 천둥 of MBLAQ)</a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('67872918');return false;">아이유 (IU)</a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('80897960');" type="button">외</button>
#  <ul class="list" id="RelationArtist_80897960"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('80218361');return false;">REAL</a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('80897960;' ,'1'); return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('80897960;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_80897960" onclick="fnAddMyAlbumForm('#add_my_album_80897960' , '80897960' ,10, 10);return false;" songid="80897960" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('80897960');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_80897960">
#  <a alt="미리 메리 크리스마스 (Feat. 천둥 of MBLAQ)" class="btn btn-basic btn-mv disabled" href="#" onclick="return false;" style="pointer-events: none;" title="재생 불가">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('80897960');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('80897960');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>]

# %%
songs=soup.select('tr')[1:]
len(songs)
# Out:
# 50

# %%
 title=song.select('p.title>a')[0].text
    singer=singer=song.select('p.artist > a')[0].text

# %%
driver=webdriver.Chrome('chromedriver.exe') #새 창이 뜸

url = 'https://music.bugs.co.kr/chart'
driver.get(url)

html=driver.page_source
soup=BeautifulSoup(html, 'html.parser')



#------------------------------------------------------
song_data=[]
rank=1 #초기화

songs=soup.select('tr')[1:]

for song in songs:
    title=song.select('p.title>a')[0].text
    singer=song.select('p.artist > a')[0].text
    print(title, singer, sep=' , ')
    mylist = ['bugs', rank, title, singer]
    song_data.append(mylist)
    rank += 1
# Out:
# C:\Users\SBAUser\AppData\Local\Temp\ipykernel_5908\3567295668.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome('chromedriver.exe') #새 창이 뜸
# 사건의 지평선 , 윤하(Younha/ユンナ)
# Hype Boy , NewJeans
# WHEN I MOVE , 카라(Kara)
# ANTIFRAGILE , LE SSERAFIM (르세라핌)
# After LIKE , IVE (아이브)
# Attention , NewJeans
# All I Want for Christmas Is You , Mariah Carey(머라이어 캐리)
# Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (feat. FIFA Sound) , 정국
# Snowman , Sia(시아)
# Nxde , (여자)아이들
# Santa Tell Me , Ariana Grande(아리아나 그란데)
# LOVE DIVE , IVE (아이브)
# 새삥 (Prod. ZICO) (Feat. 호미들) , 지코
# Shut Down , BLACKPINK
# 마이웨이 (MY WAY) (Prod. R.Tee) , 저스디스(JUSTHIS)
# Rush Hour (Feat. j-hope of BTS) , Crush
# 오르트구름 , 윤하(Younha/ユンナ)
# Pink Venom , BLACKPINK
# 자격지심 (Feat. ZICO) , BE'O (비오)
# Made You Look , Meghan Trainor(메간 트레이너)
# 미리 메리 크리스마스 (feat. 천둥 Of MBLAQ) , 아이유(IU)
# I Don’t Think That I Like Her , Charlie Puth(찰리 푸스)
# Cookie , NewJeans
# Monologue , 테이(Tei)
# ELEVEN , IVE (아이브)
# Birthday , Red Velvet (레드벨벳)
# Make It To Christmas , Alessia Cara(알레시아 카라)
# STEP , 카라(Kara)
# FEARLESS , LE SSERAFIM (르세라핌)
# TOMBOY , (여자)아이들
# 딱 10CM만 , 10CM
# 너의 모든 순간 , 성시경
# 그라데이션 , 10CM
# 해요 (2022) , #안녕
# 위하여 (We Higher) (Prod. GroovyRoom) , 그루비룸 (GroovyRoom)
# Unholy , Sam Smith(샘 스미스)
# 크리스마스니까 , 성시경
# When I Get Old , Christopher(크리스토퍼)
# 우린 그렇게 사랑해서 , 강민경
# That's Hilarious , Charlie Puth(찰리 푸스)
# 사랑인가 봐 , 멜로망스(MeloMance)
# 첫 눈 , EXO
# 정이라고 하자 (Feat. 10CM) , BIG Naughty (서동현)
# 봄여름가을겨울 (Still Life) , BIGBANG (빅뱅)
# Dangerously , Charlie Puth(찰리 푸스)
# Cheshire , ITZY (있지)
# Underneath the Tree , Kelly Clarkson(켈리 클락슨)
# 신호등 , 이무진
# 그때 그 순간 그대로 (그그그) , WSG워너비 (가야G)
# Off My Face , Justin Bieber(저스틴 비버)
# GHOST TOWN , Benson Boone
# 사랑은 늘 도망가 , 임영웅
# 사랑하긴 했었나요 스쳐가는 인연이었나요 짧지않은 우리 함께했던 시간들이 자꾸 내 마음을 가둬두네 , 잔나비
# 내 기쁨은 너가 벤틀리를 끄는 거야 , 김승민
# 도깨비불 (Illusion) , aespa
# Last Christmas , Wham!(왬)
# ZOOM , Red Velvet (레드벨벳)
# DICE , NMIXX
# 내가 아니라도 , 주호
# 모든 날, 모든 순간 (Every day, Every Moment) , 폴킴(Paul Kim)
# WE (Feat. 박재범) (Prod. by Slom) , 이영지
# 나의 X에게 , 경서
# Love story , 볼빨간사춘기
# 찬바람이 불어오네요 , 케이시
# strawberry moon , 아이유(IU)
# Next Level , aespa
# 진심이었던 사람만 바보가 돼 , 권진아
# 드라마 , 아이유(IU)
# STAY , The Kid LAROI
# 팡파레 , 다비치
# 보고싶었어 , WSG워너비 (4FIRE)
# Anti-Hero , Taylor Swift(테일러 스위프트)
# 잘가요 , 주호
# 취중고백 , 김민석 (멜로망스)
# LOVE me , BE'O (비오)
# Impurities , LE SSERAFIM (르세라핌)
# Talk that Talk , TWICE (트와이스)
# 다정히 내 이름을 부르면 , 경서예지
# 그 겨울이 잠든 거리에서 , 경서예지
# Left and Right (Feat. Jung Kook of BTS) , Charlie Puth(찰리 푸스)
# SNEAKERS , ITZY (있지)
# INVU , 태연 (TAEYEON)
# Feel My Rhythm , Red Velvet (레드벨벳)
# 주저하는 연인들을 위해 , 잔나비
# MY BAG , (여자)아이들
# 맘마미아 , 카라(Kara)
# FOREVER 1 , 소녀시대 (GIRLS' GENERATION)
# LAW (Prod. Czaer) , 윤미래
# I Ain't Worried , OneRepublic(원리퍼블릭)
# 첫사랑 , 백아(Baek A)
# 떠나보낼 준비해 둘걸 그랬어 , 임한별
# 한 페이지가 될 수 있게 , DAY6 (데이식스)
# 루팡 (Lupin) , 카라(Kara)
# 눈이 오잖아(Feat.헤이즈) , 이무진
# 롤러코스터 (On A Ride) , Red Velvet (레드벨벳)
# 나쁜X , 비비(BIBI)
# 가을밤에 든 생각 , 잔나비
# Flick (Feat. BE'O (비오), 김하온 (HAON)) (Prod. GroovyRoom) , 노윤하
# 겨울이 좋아졌어 , 정승환
# Must Have Love (우리들의 겨울) , SG워너비
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5908\3567295668.py in <module>
#      16
#      17 for song in songs:
# ---> 18     title=song.select('p.title>a')[0].text
#      19     singer=song.select('p.artist > a')[0].text
#      20     print(title, singer, sep=' , ')
#
# IndexError: list index out of range

# %%
type(song_data)
# Out:
# list

# %%
import pandas as pd

df=pd.DataFrame(song_data, columns=['서비스업체', '순위', '타이틀(곡명)', '가수'])
df
# Out:
#    서비스업체   순위                                            타이틀(곡명)  \
# 0   bugs    1                                            사건의 지평선
# 1   bugs    2                                           Hype Boy
# 2   bugs    3                                        WHEN I MOVE
# 3   bugs    4                                        ANTIFRAGILE
# 4   bugs    5                                         After LIKE
# ..   ...  ...                                                ...
# 95  bugs   96                                                나쁜X
# 96  bugs   97                                          가을밤에 든 생각
# 97  bugs   98  Flick (Feat. BE'O (비오), 김하온 (HAON)) (Prod. Gro...
# 98  bugs   99                                           겨울이 좋아졌어
# 99  bugs  100                           Must Have Love (우리들의 겨울)
#
#                     가수
# 0       윤하(Younha/ユンナ)
# 1             NewJeans
# 2             카라(Kara)
# 3   LE SSERAFIM (르세라핌)
# 4            IVE (아이브)
# ..                 ...
# 95            비비(BIBI)
# 96                 잔나비
# 97                 노윤하
# 98                 정승환
# 99               SG워너비
#
# [100 rows x 4 columns]

# %%
df.to_excel('./bugs_rank.xlsx', index=False)
