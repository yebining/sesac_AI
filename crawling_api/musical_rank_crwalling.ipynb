# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (4.7.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from selenium) (1.26.13)
# Requirement already satisfied: trio~=0.17 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: async-generator>=1.9 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: outcome in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: idna in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: sniffio in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\sbauser\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
title[0].text
# Out:
# '태양의서커스〈뉴 알레그리아〉'

# %%
loc=musical.select('body > div.rankingDetailBody > div:nth-child(2) > table > tbody > tr > td.prds > div.prdInfo > a')[0].text.strip().replace('\n\t                                    ',',')    
loc
# Out:
# '태양의서커스〈뉴 알레그리아〉,잠실종합운동장 내 빅탑'

# %%
soup.select('div.prdInfo > a')[3].text.strip().replace('  ','')
# Out:
# '뮤지컬 〈아이다〉\n\t블루스퀘어 신한카드홀'

# %%
soup.select('div.prdInfo > a')[2].text.strip().replace(' 
 ','').replace('\n\t',',')
# Out:
# '뮤지컬 〈엘리자벳〉 10주년 기념공연\n\t블루스퀘어 신한카드홀'

# %%
soup.select('div.prdInfo > a')[1].text.strip().replace('  ','').replace('\n\t',',')
# Out:
# '뮤지컬 〈킹키부츠〉,충무아트센터 대극장'

# %%
location=loc.split(',')[1] 
location
# Out:
# '잠실종합운동장 내 빅탑'

# %%
# musical=soup.select('div.prdInfo > a')
# musical
title=musical.select('div.prdInfo > a')[0].text.strip().replace(' ','').replace('\n\t',',')
title
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[120], line 3
#       1 # musical=soup.select('div.prdInfo > a')
#       2 # musical
# ----> 3 title=musical.select('div.prdInfo > a')[0].text.strip().replace(' ','').replace('\n\t',',')
#       4 title
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\bs4\element.py:2289, in ResultSet.__getattr__(self, key)
#    2287 def __getattr__(self, key):
#    2288     """Raise a helpful exception to explain a common code fix."""
# -> 2289     raise AttributeError(
#    2290         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2291     )
#
# AttributeError: ResultSet object has no attribute 'select'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
musical_data=[]
rank=1 #초기화

musicals = soup.select("body > div.rankingDetailBody")
musical=soup.select('div.prdInfo > a')


for i in musical:
    title=i.select('div.prdInfo > a')[0].text.strip().replace('  ','').replace('\n\t',',')
    # loc=i.select('div.prdInfo > a')[0].text.strip().replace('      ','').replace('\n\t',',')[1]

    
    print(title, loc, sep=' , ')
    mylist = ['interpark', rank, title, loc]
    musical_data.append(mylist)
    rank += 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[118], line 9
#       5 musical=soup.select('div.prdInfo > a')
#       8 for i in musical:
# ----> 9     title=i.select('div.prdInfo > a')[1].text.strip().replace('  ','').replace('\n\t',',')
#      10     # loc=i.select('div.prdInfo > a')[0].text.strip().replace('      ','').replace('\n\t',',')[1]
#      13     print(title, loc, sep=' , ')
#
# IndexError: list index out of range

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

driver = webdriver.Chrome('./chromedriver.exe')

url = 'http://ticket.interpark.com/contents/Ranking/RankList?pKind=01011&pCate=01011&pType=Y&pDate=20220101'
driver.get(url)

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

musicals = soup.select('div.prdInfo')
#musical=musicals[0]

musical_data = []
Rank = 1

for musical in musicals:
    title = musical.select('a')[0].text.strip().replace('  ','').replace('\n\t',',').split(',')[0]
    loc = musical.select('a')[0].text.strip().replace('  ','').replace('\n\t',',').split(',')[1]
    
    my_list = ['Interpark',Rank, title, loc]
    musical_data.append(my_list)
    Rank += 1
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8836\174982983.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver.exe')

# %%
musical_data
# Out:
# [['Interpark', 1, '태양의서커스〈뉴 알레그리아〉', '잠실종합운동장 내 빅탑'],
#  ['Interpark', 2, '뮤지컬 〈킹키부츠〉', '충무아트센터 대극장'],
#  ['Interpark', 3, '뮤지컬 〈엘리자벳〉 10주년 기념공연', '블루스퀘어 신한카드홀'],
#  ['Interpark', 4, '뮤지컬 〈아이다〉', '블루스퀘어 신한카드홀'],
#  ['Interpark', 5, '뮤지컬 〈마틸다〉', '대성 디큐브아트센터'],
#  ['Interpark', 6, '뮤지컬 〈웃는 남자〉', '세종문화회관 대극장'],
#  ['Interpark',
#   7,
#   '뮤지컬 〈물랑루즈!〉 아시아 초연 (Moulin Rouge! The Musical)',
#   '블루스퀘어 신한카드홀'],
#  ['Interpark', 8, '뮤지컬 데스노트 (The Musical Death Note)', '충무아트센터 대극장'],
#  ['Interpark', 9, '뮤지컬 데스노트 (The Musical Death Note)', '예술의전당 오페라극장'],
#  ['Interpark', 10, '뮤지컬 지킬앤하이드 (Jekyll＆Hyde)', '샤롯데씨어터'],
#  ['Interpark', 11, '뮤지컬 〈사의찬미〉', '대학로 TOM(티오엠) 1관'],
#  ['Interpark', 12, '뮤지컬 〈미세스 다웃파이어〉', '샤롯데씨어터'],
#  ['Interpark',
#   13,
#   '뮤지컬 라이온 킹 인터내셔널 투어 - 서울 (Musical The Lion King)',
#   '예술의전당 오페라극장'],
#  ['Interpark', 14, '뮤지컬 〈여신님이 보고 계셔〉 10th Anniversary', '대학로 유니플렉스 1관'],
#  ['Interpark', 15, '뮤지컬 〈마타하리〉', '샤롯데씨어터'],
#  ['Interpark', 16, '뮤지컬 〈브로드웨이 42번가〉', '예술의전당 CJ 토월극장'],
#  ['Interpark', 17, '뮤지컬 〈지저스 크라이스트 수퍼스타〉 50주년 기념 한국 공연', '광림아트센터 BBCH홀'],
#  ['Interpark', 18, '뮤지컬 〈빨래〉', '대학로 유니플렉스 2관'],
#  ['Interpark', 19, '뮤지컬 〈베토벤; Beethoven Secret〉', '예술의전당 오페라극장'],
#  ['Interpark', 20, '뮤지컬 ＇영웅＇', 'LG아트센터 서울 LG SIGNATURE 홀'],
#  ['Interpark', 21, '뮤지컬 〈웨스트 사이드 스토리〉', '충무아트센터 대극장'],
#  ['Interpark', 22, '뮤지컬 〈프랑켄슈타인〉', '블루스퀘어 신한카드홀'],
#  ['Interpark', 23, '뮤지컬 〈서편제〉', '광림아트센터 BBCH홀'],
#  ['Interpark', 24, '베어 더 뮤지컬(bare the musical)', '두산아트센터 연강홀'],
#  ['Interpark', 25, '뮤지컬 〈스위니토드〉', '샤롯데씨어터'],
#  ['Interpark', 26, '뮤지컬 〈웨스턴 스토리〉', '대학로 유니플렉스 1관'],
#  ['Interpark', 27, '뮤지컬 〈팬레터〉', 'coex 신한카드 artium'],
#  ['Interpark', 28, '뮤지컬 〈배니싱〉', '대학로 아트원씨어터 1관'],
#  ['Interpark', 29, '뮤지컬 〈캣츠〉 오리지널 내한－서울（Musical CATS）', '세종문화회관 대극장'],
#  ['Interpark', 30, '뮤지컬 〈미오 프라텔로〉', '드림아트센터 1관'],
#  ['Interpark', 31, '뮤지컬 〈빌리 엘리어트〉', '대성 디큐브아트센터'],
#  ['Interpark', 32, '뮤지컬 〈니진스키〉', '대학로 아트원씨어터 1관'],
#  ['Interpark', 33, '뮤지컬 〈빨래〉', '대학로 유니플렉스 2관'],
#  ['Interpark', 34, '뮤지컬 〈사랑의 불시착〉', 'coex 신한카드 artium'],
#  ['Interpark', 35, '육군 창작 뮤지컬 〈블루헬멧 : 메이사의 노래〉', '대성 디큐브아트센터'],
#  ['Interpark', 36, '뮤지컬 〈브론테〉', '대학로 자유극장'],
#  ['Interpark', 37, '블루맨그룹 월드투어', 'coex 신한카드 artium'],
#  ['Interpark',
#   38,
#   '뮤지컬 라이온 킹 인터내셔널 투어 - 부산(Musical The Lion King)',
#   '부산 드림씨어터'],
#  ['Interpark', 39, '뮤지컬 〈리지〉', '두산아트센터 연강홀'],
#  ['Interpark', 40, '뮤지컬 〈랭보〉', '대학로 TOM(티오엠) 1관'],
#  ['Interpark', 41, '뮤지컬 〈레베카〉', '충무아트센터 대극장'],
#  ['Interpark', 42, '뮤지컬 〈디아길레프〉', '대학로 아트원씨어터 1관'],
#  ['Interpark', 43, '뮤지컬〈하데스타운〉 최초 한국 공연 (MUSICAL HADESTOWN)', 'LG아트센터'],
#  ['Interpark', 44, '뮤지컬 〈곤 투모로우〉', '홍익대 대학로 아트센터 대극장'],
#  ['Interpark', 45, '뮤지컬 〈V 에버 애프터〉', '드림아트센터 1관'],
#  ['Interpark', 46, '뮤지컬 〈미아 파밀리아〉', '예스24스테이지 2관'],
#  ['Interpark', 47, '뮤지컬 킹아더 (Musical King Arthur)', '홍익대 대학로 아트센터 대극장'],
#  ['Interpark', 48, '뮤지컬 〈노트르담 드 파리〉 프렌치 오리지널 내한공연 - 앙코르', '블루스퀘어 신한카드홀'],
#  ['Interpark', 49, '와일드 와일드 〈드림〉', '와일드 와일드 전용관 (명보아트홀)'],
#  ['Interpark', 50, '뮤지컬 〈이프덴〉', '홍익대 대학로 아트센터 대극장']]

# %%
import pandas as pd

df=pd.DataFrame(musical_data, columns=['서비스업체', '순위', '제목', '장소'])
df
# Out:
#         서비스업체  순위                                               제목  \
# 0   Interpark   1                                  태양의서커스〈뉴 알레그리아〉
# 1   Interpark   2                                       뮤지컬 〈킹키부츠〉
# 2   Interpark   3                             뮤지컬 〈엘리자벳〉 10주년 기념공연
# 3   Interpark   4                                        뮤지컬 〈아이다〉
# 4   Interpark   5                                        뮤지컬 〈마틸다〉
# 5   Interpark   6                                      뮤지컬 〈웃는 남자〉
# 6   Interpark   7   뮤지컬 〈물랑루즈!〉 아시아 초연 (Moulin Rouge! The Musical)
# 7   Interpark   8                뮤지컬 데스노트 (The Musical Death Note)
# 8   Interpark   9                뮤지컬 데스노트 (The Musical Death Note)
# 9   Interpark  10                         뮤지컬 지킬앤하이드 (Jekyll＆Hyde)
# 10  Interpark  11                                       뮤지컬 〈사의찬미〉
# 11  Interpark  12                                  뮤지컬 〈미세스 다웃파이어〉
# 12  Interpark  13  뮤지컬 라이온 킹 인터내셔널 투어 - 서울 (Musical The Lion King)
# 13  Interpark  14                뮤지컬 〈여신님이 보고 계셔〉 10th Anniversary
# 14  Interpark  15                                       뮤지컬 〈마타하리〉
# 15  Interpark  16                                 뮤지컬 〈브로드웨이 42번가〉
# 16  Interpark  17               뮤지컬 〈지저스 크라이스트 수퍼스타〉 50주년 기념 한국 공연
# 17  Interpark  18                                         뮤지컬 〈빨래〉
# 18  Interpark  19                      뮤지컬 〈베토벤; Beethoven Secret〉
# 19  Interpark  20                                         뮤지컬 ＇영웅＇
# 20  Interpark  21                                뮤지컬 〈웨스트 사이드 스토리〉
# 21  Interpark  22                                     뮤지컬 〈프랑켄슈타인〉
# 22  Interpark  23                                        뮤지컬 〈서편제〉
# 23  Interpark  24                       베어 더 뮤지컬(bare the musical)
# 24  Interpark  25                                      뮤지컬 〈스위니토드〉
# 25  Interpark  26                                    뮤지컬 〈웨스턴 스토리〉
# 26  Interpark  27                                        뮤지컬 〈팬레터〉
# 27  Interpark  28                                        뮤지컬 〈배니싱〉
# 28  Interpark  29                뮤지컬 〈캣츠〉 오리지널 내한－서울（Musical CATS）
# 29  Interpark  30                                    뮤지컬 〈미오 프라텔로〉
# 30  Interpark  31                                    뮤지컬 〈빌리 엘리어트〉
# 31  Interpark  32                                       뮤지컬 〈니진스키〉
# 32  Interpark  33                                         뮤지컬 〈빨래〉
# 33  Interpark  34                                    뮤지컬 〈사랑의 불시착〉
# 34  Interpark  35                       육군 창작 뮤지컬 〈블루헬멧 : 메이사의 노래〉
# 35  Interpark  36                                        뮤지컬 〈브론테〉
# 36  Interpark  37                                       블루맨그룹 월드투어
# 37  Interpark  38   뮤지컬 라이온 킹 인터내셔널 투어 - 부산(Musical The Lion King)
# 38  Interpark  39                                         뮤지컬 〈리지〉
# 39  Interpark  40                                         뮤지컬 〈랭보〉
# 40  Interpark  41                                        뮤지컬 〈레베카〉
# 41  Interpark  42                                      뮤지컬 〈디아길레프〉
# 42  Interpark  43          뮤지컬〈하데스타운〉 최초 한국 공연 (MUSICAL HADESTOWN)
# 43  Interpark  44                                     뮤지컬 〈곤 투모로우〉
# 44  Interpark  45                                   뮤지컬 〈V 에버 애프터〉
# 45  Interpark  46                                    뮤지컬 〈미아 파밀리아〉
# 46  Interpark  47                    뮤지컬 킹아더 (Musical King Arthur)
# 47  Interpark  48              뮤지컬 〈노트르담 드 파리〉 프렌치 오리지널 내한공연 - 앙코르
# 48  Interpark  49                                     와일드 와일드 〈드림〉
# 49  Interpark  50                                        뮤지컬 〈이프덴〉
#
#                           장소
# 0               잠실종합운동장 내 빅탑
# 1                 충무아트센터 대극장
# 2                블루스퀘어 신한카드홀
# 3                블루스퀘어 신한카드홀
# 4                 대성 디큐브아트센터
# 5                 세종문화회관 대극장
# 6                블루스퀘어 신한카드홀
# 7                 충무아트센터 대극장
# 8                예술의전당 오페라극장
# 9                     샤롯데씨어터
# 10           대학로 TOM(티오엠) 1관
# 11                    샤롯데씨어터
# 12               예술의전당 오페라극장
# 13              대학로 유니플렉스 1관
# 14                    샤롯데씨어터
# 15             예술의전당 CJ 토월극장
# 16              광림아트센터 BBCH홀
# 17              대학로 유니플렉스 2관
# 18               예술의전당 오페라극장
# 19  LG아트센터 서울 LG SIGNATURE 홀
# 20                충무아트센터 대극장
# 21               블루스퀘어 신한카드홀
# 22              광림아트센터 BBCH홀
# 23                두산아트센터 연강홀
# 24                    샤롯데씨어터
# 25              대학로 유니플렉스 1관
# 26          coex 신한카드 artium
# 27             대학로 아트원씨어터 1관
# 28                세종문화회관 대극장
# 29                 드림아트센터 1관
# 30                대성 디큐브아트센터
# 31             대학로 아트원씨어터 1관
# 32              대학로 유니플렉스 2관
# 33          coex 신한카드 artium
# 34                대성 디큐브아트센터
# 35                  대학로 자유극장
# 36          coex 신한카드 artium
# 37                  부산 드림씨어터
# 38                두산아트센터 연강홀
# 39           대학로 TOM(티오엠) 1관
# 40                충무아트센터 대극장
# 41             대학로 아트원씨어터 1관
# 42                    LG아트센터
# 43          홍익대 대학로 아트센터 대극장
# 44                 드림아트센터 1관
# 45               예스24스테이지 2관
# 46          홍익대 대학로 아트센터 대극장
# 47               블루스퀘어 신한카드홀
# 48       와일드 와일드 전용관 (명보아트홀)
# 49          홍익대 대학로 아트센터 대극장

# %%
df.to_excel('./musical_rank(2022).xlsx', index=False)

# %%
df.to_csv('./musical_rank(2022).csv', index=False)

# %% [markdown]
# ## 뮤지컬 말고 공연 전체로 크롤링 해보기

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

driver = webdriver.Chrome('./chromedriver.exe')

url = 'http://ticket.interpark.com/contents/Ranking/RankList?pKind=P&pCate=&pType=Y&pDate=20220101'
driver.get(url)

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

show = soup.select('div.prdInfo')
#musical=musicals[0]

show_data = []
Rank = 1

for per in show:
    title = per.select('a')[0].text.strip().replace('  ','').replace('\n\t',',').split(',')[0]
    loc = per.select('a')[0].text.strip().replace('  ','').replace('\n\t',',').split(',')[1]
    
    my_list = ['Interpark',Rank, title, loc]
    show_data.append(my_list)
    Rank += 1
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8836\4224256374.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver.exe')

# %%
show_data
# Out:
# [['Interpark', 1, '태양의서커스〈뉴 알레그리아〉', '잠실종합운동장 내 빅탑'],
#  ['Interpark', 2, '싸이 흠뻑쇼 SUMMER SWAG 2022 - 서울', '잠실종합운동장 올림픽주경기장'],
#  ['Interpark', 3, '뮤지컬 〈킹키부츠〉', '충무아트센터 대극장'],
#  ['Interpark', 4, '뮤지컬 〈엘리자벳〉 10주년 기념공연', '블루스퀘어 신한카드홀'],
#  ['Interpark', 5, '뮤지컬 〈아이다〉', '블루스퀘어 신한카드홀'],
#  ['Interpark', 6, '뮤지컬 〈마틸다〉', '대성 디큐브아트센터'],
#  ['Interpark', 7, '뮤지컬 〈웃는 남자〉', '세종문화회관 대극장'],
#  ['Interpark', 8, '싸이 흠뻑쇼 SUMMER SWAG 2022 - 대구', '대구스타디움 주경기장'],
#  ['Interpark', 9, '뮤지컬 데스노트 (The Musical Death Note)', '충무아트센터 대극장'],
#  ['Interpark', 10, '뮤지컬 데스노트 (The Musical Death Note)', '예술의전당 오페라극장'],
#  ['Interpark', 11, '연극 〈쉬어매드니스〉 - 서울 대학로', '콘텐츠박스(KONTENTZ BOX)'],
#  ['Interpark', 12, '뮤지컬 지킬앤하이드 (Jekyll＆Hyde)', '샤롯데씨어터'],
#  ['Interpark', 13, '뮤지컬 〈사의찬미〉', '대학로 TOM(티오엠) 1관'],
#  ['Interpark', 14, '뮤지컬 〈미세스 다웃파이어〉', '샤롯데씨어터'],
#  ['Interpark',
#   15,
#   '뮤지컬 〈물랑루즈!〉 아시아 초연 (Moulin Rouge! The Musical)',
#   '블루스퀘어 신한카드홀'],
#  ['Interpark',
#   16,
#   '뮤지컬 라이온 킹 인터내셔널 투어 - 서울 (Musical The Lion King)',
#   '예술의전당 오페라극장'],
#  ['Interpark', 17, 'BTS PERMISSION TO DANCE ON STAGE - SEOUL', '잠실종합운동장 주경기장'],
#  ['Interpark', 18, '뮤지컬 〈마타하리〉', '샤롯데씨어터'],
#  ['Interpark', 19, '뮤지컬 〈여신님이 보고 계셔〉 10th Anniversary', '대학로 유니플렉스 1관'],
#  ['Interpark',
#   20,
#   '2030 부산세계박람회 유치 기원 콘서트 BTS 〈Yet To Come〉 in BUSAN',
#   '부산 아시아드 주경기장'],
#  ['Interpark', 21, '뮤지컬 〈지저스 크라이스트 수퍼스타〉 50주년 기념 한국 공연', '광림아트센터 BBCH홀'],
#  ['Interpark', 22, '뮤지컬 〈브로드웨이 42번가〉', '예술의전당 CJ 토월극장'],
#  ['Interpark', 23, '뮤지컬 〈빨래〉', '대학로 유니플렉스 2관'],
#  ['Interpark', 24, 'SEVENTEEN WORLD TOUR ［BE THE SUN］- SEOUL', '고척스카이돔'],
#  ['Interpark', 25, '싸이 올나잇스탠드 2022 〈막차와 첫차 싸이〉', 'KSPO DOME'],
#  ['Interpark', 26, '뮤지컬 〈베토벤; Beethoven Secret〉', '예술의전당 오페라극장'],
#  ['Interpark', 27, '뮤지컬 〈프랑켄슈타인〉', '블루스퀘어 신한카드홀'],
#  ['Interpark', 28, '뮤지컬 〈서편제〉', '광림아트센터 BBCH홀'],
#  ['Interpark', 29, '뮤지컬 〈웨스트 사이드 스토리〉', '충무아트센터 대극장'],
#  ['Interpark', 30, '2022 성시경의 축가 콘서트', '잠실종합운동장 보조경기장'],
#  ['Interpark', 31, '베어 더 뮤지컬(bare the musical)', '두산아트센터 연강홀'],
#  ['Interpark', 32, '2022 성시경 연말 콘서트', '잠실실내체육관'],
#  ['Interpark', 33, '싸이 흠뻑쇼 SUMMER SWAG 2022 - 인천', '인천아시아드 주경기장'],
#  ['Interpark', 34, '2022 god ［ON］', 'KSPO DOME (올림픽체조경기장)'],
#  ['Interpark', 35, '싸이 흠뻑쇼 SUMMER SWAG 2022 - 여수', '여수 진남 종합운동장'],
#  ['Interpark', 36, '뮤지컬 〈웨스턴 스토리〉', '대학로 유니플렉스 1관'],
#  ['Interpark', 37, '싸이 흠뻑쇼 SUMMER SWAG 2022 - 강릉', '강릉종합운동장'],
#  ['Interpark', 38, '뮤지컬 〈팬레터〉', 'coex 신한카드 artium'],
#  ['Interpark', 39, '싸이 흠뻑쇼 SUMMER SWAG 2022 - 부산', '부산 아시아드 보조경기장'],
#  ['Interpark', 40, '뮤지컬 〈배니싱〉', '대학로 아트원씨어터 1관'],
#  ['Interpark', 41, '뮤지컬 ＇영웅＇', 'LG아트센터 서울 LG SIGNATURE 홀'],
#  ['Interpark', 42, '싸이 흠뻑쇼 SUMMER SWAG 2022 - 수원', '수원 월드컵경기장 보조경기장'],
#  ['Interpark',
#   43,
#   '2022 KIM HO JOONG CONCERT TOUR ［ARISTRA］',
#   'KSPO DOME(올림픽 체조경기장)'],
#  ['Interpark', 44, '뮤지컬 〈스위니토드〉', '샤롯데씨어터'],
#  ['Interpark', 45, '연극 〈더 헬멧〉', '홍익대 대학로 아트센터 소극장'],
#  ['Interpark', 46, '연극 옥탑방고양이 - 틴틴홀', '대학로 틴틴홀'],
#  ['Interpark', 47, '코믹감동 휴먼판타지 연극 〈2호선 세입자〉', '대학로 바탕골 소극장'],
#  ['Interpark', 48, '제14회 서울재즈페스티벌 2022', '올림픽공원 내 88잔디마당'],
#  ['Interpark',
#   49,
#   'BTOB 10TH ANNIVERSARY CONCERT 2022 BTOB TIME ［Be Together］',
#   'KSPO DOME'],
#  ['Interpark', 50, '뮤지컬 〈미오 프라텔로〉', '드림아트센터 1관']]

# %%
import pandas as pd

df_1=pd.DataFrame(show_data, columns=['서비스업체', '순위', '제목', '장소'])
df_1
# Out:
#         서비스업체  순위                                                 제목  \
# 0   Interpark   1                                    태양의서커스〈뉴 알레그리아〉
# 1   Interpark   2                       싸이 흠뻑쇼 SUMMER SWAG 2022 - 서울
# 2   Interpark   3                                         뮤지컬 〈킹키부츠〉
# 3   Interpark   4                               뮤지컬 〈엘리자벳〉 10주년 기념공연
# 4   Interpark   5                                          뮤지컬 〈아이다〉
# 5   Interpark   6                                          뮤지컬 〈마틸다〉
# 6   Interpark   7                                        뮤지컬 〈웃는 남자〉
# 7   Interpark   8     뮤지컬 〈물랑루즈!〉 아시아 초연 (Moulin Rouge! The Musical)
# 8   Interpark   9                       싸이 흠뻑쇼 SUMMER SWAG 2022 - 대구
# 9   Interpark  10                  뮤지컬 데스노트 (The Musical Death Note)
# 10  Interpark  11                  뮤지컬 데스노트 (The Musical Death Note)
# 11  Interpark  12                               연극 〈쉬어매드니스〉 - 서울 대학로
# 12  Interpark  13                           뮤지컬 지킬앤하이드 (Jekyll＆Hyde)
# 13  Interpark  14                                         뮤지컬 〈사의찬미〉
# 14  Interpark  15                                    뮤지컬 〈미세스 다웃파이어〉
# 15  Interpark  16    뮤지컬 라이온 킹 인터내셔널 투어 - 서울 (Musical The Lion King)
# 16  Interpark  17           BTS PERMISSION TO DANCE ON STAGE - SEOUL
# 17  Interpark  18                  뮤지컬 〈여신님이 보고 계셔〉 10th Anniversary
# 18  Interpark  19                                         뮤지컬 〈마타하리〉
# 19  Interpark  20                                   뮤지컬 〈브로드웨이 42번가〉
# 20  Interpark  21                 뮤지컬 〈지저스 크라이스트 수퍼스타〉 50주년 기념 한국 공연
# 21  Interpark  22  2030 부산세계박람회 유치 기원 콘서트 BTS 〈Yet To Come〉 in BUSAN
# 22  Interpark  23                                           뮤지컬 〈빨래〉
# 23  Interpark  24           SEVENTEEN WORLD TOUR ［BE THE SUN］- SEOUL
# 24  Interpark  25                        뮤지컬 〈베토벤; Beethoven Secret〉
# 25  Interpark  26                                           뮤지컬 ＇영웅＇
# 26  Interpark  27                                  뮤지컬 〈웨스트 사이드 스토리〉
# 27  Interpark  28                                       뮤지컬 〈프랑켄슈타인〉
# 28  Interpark  29                         싸이 올나잇스탠드 2022 〈막차와 첫차 싸이〉
# 29  Interpark  30                                          뮤지컬 〈서편제〉
# 30  Interpark  31                                   2022 성시경의 축가 콘서트
# 31  Interpark  32                                    2022 성시경 연말 콘서트
# 32  Interpark  33                         베어 더 뮤지컬(bare the musical)
# 33  Interpark  34                       싸이 흠뻑쇼 SUMMER SWAG 2022 - 인천
# 34  Interpark  35                                        뮤지컬 〈스위니토드〉
# 35  Interpark  36                                      2022 god ［ON］
# 36  Interpark  37                       싸이 흠뻑쇼 SUMMER SWAG 2022 - 여수
# 37  Interpark  38                                      뮤지컬 〈웨스턴 스토리〉
# 38  Interpark  39                       싸이 흠뻑쇼 SUMMER SWAG 2022 - 강릉
# 39  Interpark  40                                          뮤지컬 〈팬레터〉
# 40  Interpark  41                       싸이 흠뻑쇼 SUMMER SWAG 2022 - 부산
# 41  Interpark  42                                          뮤지컬 〈배니싱〉
# 42  Interpark  43                            코믹감동 휴먼판타지 연극 〈2호선 세입자〉
# 43  Interpark  44                                    연극 옥탑방고양이 - 틴틴홀
# 44  Interpark  45                       싸이 흠뻑쇼 SUMMER SWAG 2022 - 수원
# 45  Interpark  46           2022 KIM HO JOONG CONCERT TOUR ［ARISTRA］
# 46  Interpark  47                                          연극 〈더 헬멧〉
# 47  Interpark  48  BTOB 10TH ANNIVERSARY CONCERT 2022 BTOB TIME ［...
# 48  Interpark  49                                 제14회 서울재즈페스티벌 2022
# 49  Interpark  50                        2022 예술의전당 ＆ 국립발레단 〈호두까기인형〉
#
#                           장소
# 0               잠실종합운동장 내 빅탑
# 1            잠실종합운동장 올림픽주경기장
# 2                 충무아트센터 대극장
# 3                블루스퀘어 신한카드홀
# 4                블루스퀘어 신한카드홀
# 5                 대성 디큐브아트센터
# 6                 세종문화회관 대극장
# 7                블루스퀘어 신한카드홀
# 8                대구스타디움 주경기장
# 9                 충무아트센터 대극장
# 10               예술의전당 오페라극장
# 11       콘텐츠박스(KONTENTZ BOX)
# 12                    샤롯데씨어터
# 13           대학로 TOM(티오엠) 1관
# 14                    샤롯데씨어터
# 15               예술의전당 오페라극장
# 16              잠실종합운동장 주경기장
# 17              대학로 유니플렉스 1관
# 18                    샤롯데씨어터
# 19             예술의전당 CJ 토월극장
# 20              광림아트센터 BBCH홀
# 21              부산 아시아드 주경기장
# 22              대학로 유니플렉스 2관
# 23                    고척스카이돔
# 24               예술의전당 오페라극장
# 25  LG아트센터 서울 LG SIGNATURE 홀
# 26                충무아트센터 대극장
# 27               블루스퀘어 신한카드홀
# 28                 KSPO DOME
# 29              광림아트센터 BBCH홀
# 30             잠실종합운동장 보조경기장
# 31                   잠실실내체육관
# 32                두산아트센터 연강홀
# 33               인천아시아드 주경기장
# 34                    샤롯데씨어터
# 35      KSPO DOME (올림픽체조경기장)
# 36               여수 진남 종합운동장
# 37              대학로 유니플렉스 1관
# 38                   강릉종합운동장
# 39          coex 신한카드 artium
# 40             부산 아시아드 보조경기장
# 41             대학로 아트원씨어터 1관
# 42               대학로 바탕골 소극장
# 43                   대학로 틴틴홀
# 44           수원 월드컵경기장 보조경기장
# 45      KSPO DOME(올림픽 체조경기장)
# 46          홍익대 대학로 아트센터 소극장
# 47                 KSPO DOME
# 48            올림픽공원 내 88잔디마당
# 49               예술의전당 오페라극장

# %%
df.to_excel('./show_rank.xlsx', index=False)
