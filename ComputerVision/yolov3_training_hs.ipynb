# %%
import os, sys

# %% [markdown]
# config

# %%
# YOLO options
YOLO_DARKNET_WEIGHTS        = "./yolov3.weights"
YOLO_COCO_CLASSES           = "./coco.names"
YOLO_STRIDES                = [8, 16, 32]
YOLO_IOU_LOSS_THRESH        = 0.5
YOLO_ANCHOR_PER_SCALE       = 3
YOLO_MAX_BBOX_PER_SCALE     = 100
YOLO_INPUT_SIZE             = 416
YOLO_ANCHORS                = [[[10,  13], [16,   30], [33,   23]],
                               [[30,  61], [62,   45], [59,  119]],
                               [[116, 90], [156, 198], [373, 326]]]
# Train options 
TRAIN_CLASSES               = "./416_helmet/helmet.names"
TRAIN_ANNOT_PATH            = "./helmet_data/train.txt"
TRAIN_BATCH_SIZE            = 4
TRAIN_INPUT_SIZE            = 416
TRAIN_DATA_AUG              = False
TRAIN_TRANSFER              = False
TRAIN_FROM_CHECKPOINT       = "./checkpoints/yolov3_custom"

TRAIN_LR_INIT               = 1e-4
TRAIN_LR_END                = 1e-6
TRAIN_WARMUP_EPOCHS         = 2
TRAIN_EPOCHS                = 50

# TEST options
TEST_ANNOT_PATH             = "./helmet_data/val.txt"
TEST_BATCH_SIZE             = 4
TEST_INPUT_SIZE             = 416
TEST_DATA_AUG               = False

# %%
import cv2
import time
import random
import colorsys
import numpy as np
import tensorflow as tf

# %% [markdown]
# utils

# %%
def load_yolo_weights(model, weights_file):
    tf.keras.backend.clear_session() # used to reset layer names
    # load Darknet original weights to Keras model
    with open(weights_file, 'rb') as wf:
        major, minor, revision, seen, _ = np.fromfile(wf, dtype=np.int32, count=5)

        j = 0
        for i in range(75):
            if i > 0:
                conv_layer_name = 'conv2d_%d' %i
            else:
                conv_layer_name = 'conv2d'
                
            if j > 0:
                bn_layer_name = 'batch_normalization_%d' %j
            else:
                bn_layer_name = 'batch_normalization'
            
            conv_layer = model.get_layer(conv_layer_name)
            filters = conv_layer.filters
            k_size = conv_layer.kernel_size[0]
            in_dim = conv_layer.input_shape[-1]

            if i not in [58, 66, 74]:
                # darknet weights: [beta, gamma, mean, variance]
                bn_weights = np.fromfile(wf, dtype=np.float32, count=4 * filters)
                # tf weights: [gamma, beta, mean, variance]
                bn_weights = bn_weights.reshape((4, filters))[[1, 0, 2, 3]]
                bn_layer = model.get_layer(bn_layer_name)
                j += 1
            else:
                conv_bias = np.fromfile(wf, dtype=np.float32, count=filters)

            # darknet shape (out_dim, in_dim, height, width)
            conv_shape = (filters, in_dim, k_size, k_size)
            conv_weights = np.fromfile(wf, dtype=np.float32, count=np.product(conv_shape))
            # tf shape (height, width, in_dim, out_dim)
            conv_weights = conv_weights.reshape(conv_shape).transpose([2, 3, 1, 0])

            if i not in [58, 66, 74]:
                conv_layer.set_weights([conv_weights])
                bn_layer.set_weights(bn_weights)
            else:
                conv_layer.set_weights([conv_weights, conv_bias])

# %%
def read_class_names(class_file_name):
    # loads class name from a file
    #print(class_file_name)
    names = {}
    with open(class_file_name, 'r') as data:
        for ID, name in enumerate(data):
            names[ID] = name.strip('\n')
    return names

# %%
TRAIN_ANNOT_PATH
# Out:
# './helmet_data/train.txt'

# %%
read_class_names(TRAIN_ANNOT_PATH)
# Out:
# {0: './helmet_data/train/helmet_img_0.png 143,32,263,213,1',
#  1: './helmet_data/train/helmet_img_1.png 127,18,232,213,1',
#  2: './helmet_data/train/helmet_img_10.png 73,5,284,314,1',
#  3: './helmet_data/train/helmet_img_100.png 203,62,254,121,0',
#  4: './helmet_data/train/helmet_img_1000.png 301,131,325,177,0 215,138,232,168,0',
#  5: './helmet_data/train/helmet_img_1002.png 185,109,236,182,1 117,60,150,120,1 136,11,169,66,1',
#  6: './helmet_data/train/helmet_img_1003.png 208,60,252,131,1 118,96,141,125,1',
#  7: './helmet_data/train/helmet_img_1005.png 180,39,227,113,0 229,44,273,98,0',
#  8: './helmet_data/train/helmet_img_1009.png 173,110,211,168,1 280,74,328,148,1',
#  9: './helmet_data/train/helmet_img_1011.png 44,57,98,150,1 143,43,214,153,1 262,0,347,132,1',
#  10: './helmet_data/train/helmet_img_1012.png 162,8,266,191,1',
#  11: './helmet_data/train/helmet_img_1013.png 101,3,176,115,1',
#  12: './helmet_data/train/helmet_img_1014.png 217,7,289,86,1 107,26,183,98,1',
#  13: './helmet_data/train/helmet_img_1015.png 183,56,304,251,1',
#  14: './helmet_data/train/helmet_img_1020.png 146,0,223,109,1',
#  15: './helmet_data/train/helmet_img_1021.png 193,22,240,95,1',
#  16: './helmet_data/train/helmet_img_1023.png 212,3,314,79,1',
#  17: './helmet_data/train/helmet_img_1024.png 180,33,260,124,0',
#  18: './helmet_data/train/helmet_img_1025.png 132,39,195,131,1 206,46,244,113,1 284,0,335,78,0',
#  19: './helmet_data/train/helmet_img_1027.png 130,17,182,106,1',
#  20: './helmet_data/train/helmet_img_1028.png 152,107,248,256,1',
#  21: './helmet_data/train/helmet_img_1029.png 63,83,148,180,1 197,193,269,290,1 283,2,351,108,1',
#  22: './helmet_data/train/helmet_img_103.png 143,2,260,235,0',
#  23: './helmet_data/train/helmet_img_1030.png 113,123,165,204,1 225,39,282,133,1',
#  24: './helmet_data/train/helmet_img_1032.png 94,62,170,162,1 189,88,251,175,1',
#  25: './helmet_data/train/helmet_img_1034.png 197,33,310,176,0',
#  26: './helmet_data/train/helmet_img_1037.png 204,86,247,143,0 238,151,269,199,0',
#  27: './helmet_data/train/helmet_img_1039.png 198,55,241,123,1',
#  28: './helmet_data/train/helmet_img_104.png 170,27,296,278,0',
#  29: './helmet_data/train/helmet_img_1040.png 121,1,180,91,0',
#  30: './helmet_data/train/helmet_img_1041.png 94,88,131,164,1 193,57,226,121,1 307,42,336,99,1',
#  31: './helmet_data/train/helmet_img_1044.png 352,46,390,108,0 204,63,234,117,0 317,57,346,104,1',
#  32: './helmet_data/train/helmet_img_1046.png 192,3,263,138,1',
#  33: './helmet_data/train/helmet_img_1047.png 198,24,254,98,0 257,14,313,88,0 309,13,357,89,0',
#  34: './helmet_data/train/helmet_img_1048.png 373,18,403,161,0 247,18,277,157,0 312,0,340,29,0 215,75,238,159,0 20,34,62,144,1 312,81,342,173,1',
#  35: './helmet_data/train/helmet_img_1049.png 141,0,201,72,1',
#  36: './helmet_data/train/helmet_img_1050.png 160,42,234,118,1 241,27,292,72,1 295,143,373,229,1 254,128,307,189,1',
#  37: './helmet_data/train/helmet_img_1053.png 45,26,91,87,1 117,40,164,99,1 184,56,229,126,1',
#  38: './helmet_data/train/helmet_img_1054.png 242,62,296,132,1',
#  39: './helmet_data/train/helmet_img_1055.png 306,140,342,190,1 250,157,283,201,1 180,143,218,192,1',
#  40: './helmet_data/train/helmet_img_1057.png 15,107,48,179,1 99,68,143,156,1 154,79,193,162,1 252,49,295,152,1 325,55,377,169,1',
#  41: './helmet_data/train/helmet_img_1059.png 218,13,278,94,1 280,4,338,79,1',
#  42: './helmet_data/train/helmet_img_106.png 290,44,416,266,0',
#  43: './helmet_data/train/helmet_img_1060.png 163,68,299,255,1',
#  44: './helmet_data/train/helmet_img_1061.png 82,19,167,163,1 251,3,332,156,1',
#  45: './helmet_data/train/helmet_img_1062.png 156,48,252,171,1',
#  46: './helmet_data/train/helmet_img_1063.png 317,75,355,123,1 171,75,204,135,1 99,93,134,144,1',
#  47: './helmet_data/train/helmet_img_1064.png 198,26,353,111,1 238,39,286,117,1 198,44,242,102,1',
#  48: './helmet_data/train/helmet_img_1065.png 164,8,219,82,1 349,67,380,110,1',
#  49: './helmet_data/train/helmet_img_1066.png 62,156,91,196,0 235,161,257,190,0',
#  50: './helmet_data/train/helmet_img_1068.png 52,56,89,111,1 87,56,125,114,1 174,29,217,95,1 349,10,404,98,1',
#  51: './helmet_data/train/helmet_img_1069.png 173,0,219,83,1',
#  52: './helmet_data/train/helmet_img_107.png 225,3,328,95,0',
#  53: './helmet_data/train/helmet_img_1070.png 254,14,316,87,1',
#  54: './helmet_data/train/helmet_img_1071.png 48,61,89,157,1 152,52,201,150,1 273,0,334,121,1 83,33,138,99,1',
#  55: './helmet_data/train/helmet_img_1072.png 179,48,229,117,1',
#  56: './helmet_data/train/helmet_img_1073.png 197,18,267,119,1',
#  57: './helmet_data/train/helmet_img_1076.png 104,26,210,130,0',
#  58: './helmet_data/train/helmet_img_1077.png 213,26,266,104,1 265,7,304,65,1',
#  59: './helmet_data/train/helmet_img_1078.png 173,3,229,104,1',
#  60: './helmet_data/train/helmet_img_108.png 132,10,179,74,0',
#  61: './helmet_data/train/helmet_img_1080.png 125,60,182,115,1 237,52,300,106,1',
#  62: './helmet_data/train/helmet_img_1081.png 273,23,301,69,1 179,19,210,74,1 126,57,152,92,1 353,184,404,256,0 195,145,224,192,0 85,137,117,182,1',
#  63: './helmet_data/train/helmet_img_1083.png 115,84,204,182,1',
#  64: './helmet_data/train/helmet_img_1085.png 157,17,236,105,1',
#  65: './helmet_data/train/helmet_img_1087.png 222,13,274,93,1 283,1,336,83,1',
#  66: './helmet_data/train/helmet_img_1089.png 148,26,185,87,0 105,100,143,160,0',
#  67: './helmet_data/train/helmet_img_1090.png 255,0,384,130,1',
#  68: './helmet_data/train/helmet_img_1094.png 121,0,219,109,1',
#  69: './helmet_data/train/helmet_img_1095.png 136,33,198,86,1 299,4,380,91,1',
#  70: './helmet_data/train/helmet_img_1096.png 171,0,223,81,1',
#  71: './helmet_data/train/helmet_img_11.png 100,23,263,299,1',
#  72: './helmet_data/train/helmet_img_110.png 208,7,263,72,0',
#  73: './helmet_data/train/helmet_img_1100.png 260,20,362,167,1 195,43,276,156,1',
#  74: './helmet_data/train/helmet_img_1101.png 185,91,329,152,1 278,73,329,154,1',
#  75: './helmet_data/train/helmet_img_1104.png 351,45,393,105,0 176,47,208,105,0 208,60,239,117,0 110,74,138,121,0',
#  76: './helmet_data/train/helmet_img_1106.png 140,99,206,166,1 286,66,353,133,1',
#  77: './helmet_data/train/helmet_img_1107.png 247,13,314,82,1 173,22,212,71,1',
#  78: './helmet_data/train/helmet_img_1108.png 197,97,231,145,0 223,80,258,131,0',
#  79: './helmet_data/train/helmet_img_1111.png 40,49,169,211,1 221,47,357,210,1',
#  80: './helmet_data/train/helmet_img_1113.png 108,53,203,175,1 300,162,361,238,1',
#  81: './helmet_data/train/helmet_img_1114.png 134,9,215,99,1 78,13,138,88,1',
#  82: './helmet_data/train/helmet_img_1115.png 156,53,190,107,0 303,46,334,104,0 29,112,70,160,0',
#  83: './helmet_data/train/helmet_img_1117.png 191,2,269,154,1',
#  84: './helmet_data/train/helmet_img_1118.png 145,76,213,141,1',
#  85: './helmet_data/train/helmet_img_1120.png 104,93,271,332,1',
#  86: './helmet_data/train/helmet_img_1121.png 167,70,237,132,1',
#  87: './helmet_data/train/helmet_img_1124.png 286,123,364,205,0',
#  88: './helmet_data/train/helmet_img_1125.png 262,130,386,247,0',
#  89: './helmet_data/train/helmet_img_1126.png 166,67,247,148,0',
#  90: './helmet_data/train/helmet_img_1128.png 65,18,149,88,0',
#  91: './helmet_data/train/helmet_img_1129.png 53,65,234,242,0',
#  92: './helmet_data/train/helmet_img_1130.png 94,6,218,89,0',
#  93: './helmet_data/train/helmet_img_1131.png 176,11,286,94,0',
#  94: './helmet_data/train/helmet_img_1132.png 197,15,307,101,0',
#  95: './helmet_data/train/helmet_img_1137.png 165,81,248,151,0',
#  96: './helmet_data/train/helmet_img_1139.png 104,98,310,260,0',
#  97: './helmet_data/train/helmet_img_1142.png 138,107,358,286,0',
#  98: './helmet_data/train/helmet_img_1143.png 154,108,354,283,0',
#  99: './helmet_data/train/helmet_img_115.png 182,91,217,146,0',
#  100: './helmet_data/train/helmet_img_1151.png 111,139,237,240,0',
#  101: './helmet_data/train/helmet_img_1153.png 94,81,284,242,0',
#  102: './helmet_data/train/helmet_img_1154.png 84,85,198,183,0',
#  103: './helmet_data/train/helmet_img_1159.png 130,188,241,297,0',
#  104: './helmet_data/train/helmet_img_116.png 206,39,252,87,0',
#  105: './helmet_data/train/helmet_img_1160.png 107,130,212,234,0',
#  106: './helmet_data/train/helmet_img_1161.png 78,136,204,247,0',
#  107: './helmet_data/train/helmet_img_1162.png 65,124,198,255,0',
#  108: './helmet_data/train/helmet_img_1163.png 59,117,214,276,0',
#  109: './helmet_data/train/helmet_img_1167.png 176,74,386,257,0',
#  110: './helmet_data/train/helmet_img_1168.png 136,152,371,349,0',
#  111: './helmet_data/train/helmet_img_1169.png 156,117,365,317,0',
#  112: './helmet_data/train/helmet_img_117.png 195,8,252,75,0',
#  113: './helmet_data/train/helmet_img_1170.png 243,100,300,153,0',
#  114: './helmet_data/train/helmet_img_1173.png 133,108,312,292,0',
#  115: './helmet_data/train/helmet_img_1175.png 23,47,265,293,0',
#  116: './helmet_data/train/helmet_img_1176.png 27,96,216,304,0',
#  117: './helmet_data/train/helmet_img_1178.png 196,130,406,342,0',
#  118: './helmet_data/train/helmet_img_1179.png 35,139,242,318,0',
#  119: './helmet_data/train/helmet_img_118.png 184,57,226,106,0',
#  120: './helmet_data/train/helmet_img_1183.png 176,195,366,367,0',
#  121: './helmet_data/train/helmet_img_1185.png 179,120,374,320,0',
#  122: './helmet_data/train/helmet_img_1186.png 32,148,225,302,0',
#  123: './helmet_data/train/helmet_img_119.png 172,21,223,81,0',
#  124: './helmet_data/train/helmet_img_1190.png 43,118,319,385,0',
#  125: './helmet_data/train/helmet_img_1191.png 102,147,377,367,0',
#  126: './helmet_data/train/helmet_img_1193.png 126,125,385,345,0',
#  127: './helmet_data/train/helmet_img_1194.png 5,147,163,302,0',
#  128: './helmet_data/train/helmet_img_1195.png 138,94,385,294,0',
#  129: './helmet_data/train/helmet_img_1196.png 208,107,408,303,0',
#  130: './helmet_data/train/helmet_img_1197.png 19,72,195,215,0',
#  131: './helmet_data/train/helmet_img_12.png 17,3,256,411,1',
#  132: './helmet_data/train/helmet_img_120.png 232,39,276,93,0',
#  133: './helmet_data/train/helmet_img_1202.png 92,163,177,231,0',
#  134: './helmet_data/train/helmet_img_1203.png 157,112,211,156,0',
#  135: './helmet_data/train/helmet_img_1205.png 83,167,179,247,0',
#  136: './helmet_data/train/helmet_img_121.png 196,17,224,61,0 234,34,253,76,0',
#  137: './helmet_data/train/helmet_img_1212.png 63,69,305,325,0',
#  138: './helmet_data/train/helmet_img_1213.png 135,133,360,341,0',
#  139: './helmet_data/train/helmet_img_1215.png 54,89,255,256,0',
#  140: './helmet_data/train/helmet_img_1217.png 50,24,355,341,0',
#  141: './helmet_data/train/helmet_img_1219.png 71,127,273,314,0',
#  142: './helmet_data/train/helmet_img_122.png 84,58,271,262,0',
#  143: './helmet_data/train/helmet_img_1221.png 171,108,400,347,0',
#  144: './helmet_data/train/helmet_img_1226.png 150,104,342,287,0',
#  145: './helmet_data/train/helmet_img_123.png 185,2,225,59,0',
#  146: './helmet_data/train/helmet_img_1230.png 1,15,282,394,0',
#  147: './helmet_data/train/helmet_img_1231.png 3,0,304,309,0',
#  148: './helmet_data/train/helmet_img_1235.png 63,47,410,345,0',
#  149: './helmet_data/train/helmet_img_1236.png 171,112,319,260,0',
#  150: './helmet_data/train/helmet_img_1239.png 22,0,378,242,0',
#  151: './helmet_data/train/helmet_img_1241.png 140,130,189,171,0',
#  152: './helmet_data/train/helmet_img_1242.png 108,133,165,175,0',
#  153: './helmet_data/train/helmet_img_1244.png 174,131,214,174,0',
#  154: './helmet_data/train/helmet_img_1246.png 166,124,212,167,0',
#  155: './helmet_data/train/helmet_img_1247.png 184,121,227,166,0',
#  156: './helmet_data/train/helmet_img_125.png 108,117,128,153,0 148,127,168,166,0',
#  157: './helmet_data/train/helmet_img_1250.png 83,80,269,273,0',
#  158: './helmet_data/train/helmet_img_1251.png 144,118,192,164,0',
#  159: './helmet_data/train/helmet_img_1253.png 180,122,226,166,0',
#  160: './helmet_data/train/helmet_img_1254.png 169,124,215,165,0',
#  161: './helmet_data/train/helmet_img_1256.png 152,121,196,162,0',
#  162: './helmet_data/train/helmet_img_1257.png 153,112,218,163,0',
#  163: './helmet_data/train/helmet_img_1259.png 180,109,240,171,0',
#  164: './helmet_data/train/helmet_img_1264.png 165,102,267,195,0',
#  165: './helmet_data/train/helmet_img_1267.png 171,111,261,203,0',
#  166: './helmet_data/train/helmet_img_1268.png 157,144,244,240,0',
#  167: './helmet_data/train/helmet_img_127.png 208,11,241,73,0',
#  168: './helmet_data/train/helmet_img_1270.png 130,163,235,257,0',
#  169: './helmet_data/train/helmet_img_1271.png 258,109,377,234,0',
#  170: './helmet_data/train/helmet_img_1273.png 140,182,226,265,0',
#  171: './helmet_data/train/helmet_img_1274.png 169,151,260,228,0',
#  172: './helmet_data/train/helmet_img_1275.png 196,177,271,251,0',
#  173: './helmet_data/train/helmet_img_1278.png 191,94,293,196,0',
#  174: './helmet_data/train/helmet_img_128.png 152,49,208,95,0',
#  175: './helmet_data/train/helmet_img_1280.png 222,40,353,184,0',
#  176: './helmet_data/train/helmet_img_1281.png 202,7,390,164,0',
#  177: './helmet_data/train/helmet_img_1284.png 286,60,409,197,0',
#  178: './helmet_data/train/helmet_img_1286.png 120,78,310,231,0',
#  179: './helmet_data/train/helmet_img_1288.png 67,124,202,227,0',
#  180: './helmet_data/train/helmet_img_129.png 150,2,193,59,0',
#  181: './helmet_data/train/helmet_img_1294.png 134,92,239,199,0',
#  182: './helmet_data/train/helmet_img_1295.png 96,78,188,137,0',
#  183: './helmet_data/train/helmet_img_1296.png 313,109,416,237,0',
#  184: './helmet_data/train/helmet_img_1297.png 141,81,219,141,0',
#  185: './helmet_data/train/helmet_img_1299.png 141,82,222,144,0',
#  186: './helmet_data/train/helmet_img_13.png 187,2,392,382,1',
#  187: './helmet_data/train/helmet_img_130.png 184,46,231,96,0',
#  188: './helmet_data/train/helmet_img_1302.png 193,60,274,124,0',
#  189: './helmet_data/train/helmet_img_1303.png 188,61,250,123,0',
#  190: './helmet_data/train/helmet_img_1304.png 178,70,247,128,0',
#  191: './helmet_data/train/helmet_img_1309.png 177,62,266,141,0',
#  192: './helmet_data/train/helmet_img_131.png 189,40,234,105,0',
#  193: './helmet_data/train/helmet_img_1311.png 163,105,335,230,0',
#  194: './helmet_data/train/helmet_img_1312.png 120,101,296,239,0',
#  195: './helmet_data/train/helmet_img_1313.png 130,104,295,251,0',
#  196: './helmet_data/train/helmet_img_1316.png 118,54,203,145,0',
#  197: './helmet_data/train/helmet_img_1317.png 117,143,236,245,0',
#  198: './helmet_data/train/helmet_img_1318.png 93,52,294,219,0',
#  199: './helmet_data/train/helmet_img_1319.png 99,93,217,189,0',
#  200: './helmet_data/train/helmet_img_1325.png 209,102,287,165,0',
#  201: './helmet_data/train/helmet_img_1326.png 188,43,288,115,0',
#  202: './helmet_data/train/helmet_img_1327.png 78,169,119,216,0 276,134,358,199,0',
#  203: './helmet_data/train/helmet_img_1328.png 110,165,152,210,0 262,133,356,198,0',
#  204: './helmet_data/train/helmet_img_1333.png 159,234,227,304,0 223,130,290,200,0',
#  205: './helmet_data/train/helmet_img_1334.png 141,228,215,288,0 215,137,286,202,0',
#  206: './helmet_data/train/helmet_img_1337.png 106,158,186,234,0 238,148,331,222,0',
#  207: './helmet_data/train/helmet_img_1340.png 130,168,171,213,0 307,107,369,174,0',
#  208: './helmet_data/train/helmet_img_1341.png 204,185,260,248,0 309,147,369,214,0',
#  209: './helmet_data/train/helmet_img_1343.png 91,174,161,240,0 239,147,329,213,0',
#  210: './helmet_data/train/helmet_img_1345.png 109,154,170,223,0 343,130,411,211,0',
#  211: './helmet_data/train/helmet_img_1346.png 151,160,214,227,0',
#  212: './helmet_data/train/helmet_img_135.png 72,75,108,113,0 130,75,169,132,0',
#  213: './helmet_data/train/helmet_img_1350.png 153,199,202,260,0 333,190,409,255,0',
#  214: './helmet_data/train/helmet_img_1353.png 33,210,102,276,0 213,199,290,255,0',
#  215: './helmet_data/train/helmet_img_1354.png 2,206,69,268,0 208,202,267,261,0',
#  216: './helmet_data/train/helmet_img_1356.png 53,193,127,258,0 263,195,325,254,0',
#  217: './helmet_data/train/helmet_img_1357.png 108,177,165,242,0 299,169,364,229,0',
#  218: './helmet_data/train/helmet_img_1358.png 40,159,106,223,0 261,165,334,229,0',
#  219: './helmet_data/train/helmet_img_1359.png 81,162,134,224,0 276,160,340,218,0',
#  220: './helmet_data/train/helmet_img_1362.png 80,133,130,176,0 230,136,307,192,0',
#  221: './helmet_data/train/helmet_img_1363.png 52,168,102,235,0 293,190,372,253,0',
#  222: './helmet_data/train/helmet_img_1367.png 66,173,130,225,0 269,153,351,222,0',
#  223: './helmet_data/train/helmet_img_1370.png 104,145,167,208,0 257,127,331,203,0',
#  224: './helmet_data/train/helmet_img_1372.png 110,151,162,208,0 270,124,365,185,0',
#  225: './helmet_data/train/helmet_img_1373.png 78,139,130,179,0 247,131,308,184,0',
#  226: './helmet_data/train/helmet_img_1375.png 113,145,166,200,0 270,186,354,257,0 310,121,360,170,0',
#  227: './helmet_data/train/helmet_img_1376.png 106,138,169,202,0 312,115,358,177,0 344,171,407,240,0',
#  228: './helmet_data/train/helmet_img_1377.png 32,138,99,199,0 235,117,287,189,0 294,176,362,229,0',
#  229: './helmet_data/train/helmet_img_1380.png 85,102,143,159,0 277,81,326,152,0 371,133,416,175,0',
#  230: './helmet_data/train/helmet_img_1382.png 113,122,163,166,0 251,101,294,151,0',
#  231: './helmet_data/train/helmet_img_1384.png 97,135,137,183,0 263,86,329,160,0',
#  232: './helmet_data/train/helmet_img_1387.png 84,165,128,198,0 173,174,209,210,0 219,171,244,202,0 276,156,325,189,0',
#  233: './helmet_data/train/helmet_img_1390.png 76,170,118,204,0 174,188,203,226,0 212,184,242,214,0 296,158,341,199,0',
#  234: './helmet_data/train/helmet_img_1394.png 63,167,102,205,0 131,234,168,276,0 204,189,240,221,0 280,162,343,198,0',
#  235: './helmet_data/train/helmet_img_1396.png 60,168,95,201,0 139,229,176,273,0 201,190,235,222,0 318,159,373,206,0',
#  236: './helmet_data/train/helmet_img_1397.png 70,169,110,208,0 136,214,178,264,0 211,193,245,224,0 302,160,362,215,0',
#  237: './helmet_data/train/helmet_img_1399.png 69,188,108,232,0 185,189,227,221,0 288,172,349,215,0',
#  238: './helmet_data/train/helmet_img_14.png 29,164,84,247,1 130,102,195,231,1 212,72,249,150,1 323,31,384,144,1',
#  239: './helmet_data/train/helmet_img_1400.png 83,206,128,248,0 179,193,221,228,0 313,170,369,227,0',
#  240: './helmet_data/train/helmet_img_1401.png 83,205,130,253,0 171,198,214,226,0 325,178,377,227,0',
#  241: './helmet_data/train/helmet_img_1406.png 9,157,52,197,0 109,173,144,218,0 211,175,256,208,0 327,144,382,199,0',
#  242: './helmet_data/train/helmet_img_1408.png 49,148,105,198,0 177,166,214,206,0 317,164,359,202,0',
#  243: './helmet_data/train/helmet_img_1411.png 227,91,255,126,0 228,209,263,239,0',
#  244: './helmet_data/train/helmet_img_1412.png 84,208,122,240,0 198,208,236,239,0',
#  245: './helmet_data/train/helmet_img_1416.png 107,169,132,193,0 255,171,279,196,0 387,141,416,184,0',
#  246: './helmet_data/train/helmet_img_142.png 114,98,190,228,0 202,100,280,234,0',
#  247: './helmet_data/train/helmet_img_1421.png 40,182,82,212,0 167,187,200,208,0 290,159,335,193,0',
#  248: './helmet_data/train/helmet_img_1424.png 76,156,115,196,0 244,120,306,173,0',
#  249: './helmet_data/train/helmet_img_1425.png 99,208,126,237,0 211,202,245,229,0 306,182,359,218,0',
#  250: './helmet_data/train/helmet_img_1427.png 106,212,136,240,0 250,221,278,247,0 310,200,359,237,0',
#  251: './helmet_data/train/helmet_img_143.png 161,105,200,174,0 244,84,286,162,0',
#  252: './helmet_data/train/helmet_img_1430.png 81,208,114,235,0 247,206,273,232,0 294,180,339,224,0',
#  253: './helmet_data/train/helmet_img_1434.png 5,211,42,238,0 133,214,162,240,0 244,196,290,237,0',
#  254: './helmet_data/train/helmet_img_1435.png 121,166,162,210,0 260,130,356,195,0',
#  255: './helmet_data/train/helmet_img_1438.png 93,192,122,223,0 173,193,217,234,0 351,187,395,230,0',
#  256: './helmet_data/train/helmet_img_144.png 130,32,266,179,0',
#  257: './helmet_data/train/helmet_img_1440.png 381,175,416,216,0 27,219,57,255,0',
#  258: './helmet_data/train/helmet_img_1442.png 182,198,215,230,0',
#  259: './helmet_data/train/helmet_img_1443.png 266,196,293,228,0',
#  260: './helmet_data/train/helmet_img_1445.png 221,195,262,234,0',
#  261: './helmet_data/train/helmet_img_1448.png 294,180,336,219,0',
#  262: './helmet_data/train/helmet_img_1450.png 302,186,347,229,0',
#  263: './helmet_data/train/helmet_img_1451.png 240,173,273,208,0 131,156,168,195,0',
#  264: './helmet_data/train/helmet_img_1455.png 109,172,143,210,0',
#  265: './helmet_data/train/helmet_img_1456.png 122,176,153,210,0 257,197,289,228,0',
#  266: './helmet_data/train/helmet_img_1458.png 30,161,78,208,0 266,174,314,221,0',
#  267: './helmet_data/train/helmet_img_1461.png 145,133,199,195,0',
#  268: './helmet_data/train/helmet_img_1462.png 91,143,143,201,0 340,161,394,213,0',
#  269: './helmet_data/train/helmet_img_1465.png 2,138,52,189,0',
#  270: './helmet_data/train/helmet_img_1467.png 39,187,72,228,0',
#  271: './helmet_data/train/helmet_img_1468.png 35,190,68,236,0 314,213,352,250,0',
#  272: './helmet_data/train/helmet_img_1469.png 117,182,143,208,0 255,160,293,204,0',
#  273: './helmet_data/train/helmet_img_1470.png 307,195,346,231,0',
#  274: './helmet_data/train/helmet_img_1472.png 74,154,110,201,0 271,179,306,214,0',
#  275: './helmet_data/train/helmet_img_1474.png 226,177,263,216,0',
#  276: './helmet_data/train/helmet_img_1475.png 43,154,87,199,0 247,182,286,221,0',
#  277: './helmet_data/train/helmet_img_1476.png 196,209,243,251,0',
#  278: './helmet_data/train/helmet_img_1477.png 11,179,55,224,0 242,208,286,250,0',
#  279: './helmet_data/train/helmet_img_1480.png 13,165,56,208,0',
#  280: './helmet_data/train/helmet_img_1482.png 52,149,110,208,0 264,172,308,213,0',
#  281: './helmet_data/train/helmet_img_1484.png 14,115,67,175,0',
#  282: './helmet_data/train/helmet_img_1485.png 0,110,36,173,0',
#  283: './helmet_data/train/helmet_img_1486.png 69,131,126,196,0',
#  284: './helmet_data/train/helmet_img_1487.png 133,161,198,229,0',
#  285: './helmet_data/train/helmet_img_1488.png 339,184,392,234,0 15,163,78,231,0',
#  286: './helmet_data/train/helmet_img_1489.png 123,162,177,219,0',
#  287: './helmet_data/train/helmet_img_1492.png 271,169,312,209,0',
#  288: './helmet_data/train/helmet_img_1494.png 295,167,341,209,0 43,143,91,184,0',
#  289: './helmet_data/train/helmet_img_1495.png 130,192,153,218,0 279,166,313,204,0',
#  290: './helmet_data/train/helmet_img_1499.png 342,176,387,221,0',
#  291: './helmet_data/train/helmet_img_15.png 80,26,110,82,1 168,15,202,76,1 262,60,290,122,1',
#  292: './helmet_data/train/helmet_img_1501.png 89,152,143,213,0 323,199,369,242,0',
#  293: './helmet_data/train/helmet_img_1504.png 97,156,143,210,0 327,189,371,232,0',
#  294: './helmet_data/train/helmet_img_1505.png 26,153,69,203,0 315,184,362,230,0',
#  295: './helmet_data/train/helmet_img_1507.png 296,186,340,228,0',
#  296: './helmet_data/train/helmet_img_1509.png 297,199,335,234,0 11,190,47,234,0',
#  297: './helmet_data/train/helmet_img_1510.png 107,158,151,208,0 273,122,338,184,0',
#  298: './helmet_data/train/helmet_img_1513.png 230,183,263,214,0',
#  299: './helmet_data/train/helmet_img_1514.png 213,187,249,216,0',
#  300: './helmet_data/train/helmet_img_1517.png 226,206,262,241,0',
#  301: './helmet_data/train/helmet_img_1523.png 80,132,106,163,0',
#  302: './helmet_data/train/helmet_img_1527.png 192,133,219,167,0',
#  303: './helmet_data/train/helmet_img_1529.png 351,152,379,182,0',
#  304: './helmet_data/train/helmet_img_153.png 179,0,228,55,0',
#  305: './helmet_data/train/helmet_img_1530.png 105,195,133,225,0 221,170,269,210,0',
#  306: './helmet_data/train/helmet_img_1532.png 42,160,76,204,0',
#  307: './helmet_data/train/helmet_img_1533.png 28,160,56,195,0 269,163,295,190,0',
#  308: './helmet_data/train/helmet_img_1535.png 36,160,65,193,0 279,167,306,193,0',
#  309: './helmet_data/train/helmet_img_1539.png 42,193,71,226,0 170,174,216,217,0',
#  310: './helmet_data/train/helmet_img_1540.png 156,154,191,201,0',
#  311: './helmet_data/train/helmet_img_1541.png 99,152,133,197,0',
#  312: './helmet_data/train/helmet_img_1542.png 34,154,73,206,0',
#  313: './helmet_data/train/helmet_img_1545.png 152,147,183,188,0 275,170,307,208,0',
#  314: './helmet_data/train/helmet_img_1546.png 40,192,72,223,0 177,173,229,215,0',
#  315: './helmet_data/train/helmet_img_1547.png 128,132,179,191,0 297,160,347,211,0',
#  316: './helmet_data/train/helmet_img_1549.png 337,170,403,236,0',
#  317: './helmet_data/train/helmet_img_155.png 214,110,260,151,0',
#  318: './helmet_data/train/helmet_img_1553.png 52,165,110,224,0 320,189,353,227,0',
#  319: './helmet_data/train/helmet_img_1554.png 65,163,123,223,0 312,188,348,227,0',
#  320: './helmet_data/train/helmet_img_1555.png 61,190,89,221,0 203,191,256,237,0',
#  321: './helmet_data/train/helmet_img_1559.png 91,156,157,221,0 269,179,303,212,0',
#  322: './helmet_data/train/helmet_img_156.png 174,2,243,60,0',
#  323: './helmet_data/train/helmet_img_1561.png 229,145,227,221,0 229,169,267,208,0',
#  324: './helmet_data/train/helmet_img_1565.png 43,120,101,192,0',
#  325: './helmet_data/train/helmet_img_1568.png 219,102,253,134,0',
#  326: './helmet_data/train/helmet_img_1569.png 54,68,131,149,0 216,91,255,127,0',
#  327: './helmet_data/train/helmet_img_157.png 212,7,251,69,0',
#  328: './helmet_data/train/helmet_img_1570.png 63,67,130,145,0 197,97,234,133,0',
#  329: './helmet_data/train/helmet_img_1572.png 136,69,205,139,0 336,98,381,139,0',
#  330: './helmet_data/train/helmet_img_1573.png 316,127,362,168,0',
#  331: './helmet_data/train/helmet_img_1576.png 99,191,130,225,0 217,172,269,209,0',
#  332: './helmet_data/train/helmet_img_1577.png 214,24,290,100,0',
#  333: './helmet_data/train/helmet_img_158.png 179,104,221,157,0',
#  334: './helmet_data/train/helmet_img_1580.png 111,191,144,221,0 203,172,262,208,0',
#  335: './helmet_data/train/helmet_img_1581.png 291,135,349,184,0',
#  336: './helmet_data/train/helmet_img_1582.png 291,130,342,176,0 152,151,206,195,0',
#  337: './helmet_data/train/helmet_img_1584.png 161,146,206,190,0 288,132,339,179,0',
#  338: './helmet_data/train/helmet_img_1586.png 119,144,157,190,0 275,131,334,184,0',
#  339: './helmet_data/train/helmet_img_1587.png 114,147,153,185,0',
#  340: './helmet_data/train/helmet_img_159.png 249,23,292,97,0 329,13,377,71,0',
#  341: './helmet_data/train/helmet_img_1591.png 137,172,165,199,0 263,153,303,188,0',
#  342: './helmet_data/train/helmet_img_1595.png 132,163,170,208,0 332,151,387,203,0',
#  343: './helmet_data/train/helmet_img_1597.png 91,162,137,202,0 225,149,280,201,0',
#  344: './helmet_data/train/helmet_img_16.png 120,67,227,267,1',
#  345: './helmet_data/train/helmet_img_160.png 88,79,209,289,0 211,52,352,262,0',
#  346: './helmet_data/train/helmet_img_1600.png 171,195,205,234,0',
#  347: './helmet_data/train/helmet_img_161.png 123,45,203,179,0 216,43,296,187,0',
#  348: './helmet_data/train/helmet_img_1611.png 75,135,123,182,0 186,128,230,170,0',
#  349: './helmet_data/train/helmet_img_1612.png 65,131,115,178,0 189,131,225,168,0',
#  350: './helmet_data/train/helmet_img_1614.png 55,127,104,172,0 208,117,260,165,0',
#  351: './helmet_data/train/helmet_img_1615.png 169,111,214,159,0',
#  352: './helmet_data/train/helmet_img_1616.png 13,119,55,162,0 262,86,315,139,0',
#  353: './helmet_data/train/helmet_img_1617.png 47,114,92,163,0',
#  354: './helmet_data/train/helmet_img_1619.png 144,174,179,203,0 235,158,284,189,0',
#  355: './helmet_data/train/helmet_img_162.png 267,7,316,65,0',
#  356: './helmet_data/train/helmet_img_1623.png 0,106,39,161,0',
#  357: './helmet_data/train/helmet_img_1625.png 83,123,132,171,0',
#  358: './helmet_data/train/helmet_img_163.png 257,2,295,101,0',
#  359: './helmet_data/train/helmet_img_1633.png 131,115,189,172,0',
#  360: './helmet_data/train/helmet_img_1635.png 108,139,172,187,0',
#  361: './helmet_data/train/helmet_img_1637.png 118,141,176,195,0',
#  362: './helmet_data/train/helmet_img_165.png 153,71,214,119,0',
#  363: './helmet_data/train/helmet_img_1650.png 31,114,83,157,0 153,117,206,159,0',
#  364: './helmet_data/train/helmet_img_1652.png 149,119,195,166,0 208,114,260,161,0',
#  365: './helmet_data/train/helmet_img_1653.png 205,120,254,167,0 269,114,328,164,0',
#  366: './helmet_data/train/helmet_img_1654.png 204,105,247,156,0 297,98,351,152,0',
#  367: './helmet_data/train/helmet_img_1655.png 189,110,236,154,0 296,97,351,145,0',
#  368: './helmet_data/train/helmet_img_1656.png 278,98,336,151,0 163,109,204,158,0',
#  369: './helmet_data/train/helmet_img_1657.png 134,111,176,158,0',
#  370: './helmet_data/train/helmet_img_1659.png 209,98,274,154,0',
#  371: './helmet_data/train/helmet_img_166.png 50,4,125,175,0',
#  372: './helmet_data/train/helmet_img_1667.png 88,105,136,143,0 227,88,277,140,0',
#  373: './helmet_data/train/helmet_img_1670.png 80,95,127,140,0 205,93,269,147,0',
#  374: './helmet_data/train/helmet_img_1671.png 130,97,173,141,0 221,97,283,151,0',
#  375: './helmet_data/train/helmet_img_1672.png 157,99,199,141,0 257,94,319,153,0',
#  376: './helmet_data/train/helmet_img_1673.png 153,96,199,140,0 237,99,299,149,0',
#  377: './helmet_data/train/helmet_img_1674.png 94,94,143,136,0 166,98,229,150,0',
#  378: './helmet_data/train/helmet_img_1675.png 57,94,91,135,0 126,95,187,151,0',
#  379: './helmet_data/train/helmet_img_1677.png 40,93,88,141,0 208,93,273,152,0',
#  380: './helmet_data/train/helmet_img_1678.png 78,95,120,139,0 281,86,339,147,0',
#  381: './helmet_data/train/helmet_img_1679.png 131,93,182,143,0',
#  382: './helmet_data/train/helmet_img_168.png 243,30,282,107,0',
#  383: './helmet_data/train/helmet_img_1680.png 117,94,163,146,0',
#  384: './helmet_data/train/helmet_img_1683.png 69,99,120,156,0',
#  385: './helmet_data/train/helmet_img_1684.png 16,98,75,153,0 195,82,261,143,0',
#  386: './helmet_data/train/helmet_img_1685.png 21,100,72,158,0 143,83,204,139,0',
#  387: './helmet_data/train/helmet_img_1686.png 72,104,121,158,0 183,98,239,156,0',
#  388: './helmet_data/train/helmet_img_1689.png 109,97,156,159,0 234,185,294,239,0',
#  389: './helmet_data/train/helmet_img_1691.png 102,104,152,163,0 265,78,315,128,0',
#  390: './helmet_data/train/helmet_img_1692.png 106,110,156,167,0 288,93,349,147,0',
#  391: './helmet_data/train/helmet_img_1699.png 136,99,196,156,0 241,91,300,151,0',
#  392: './helmet_data/train/helmet_img_17.png 30,30,195,401,1',
#  393: './helmet_data/train/helmet_img_1701.png 61,106,126,165,0 195,95,253,152,0',
#  394: './helmet_data/train/helmet_img_1703.png 93,113,157,172,0 281,109,351,169,0',
#  395: './helmet_data/train/helmet_img_1704.png 98,120,165,187,0 328,91,406,168,0',
#  396: './helmet_data/train/helmet_img_1705.png 102,117,169,180,0 351,91,416,160,0',
#  397: './helmet_data/train/helmet_img_1706.png 146,117,206,178,0 357,88,414,160,0',
#  398: './helmet_data/train/helmet_img_1707.png 146,107,208,161,0 270,84,340,161,0',
#  399: './helmet_data/train/helmet_img_1708.png 166,88,240,151,0',
#  400: './helmet_data/train/helmet_img_1710.png 179,175,217,208,0 277,162,329,198,0',
#  401: './helmet_data/train/helmet_img_1712.png 143,72,200,123,0',
#  402: './helmet_data/train/helmet_img_1713.png 124,69,182,127,0',
#  403: './helmet_data/train/helmet_img_1716.png 269,72,342,136,0',
#  404: './helmet_data/train/helmet_img_1717.png 316,76,385,137,0',
#  405: './helmet_data/train/helmet_img_1723.png 267,114,320,168,0',
#  406: './helmet_data/train/helmet_img_1725.png 274,123,331,177,0 13,128,78,189,0',
#  407: './helmet_data/train/helmet_img_1726.png 50,130,115,191,0 289,114,351,170,0',
#  408: './helmet_data/train/helmet_img_1727.png 82,130,139,180,0 330,113,380,172,0',
#  409: './helmet_data/train/helmet_img_1728.png 329,114,377,162,0',
#  410: './helmet_data/train/helmet_img_1730.png 42,120,99,169,0 274,113,319,160,0',
#  411: './helmet_data/train/helmet_img_1733.png 256,104,297,150,0',
#  412: './helmet_data/train/helmet_img_1735.png 167,105,223,154,0',
#  413: './helmet_data/train/helmet_img_1736.png 162,107,210,156,0',
#  414: './helmet_data/train/helmet_img_1739.png 193,158,225,190,0 273,153,313,189,0',
#  415: './helmet_data/train/helmet_img_174.png 210,0,266,49,0',
#  416: './helmet_data/train/helmet_img_1745.png 151,78,216,146,0 320,85,392,165,0',
#  417: './helmet_data/train/helmet_img_1746.png 244,62,309,136,0',
#  418: './helmet_data/train/helmet_img_1747.png 355,44,410,119,0',
#  419: './helmet_data/train/helmet_img_1751.png 193,158,226,189,0 260,157,288,187,0',
#  420: './helmet_data/train/helmet_img_1752.png 182,158,210,187,0 256,143,284,180,0',
#  421: './helmet_data/train/helmet_img_1753.png 177,159,206,188,0 250,144,284,179,0',
#  422: './helmet_data/train/helmet_img_1754.png 176,163,205,192,0 238,144,269,186,0',
#  423: './helmet_data/train/helmet_img_1755.png 124,148,159,190,0 198,132,262,182,0',
#  424: './helmet_data/train/helmet_img_1756.png 162,149,211,188,0 268,130,304,177,0',
#  425: './helmet_data/train/helmet_img_1758.png 104,124,172,190,0 274,89,338,158,0',
#  426: './helmet_data/train/helmet_img_1759.png 92,122,172,196,0 287,85,367,168,0',
#  427: './helmet_data/train/helmet_img_1760.png 63,125,113,189,0 276,91,344,163,0',
#  428: './helmet_data/train/helmet_img_1762.png 119,131,171,208,0 296,110,361,178,0',
#  429: './helmet_data/train/helmet_img_1763.png 48,174,109,250,0 247,140,314,223,0',
#  430: './helmet_data/train/helmet_img_1764.png 23,174,89,251,0 234,132,317,228,0',
#  431: './helmet_data/train/helmet_img_1765.png 65,163,130,238,0 266,130,335,221,0',
#  432: './helmet_data/train/helmet_img_1767.png 39,159,105,230,0 253,120,331,209,0',
#  433: './helmet_data/train/helmet_img_1768.png 21,158,98,231,0 288,121,359,208,0',
#  434: './helmet_data/train/helmet_img_177.png 182,3,222,58,0',
#  435: './helmet_data/train/helmet_img_1770.png 69,156,121,223,0 245,128,309,208,0',
#  436: './helmet_data/train/helmet_img_1772.png 81,97,143,168,0 269,65,339,143,0',
#  437: './helmet_data/train/helmet_img_1773.png 87,140,130,183,0 226,108,301,173,0',
#  438: './helmet_data/train/helmet_img_1774.png 89,107,151,177,0 247,83,329,173,0',
#  439: './helmet_data/train/helmet_img_1775.png 91,117,151,202,0 223,106,292,180,0',
#  440: './helmet_data/train/helmet_img_1776.png 91,118,152,184,0 210,91,289,162,0',
#  441: './helmet_data/train/helmet_img_1777.png 143,159,209,237,0 212,99,299,171,0',
#  442: './helmet_data/train/helmet_img_1781.png 247,101,320,179,0 276,205,347,280,0',
#  443: './helmet_data/train/helmet_img_1784.png 143,130,255,240,1',
#  444: './helmet_data/train/helmet_img_1785.png 125,140,212,249,1',
#  445: './helmet_data/train/helmet_img_1787.png 99,193,186,278,1',
#  446: './helmet_data/train/helmet_img_1788.png 187,179,271,273,1',
#  447: './helmet_data/train/helmet_img_1789.png 167,172,253,261,1',
#  448: './helmet_data/train/helmet_img_179.png 188,23,249,91,0',
#  449: './helmet_data/train/helmet_img_1793.png 172,159,275,257,1',
#  450: './helmet_data/train/helmet_img_18.png 174,48,295,297,1',
#  451: './helmet_data/train/helmet_img_1803.png 89,192,172,275,1',
#  452: './helmet_data/train/helmet_img_1809.png 234,179,351,320,1',
#  453: './helmet_data/train/helmet_img_1810.png 242,176,360,301,1',
#  454: './helmet_data/train/helmet_img_1819.png 192,143,277,256,1',
#  455: './helmet_data/train/helmet_img_182.png 124,93,167,138,0',
#  456: './helmet_data/train/helmet_img_1827.png 101,187,192,277,1',
#  457: './helmet_data/train/helmet_img_1839.png 94,182,188,281,1',
#  458: './helmet_data/train/helmet_img_184.png 230,63,262,119,0',
#  459: './helmet_data/train/helmet_img_1851.png 119,169,196,255,1',
#  460: './helmet_data/train/helmet_img_1864.png 98,151,192,247,1',
#  461: './helmet_data/train/helmet_img_187.png 239,39,288,102,0',
#  462: './helmet_data/train/helmet_img_1876.png 140,185,221,267,1',
#  463: './helmet_data/train/helmet_img_1877.png 137,184,211,273,1',
#  464: './helmet_data/train/helmet_img_1878.png 126,201,195,300,1',
#  465: './helmet_data/train/helmet_img_1881.png 135,209,215,283,1',
#  466: './helmet_data/train/helmet_img_1882.png 136,213,225,293,1',
#  467: './helmet_data/train/helmet_img_1883.png 190,209,282,294,1',
#  468: './helmet_data/train/helmet_img_1884.png 206,219,303,309,1',
#  469: './helmet_data/train/helmet_img_1887.png 224,221,326,313,1',
#  470: './helmet_data/train/helmet_img_1888.png 223,227,325,322,1',
#  471: './helmet_data/train/helmet_img_189.png 153,9,197,65,0',
#  472: './helmet_data/train/helmet_img_1896.png 196,151,275,253,1',
#  473: './helmet_data/train/helmet_img_1898.png 133,199,219,315,1',
#  474: './helmet_data/train/helmet_img_19.png 22,2,270,370,1',
#  475: './helmet_data/train/helmet_img_1900.png 78,145,131,190,1',
#  476: './helmet_data/train/helmet_img_1901.png 106,131,161,186,1',
#  477: './helmet_data/train/helmet_img_1903.png 75,126,131,184,1',
#  478: './helmet_data/train/helmet_img_1905.png 107,126,163,187,1',
#  479: './helmet_data/train/helmet_img_1906.png 136,122,198,187,1',
#  480: './helmet_data/train/helmet_img_191.png 205,0,255,62,0',
#  481: './helmet_data/train/helmet_img_1910.png 82,204,176,295,1',
#  482: './helmet_data/train/helmet_img_1911.png 83,106,164,183,1',
#  483: './helmet_data/train/helmet_img_1912.png 123,117,190,182,1',
#  484: './helmet_data/train/helmet_img_1913.png 76,140,125,195,1',
#  485: './helmet_data/train/helmet_img_1914.png 80,147,125,200,1',
#  486: './helmet_data/train/helmet_img_1920.png 121,204,206,299,1',
#  487: './helmet_data/train/helmet_img_1932.png 138,200,221,294,1',
#  488: './helmet_data/train/helmet_img_1941.png 146,134,242,240,1',
#  489: './helmet_data/train/helmet_img_1944.png 106,214,185,299,1',
#  490: './helmet_data/train/helmet_img_1956.png 67,221,138,294,1',
#  491: './helmet_data/train/helmet_img_1969.png 172,187,221,231,0',
#  492: './helmet_data/train/helmet_img_197.png 149,14,292,140,0',
#  493: './helmet_data/train/helmet_img_1971.png 126,187,199,260,1',
#  494: './helmet_data/train/helmet_img_1973.png 249,132,322,202,0',
#  495: './helmet_data/train/helmet_img_1981.png 145,70,172,100,1',
#  496: './helmet_data/train/helmet_img_1984.png 139,65,177,106,1',
#  497: './helmet_data/train/helmet_img_1986.png 160,71,198,101,1',
#  498: './helmet_data/train/helmet_img_1987.png 153,67,193,107,1',
#  499: './helmet_data/train/helmet_img_1988.png 131,132,168,171,1',
#  500: './helmet_data/train/helmet_img_1989.png 120,143,164,191,1',
#  501: './helmet_data/train/helmet_img_199.png 74,7,125,63,0',
#  502: './helmet_data/train/helmet_img_1990.png 57,132,113,198,1',
#  503: './helmet_data/train/helmet_img_1991.png 49,113,106,184,1',
#  504: './helmet_data/train/helmet_img_1994.png 19,119,89,198,1',
#  505: './helmet_data/train/helmet_img_1995.png 35,117,108,204,1',
#  506: './helmet_data/train/helmet_img_1997.png 75,125,174,240,1',
#  507: './helmet_data/train/helmet_img_1998.png 31,122,130,241,1',
#  508: './helmet_data/train/helmet_img_1999.png 3,120,108,234,1',
#  509: './helmet_data/train/helmet_img_20.png 63,0,315,354,1',
#  510: './helmet_data/train/helmet_img_200.png 110,31,184,147,1 263,7,332,117,1',
#  511: './helmet_data/train/helmet_img_2000.png 0,98,88,208,1',
#  512: './helmet_data/train/helmet_img_2001.png 35,97,118,191,1',
#  513: './helmet_data/train/helmet_img_2003.png 2,126,81,213,1',
#  514: './helmet_data/train/helmet_img_2004.png 302,130,357,192,0',
#  515: './helmet_data/train/helmet_img_2005.png 53,144,137,230,1',
#  516: './helmet_data/train/helmet_img_2006.png 118,137,201,221,1',
#  517: './helmet_data/train/helmet_img_2009.png 102,136,201,232,1',
#  518: './helmet_data/train/helmet_img_201.png 73,60,120,159,1 265,41,310,140,1',
#  519: './helmet_data/train/helmet_img_2011.png 174,170,262,263,1',
#  520: './helmet_data/train/helmet_img_2012.png 188,176,265,255,1',
#  521: './helmet_data/train/helmet_img_2017.png 331,151,374,201,0',
#  522: './helmet_data/train/helmet_img_202.png 119,127,315,286,1',
#  523: './helmet_data/train/helmet_img_203.png 76,8,133,101,1 174,52,209,121,1 265,84,299,152,1 306,118,330,162,1 340,143,362,182,1 374,159,393,193,1',
#  524: './helmet_data/train/helmet_img_2038.png 4,143,152,296,1',
#  525: './helmet_data/train/helmet_img_2039.png 61,143,168,264,1',
#  526: './helmet_data/train/helmet_img_204.png 289,0,271,69,1 289,8,335,137,1',
#  527: './helmet_data/train/helmet_img_2040.png 50,186,144,296,1',
#  528: './helmet_data/train/helmet_img_2043.png 56,205,148,306,1',
#  529: './helmet_data/train/helmet_img_2044.png 88,172,187,268,1',
#  530: './helmet_data/train/helmet_img_2046.png 146,112,241,224,1',
#  531: './helmet_data/train/helmet_img_2049.png 138,178,237,284,1',
#  532: './helmet_data/train/helmet_img_205.png 54,0,127,74,1 234,35,274,174,1 349,150,382,209,1',
#  533: './helmet_data/train/helmet_img_206.png 140,23,252,127,1',
#  534: './helmet_data/train/helmet_img_207.png 115,22,308,299,1',
#  535: './helmet_data/train/helmet_img_2073.png 248,117,344,223,0',
#  536: './helmet_data/train/helmet_img_2076.png 144,63,294,247,0',
#  537: './helmet_data/train/helmet_img_2077.png 175,0,386,257,0',
#  538: './helmet_data/train/helmet_img_2078.png 140,183,198,252,1',
#  539: './helmet_data/train/helmet_img_208.png 87,26,275,321,1',
#  540: './helmet_data/train/helmet_img_2081.png 215,172,321,299,1',
#  541: './helmet_data/train/helmet_img_2082.png 187,114,312,260,1',
#  542: './helmet_data/train/helmet_img_2083.png 119,102,255,247,1',
#  543: './helmet_data/train/helmet_img_2084.png 112,121,240,263,1',
#  544: './helmet_data/train/helmet_img_2086.png 20,146,173,308,1',
#  545: './helmet_data/train/helmet_img_209.png 85,170,136,211,1 182,184,224,222,1 312,195,349,232,1',
#  546: './helmet_data/train/helmet_img_2092.png 192,168,229,213,0',
#  547: './helmet_data/train/helmet_img_2097.png 18,190,66,235,1',
#  548: './helmet_data/train/helmet_img_2098.png 101,178,148,223,1',
#  549: './helmet_data/train/helmet_img_21.png 32,0,119,157,1 157,0,238,152,1 280,5,362,152,1 54,185,150,371,1',
#  550: './helmet_data/train/helmet_img_210.png 121,37,164,104,1',
#  551: './helmet_data/train/helmet_img_2103.png 203,154,248,202,1',
#  552: './helmet_data/train/helmet_img_2105.png 179,154,236,215,1',
#  553: './helmet_data/train/helmet_img_2106.png 158,157,218,222,1',
#  554: './helmet_data/train/helmet_img_2108.png 133,161,185,221,1',
#  555: './helmet_data/train/helmet_img_2109.png 92,157,156,225,1',
#  556: './helmet_data/train/helmet_img_211.png 150,200,175,234,1 229,190,251,221,1',
#  557: './helmet_data/train/helmet_img_2111.png 135,154,197,217,1',
#  558: './helmet_data/train/helmet_img_2112.png 156,178,208,239,1',
#  559: './helmet_data/train/helmet_img_2113.png 140,165,208,234,1',
#  560: './helmet_data/train/helmet_img_2114.png 145,161,218,237,1',
#  561: './helmet_data/train/helmet_img_2115.png 143,149,225,242,1',
#  562: './helmet_data/train/helmet_img_2116.png 162,231,236,315,1',
#  563: './helmet_data/train/helmet_img_212.png 121,47,168,110,1',
#  564: './helmet_data/train/helmet_img_2120.png 252,230,313,301,1',
#  565: './helmet_data/train/helmet_img_2121.png 214,202,270,275,1',
#  566: './helmet_data/train/helmet_img_2122.png 195,226,249,291,1',
#  567: './helmet_data/train/helmet_img_2123.png 208,219,270,289,1',
#  568: './helmet_data/train/helmet_img_2124.png 187,214,256,291,1',
#  569: './helmet_data/train/helmet_img_2125.png 151,182,201,241,1',
#  570: './helmet_data/train/helmet_img_2126.png 187,197,260,277,1',
#  571: './helmet_data/train/helmet_img_2127.png 212,177,283,250,1',
#  572: './helmet_data/train/helmet_img_2128.png 200,175,270,252,1',
#  573: './helmet_data/train/helmet_img_213.png 73,91,117,124,1 198,84,274,149,1',
#  574: './helmet_data/train/helmet_img_2131.png 163,183,237,265,1',
#  575: './helmet_data/train/helmet_img_2132.png 185,186,256,267,1',
#  576: './helmet_data/train/helmet_img_2133.png 154,190,221,269,1',
#  577: './helmet_data/train/helmet_img_2134.png 158,190,223,265,1',
#  578: './helmet_data/train/helmet_img_2135.png 201,188,268,273,1',
#  579: './helmet_data/train/helmet_img_2137.png 108,184,160,250,1',
#  580: './helmet_data/train/helmet_img_2138.png 355,184,416,265,1',
#  581: './helmet_data/train/helmet_img_214.png 185,89,221,143,1',
#  582: './helmet_data/train/helmet_img_2140.png 241,183,303,252,1',
#  583: './helmet_data/train/helmet_img_2142.png 199,168,258,234,1',
#  584: './helmet_data/train/helmet_img_2143.png 196,184,245,241,1',
#  585: './helmet_data/train/helmet_img_2144.png 196,177,251,237,1',
#  586: './helmet_data/train/helmet_img_2146.png 143,164,196,230,1',
#  587: './helmet_data/train/helmet_img_2147.png 148,170,206,240,1',
#  588: './helmet_data/train/helmet_img_2148.png 188,158,247,234,1',
#  589: './helmet_data/train/helmet_img_2149.png 86,183,148,247,1',
#  590: './helmet_data/train/helmet_img_215.png 88,29,224,82,1 359,39,394,97,1 312,195,331,239,1 239,195,260,232,1 224,221,244,267,1 4,193,131,229,1 78,205,101,237,1 27,245,53,289,1 0,168,26,208,1',
#  591: './helmet_data/train/helmet_img_2150.png 137,164,206,239,1',
#  592: './helmet_data/train/helmet_img_2151.png 92,197,172,284,1',
#  593: './helmet_data/train/helmet_img_2153.png 138,199,216,289,1',
#  594: './helmet_data/train/helmet_img_2154.png 147,213,234,308,1',
#  595: './helmet_data/train/helmet_img_2155.png 158,224,241,321,1',
#  596: './helmet_data/train/helmet_img_2156.png 198,98,274,195,1',
#  597: './helmet_data/train/helmet_img_2159.png 97,189,167,273,1',
#  598: './helmet_data/train/helmet_img_216.png 169,108,229,164,1',
#  599: './helmet_data/train/helmet_img_2160.png 223,79,279,152,1',
#  600: './helmet_data/train/helmet_img_2161.png 218,110,276,182,1',
#  601: './helmet_data/train/helmet_img_2162.png 241,125,305,200,1',
#  602: './helmet_data/train/helmet_img_2164.png 232,156,291,229,1',
#  603: './helmet_data/train/helmet_img_2165.png 218,177,283,257,1',
#  604: './helmet_data/train/helmet_img_2166.png 208,196,273,273,1',
#  605: './helmet_data/train/helmet_img_2167.png 198,202,256,273,1',
#  606: './helmet_data/train/helmet_img_217.png 170,4,236,87,1',
#  607: './helmet_data/train/helmet_img_2170.png 173,203,234,281,1',
#  608: './helmet_data/train/helmet_img_2171.png 119,123,258,261,1',
#  609: './helmet_data/train/helmet_img_2172.png 106,95,221,223,1',
#  610: './helmet_data/train/helmet_img_2175.png 128,126,208,222,1',
#  611: './helmet_data/train/helmet_img_2176.png 123,123,205,211,1',
#  612: './helmet_data/train/helmet_img_2179.png 167,147,243,234,1',
#  613: './helmet_data/train/helmet_img_218.png 250,9,299,73,1',
#  614: './helmet_data/train/helmet_img_2181.png 178,136,274,230,1',
#  615: './helmet_data/train/helmet_img_2182.png 193,134,289,234,1',
#  616: './helmet_data/train/helmet_img_2183.png 163,137,262,241,1',
#  617: './helmet_data/train/helmet_img_2185.png 112,117,209,225,1',
#  618: './helmet_data/train/helmet_img_2186.png 137,150,215,241,1',
#  619: './helmet_data/train/helmet_img_2187.png 132,148,218,241,1',
#  620: './helmet_data/train/helmet_img_2188.png 107,138,195,237,1',
#  621: './helmet_data/train/helmet_img_2189.png 108,132,188,226,1',
#  622: './helmet_data/train/helmet_img_219.png 267,42,325,121,1',
#  623: './helmet_data/train/helmet_img_2190.png 153,125,242,219,1',
#  624: './helmet_data/train/helmet_img_2191.png 159,111,255,213,1',
#  625: './helmet_data/train/helmet_img_2192.png 150,153,245,257,1',
#  626: './helmet_data/train/helmet_img_2193.png 115,173,219,284,1',
#  627: './helmet_data/train/helmet_img_2194.png 84,157,198,275,1',
#  628: './helmet_data/train/helmet_img_2197.png 168,148,244,234,1',
#  629: './helmet_data/train/helmet_img_2198.png 127,157,204,250,1',
#  630: './helmet_data/train/helmet_img_2199.png 136,167,208,254,1',
#  631: './helmet_data/train/helmet_img_22.png 74,41,282,214,1',
#  632: './helmet_data/train/helmet_img_220.png 65,26,104,110,1 286,45,330,110,1',
#  633: './helmet_data/train/helmet_img_2200.png 82,187,156,271,1',
#  634: './helmet_data/train/helmet_img_2201.png 48,179,138,277,1',
#  635: './helmet_data/train/helmet_img_2204.png 152,121,267,250,1',
#  636: './helmet_data/train/helmet_img_2208.png 166,105,337,306,1',
#  637: './helmet_data/train/helmet_img_2209.png 182,125,358,312,1',
#  638: './helmet_data/train/helmet_img_2210.png 177,134,279,244,1',
#  639: './helmet_data/train/helmet_img_2211.png 160,146,264,254,1',
#  640: './helmet_data/train/helmet_img_2212.png 140,165,218,268,1',
#  641: './helmet_data/train/helmet_img_2213.png 139,202,216,288,1',
#  642: './helmet_data/train/helmet_img_2214.png 161,199,223,273,1',
#  643: './helmet_data/train/helmet_img_2215.png 210,121,270,202,0',
#  644: './helmet_data/train/helmet_img_2216.png 171,200,221,264,1',
#  645: './helmet_data/train/helmet_img_2217.png 158,182,213,243,1',
#  646: './helmet_data/train/helmet_img_2219.png 159,167,211,221,1',
#  647: './helmet_data/train/helmet_img_2220.png 174,180,214,229,1',
#  648: './helmet_data/train/helmet_img_2222.png 199,183,244,230,1',
#  649: './helmet_data/train/helmet_img_223.png 192,124,249,212,1 247,98,291,164,1 315,37,366,104,1',
#  650: './helmet_data/train/helmet_img_224.png 63,0,258,274,1',
# ...
#  839: './helmet_data/train/helmet_img_257.png 97,0,247,187,1',
#  840: './helmet_data/train/helmet_img_2570.png 23,149,87,209,0 131,130,192,194,0 217,75,314,208,1',
#  841: './helmet_data/train/helmet_img_2576.png 104,198,154,258,0 205,197,251,247,0 321,171,373,224,0',
#  842: './helmet_data/train/helmet_img_2577.png 38,164,102,238,0 169,143,218,224,0 208,67,329,240,1',
#  843: './helmet_data/train/helmet_img_2581.png 61,203,101,252,0 156,173,203,230,0 190,100,296,257,1',
#  844: './helmet_data/train/helmet_img_2582.png 92,182,136,237,0 187,160,237,225,0 223,90,327,249,1',
#  845: './helmet_data/train/helmet_img_2585.png 0,130,56,198,0 43,133,150,200,0 197,113,249,184,0 256,36,392,229,1',
#  846: './helmet_data/train/helmet_img_2587.png 71,212,127,273,0 173,213,227,266,0 296,190,347,243,0',
#  847: './helmet_data/train/helmet_img_2588.png 24,84,86,197,0 135,110,208,171,0 203,8,333,201,1',
#  848: './helmet_data/train/helmet_img_259.png 137,8,337,289,1 26,8,182,265,1',
#  849: './helmet_data/train/helmet_img_2591.png 15,166,69,229,0 110,166,165,240,0 205,138,254,203,0 249,41,359,210,1',
#  850: './helmet_data/train/helmet_img_2592.png 9,161,63,228,0 116,158,172,216,0 197,64,301,204,1',
#  851: './helmet_data/train/helmet_img_2594.png 138,37,227,186,1',
#  852: './helmet_data/train/helmet_img_2595.png 96,19,174,175,1',
#  853: './helmet_data/train/helmet_img_2598.png 69,224,123,281,0 187,192,234,249,0 286,141,374,251,1',
#  854: './helmet_data/train/helmet_img_26.png 93,48,309,235,1',
#  855: './helmet_data/train/helmet_img_2601.png 25,203,82,279,0 176,180,229,250,0 225,69,350,270,1',
#  856: './helmet_data/train/helmet_img_2613.png 94,71,253,309,1',
#  857: './helmet_data/train/helmet_img_2614.png 3,64,132,307,1',
#  858: './helmet_data/train/helmet_img_2615.png 239,61,380,272,1 99,157,164,239,0 0,201,62,268,0',
#  859: './helmet_data/train/helmet_img_2616.png 134,145,203,229,0 32,181,87,258,0 300,85,416,305,1',
#  860: './helmet_data/train/helmet_img_2620.png 29,188,104,266,0 158,146,249,231,0 312,89,416,288,1',
#  861: './helmet_data/train/helmet_img_2626.png 145,101,216,201,0 5,149,57,227,0 232,15,376,242,1',
#  862: './helmet_data/train/helmet_img_2629.png 257,130,322,215,1 132,177,190,236,0 56,182,114,244,0',
#  863: './helmet_data/train/helmet_img_263.png 26,163,109,260,1',
#  864: './helmet_data/train/helmet_img_2637.png 207,89,327,229,1 136,140,212,231,0 18,188,90,255,0',
#  865: './helmet_data/train/helmet_img_264.png 107,19,147,95,1',
#  866: './helmet_data/train/helmet_img_2640.png 266,114,381,245,1 168,164,248,237,0 59,205,127,275,0',
#  867: './helmet_data/train/helmet_img_2641.png 10,213,72,275,0 145,188,199,252,0 190,151,291,251,1',
#  868: './helmet_data/train/helmet_img_2643.png 240,91,346,227,1 166,132,239,214,0 42,182,111,248,0',
#  869: './helmet_data/train/helmet_img_2645.png 14,163,77,225,0 153,119,219,201,0 225,82,321,198,1',
#  870: './helmet_data/train/helmet_img_2651.png 32,140,99,230,0 201,111,253,175,0 264,77,346,184,1',
#  871: './helmet_data/train/helmet_img_2653.png 71,150,135,226,0 140,145,196,210,0 290,70,372,178,1',
#  872: './helmet_data/train/helmet_img_2655.png 21,161,87,242,0 100,160,148,222,0 195,130,261,204,0 252,104,353,212,1',
#  873: './helmet_data/train/helmet_img_2657.png 21,164,82,240,0 112,111,162,225,0 215,111,296,213,1',
#  874: './helmet_data/train/helmet_img_2658.png 52,147,108,232,0 112,160,161,221,0 179,127,248,195,0 250,101,328,207,1',
#  875: './helmet_data/train/helmet_img_2659.png 42,153,95,231,0 109,152,162,216,0 187,123,249,190,0 244,100,327,202,1',
#  876: './helmet_data/train/helmet_img_2661.png 6,146,67,224,0 62,144,115,203,0 143,114,206,186,0 239,91,324,186,1',
#  877: './helmet_data/train/helmet_img_2662.png 32,157,89,238,0 99,157,145,216,0 193,126,250,192,0 259,104,340,201,1',
#  878: './helmet_data/train/helmet_img_2664.png 256,98,326,194,1 192,126,256,190,0 104,157,151,216,0 34,157,99,237,0',
#  879: './helmet_data/train/helmet_img_2665.png 47,162,115,240,0 108,149,153,225,0 182,123,249,196,0 281,110,371,203,1',
#  880: './helmet_data/train/helmet_img_2669.png 75,162,137,248,0 127,164,182,234,0 225,138,280,203,0 305,97,396,196,1',
#  881: './helmet_data/train/helmet_img_267.png 135,3,228,91,1',
#  882: './helmet_data/train/helmet_img_2675.png 4,165,62,240,0 93,166,142,220,0 191,144,246,203,0 302,126,381,216,1',
#  883: './helmet_data/train/helmet_img_2679.png 40,164,99,223,0 142,135,199,194,0 224,108,306,186,1',
#  884: './helmet_data/train/helmet_img_2680.png 24,169,83,234,0 81,154,142,212,0 165,129,238,194,0 244,106,337,193,1',
#  885: './helmet_data/train/helmet_img_2681.png 82,171,140,237,0 159,169,211,217,0 241,138,305,198,0 365,110,416,203,1',
#  886: './helmet_data/train/helmet_img_2682.png 88,175,143,236,0 158,156,215,222,0 256,135,313,211,0 374,123,416,235,1',
#  887: './helmet_data/train/helmet_img_2684.png 21,205,97,279,0 112,199,184,262,0 203,173,273,245,0 337,164,416,267,1',
#  888: './helmet_data/train/helmet_img_2688.png 47,190,110,248,0 146,162,215,221,0 261,139,346,227,1',
#  889: './helmet_data/train/helmet_img_269.png 68,0,151,115,1 189,67,227,138,1 352,62,403,136,1 54,58,107,131,1',
#  890: './helmet_data/train/helmet_img_2690.png 97,170,151,221,0 11,178,68,247,0 179,143,253,198,0 262,111,355,199,1',
#  891: './helmet_data/train/helmet_img_2693.png 32,154,93,225,0 121,150,177,212,0 224,125,282,188,0 275,86,365,186,1',
#  892: './helmet_data/train/helmet_img_270.png 156,0,208,82,1',
#  893: './helmet_data/train/helmet_img_2701.png 41,125,96,191,0 137,130,211,192,0 255,111,320,171,0 332,70,416,184,1',
#  894: './helmet_data/train/helmet_img_2702.png 56,131,111,206,0 145,125,212,201,0 253,110,327,175,0 355,82,416,190,1',
#  895: './helmet_data/train/helmet_img_271.png 195,120,289,277,1',
#  896: './helmet_data/train/helmet_img_2716.png 106,154,168,210,0 201,153,247,203,0 253,125,314,185,0 312,114,379,190,1',
#  897: './helmet_data/train/helmet_img_2717.png 112,132,175,198,0 190,140,242,191,0 264,104,306,167,0 299,85,364,172,1',
#  898: './helmet_data/train/helmet_img_2719.png 109,148,169,202,0 197,139,251,201,0 264,117,316,186,0 308,93,383,174,1',
#  899: './helmet_data/train/helmet_img_272.png 14,0,260,401,1',
#  900: './helmet_data/train/helmet_img_2722.png 95,163,147,210,0 183,160,225,202,0 283,116,339,186,1',
#  901: './helmet_data/train/helmet_img_2725.png 8,157,56,217,0 117,154,163,210,0 192,125,240,182,0 240,104,302,175,1',
#  902: './helmet_data/train/helmet_img_2727.png 23,166,71,218,0 129,153,174,203,0 208,121,257,179,0 257,93,337,185,1',
#  903: './helmet_data/train/helmet_img_273.png 169,123,274,295,1',
#  904: './helmet_data/train/helmet_img_2730.png 72,158,135,216,0 155,150,208,203,0 246,121,302,185,0 301,112,372,195,1',
#  905: './helmet_data/train/helmet_img_2731.png 153,145,208,190,0 241,121,293,177,0 296,95,366,182,1',
#  906: './helmet_data/train/helmet_img_2735.png 59,175,112,234,0 135,166,187,218,0 284,115,352,190,1',
#  907: './helmet_data/train/helmet_img_274.png 44,96,89,147,1 189,96,228,151,1 309,107,348,165,1',
#  908: './helmet_data/train/helmet_img_2747.png 124,208,186,268,0 195,188,240,229,0 249,125,300,188,0 283,80,352,153,1',
#  909: './helmet_data/train/helmet_img_2748.png 117,198,179,261,0 187,179,236,225,0 242,126,298,179,0 296,73,377,160,1',
#  910: './helmet_data/train/helmet_img_2749.png 108,192,169,257,0 173,177,223,216,0 216,119,268,173,0 273,71,348,151,1',
#  911: './helmet_data/train/helmet_img_275.png 199,0,271,84,1',
#  912: './helmet_data/train/helmet_img_2755.png 117,110,156,161,0 166,119,196,156,0 247,86,288,140,0 283,75,331,145,1',
#  913: './helmet_data/train/helmet_img_276.png 279,41,327,113,1',
#  914: './helmet_data/train/helmet_img_2761.png 75,108,127,158,0 134,92,182,132,0 225,77,273,127,0 277,61,344,121,1',
#  915: './helmet_data/train/helmet_img_2762.png 28,102,80,156,0 111,93,159,135,0 193,75,243,125,0 257,70,307,126,1',
#  916: './helmet_data/train/helmet_img_2767.png 9,138,58,185,0 91,138,138,177,0 202,117,240,173,0 266,114,320,171,1',
#  917: './helmet_data/train/helmet_img_277.png 177,115,231,187,1',
#  918: './helmet_data/train/helmet_img_2772.png 10,139,51,190,0 61,145,101,186,0 168,120,214,166,0 253,112,303,162,1',
#  919: './helmet_data/train/helmet_img_2773.png 21,132,62,188,0 177,113,221,156,0 268,105,316,158,1',
#  920: './helmet_data/train/helmet_img_2775.png 42,146,83,201,0 109,145,140,190,0 189,123,236,172,0 289,110,340,169,1',
#  921: './helmet_data/train/helmet_img_2779.png 26,139,83,193,0 99,140,143,188,0 189,120,238,172,0 262,107,321,172,1',
#  922: './helmet_data/train/helmet_img_278.png 99,26,304,179,1',
#  923: './helmet_data/train/helmet_img_2780.png 19,144,71,199,0 99,146,142,191,0 179,131,236,184,0 272,125,329,194,1',
#  924: './helmet_data/train/helmet_img_2781.png 29,164,82,224,0 99,163,145,210,0 197,136,251,194,0 271,130,333,193,1',
#  925: './helmet_data/train/helmet_img_2784.png 17,147,70,205,0 95,151,137,196,0 201,127,256,188,0 288,117,353,185,1',
#  926: './helmet_data/train/helmet_img_2786.png 255,98,227,183,1 171,123,227,180,0 73,149,121,197,0',
#  927: './helmet_data/train/helmet_img_2788.png 24,127,83,186,0 118,130,162,180,0 225,114,267,169,0 309,104,383,177,1',
#  928: './helmet_data/train/helmet_img_2789.png 84,134,131,182,0 174,120,218,170,0 260,100,326,179,1',
#  929: './helmet_data/train/helmet_img_279.png 124,58,195,130,1',
#  930: './helmet_data/train/helmet_img_2798.png 39,172,93,223,0 123,167,166,214,0 229,142,287,199,0 288,133,353,202,1',
#  931: './helmet_data/train/helmet_img_28.png 208,41,333,250,1',
#  932: './helmet_data/train/helmet_img_2800.png 39,101,83,203,0 117,150,164,201,0 225,129,270,184,0 313,101,383,188,1',
#  933: './helmet_data/train/helmet_img_2801.png 67,139,112,186,0 173,121,222,174,0 260,103,329,186,1',
#  934: './helmet_data/train/helmet_img_2802.png 41,140,97,196,0 117,142,162,191,0 222,117,277,169,0 321,108,393,179,1',
#  935: './helmet_data/train/helmet_img_2803.png 0,143,45,199,0 20,144,127,190,0 197,117,244,167,0 288,91,365,179,1',
#  936: './helmet_data/train/helmet_img_2805.png 58,136,120,193,0 146,130,192,182,0 251,105,314,165,0 347,87,416,179,1',
#  937: './helmet_data/train/helmet_img_281.png 96,7,159,98,1 293,15,339,94,1',
#  938: './helmet_data/train/helmet_img_2812.png 14,147,60,198,0 87,144,143,193,0 173,111,228,177,0 306,88,386,175,1',
#  939: './helmet_data/train/helmet_img_2815.png 0,153,49,209,0 28,153,137,196,0 147,123,209,182,0 299,103,375,180,1',
#  940: './helmet_data/train/helmet_img_2816.png 4,146,47,196,0 81,100,125,195,0 145,119,206,185,0 282,100,362,190,1',
#  941: './helmet_data/train/helmet_img_2817.png 2,139,46,194,0 65,136,111,185,0 137,110,195,172,0 286,88,351,173,1',
#  942: './helmet_data/train/helmet_img_282.png 119,76,163,143,1',
#  943: './helmet_data/train/helmet_img_2821.png 10,132,58,186,0 69,132,117,185,0 150,102,207,157,0 290,84,362,166,1',
#  944: './helmet_data/train/helmet_img_2824.png 36,159,96,218,0 103,158,150,217,0 196,133,256,196,0 334,113,408,195,1',
#  945: './helmet_data/train/helmet_img_2827.png 26,182,70,232,0 92,182,135,231,0 206,151,257,202,0 297,133,374,218,1',
#  946: './helmet_data/train/helmet_img_2830.png 13,204,57,257,0 75,194,125,245,0 199,173,249,224,0 259,151,322,221,1',
#  947: './helmet_data/train/helmet_img_2832.png 296,131,355,212,1 238,154,284,202,0 122,179,179,229,0 47,184,95,236,0',
#  948: './helmet_data/train/helmet_img_2833.png 49,174,108,219,0 140,164,175,216,0 223,147,273,199,0 272,119,335,192,1',
#  949: './helmet_data/train/helmet_img_2834.png 37,151,101,213,0 121,153,182,203,0 199,126,259,186,0 262,119,329,197,1',
#  950: './helmet_data/train/helmet_img_2836.png 42,166,93,217,0 134,143,174,185,0 170,116,236,198,1',
#  951: './helmet_data/train/helmet_img_284.png 179,39,236,108,1',
#  952: './helmet_data/train/helmet_img_2844.png 83,166,130,227,0 156,169,208,222,0 236,151,296,208,0 289,127,370,211,1',
#  953: './helmet_data/train/helmet_img_2845.png 75,165,125,223,0 156,163,211,223,0 244,148,295,207,0 296,132,370,209,1',
#  954: './helmet_data/train/helmet_img_2849.png 13,104,64,169,0 96,107,145,173,0 184,93,237,160,0 290,89,375,179,1',
#  955: './helmet_data/train/helmet_img_2855.png 9,175,60,239,0 84,167,140,225,0 190,136,249,203,0 297,123,377,208,1',
#  956: './helmet_data/train/helmet_img_2857.png 67,175,123,234,0 171,146,225,211,0 249,126,329,216,1',
#  957: './helmet_data/train/helmet_img_2858.png 58,175,122,236,0 171,148,225,210,0 267,135,334,210,1',
#  958: './helmet_data/train/helmet_img_2859.png 26,177,89,240,0 138,152,199,217,0 241,132,319,217,1',
#  959: './helmet_data/train/helmet_img_286.png 125,0,267,152,1',
#  960: './helmet_data/train/helmet_img_2860.png 2,173,60,245,0 108,149,169,216,0 220,130,289,210,1',
#  961: './helmet_data/train/helmet_img_2868.png 75,219,138,283,0 214,185,277,263,0 342,170,416,284,1',
#  962: './helmet_data/train/helmet_img_2869.png 83,204,135,262,0 196,181,254,241,0',
#  963: './helmet_data/train/helmet_img_2870.png 69,183,127,240,0 161,181,216,240,0',
#  964: './helmet_data/train/helmet_img_2871.png 110,179,165,244,0 199,174,253,235,0 307,143,374,212,0',
#  965: './helmet_data/train/helmet_img_2876.png 61,164,118,224,0 152,158,203,213,0 270,143,329,209,0 331,125,407,211,0',
#  966: './helmet_data/train/helmet_img_2877.png 62,160,122,223,0 168,162,227,221,0 364,132,416,212,0',
#  967: './helmet_data/train/helmet_img_2878.png 62,172,122,230,0 164,175,218,230,0 261,156,325,235,1',
#  968: './helmet_data/train/helmet_img_2879.png 17,170,78,233,0 131,178,186,230,0 233,156,295,230,1',
#  969: './helmet_data/train/helmet_img_288.png 138,26,232,158,1',
#  970: './helmet_data/train/helmet_img_2885.png 78,182,132,249,0 189,157,250,232,0 238,91,374,240,1',
#  971: './helmet_data/train/helmet_img_289.png 81,52,149,127,1 217,52,282,143,1 316,109,351,172,1',
#  972: './helmet_data/train/helmet_img_2890.png 214,151,268,202,1 106,172,147,216,0 39,175,80,223,0',
#  973: './helmet_data/train/helmet_img_2891.png 91,162,148,226,0 174,169,216,216,0 274,140,330,199,1',
#  974: './helmet_data/train/helmet_img_2893.png 55,159,98,205,0 117,162,169,217,0 205,140,265,198,1 345,140,403,203,0',
#  975: './helmet_data/train/helmet_img_2894.png 28,149,91,205,0 121,160,156,205,0 193,136,249,189,1 324,127,387,195,0',
#  976: './helmet_data/train/helmet_img_29.png 177,40,239,149,1',
#  977: './helmet_data/train/helmet_img_290.png 149,40,304,133,1',
#  978: './helmet_data/train/helmet_img_2901.png 54,138,104,185,0 301,119,355,185,0 170,119,227,175,1',
#  979: './helmet_data/train/helmet_img_291.png 62,61,258,340,1',
#  980: './helmet_data/train/helmet_img_2910.png 134,149,182,192,0 5,149,42,190,0 369,108,416,198,0 237,125,299,182,1',
#  981: './helmet_data/train/helmet_img_2912.png 110,143,158,185,0 322,115,393,192,0 227,126,278,188,1',
#  982: './helmet_data/train/helmet_img_2913.png 24,143,64,181,0 146,147,184,195,0 266,136,321,205,1',
#  983: './helmet_data/train/helmet_img_2914.png 132,156,178,197,0 19,148,62,188,0 233,136,290,195,1',
#  984: './helmet_data/train/helmet_img_2916.png 45,156,93,201,0 316,130,388,225,0 153,136,214,204,1',
#  985: './helmet_data/train/helmet_img_292.png 9,2,328,349,1',
#  986: './helmet_data/train/helmet_img_2921.png 6,150,54,206,0 117,127,177,184,1 328,106,399,201,0',
#  987: './helmet_data/train/helmet_img_2923.png 97,145,155,208,1',
#  988: './helmet_data/train/helmet_img_2925.png 104,121,165,190,1',
#  989: './helmet_data/train/helmet_img_293.png 81,0,316,284,1',
#  990: './helmet_data/train/helmet_img_2935.png 71,86,138,164,1',
#  991: './helmet_data/train/helmet_img_2936.png 70,107,130,182,1',
#  992: './helmet_data/train/helmet_img_2937.png 43,111,123,189,1',
#  993: './helmet_data/train/helmet_img_2938.png 39,114,124,188,1',
#  994: './helmet_data/train/helmet_img_294.png 11,56,368,300,1',
#  995: './helmet_data/train/helmet_img_2940.png 0,208,52,272,0 80,179,189,244,0 244,108,364,254,1',
#  996: './helmet_data/train/helmet_img_2950.png 142,115,202,175,1 342,123,400,192,0 10,131,43,179,0',
#  997: './helmet_data/train/helmet_img_2956.png 10,127,67,178,0 145,112,210,179,1 365,113,416,190,0',
#  998: './helmet_data/train/helmet_img_2959.png 12,127,69,186,0 361,126,416,199,0 177,114,240,178,1',
#  999: './helmet_data/train/helmet_img_296.png 54,67,316,318,1',
#  ...}

# %%
def image_preprocess(image, target_size, gt_boxes=None):
    ih, iw    = target_size
    h,  w, _  = image.shape

    scale = min(iw/w, ih/h)
    nw, nh  = int(scale * w), int(scale * h)
    image_resized = cv2.resize(image, (nw, nh))

    image_paded = np.full(shape=[ih, iw, 3], fill_value=128.0)
    dw, dh = (iw - nw) // 2, (ih-nh) // 2
    image_paded[dh:nh+dh, dw:nw+dw, :] = image_resized
    image_paded = image_paded / 255.

    if gt_boxes is None:
        return image_paded

    else:
        gt_boxes[:, [0, 2]] = gt_boxes[:, [0, 2]] * scale + dw
        gt_boxes[:, [1, 3]] = gt_boxes[:, [1, 3]] * scale + dh
        return image_paded, gt_boxes

# %%
def draw_bbox(image, bboxes, CLASSES=YOLO_COCO_CLASSES, show_label=True, show_confidence = True, Text_colors=(255,255,0), rectangle_colors=''):   
    NUM_CLASS = read_class_names(CLASSES)
    num_classes = len(NUM_CLASS)
    image_h, image_w, _ = image.shape
    hsv_tuples = [(1.0 * x / num_classes, 1., 1.) for x in range(num_classes)]
    #print("hsv_tuples", hsv_tuples)
    colors = list(map(lambda x: colorsys.hsv_to_rgb(*x), hsv_tuples))
    colors = list(map(lambda x: (int(x[0] * 255), int(x[1] * 255), int(x[2] * 255)), colors))

    random.seed(0)
    random.shuffle(colors)
    random.seed(None)

    for i, bbox in enumerate(bboxes):
        coor = np.array(bbox[:4], dtype=np.int32)
        score = bbox[4]
        class_ind = int(bbox[5])
        bbox_color = rectangle_colors if rectangle_colors != ''else colors[class_ind]
        bbox_thick = int(0.6 * (image_h + image_w) / 1000)
        if bbox_thick < 1: bbox_thick = 1
        #print(image_h, image_w, bbox_thick)
        fontScale = 1.7
        (x1, y1), (x2, y2) = (coor[0], coor[1]), (coor[2], coor[3])

        # put object rectangle
        cv2.rectangle(image, (x1, y1), (x2, y2), bbox_color, bbox_thick*2)

        if show_label:
            # get text label
            score_str = f'{score:.2f}' if show_confidence else '' 
            label = f'{NUM_CLASS[class_ind]}' + score_str

            # get text size
            (text_width, text_height), baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_COMPLEX_SMALL,
                                                                  fontScale, thickness=bbox_thick)
            # put filled text rectangle
            cv2.rectangle(image, (x1, y2), (x1 + text_width, y2 - text_height - baseline), bbox_color, thickness=cv2.FILLED)

            # put text above rectangle
            cv2.putText(image, label, (x1, y2-4), cv2.FONT_HERSHEY_COMPLEX_SMALL,
                        fontScale, Text_colors, bbox_thick, cv2.LINE_AA)

    return image

# %%
def bboxes_iou(boxes1, boxes2):
    boxes1 = np.array(boxes1)
    boxes2 = np.array(boxes2)

    boxes1_area = (boxes1[..., 2] - boxes1[..., 0]) * (boxes1[..., 3] - boxes1[..., 1])
    boxes2_area = (boxes2[..., 2] - boxes2[..., 0]) * (boxes2[..., 3] - boxes2[..., 1])

    left_up       = np.maximum(boxes1[..., :2], boxes2[..., :2])
    right_down    = np.minimum(boxes1[..., 2:], boxes2[..., 2:])

    inter_section = np.maximum(right_down - left_up, 0.0)
    inter_area    = inter_section[..., 0] * inter_section[..., 1]
    union_area    = boxes1_area + boxes2_area - inter_area
    ious          = np.maximum(1.0 * inter_area / union_area, np.finfo(np.float32).eps)

    return ious

# %%
def nms(bboxes, iou_threshold, sigma=0.3):

    classes_in_img = list(set(bboxes[:, 5]))
    best_bboxes = []

    for cls in classes_in_img:
        cls_mask = (bboxes[:, 5] == cls)
        cls_bboxes = bboxes[cls_mask]
        # Process 1: Determine whether the number of bounding boxes is greater than 0 
        while len(cls_bboxes) > 0:
            # Process 2: Select the bounding box with the highest score according to socre order A
            max_ind = np.argmax(cls_bboxes[:, 4])
            best_bbox = cls_bboxes[max_ind]
            best_bboxes.append(best_bbox)
            cls_bboxes = np.concatenate([cls_bboxes[: max_ind], cls_bboxes[max_ind + 1:]])
            # Process 3: Calculate this bounding box A and
            # Remain all iou of the bounding box and remove those bounding boxes whose iou value is higher than the threshold 
            iou = bboxes_iou(best_bbox[np.newaxis, :4], cls_bboxes[:, :4])
            weight = np.ones((len(iou),), dtype=np.float32)

            iou_mask = iou > iou_threshold
            weight[iou_mask] = 0.0

            cls_bboxes[:, 4] = cls_bboxes[:, 4] * weight
            score_mask = cls_bboxes[:, 4] > 0.
            cls_bboxes = cls_bboxes[score_mask]

    return best_bboxes

# %%
def postprocess_boxes(pred_bbox, original_image, input_size, score_threshold):
    valid_scale=[0, np.inf]
    pred_bbox = np.array(pred_bbox)

    pred_xywh = pred_bbox[:, 0:4]
    pred_conf = pred_bbox[:, 4]
    pred_prob = pred_bbox[:, 5:]

    # 1. (x, y, w, h) --> (xmin, ymin, xmax, ymax)
    pred_coor = np.concatenate([pred_xywh[:, :2] - pred_xywh[:, 2:] * 0.5,
                                pred_xywh[:, :2] + pred_xywh[:, 2:] * 0.5], axis=-1)
    # 2. (xmin, ymin, xmax, ymax) -> (xmin_org, ymin_org, xmax_org, ymax_org)
    org_h, org_w = original_image.shape[:2]
    resize_ratio = min(input_size / org_w, input_size / org_h)

    dw = (input_size - resize_ratio * org_w) / 2
    dh = (input_size - resize_ratio * org_h) / 2

    pred_coor[:, 0::2] = 1.0 * (pred_coor[:, 0::2] - dw) / resize_ratio
    pred_coor[:, 1::2] = 1.0 * (pred_coor[:, 1::2] - dh) / resize_ratio

    # 3. clip some boxes those are out of range
    pred_coor = np.concatenate([np.maximum(pred_coor[:, :2], [0, 0]),
                                np.minimum(pred_coor[:, 2:], [org_w - 1, org_h - 1])], axis=-1)
    invalid_mask = np.logical_or((pred_coor[:, 0] > pred_coor[:, 2]), (pred_coor[:, 1] > pred_coor[:, 3]))
    pred_coor[invalid_mask] = 0

    # 4. discard some invalid boxes
    bboxes_scale = np.sqrt(np.multiply.reduce(pred_coor[:, 2:4] - pred_coor[:, 0:2], axis=-1))
    scale_mask = np.logical_and((valid_scale[0] < bboxes_scale), (bboxes_scale < valid_scale[1]))

    # 5. discard boxes with low scores
    classes = np.argmax(pred_prob, axis=-1)
    scores = pred_conf * pred_prob[np.arange(len(pred_coor)), classes]
    score_mask = scores > score_threshold
    mask = np.logical_and(scale_mask, score_mask)
    coors, scores, classes = pred_coor[mask], scores[mask], classes[mask]
    #print(coors)

    #print(coors[0])
    return np.concatenate([coors, scores[:, np.newaxis], classes[:, np.newaxis]], axis=-1)

# %%
def detect_image(YoloV3, image_path, output_path, input_size=416, show=False, CLASSES=YOLO_COCO_CLASSES, score_threshold=0.5, iou_threshold=0.5, rectangle_colors=''):
    original_image      = cv2.imread(image_path)
    original_image      = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB, dst=original_image)
    # original_image      = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB, dst=original_image)

    image_data = image_preprocess(np.copy(original_image), [input_size, input_size])
    image_data = tf.expand_dims(image_data, 0)

    pred_bbox = YoloV3.predict(image_data)
    pred_bbox = [tf.reshape(x, (-1, tf.shape(x)[-1])) for x in pred_bbox]
    pred_bbox = tf.concat(pred_bbox, axis=0)
    
    bboxes = postprocess_boxes(pred_bbox, original_image, input_size, score_threshold)
    #xx=np.array(bboxes)
    #print(xx.shape)

    bboxes = nms(bboxes, iou_threshold)
    image = draw_bbox(original_image, bboxes, CLASSES=CLASSES, rectangle_colors=rectangle_colors)
    #cv2.imwrite('./output.jpg', image)
        
    return image

# %% [markdown]
# model

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Input, LeakyReLU, ZeroPadding2D, BatchNormalization
from tensorflow.keras.regularizers import l2



STRIDES         = np.array(YOLO_STRIDES)
ANCHORS         = (np.array(YOLO_ANCHORS).T/STRIDES).T
IOU_LOSS_THRESH = YOLO_IOU_LOSS_THRESH

# %%
class BatchNormalization(BatchNormalization):
    # "Frozen state" and "inference mode" are two separate concepts.
    # `layer.trainable = False` is to freeze the layer, so the layer will use
    # stored moving `var` and `mean` in the "inference mode", and both `gamma`
    # and `beta` will not be updated !
    def call(self, x, training=False):
        if not training:
            training = tf.constant(False)
        training = tf.logical_and(training, self.trainable)
        return super().call(x, training)

def convolutional(input_layer, filters_shape, downsample=False, activate=True, bn=True):
    if downsample:
        input_layer = ZeroPadding2D(((1, 0), (1, 0)))(input_layer)
        padding = 'valid'
        strides = 2
    else:
        strides = 1
        padding = 'same'

    conv = Conv2D(filters=filters_shape[-1], kernel_size = filters_shape[0], strides=strides,
                  padding=padding, use_bias=not bn, kernel_regularizer=l2(0.0005),
                  kernel_initializer=tf.random_normal_initializer(stddev=0.01),
                  bias_initializer=tf.constant_initializer(0.))(input_layer)
    if bn:
        conv = BatchNormalization()(conv)
    if activate == True:
        conv = LeakyReLU(alpha=0.1)(conv)

    return conv

def residual_block(input_layer, input_channel, filter_num1, filter_num2):
    short_cut = input_layer
    conv = convolutional(input_layer, filters_shape=(1, 1, input_channel, filter_num1))
    conv = convolutional(conv       , filters_shape=(3, 3, filter_num1,   filter_num2))

    residual_output = short_cut + conv
    return residual_output

def upsample(input_layer):
    return tf.image.resize(input_layer, (input_layer.shape[1] * 2, input_layer.shape[2] * 2), method='nearest')


def darknet53(input_data):
    input_data = convolutional(input_data, (3, 3,  3,  32))
    input_data = convolutional(input_data, (3, 3, 32,  64), downsample=True)

    for i in range(1):
        input_data = residual_block(input_data,  64,  32, 64)

    input_data = convolutional(input_data, (3, 3,  64, 128), downsample=True)

    for i in range(2):
        input_data = residual_block(input_data, 128,  64, 128)

    input_data = convolutional(input_data, (3, 3, 128, 256), downsample=True)

    for i in range(8):
        input_data = residual_block(input_data, 256, 128, 256)

    route_1 = input_data
    input_data = convolutional(input_data, (3, 3, 256, 512), downsample=True)

    for i in range(8):
        input_data = residual_block(input_data, 512, 256, 512)

    route_2 = input_data
    input_data = convolutional(input_data, (3, 3, 512, 1024), downsample=True)

    for i in range(4):
        input_data = residual_block(input_data, 1024, 512, 1024)

    return route_1, route_2, input_data

def YOLOv3(input_layer, NUM_CLASS):
    # After the input layer enters the Darknet-53 network, we get three branches
    route_1, route_2, conv = darknet53(input_layer)
    # See the orange module (DBL) in the figure above, a total of 5 Subconvolution operation
    conv = convolutional(conv, (1, 1, 1024,  512))
    conv = convolutional(conv, (3, 3,  512, 1024))
    conv = convolutional(conv, (1, 1, 1024,  512))
    conv = convolutional(conv, (3, 3,  512, 1024))
    conv = convolutional(conv, (1, 1, 1024,  512))
    conv_lobj_branch = convolutional(conv, (3, 3, 512, 1024))
    
    # conv_lbbox is used to predict large-sized objects , Shape = [None, 13, 13, 255] 
    conv_lbbox = convolutional(conv_lobj_branch, (1, 1, 1024, 3*(NUM_CLASS + 5)), activate=False, bn=False)

    conv = convolutional(conv, (1, 1,  512,  256))
    # upsample here uses the nearest neighbor interpolation method, which has the advantage that the
    # upsampling process does not need to learn, thereby reducing the network parameter  
    conv = upsample(conv)

    conv = tf.concat([conv, route_2], axis=-1)
    conv = convolutional(conv, (1, 1, 768, 256))
    conv = convolutional(conv, (3, 3, 256, 512))
    conv = convolutional(conv, (1, 1, 512, 256))
    conv = convolutional(conv, (3, 3, 256, 512))
    conv = convolutional(conv, (1, 1, 512, 256))
    conv_mobj_branch = convolutional(conv, (3, 3, 256, 512))

    # conv_mbbox is used to predict medium-sized objects, shape = [None, 26, 26, 255]
    conv_mbbox = convolutional(conv_mobj_branch, (1, 1, 512, 3*(NUM_CLASS + 5)), activate=False, bn=False)

    conv = convolutional(conv, (1, 1, 256, 128))
    conv = upsample(conv)

    conv = tf.concat([conv, route_1], axis=-1)
    conv = convolutional(conv, (1, 1, 384, 128))
    conv = convolutional(conv, (3, 3, 128, 256))
    conv = convolutional(conv, (1, 1, 256, 128))
    conv = convolutional(conv, (3, 3, 128, 256))
    conv = convolutional(conv, (1, 1, 256, 128))
    conv_sobj_branch = convolutional(conv, (3, 3, 128, 256))
    
    # conv_sbbox is used to predict small size objects, shape = [None, 52, 52, 255]
    conv_sbbox = convolutional(conv_sobj_branch, (1, 1, 256, 3*(NUM_CLASS +5)), activate=False, bn=False)
        
    return [conv_sbbox, conv_mbbox, conv_lbbox]

def Create_Yolov3(input_size=416, channels=3, training=False, CLASSES=YOLO_COCO_CLASSES):
    NUM_CLASS = len(read_class_names(CLASSES))
    input_layer  = Input([input_size, input_size, channels])

    conv_tensors = YOLOv3(input_layer, NUM_CLASS)

    output_tensors = []
    for i, conv_tensor in enumerate(conv_tensors):
        pred_tensor = decode(conv_tensor, NUM_CLASS, i)
        if training: output_tensors.append(conv_tensor)
        output_tensors.append(pred_tensor)

    YoloV3 = tf.keras.Model(input_layer, output_tensors)
    return YoloV3

def decode(conv_output, NUM_CLASS, i=0):
    # where i = 0, 1 or 2 to correspond to the three grid scales  
    conv_shape       = tf.shape(conv_output)
    batch_size       = conv_shape[0]
    output_size      = conv_shape[1]

    conv_output = tf.reshape(conv_output, (batch_size, output_size, output_size, 3, 5 + NUM_CLASS))

    conv_raw_dxdy = conv_output[:, :, :, :, 0:2] # offset of center position     
    conv_raw_dwdh = conv_output[:, :, :, :, 2:4] # Prediction box length and width offset
    conv_raw_conf = conv_output[:, :, :, :, 4:5] # confidence of the prediction box
    conv_raw_prob = conv_output[:, :, :, :, 5: ] # category probability of the prediction box 

    # next need Draw the grid. Where output_size is equal to 13, 26 or 52  
    y = tf.range(output_size, dtype=tf.int32)
    y = tf.expand_dims(y, -1)
    y = tf.tile(y, [1, output_size])
    x = tf.range(output_size,dtype=tf.int32)
    x = tf.expand_dims(x, 0)
    x = tf.tile(x, [output_size, 1])

    xy_grid = tf.concat([x[:, :, tf.newaxis], y[:, :, tf.newaxis]], axis=-1)
    xy_grid = tf.tile(xy_grid[tf.newaxis, :, :, tf.newaxis, :], [batch_size, 1, 1, 3, 1])
    xy_grid = tf.cast(xy_grid, tf.float32)

    # Calculate the center position of the prediction box:
    pred_xy = (tf.sigmoid(conv_raw_dxdy) + xy_grid) * STRIDES[i]
    # Calculate the length and width of the prediction box:
    pred_wh = (tf.exp(conv_raw_dwdh) * ANCHORS[i]) * STRIDES[i]

    pred_xywh = tf.concat([pred_xy, pred_wh], axis=-1)
    pred_conf = tf.sigmoid(conv_raw_conf) # object box calculates the predicted confidence
    pred_prob = tf.sigmoid(conv_raw_prob) # calculating the predicted probability category box object

    # calculating the predicted probability category box object
    return tf.concat([pred_xywh, pred_conf, pred_prob], axis=-1)

def bbox_iou(boxes1, boxes2):
    boxes1_area = boxes1[..., 2] * boxes1[..., 3]
    boxes2_area = boxes2[..., 2] * boxes2[..., 3]

    boxes1 = tf.concat([boxes1[..., :2] - boxes1[..., 2:] * 0.5,
                        boxes1[..., :2] + boxes1[..., 2:] * 0.5], axis=-1)
    boxes2 = tf.concat([boxes2[..., :2] - boxes2[..., 2:] * 0.5,
                        boxes2[..., :2] + boxes2[..., 2:] * 0.5], axis=-1)

    left_up = tf.maximum(boxes1[..., :2], boxes2[..., :2])
    right_down = tf.minimum(boxes1[..., 2:], boxes2[..., 2:])

    inter_section = tf.maximum(right_down - left_up, 0.0)
    inter_area = inter_section[..., 0] * inter_section[..., 1]
    union_area = boxes1_area + boxes2_area - inter_area

    return 1.0 * inter_area / union_area

def bbox_giou(boxes1, boxes2):
    boxes1 = tf.concat([boxes1[..., :2] - boxes1[..., 2:] * 0.5,
                        boxes1[..., :2] + boxes1[..., 2:] * 0.5], axis=-1)
    boxes2 = tf.concat([boxes2[..., :2] - boxes2[..., 2:] * 0.5,
                        boxes2[..., :2] + boxes2[..., 2:] * 0.5], axis=-1)

    boxes1 = tf.concat([tf.minimum(boxes1[..., :2], boxes1[..., 2:]),
                        tf.maximum(boxes1[..., :2], boxes1[..., 2:])], axis=-1)
    boxes2 = tf.concat([tf.minimum(boxes2[..., :2], boxes2[..., 2:]),
                        tf.maximum(boxes2[..., :2], boxes2[..., 2:])], axis=-1)

    boxes1_area = (boxes1[..., 2] - boxes1[..., 0]) * (boxes1[..., 3] - boxes1[..., 1])
    boxes2_area = (boxes2[..., 2] - boxes2[..., 0]) * (boxes2[..., 3] - boxes2[..., 1])

    left_up = tf.maximum(boxes1[..., :2], boxes2[..., :2])
    right_down = tf.minimum(boxes1[..., 2:], boxes2[..., 2:])

    inter_section = tf.maximum(right_down - left_up, 0.0)
    inter_area = inter_section[..., 0] * inter_section[..., 1]
    union_area = boxes1_area + boxes2_area - inter_area
    iou = inter_area / union_area

    enclose_left_up = tf.minimum(boxes1[..., :2], boxes2[..., :2])
    enclose_right_down = tf.maximum(boxes1[..., 2:], boxes2[..., 2:])
    enclose = tf.maximum(enclose_right_down - enclose_left_up, 0.0)
    enclose_area = enclose[..., 0] * enclose[..., 1]
    giou = iou - 1.0 * (enclose_area - union_area) / enclose_area

    return giou


def compute_loss(pred, conv, label, bboxes, i=0, CLASSES=YOLO_COCO_CLASSES):
    NUM_CLASS = len(read_class_names(CLASSES))
    conv_shape  = tf.shape(conv)
    batch_size  = conv_shape[0]
    output_size = conv_shape[1]
    input_size  = STRIDES[i] * output_size
    conv = tf.reshape(conv, (batch_size, output_size, output_size, 3, 5 + NUM_CLASS))

    conv_raw_conf = conv[:, :, :, :, 4:5]
    conv_raw_prob = conv[:, :, :, :, 5:]

    pred_xywh     = pred[:, :, :, :, 0:4]
    pred_conf     = pred[:, :, :, :, 4:5]

    label_xywh    = label[:, :, :, :, 0:4]
    respond_bbox  = label[:, :, :, :, 4:5]
    label_prob    = label[:, :, :, :, 5:]

    giou = tf.expand_dims(bbox_giou(pred_xywh, label_xywh), axis=-1)
    input_size = tf.cast(input_size, tf.float32)

    bbox_loss_scale = 2.0 - 1.0 * label_xywh[:, :, :, :, 2:3] * label_xywh[:, :, :, :, 3:4] / (input_size ** 2)
    giou_loss = respond_bbox * bbox_loss_scale * (1- giou)

    iou = bbox_iou(pred_xywh[:, :, :, :, np.newaxis, :], bboxes[:, np.newaxis, np.newaxis, np.newaxis, :, :])
    max_iou = tf.expand_dims(tf.reduce_max(iou, axis=-1), axis=-1)

    respond_bgd = (1.0 - respond_bbox) * tf.cast( max_iou < IOU_LOSS_THRESH, tf.float32 )

    conf_focal = tf.pow(respond_bbox - pred_conf, 2)

    conf_loss = conf_focal * (
            respond_bbox * tf.nn.sigmoid_cross_entropy_with_logits(labels=respond_bbox, logits=conv_raw_conf)
            +
            respond_bgd * tf.nn.sigmoid_cross_entropy_with_logits(labels=respond_bbox, logits=conv_raw_conf)
    )

    prob_loss = respond_bbox * tf.nn.sigmoid_cross_entropy_with_logits(labels=label_prob, logits=conv_raw_prob)

    giou_loss = tf.reduce_mean(tf.reduce_sum(giou_loss, axis=[1,2,3,4]))
    conf_loss = tf.reduce_mean(tf.reduce_sum(conf_loss, axis=[1,2,3,4]))
    prob_loss = tf.reduce_mean(tf.reduce_sum(prob_loss, axis=[1,2,3,4]))

    return giou_loss, conf_loss, prob_loss

# %% [markdown]
# dataset

# %%
import os
import cv2
import random
import numpy as np
import tensorflow as tf



class Dataset(object):
    # Dataset preprocess implementation
    def __init__(self, dataset_type):
        self.annot_path  = TRAIN_ANNOT_PATH if dataset_type == 'train' else TEST_ANNOT_PATH
        self.input_sizes = TRAIN_INPUT_SIZE if dataset_type == 'train' else TEST_INPUT_SIZE
        self.batch_size  = TRAIN_BATCH_SIZE if dataset_type == 'train' else TEST_BATCH_SIZE
        self.data_aug    = TRAIN_DATA_AUG   if dataset_type == 'train' else TEST_DATA_AUG

        self.train_input_sizes = TRAIN_INPUT_SIZE
        self.strides = np.array(YOLO_STRIDES)
        self.classes = read_class_names(TRAIN_CLASSES)
        self.num_classes = len(self.classes)
        self.anchors = (np.array(YOLO_ANCHORS).T/self.strides).T
        self.anchor_per_scale = YOLO_ANCHOR_PER_SCALE
        self.max_bbox_per_scale = YOLO_MAX_BBOX_PER_SCALE

        self.annotations = self.load_annotations(dataset_type)
        self.num_samples = len(self.annotations)
        self.num_batchs = int(np.ceil(self.num_samples / self.batch_size))
        self.batch_count = 0


    def load_annotations(self, dataset_type):
        final_annotations = []
        with open(self.annot_path, 'r') as f:
            txt = f.readlines()
            annotations = [line.strip() for line in txt if len(line.strip().split()[1:]) != 0]
        np.random.shuffle(annotations)
        
        for annotation in annotations:
            # fully parse annotations
            line = annotation.split()
            image_path, index = "", 1
            for i, one_line in enumerate(line):
                if not one_line.replace(",","").isnumeric():
                    if image_path != "": image_path += " "
                    image_path += one_line
                else:
                    index = i
                    break
            if not os.path.exists(image_path):
                raise KeyError("%s does not exist ... " %image_path)

            final_annotations.append([image_path, line[index:]])

        return final_annotations

    def __iter__(self):
        return self

    def __next__(self):
        with tf.device('/cpu:0'):
            self.train_input_size = random.choice([self.train_input_sizes])
            self.train_output_sizes = self.train_input_size // self.strides

            batch_image = np.zeros((self.batch_size, self.train_input_size, self.train_input_size, 3), dtype=np.float32)

            batch_label_sbbox = np.zeros((self.batch_size, self.train_output_sizes[0], self.train_output_sizes[0],
                                          self.anchor_per_scale, 5 + self.num_classes), dtype=np.float32)
            batch_label_mbbox = np.zeros((self.batch_size, self.train_output_sizes[1], self.train_output_sizes[1],
                                          self.anchor_per_scale, 5 + self.num_classes), dtype=np.float32)
            batch_label_lbbox = np.zeros((self.batch_size, self.train_output_sizes[2], self.train_output_sizes[2],
                                          self.anchor_per_scale, 5 + self.num_classes), dtype=np.float32)

            batch_sbboxes = np.zeros((self.batch_size, self.max_bbox_per_scale, 4), dtype=np.float32)
            batch_mbboxes = np.zeros((self.batch_size, self.max_bbox_per_scale, 4), dtype=np.float32)
            batch_lbboxes = np.zeros((self.batch_size, self.max_bbox_per_scale, 4), dtype=np.float32)

            num = 0
            if self.batch_count < self.num_batchs:
                while num < self.batch_size:
                    index = self.batch_count * self.batch_size + num
                    if index >= self.num_samples: index -= self.num_samples
                    annotation = self.annotations[index]
                    image, bboxes = self.parse_annotation(annotation)
                    label_sbbox, label_mbbox, label_lbbox, sbboxes, mbboxes, lbboxes = self.preprocess_true_boxes(bboxes)

                    batch_image[num, :, :, :] = image
                    batch_label_sbbox[num, :, :, :, :] = label_sbbox
                    batch_label_mbbox[num, :, :, :, :] = label_mbbox
                    batch_label_lbbox[num, :, :, :, :] = label_lbbox
                    batch_sbboxes[num, :, :] = sbboxes
                    batch_mbboxes[num, :, :] = mbboxes
                    batch_lbboxes[num, :, :] = lbboxes
                    num += 1
                self.batch_count += 1
                batch_smaller_target = batch_label_sbbox, batch_sbboxes
                batch_medium_target  = batch_label_mbbox, batch_mbboxes
                batch_larger_target  = batch_label_lbbox, batch_lbboxes

                return batch_image, (batch_smaller_target, batch_medium_target, batch_larger_target)
            else:
                self.batch_count = 0
                np.random.shuffle(self.annotations)
                raise StopIteration

    def random_horizontal_flip(self, image, bboxes):
        if random.random() < 0.5:
            _, w, _ = image.shape
            image = image[:, ::-1, :]
            bboxes[:, [0,2]] = w - bboxes[:, [2,0]]

        return image, bboxes

    def random_crop(self, image, bboxes):
        if random.random() < 0.5:
            h, w, _ = image.shape
            max_bbox = np.concatenate([np.min(bboxes[:, 0:2], axis=0), np.max(bboxes[:, 2:4], axis=0)], axis=-1)

            max_l_trans = max_bbox[0]
            max_u_trans = max_bbox[1]
            max_r_trans = w - max_bbox[2]
            max_d_trans = h - max_bbox[3]

            crop_xmin = max(0, int(max_bbox[0] - random.uniform(0, max_l_trans)))
            crop_ymin = max(0, int(max_bbox[1] - random.uniform(0, max_u_trans)))
            crop_xmax = max(w, int(max_bbox[2] + random.uniform(0, max_r_trans)))
            crop_ymax = max(h, int(max_bbox[3] + random.uniform(0, max_d_trans)))

            image = image[crop_ymin : crop_ymax, crop_xmin : crop_xmax]

            bboxes[:, [0, 2]] = bboxes[:, [0, 2]] - crop_xmin
            bboxes[:, [1, 3]] = bboxes[:, [1, 3]] - crop_ymin

        return image, bboxes

    def random_translate(self, image, bboxes):
        if random.random() < 0.5:
            h, w, _ = image.shape
            max_bbox = np.concatenate([np.min(bboxes[:, 0:2], axis=0), np.max(bboxes[:, 2:4], axis=0)], axis=-1)

            max_l_trans = max_bbox[0]
            max_u_trans = max_bbox[1]
            max_r_trans = w - max_bbox[2]
            max_d_trans = h - max_bbox[3]

            tx = random.uniform(-(max_l_trans - 1), (max_r_trans - 1))
            ty = random.uniform(-(max_u_trans - 1), (max_d_trans - 1))

            M = np.array([[1, 0, tx], [0, 1, ty]])
            image = cv2.warpAffine(image, M, (w, h))

            bboxes[:, [0, 2]] = bboxes[:, [0, 2]] + tx
            bboxes[:, [1, 3]] = bboxes[:, [1, 3]] + ty

        return image, bboxes

    def parse_annotation(self, annotation):

        image_path = annotation[0]
        image = cv2.imread(image_path)
            
        bboxes = np.array([list(map(int, box.split(','))) for box in annotation[1]])

        if self.data_aug:
            image, bboxes = self.random_horizontal_flip(np.copy(image), np.copy(bboxes))
            image, bboxes = self.random_crop(np.copy(image), np.copy(bboxes))
            image, bboxes = self.random_translate(np.copy(image), np.copy(bboxes))

        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image, bboxes = image_preprocess(np.copy(image), [self.train_input_size, self.train_input_size], np.copy(bboxes))
        return image, bboxes

    def preprocess_true_boxes(self, bboxes):
        label = [np.zeros((self.train_output_sizes[i], self.train_output_sizes[i], self.anchor_per_scale,
                           5 + self.num_classes)) for i in range(3)]
        bboxes_xywh = [np.zeros((self.max_bbox_per_scale, 4)) for _ in range(3)]
        bbox_count = np.zeros((3,))

        for bbox in bboxes:
            bbox_coor = bbox[:4]
            bbox_class_ind = bbox[4]

            onehot = np.zeros(self.num_classes, dtype=np.float)
            onehot[bbox_class_ind] = 1.0
            uniform_distribution = np.full(self.num_classes, 1.0 / self.num_classes)
            deta = 0.01
            smooth_onehot = onehot * (1 - deta) + deta * uniform_distribution

            bbox_xywh = np.concatenate([(bbox_coor[2:] + bbox_coor[:2]) * 0.5, bbox_coor[2:] - bbox_coor[:2]], axis=-1)
            bbox_xywh_scaled = 1.0 * bbox_xywh[np.newaxis, :] / self.strides[:, np.newaxis]

            iou = []
            exist_positive = False
            for i in range(3):
                anchors_xywh = np.zeros((self.anchor_per_scale, 4))
                anchors_xywh[:, 0:2] = np.floor(bbox_xywh_scaled[i, 0:2]).astype(np.int32) + 0.5
                anchors_xywh[:, 2:4] = self.anchors[i]

                iou_scale = bbox_iou(bbox_xywh_scaled[i][np.newaxis, :], anchors_xywh)
                iou.append(iou_scale)
                iou_mask = iou_scale > 0.3

                if np.any(iou_mask):
                    xind, yind = np.floor(bbox_xywh_scaled[i, 0:2]).astype(np.int32)

                    label[i][yind, xind, iou_mask, :] = 0
                    label[i][yind, xind, iou_mask, 0:4] = bbox_xywh
                    label[i][yind, xind, iou_mask, 4:5] = 1.0
                    label[i][yind, xind, iou_mask, 5:] = smooth_onehot

                    bbox_ind = int(bbox_count[i] % self.max_bbox_per_scale)
                    bboxes_xywh[i][bbox_ind, :4] = bbox_xywh
                    bbox_count[i] += 1

                    exist_positive = True

            if not exist_positive:
                best_anchor_ind = np.argmax(np.array(iou).reshape(-1), axis=-1)
                best_detect = int(best_anchor_ind / self.anchor_per_scale)
                best_anchor = int(best_anchor_ind % self.anchor_per_scale)
                xind, yind = np.floor(bbox_xywh_scaled[best_detect, 0:2]).astype(np.int32)

                label[best_detect][yind, xind, best_anchor, :] = 0
                label[best_detect][yind, xind, best_anchor, 0:4] = bbox_xywh
                label[best_detect][yind, xind, best_anchor, 4:5] = 1.0
                label[best_detect][yind, xind, best_anchor, 5:] = smooth_onehot
                
                bbox_ind = int(bbox_count[best_detect] % self.max_bbox_per_scale)
                bboxes_xywh[best_detect][bbox_ind, :4] = bbox_xywh
                bbox_count[best_detect] += 1

        label_sbbox, label_mbbox, label_lbbox = label
        sbboxes, mbboxes, lbboxes = bboxes_xywh
        return label_sbbox, label_mbbox, label_lbbox, sbboxes, mbboxes, lbboxes

    def __len__(self):
        return self.num_batchs

# %% [markdown]
# training

# %%
import os
import shutil
import numpy as np
import tensorflow as tf


global TRAIN_FROM_CHECKPOINT
input_size = YOLO_INPUT_SIZE
Darknet_weights = YOLO_DARKNET_WEIGHTS


save_best_only = True # saves only best model according validation loss
save_checkpoints = True # saves all best validated checkpoints in training process (may require a lot disk space)


trainset = Dataset('train')
testset = Dataset('test')

steps_per_epoch = len(trainset)
global_steps = tf.Variable(1, trainable=False, dtype=tf.int64)
warmup_steps = TRAIN_WARMUP_EPOCHS * steps_per_epoch
total_steps = TRAIN_EPOCHS * steps_per_epoch

if TRAIN_TRANSFER:
    Darknet = Create_Yolov3(input_size=input_size)
    load_yolo_weights(Darknet, Darknet_weights) # use darknet weights

yolo = Create_Yolov3(input_size=input_size, training=True, CLASSES=TRAIN_CLASSES)

#TRAIN_FROM_CHECKPOINT = False
if TRAIN_FROM_CHECKPOINT:
    yolo.load_weights(TRAIN_FROM_CHECKPOINT)

## transfer && Not use checkpoint
if TRAIN_TRANSFER and not TRAIN_FROM_CHECKPOINT:
    for i, l in enumerate(Darknet.layers):
        layer_weights = l.get_weights()
        if layer_weights != []:
            try:
                yolo.layers[i].set_weights(layer_weights)
            except:
                print("skipping", yolo.layers[i].name)

optimizer = tf.keras.optimizers.Adam()

def train_step(image_data, target):
    with tf.GradientTape() as tape:
        pred_result = yolo(image_data, training=True)
        giou_loss=conf_loss=prob_loss=0
        # optimizing process
        for i in range(3):
            conv, pred = pred_result[i*2], pred_result[i*2+1]
            loss_items = compute_loss(pred, conv, *target[i], i, CLASSES=TRAIN_CLASSES)
            giou_loss += loss_items[0]
            conf_loss += loss_items[1]
            prob_loss += loss_items[2]
        total_loss = giou_loss + conf_loss + prob_loss
        gradients = tape.gradient(total_loss, yolo.trainable_variables)
        optimizer.apply_gradients(zip(gradients, yolo.trainable_variables))


        # update learning rate
        global_steps.assign_add(1)
        if global_steps < warmup_steps:# and not TRAIN_TRANSFER:
            lr = global_steps / warmup_steps * TRAIN_LR_INIT
        else:
            lr = TRAIN_LR_END + 0.5 * (TRAIN_LR_INIT - TRAIN_LR_END)*(
                (1 + tf.cos((global_steps - warmup_steps) / (total_steps - warmup_steps) * np.pi)))
        optimizer.lr.assign(lr.numpy())

    return global_steps.numpy(), optimizer.lr.numpy(), giou_loss.numpy(), conf_loss.numpy(), prob_loss.numpy(), total_loss.numpy()



def validate_step(image_data, target):
    with tf.GradientTape() as tape:
        pred_result = yolo(image_data, training=False)
        giou_loss=conf_loss=prob_loss=0

        # optimizing process
        for i in range(3):
            conv, pred = pred_result[i*2], pred_result[i*2+1]
            loss_items = compute_loss(pred, conv, *target[i], i, CLASSES=TRAIN_CLASSES)
            giou_loss += loss_items[0]
            conf_loss += loss_items[1]
            prob_loss += loss_items[2]

        total_loss = giou_loss + conf_loss + prob_loss
        
    return giou_loss.numpy(), conf_loss.numpy(), prob_loss.numpy(), total_loss.numpy()


best_val_loss = 1000 # should be large at start
    

for epoch in range(TRAIN_EPOCHS):
    for image_data, target in trainset:
        results = train_step(image_data, target)
        cur_step = results[0]%steps_per_epoch
        print("epoch:{:2.0f} step:{:5.0f}/{}, lr:{:.6f}, giou_loss:{:7.2f}, conf_loss:{:7.2f}, prob_loss:{:7.2f}, total_loss:{:7.2f}"
                  .format(epoch, cur_step, steps_per_epoch, results[1], results[2], results[3], results[4], results[5]))
        
    count, giou_val, conf_val, prob_val, total_val = 0., 0, 0, 0, 0
    for image_data, target in testset:
        results = validate_step(image_data, target)
        count += 1
        giou_val += results[0]
        conf_val += results[1]
        prob_val += results[2]
        total_val += results[3]

        
    print("\n\ngiou_val_loss:{:7.2f}, conf_val_loss:{:7.2f}, prob_val_loss:{:7.2f}, total_val_loss:{:7.2f}\n\n".
          format(giou_val/count, conf_val/count, prob_val/count, total_val/count))

    if save_best_only and best_val_loss > total_val/count: 
        yolo.save_weights("./checkpoints3/")
        best_val_loss = total_val/count
# Out:
# C:\Users\SBAuser2\AppData\Local\Temp\ipykernel_1564\2424240629.py:182: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   onehot = np.zeros(self.num_classes, dtype=np.float)
# epoch: 0 step:    2/675, lr:0.000000, giou_loss:   4.93, conf_loss:   2.92, prob_loss:   0.88, total_loss:   8.74
# epoch: 0 step:    3/675, lr:0.000000, giou_loss:   3.77, conf_loss:  60.19, prob_loss:   5.73, total_loss:  69.69
# epoch: 0 step:    4/675, lr:0.000000, giou_loss:   9.35, conf_loss:  78.03, prob_loss:   8.04, total_loss:  95.42
# epoch: 0 step:    5/675, lr:0.000000, giou_loss:   5.34, conf_loss:  58.88, prob_loss:   4.66, total_loss:  68.88
# epoch: 0 step:    6/675, lr:0.000000, giou_loss:   4.99, conf_loss:  57.02, prob_loss:   7.42, total_loss:  69.43
# epoch: 0 step:    7/675, lr:0.000001, giou_loss:   3.78, conf_loss:  63.36, prob_loss:   4.00, total_loss:  71.13
# epoch: 0 step:    8/675, lr:0.000001, giou_loss:   3.20, conf_loss:  58.39, prob_loss:   6.86, total_loss:  68.45
# epoch: 0 step:    9/675, lr:0.000001, giou_loss:   8.79, conf_loss:  81.59, prob_loss:   5.71, total_loss:  96.08
# epoch: 0 step:   10/675, lr:0.000001, giou_loss:   5.64, conf_loss:  63.71, prob_loss:   6.77, total_loss:  76.13
# epoch: 0 step:   11/675, lr:0.000001, giou_loss:   4.76, conf_loss:  49.07, prob_loss:   9.15, total_loss:  62.98
# epoch: 0 step:   12/675, lr:0.000001, giou_loss:   5.00, conf_loss:  61.22, prob_loss:   6.85, total_loss:  73.08
# epoch: 0 step:   13/675, lr:0.000001, giou_loss:   6.30, conf_loss:  55.72, prob_loss:   7.06, total_loss:  69.08
# epoch: 0 step:   14/675, lr:0.000001, giou_loss:   5.06, conf_loss:  67.03, prob_loss:   7.04, total_loss:  79.13
# epoch: 0 step:   15/675, lr:0.000001, giou_loss:  11.02, conf_loss:  59.06, prob_loss:  20.59, total_loss:  90.66
# epoch: 0 step:   16/675, lr:0.000001, giou_loss:  10.13, conf_loss:  72.89, prob_loss:  14.60, total_loss:  97.63
# epoch: 0 step:   17/675, lr:0.000001, giou_loss:   4.53, conf_loss:  54.27, prob_loss:   8.49, total_loss:  67.29
# epoch: 0 step:   18/675, lr:0.000001, giou_loss:   4.00, conf_loss:  59.16, prob_loss:   6.41, total_loss:  69.58
# epoch: 0 step:   19/675, lr:0.000001, giou_loss:  12.30, conf_loss:  67.93, prob_loss:   8.32, total_loss:  88.55
# epoch: 0 step:   20/675, lr:0.000001, giou_loss:   9.73, conf_loss:  64.68, prob_loss:   7.24, total_loss:  81.66
# epoch: 0 step:   21/675, lr:0.000002, giou_loss:  10.87, conf_loss:  73.10, prob_loss:  10.73, total_loss:  94.70
# epoch: 0 step:   22/675, lr:0.000002, giou_loss:   9.89, conf_loss:  60.03, prob_loss:  10.80, total_loss:  80.72
# epoch: 0 step:   23/675, lr:0.000002, giou_loss:   6.15, conf_loss:  59.34, prob_loss:   9.71, total_loss:  75.20
# epoch: 0 step:   24/675, lr:0.000002, giou_loss:   8.14, conf_loss:  51.94, prob_loss:  11.36, total_loss:  71.44
# epoch: 0 step:   25/675, lr:0.000002, giou_loss:   9.61, conf_loss:  59.59, prob_loss:  12.88, total_loss:  82.08
# epoch: 0 step:   26/675, lr:0.000002, giou_loss:   5.47, conf_loss:  45.22, prob_loss:   9.76, total_loss:  60.45
# epoch: 0 step:   27/675, lr:0.000002, giou_loss:   8.65, conf_loss:  54.99, prob_loss:  16.26, total_loss:  79.89
# epoch: 0 step:   28/675, lr:0.000002, giou_loss:  10.72, conf_loss:  87.65, prob_loss:   9.77, total_loss: 108.14
# epoch: 0 step:   29/675, lr:0.000002, giou_loss:   4.17, conf_loss:  50.90, prob_loss:   6.01, total_loss:  61.08
# epoch: 0 step:   30/675, lr:0.000002, giou_loss:   2.63, conf_loss:  44.46, prob_loss:   4.70, total_loss:  51.79
# epoch: 0 step:   31/675, lr:0.000002, giou_loss:  10.55, conf_loss:  51.81, prob_loss:  14.39, total_loss:  76.75
# epoch: 0 step:   32/675, lr:0.000002, giou_loss:  11.31, conf_loss:  50.33, prob_loss:  14.28, total_loss:  75.92
# epoch: 0 step:   33/675, lr:0.000002, giou_loss:  10.99, conf_loss:  42.16, prob_loss:   9.41, total_loss:  62.56
# epoch: 0 step:   34/675, lr:0.000003, giou_loss:   8.71, conf_loss:  36.35, prob_loss:   9.40, total_loss:  54.46
# epoch: 0 step:   35/675, lr:0.000003, giou_loss:   5.08, conf_loss:  38.99, prob_loss:   6.75, total_loss:  50.82
# epoch: 0 step:   36/675, lr:0.000003, giou_loss:   5.52, conf_loss:  50.38, prob_loss:  11.14, total_loss:  67.04
# epoch: 0 step:   37/675, lr:0.000003, giou_loss:   5.57, conf_loss:  38.27, prob_loss:   5.22, total_loss:  49.05
# epoch: 0 step:   38/675, lr:0.000003, giou_loss:   5.56, conf_loss:  49.53, prob_loss:  11.73, total_loss:  66.82
# epoch: 0 step:   39/675, lr:0.000003, giou_loss:   8.93, conf_loss:  48.42, prob_loss:   7.27, total_loss:  64.62
# epoch: 0 step:   40/675, lr:0.000003, giou_loss:   4.60, conf_loss:  32.05, prob_loss:  12.94, total_loss:  49.59
# epoch: 0 step:   41/675, lr:0.000003, giou_loss:   5.99, conf_loss:  26.29, prob_loss:   8.04, total_loss:  40.32
# epoch: 0 step:   42/675, lr:0.000003, giou_loss:   6.25, conf_loss:  35.26, prob_loss:   9.52, total_loss:  51.04
# epoch: 0 step:   43/675, lr:0.000003, giou_loss:   5.35, conf_loss:  36.24, prob_loss:  11.76, total_loss:  53.35
# epoch: 0 step:   44/675, lr:0.000003, giou_loss:   5.77, conf_loss:  39.36, prob_loss:   3.78, total_loss:  48.91
# epoch: 0 step:   45/675, lr:0.000003, giou_loss:  11.71, conf_loss:  41.93, prob_loss:  11.40, total_loss:  65.04
# epoch: 0 step:   46/675, lr:0.000003, giou_loss:   6.58, conf_loss:  38.91, prob_loss:   6.19, total_loss:  51.68
# epoch: 0 step:   47/675, lr:0.000003, giou_loss:   3.50, conf_loss:  26.75, prob_loss:   3.54, total_loss:  33.79
# epoch: 0 step:   48/675, lr:0.000004, giou_loss:   5.92, conf_loss:  31.15, prob_loss:   1.65, total_loss:  38.72
# epoch: 0 step:   49/675, lr:0.000004, giou_loss:   4.77, conf_loss:  30.56, prob_loss:   5.63, total_loss:  40.96
# epoch: 0 step:   50/675, lr:0.000004, giou_loss:   6.75, conf_loss:  34.82, prob_loss:   9.13, total_loss:  50.70
# epoch: 0 step:   51/675, lr:0.000004, giou_loss:   8.31, conf_loss:  37.03, prob_loss:  15.07, total_loss:  60.41
# epoch: 0 step:   52/675, lr:0.000004, giou_loss:   5.99, conf_loss:  32.92, prob_loss:  10.65, total_loss:  49.56
# epoch: 0 step:   53/675, lr:0.000004, giou_loss:   7.49, conf_loss:  36.89, prob_loss:  10.68, total_loss:  55.07
# epoch: 0 step:   54/675, lr:0.000004, giou_loss:   5.13, conf_loss:  19.39, prob_loss:   8.29, total_loss:  32.81
# epoch: 0 step:   55/675, lr:0.000004, giou_loss:  12.49, conf_loss:  35.57, prob_loss:  24.06, total_loss:  72.12
# epoch: 0 step:   56/675, lr:0.000004, giou_loss:   5.35, conf_loss:  27.96, prob_loss:  13.12, total_loss:  46.43
# epoch: 0 step:   57/675, lr:0.000004, giou_loss:   6.64, conf_loss:  23.89, prob_loss:   8.44, total_loss:  38.97
# epoch: 0 step:   58/675, lr:0.000004, giou_loss:   8.53, conf_loss:  30.54, prob_loss:   5.68, total_loss:  44.75
# epoch: 0 step:   59/675, lr:0.000004, giou_loss:   6.32, conf_loss:  29.69, prob_loss:   5.97, total_loss:  41.98
# epoch: 0 step:   60/675, lr:0.000004, giou_loss:   7.33, conf_loss:  28.91, prob_loss:  10.54, total_loss:  46.78
# epoch: 0 step:   61/675, lr:0.000005, giou_loss:   6.28, conf_loss:  34.78, prob_loss:  13.65, total_loss:  54.72
# epoch: 0 step:   62/675, lr:0.000005, giou_loss:   5.97, conf_loss:  28.80, prob_loss:   9.65, total_loss:  44.42
# epoch: 0 step:   63/675, lr:0.000005, giou_loss:   7.62, conf_loss:  35.09, prob_loss:  13.24, total_loss:  55.95
# epoch: 0 step:   64/675, lr:0.000005, giou_loss:   8.69, conf_loss:  28.52, prob_loss:  10.75, total_loss:  47.97
# epoch: 0 step:   65/675, lr:0.000005, giou_loss:   3.23, conf_loss:  16.09, prob_loss:  13.95, total_loss:  33.27
# epoch: 0 step:   66/675, lr:0.000005, giou_loss:   6.15, conf_loss:  29.84, prob_loss:   8.57, total_loss:  44.56
# epoch: 0 step:   67/675, lr:0.000005, giou_loss:   8.43, conf_loss:  25.13, prob_loss:  12.73, total_loss:  46.29
# epoch: 0 step:   68/675, lr:0.000005, giou_loss:   3.33, conf_loss:  20.15, prob_loss:   2.09, total_loss:  25.57
# epoch: 0 step:   69/675, lr:0.000005, giou_loss:   5.31, conf_loss:  16.89, prob_loss:   2.71, total_loss:  24.90
# epoch: 0 step:   70/675, lr:0.000005, giou_loss:   8.19, conf_loss:  28.47, prob_loss:  10.83, total_loss:  47.49
# epoch: 0 step:   71/675, lr:0.000005, giou_loss:   2.41, conf_loss:  18.63, prob_loss:   4.20, total_loss:  25.25
# epoch: 0 step:   72/675, lr:0.000005, giou_loss:   5.44, conf_loss:  23.40, prob_loss:  11.10, total_loss:  39.93
# epoch: 0 step:   73/675, lr:0.000005, giou_loss:   8.79, conf_loss:  35.13, prob_loss:  16.41, total_loss:  60.32
# epoch: 0 step:   74/675, lr:0.000005, giou_loss:   4.99, conf_loss:  18.67, prob_loss:   7.88, total_loss:  31.54
# epoch: 0 step:   75/675, lr:0.000006, giou_loss:   7.38, conf_loss:  23.90, prob_loss:   9.63, total_loss:  40.91
# epoch: 0 step:   76/675, lr:0.000006, giou_loss:   7.01, conf_loss:  18.05, prob_loss:   8.49, total_loss:  33.56
# epoch: 0 step:   77/675, lr:0.000006, giou_loss:   7.38, conf_loss:  24.42, prob_loss:   6.06, total_loss:  37.86
# epoch: 0 step:   78/675, lr:0.000006, giou_loss:   5.67, conf_loss:  18.90, prob_loss:   7.09, total_loss:  31.67
# epoch: 0 step:   79/675, lr:0.000006, giou_loss:  10.25, conf_loss:  27.56, prob_loss:  12.02, total_loss:  49.83
# epoch: 0 step:   80/675, lr:0.000006, giou_loss:  10.27, conf_loss:  29.85, prob_loss:  13.07, total_loss:  53.20
# epoch: 0 step:   81/675, lr:0.000006, giou_loss:   8.22, conf_loss:  20.56, prob_loss:  11.32, total_loss:  40.10
# epoch: 0 step:   82/675, lr:0.000006, giou_loss:   7.48, conf_loss:  20.02, prob_loss:   4.61, total_loss:  32.11
# epoch: 0 step:   83/675, lr:0.000006, giou_loss:   4.78, conf_loss:  17.22, prob_loss:   4.32, total_loss:  26.32
# epoch: 0 step:   84/675, lr:0.000006, giou_loss:   6.63, conf_loss:  10.92, prob_loss:   5.16, total_loss:  22.71
# epoch: 0 step:   85/675, lr:0.000006, giou_loss:   4.68, conf_loss:  20.75, prob_loss:   5.26, total_loss:  30.69
# epoch: 0 step:   86/675, lr:0.000006, giou_loss:   7.87, conf_loss:  25.76, prob_loss:   6.30, total_loss:  39.92
# epoch: 0 step:   87/675, lr:0.000006, giou_loss:   4.70, conf_loss:  13.64, prob_loss:   8.77, total_loss:  27.11
# epoch: 0 step:   88/675, lr:0.000007, giou_loss:   8.41, conf_loss:  20.24, prob_loss:   4.54, total_loss:  33.19
# epoch: 0 step:   89/675, lr:0.000007, giou_loss:   7.38, conf_loss:   9.91, prob_loss:   8.61, total_loss:  25.89
# epoch: 0 step:   90/675, lr:0.000007, giou_loss:   4.29, conf_loss:  11.77, prob_loss:   8.54, total_loss:  24.60
# epoch: 0 step:   91/675, lr:0.000007, giou_loss:   8.42, conf_loss:  17.45, prob_loss:  11.25, total_loss:  37.13
# epoch: 0 step:   92/675, lr:0.000007, giou_loss:   9.34, conf_loss:  21.76, prob_loss:  14.54, total_loss:  45.64
# epoch: 0 step:   93/675, lr:0.000007, giou_loss:   5.02, conf_loss:  15.86, prob_loss:   5.66, total_loss:  26.55
# epoch: 0 step:   94/675, lr:0.000007, giou_loss:   5.05, conf_loss:   9.84, prob_loss:   2.71, total_loss:  17.60
# epoch: 0 step:   95/675, lr:0.000007, giou_loss:   8.94, conf_loss:  20.88, prob_loss:  11.14, total_loss:  40.95
# epoch: 0 step:   96/675, lr:0.000007, giou_loss:   9.42, conf_loss:  17.82, prob_loss:  11.18, total_loss:  38.42
# epoch: 0 step:   97/675, lr:0.000007, giou_loss:   5.20, conf_loss:  14.74, prob_loss:   4.73, total_loss:  24.67
# epoch: 0 step:   98/675, lr:0.000007, giou_loss:   7.42, conf_loss:  18.02, prob_loss:   6.50, total_loss:  31.94
# epoch: 0 step:   99/675, lr:0.000007, giou_loss:   5.19, conf_loss:  18.23, prob_loss:   7.13, total_loss:  30.55
# epoch: 0 step:  100/675, lr:0.000007, giou_loss:   5.43, conf_loss:  14.79, prob_loss:  12.11, total_loss:  32.33
# epoch: 0 step:  101/675, lr:0.000007, giou_loss:   3.67, conf_loss:   9.09, prob_loss:   8.06, total_loss:  20.82
# epoch: 0 step:  102/675, lr:0.000008, giou_loss:   4.38, conf_loss:   6.31, prob_loss:   4.49, total_loss:  15.18
# epoch: 0 step:  103/675, lr:0.000008, giou_loss:   6.87, conf_loss:  12.47, prob_loss:   7.38, total_loss:  26.73
# epoch: 0 step:  104/675, lr:0.000008, giou_loss:  11.94, conf_loss:  30.50, prob_loss:  14.32, total_loss:  56.76
# epoch: 0 step:  105/675, lr:0.000008, giou_loss:   9.14, conf_loss:  11.51, prob_loss:   6.45, total_loss:  27.10
# epoch: 0 step:  106/675, lr:0.000008, giou_loss:   9.75, conf_loss:  12.34, prob_loss:  11.17, total_loss:  33.26
# epoch: 0 step:  107/675, lr:0.000008, giou_loss:   5.91, conf_loss:  12.40, prob_loss:   3.61, total_loss:  21.92
# epoch: 0 step:  108/675, lr:0.000008, giou_loss:   6.87, conf_loss:  12.14, prob_loss:   7.31, total_loss:  26.33
# epoch: 0 step:  109/675, lr:0.000008, giou_loss:   5.68, conf_loss:  11.42, prob_loss:   4.97, total_loss:  22.07
# epoch: 0 step:  110/675, lr:0.000008, giou_loss:   5.12, conf_loss:   7.76, prob_loss:   4.17, total_loss:  17.05
# epoch: 0 step:  111/675, lr:0.000008, giou_loss:   4.36, conf_loss:   6.01, prob_loss:   3.86, total_loss:  14.23
# epoch: 0 step:  112/675, lr:0.000008, giou_loss:   4.93, conf_loss:  15.13, prob_loss:   5.63, total_loss:  25.69
# epoch: 0 step:  113/675, lr:0.000008, giou_loss:   9.51, conf_loss:  17.07, prob_loss:   5.03, total_loss:  31.62
# epoch: 0 step:  114/675, lr:0.000008, giou_loss:   4.28, conf_loss:   7.98, prob_loss:   2.66, total_loss:  14.93
# epoch: 0 step:  115/675, lr:0.000009, giou_loss:   7.41, conf_loss:   8.74, prob_loss:   9.01, total_loss:  25.16
# epoch: 0 step:  116/675, lr:0.000009, giou_loss:   7.09, conf_loss:  11.87, prob_loss:   8.48, total_loss:  27.44
# epoch: 0 step:  117/675, lr:0.000009, giou_loss:   6.75, conf_loss:  16.48, prob_loss:   8.28, total_loss:  31.51
# epoch: 0 step:  118/675, lr:0.000009, giou_loss:   5.45, conf_loss:   7.79, prob_loss:   8.23, total_loss:  21.48
# epoch: 0 step:  119/675, lr:0.000009, giou_loss:   6.39, conf_loss:  11.11, prob_loss:  11.51, total_loss:  29.01
# epoch: 0 step:  120/675, lr:0.000009, giou_loss:   2.48, conf_loss:   5.03, prob_loss:   2.10, total_loss:   9.61
# epoch: 0 step:  121/675, lr:0.000009, giou_loss:   7.79, conf_loss:  13.69, prob_loss:   7.50, total_loss:  28.99
# epoch: 0 step:  122/675, lr:0.000009, giou_loss:   7.10, conf_loss:  14.00, prob_loss:   7.55, total_loss:  28.65
# epoch: 0 step:  123/675, lr:0.000009, giou_loss:   6.77, conf_loss:   7.46, prob_loss:   4.02, total_loss:  18.25
# epoch: 0 step:  124/675, lr:0.000009, giou_loss:   3.40, conf_loss:   4.63, prob_loss:   1.47, total_loss:   9.51
# epoch: 0 step:  125/675, lr:0.000009, giou_loss:   8.46, conf_loss:  12.07, prob_loss:  11.95, total_loss:  32.48
# epoch: 0 step:  126/675, lr:0.000009, giou_loss:   6.86, conf_loss:   9.84, prob_loss:   4.15, total_loss:  20.85
# epoch: 0 step:  127/675, lr:0.000009, giou_loss:   3.10, conf_loss:   7.05, prob_loss:   4.56, total_loss:  14.71
# epoch: 0 step:  128/675, lr:0.000009, giou_loss:   5.90, conf_loss:  11.26, prob_loss:   5.99, total_loss:  23.15
# epoch: 0 step:  129/675, lr:0.000010, giou_loss:   8.54, conf_loss:   9.37, prob_loss:   5.16, total_loss:  23.07
# epoch: 0 step:  130/675, lr:0.000010, giou_loss:   2.04, conf_loss:   5.76, prob_loss:   1.20, total_loss:   8.99
# epoch: 0 step:  131/675, lr:0.000010, giou_loss:   3.26, conf_loss:   6.23, prob_loss:   3.33, total_loss:  12.82
# epoch: 0 step:  132/675, lr:0.000010, giou_loss:  10.39, conf_loss:  20.21, prob_loss:   8.42, total_loss:  39.02
# epoch: 0 step:  133/675, lr:0.000010, giou_loss:   5.24, conf_loss:  11.50, prob_loss:   1.53, total_loss:  18.28
# epoch: 0 step:  134/675, lr:0.000010, giou_loss:   1.90, conf_loss:   4.38, prob_loss:   1.84, total_loss:   8.12
# epoch: 0 step:  135/675, lr:0.000010, giou_loss:   4.95, conf_loss:  10.08, prob_loss:   3.55, total_loss:  18.58
# epoch: 0 step:  136/675, lr:0.000010, giou_loss:   5.50, conf_loss:   5.35, prob_loss:   4.92, total_loss:  15.77
# epoch: 0 step:  137/675, lr:0.000010, giou_loss:   5.56, conf_loss:  10.87, prob_loss:   5.57, total_loss:  22.00
# epoch: 0 step:  138/675, lr:0.000010, giou_loss:   7.59, conf_loss:   8.98, prob_loss:   7.00, total_loss:  23.57
# epoch: 0 step:  139/675, lr:0.000010, giou_loss:   7.34, conf_loss:   8.96, prob_loss:   4.56, total_loss:  20.86
# epoch: 0 step:  140/675, lr:0.000010, giou_loss:   6.43, conf_loss:  16.97, prob_loss:  11.32, total_loss:  34.72
# epoch: 0 step:  141/675, lr:0.000010, giou_loss:   5.29, conf_loss:  11.24, prob_loss:   5.55, total_loss:  22.08
# epoch: 0 step:  142/675, lr:0.000011, giou_loss:   5.22, conf_loss:   9.22, prob_loss:   9.57, total_loss:  24.01
# epoch: 0 step:  143/675, lr:0.000011, giou_loss:   3.81, conf_loss:   4.11, prob_loss:   2.28, total_loss:  10.20
# epoch: 0 step:  144/675, lr:0.000011, giou_loss:   2.26, conf_loss:   5.49, prob_loss:   0.67, total_loss:   8.42
# epoch: 0 step:  145/675, lr:0.000011, giou_loss:   4.50, conf_loss:   6.78, prob_loss:   5.51, total_loss:  16.78
# epoch: 0 step:  146/675, lr:0.000011, giou_loss:   2.95, conf_loss:   4.54, prob_loss:   0.76, total_loss:   8.25
# epoch: 0 step:  147/675, lr:0.000011, giou_loss:   3.81, conf_loss:   8.05, prob_loss:   1.90, total_loss:  13.77
# epoch: 0 step:  148/675, lr:0.000011, giou_loss:   4.91, conf_loss:   4.29, prob_loss:   2.37, total_loss:  11.57
# epoch: 0 step:  149/675, lr:0.000011, giou_loss:   7.87, conf_loss:  10.67, prob_loss:   4.68, total_loss:  23.22
# epoch: 0 step:  150/675, lr:0.000011, giou_loss:   2.59, conf_loss:   3.12, prob_loss:   1.39, total_loss:   7.11
# epoch: 0 step:  151/675, lr:0.000011, giou_loss:   2.81, conf_loss:   7.39, prob_loss:   0.75, total_loss:  10.95
# epoch: 0 step:  152/675, lr:0.000011, giou_loss:   5.50, conf_loss:   7.03, prob_loss:  11.33, total_loss:  23.86
# epoch: 0 step:  153/675, lr:0.000011, giou_loss:   3.76, conf_loss:   4.44, prob_loss:   4.21, total_loss:  12.40
# epoch: 0 step:  154/675, lr:0.000011, giou_loss:   2.72, conf_loss:   6.28, prob_loss:   2.11, total_loss:  11.11
# epoch: 0 step:  155/675, lr:0.000011, giou_loss:   4.70, conf_loss:   8.74, prob_loss:   4.01, total_loss:  17.45
# epoch: 0 step:  156/675, lr:0.000012, giou_loss:   3.40, conf_loss:   7.59, prob_loss:   1.29, total_loss:  12.28
# epoch: 0 step:  157/675, lr:0.000012, giou_loss:   7.92, conf_loss:  11.65, prob_loss:  10.52, total_loss:  30.09
# epoch: 0 step:  158/675, lr:0.000012, giou_loss:   3.86, conf_loss:   5.75, prob_loss:   1.88, total_loss:  11.49
# epoch: 0 step:  159/675, lr:0.000012, giou_loss:   7.59, conf_loss:  16.97, prob_loss:   8.52, total_loss:  33.08
# epoch: 0 step:  160/675, lr:0.000012, giou_loss:   6.44, conf_loss:   6.59, prob_loss:   9.23, total_loss:  22.26
# epoch: 0 step:  161/675, lr:0.000012, giou_loss:   7.04, conf_loss:   8.04, prob_loss:   4.00, total_loss:  19.08
# epoch: 0 step:  162/675, lr:0.000012, giou_loss:   3.97, conf_loss:   5.27, prob_loss:   1.76, total_loss:  11.00
# epoch: 0 step:  163/675, lr:0.000012, giou_loss:   6.55, conf_loss:   7.62, prob_loss:   4.15, total_loss:  18.32
# epoch: 0 step:  164/675, lr:0.000012, giou_loss:   4.76, conf_loss:   7.20, prob_loss:   3.33, total_loss:  15.29
# epoch: 0 step:  165/675, lr:0.000012, giou_loss:   5.08, conf_loss:   7.00, prob_loss:   3.14, total_loss:  15.23
# epoch: 0 step:  166/675, lr:0.000012, giou_loss:   4.33, conf_loss:   4.76, prob_loss:   1.54, total_loss:  10.63
# epoch: 0 step:  167/675, lr:0.000012, giou_loss:   4.12, conf_loss:   5.46, prob_loss:   5.17, total_loss:  14.75
# epoch: 0 step:  168/675, lr:0.000012, giou_loss:   9.31, conf_loss:  11.98, prob_loss:   7.81, total_loss:  29.10
# epoch: 0 step:  169/675, lr:0.000013, giou_loss:   4.79, conf_loss:   8.22, prob_loss:   2.58, total_loss:  15.59
# epoch: 0 step:  170/675, lr:0.000013, giou_loss:   5.58, conf_loss:   4.95, prob_loss:   2.96, total_loss:  13.48
# epoch: 0 step:  171/675, lr:0.000013, giou_loss:   5.28, conf_loss:   9.28, prob_loss:   3.65, total_loss:  18.21
# epoch: 0 step:  172/675, lr:0.000013, giou_loss:   4.81, conf_loss:   4.06, prob_loss:   3.42, total_loss:  12.29
# epoch: 0 step:  173/675, lr:0.000013, giou_loss:   4.80, conf_loss:   7.00, prob_loss:   7.05, total_loss:  18.84
# epoch: 0 step:  174/675, lr:0.000013, giou_loss:   7.48, conf_loss:   8.59, prob_loss:   5.22, total_loss:  21.29
# epoch: 0 step:  175/675, lr:0.000013, giou_loss:   6.67, conf_loss:   7.69, prob_loss:   4.04, total_loss:  18.40
# epoch: 0 step:  176/675, lr:0.000013, giou_loss:   3.81, conf_loss:   6.49, prob_loss:   3.27, total_loss:  13.58
# epoch: 0 step:  177/675, lr:0.000013, giou_loss:   5.39, conf_loss:  12.82, prob_loss:   4.34, total_loss:  22.55
# epoch: 0 step:  178/675, lr:0.000013, giou_loss:   3.42, conf_loss:   5.83, prob_loss:   6.58, total_loss:  15.83
# epoch: 0 step:  179/675, lr:0.000013, giou_loss:   5.86, conf_loss:   4.49, prob_loss:   5.58, total_loss:  15.93
# epoch: 0 step:  180/675, lr:0.000013, giou_loss:   6.22, conf_loss:   9.02, prob_loss:   3.47, total_loss:  18.71
# epoch: 0 step:  181/675, lr:0.000013, giou_loss:   6.38, conf_loss:   8.27, prob_loss:   5.88, total_loss:  20.53
# epoch: 0 step:  182/675, lr:0.000013, giou_loss:   6.52, conf_loss:   5.79, prob_loss:   3.61, total_loss:  15.92
# epoch: 0 step:  183/675, lr:0.000014, giou_loss:   4.88, conf_loss:   3.40, prob_loss:   1.80, total_loss:  10.07
# epoch: 0 step:  184/675, lr:0.000014, giou_loss:   4.14, conf_loss:   6.00, prob_loss:   1.42, total_loss:  11.56
# epoch: 0 step:  185/675, lr:0.000014, giou_loss:   4.91, conf_loss:   5.69, prob_loss:   3.34, total_loss:  13.93
# epoch: 0 step:  186/675, lr:0.000014, giou_loss:   5.04, conf_loss:   6.20, prob_loss:   6.00, total_loss:  17.24
# epoch: 0 step:  187/675, lr:0.000014, giou_loss:   7.02, conf_loss:  10.57, prob_loss:   6.53, total_loss:  24.11
# epoch: 0 step:  188/675, lr:0.000014, giou_loss:   5.16, conf_loss:   7.09, prob_loss:   5.11, total_loss:  17.36
# epoch: 0 step:  189/675, lr:0.000014, giou_loss:   7.17, conf_loss:  13.67, prob_loss:   5.77, total_loss:  26.61
# epoch: 0 step:  190/675, lr:0.000014, giou_loss:   4.54, conf_loss:   3.23, prob_loss:   1.31, total_loss:   9.08
# epoch: 0 step:  191/675, lr:0.000014, giou_loss:   6.63, conf_loss:   9.49, prob_loss:   5.02, total_loss:  21.13
# epoch: 0 step:  192/675, lr:0.000014, giou_loss:   3.49, conf_loss:   5.45, prob_loss:   2.66, total_loss:  11.60
# epoch: 0 step:  193/675, lr:0.000014, giou_loss:   5.70, conf_loss:   6.78, prob_loss:   3.21, total_loss:  15.69
# epoch: 0 step:  194/675, lr:0.000014, giou_loss:   4.43, conf_loss:   7.12, prob_loss:   2.35, total_loss:  13.89
# epoch: 0 step:  195/675, lr:0.000014, giou_loss:   6.67, conf_loss:   9.18, prob_loss:   5.49, total_loss:  21.34
# epoch: 0 step:  196/675, lr:0.000015, giou_loss:   4.95, conf_loss:   3.44, prob_loss:   1.35, total_loss:   9.75
# epoch: 0 step:  197/675, lr:0.000015, giou_loss:   4.80, conf_loss:   6.66, prob_loss:   2.93, total_loss:  14.38
# epoch: 0 step:  198/675, lr:0.000015, giou_loss:   3.85, conf_loss:   3.13, prob_loss:   1.52, total_loss:   8.49
# epoch: 0 step:  199/675, lr:0.000015, giou_loss:   4.04, conf_loss:   6.44, prob_loss:   2.33, total_loss:  12.81
# epoch: 0 step:  200/675, lr:0.000015, giou_loss:   3.22, conf_loss:   4.36, prob_loss:   2.56, total_loss:  10.15
# epoch: 0 step:  201/675, lr:0.000015, giou_loss:   1.43, conf_loss:   2.71, prob_loss:   1.18, total_loss:   5.32
# epoch: 0 step:  202/675, lr:0.000015, giou_loss:   4.28, conf_loss:   6.26, prob_loss:   4.47, total_loss:  15.01
# epoch: 0 step:  203/675, lr:0.000015, giou_loss:   5.85, conf_loss:   5.94, prob_loss:   3.17, total_loss:  14.96
# epoch: 0 step:  204/675, lr:0.000015, giou_loss:   3.54, conf_loss:   3.79, prob_loss:   1.20, total_loss:   8.52
# epoch: 0 step:  205/675, lr:0.000015, giou_loss:   1.28, conf_loss:   2.51, prob_loss:   0.41, total_loss:   4.20
# epoch: 0 step:  206/675, lr:0.000015, giou_loss:   3.45, conf_loss:   4.71, prob_loss:   3.03, total_loss:  11.19
# epoch: 0 step:  207/675, lr:0.000015, giou_loss:   6.27, conf_loss:   5.22, prob_loss:   1.27, total_loss:  12.76
# epoch: 0 step:  208/675, lr:0.000015, giou_loss:   3.89, conf_loss:   2.05, prob_loss:   1.02, total_loss:   6.97
# epoch: 0 step:  209/675, lr:0.000015, giou_loss:   5.22, conf_loss:   8.04, prob_loss:   5.27, total_loss:  18.53
# epoch: 0 step:  210/675, lr:0.000016, giou_loss:   6.72, conf_loss:   7.12, prob_loss:   1.92, total_loss:  15.77
# epoch: 0 step:  211/675, lr:0.000016, giou_loss:   5.45, conf_loss:   6.02, prob_loss:   2.16, total_loss:  13.63
# epoch: 0 step:  212/675, lr:0.000016, giou_loss:   5.05, conf_loss:   6.50, prob_loss:   3.09, total_loss:  14.64
# epoch: 0 step:  213/675, lr:0.000016, giou_loss:   7.61, conf_loss:  10.55, prob_loss:   8.75, total_loss:  26.91
# epoch: 0 step:  214/675, lr:0.000016, giou_loss:   3.49, conf_loss:   5.26, prob_loss:   1.46, total_loss:  10.21
# epoch: 0 step:  215/675, lr:0.000016, giou_loss:   2.73, conf_loss:   4.16, prob_loss:   0.92, total_loss:   7.81
# epoch: 0 step:  216/675, lr:0.000016, giou_loss:   4.42, conf_loss:   5.30, prob_loss:   4.03, total_loss:  13.75
# epoch: 0 step:  217/675, lr:0.000016, giou_loss:   4.05, conf_loss:   5.26, prob_loss:   2.78, total_loss:  12.09
# epoch: 0 step:  218/675, lr:0.000016, giou_loss:   4.17, conf_loss:   7.56, prob_loss:   4.38, total_loss:  16.12
# epoch: 0 step:  219/675, lr:0.000016, giou_loss:   8.05, conf_loss:   9.65, prob_loss:   3.58, total_loss:  21.29
# epoch: 0 step:  220/675, lr:0.000016, giou_loss:   2.46, conf_loss:   3.00, prob_loss:   0.55, total_loss:   6.01
# epoch: 0 step:  221/675, lr:0.000016, giou_loss:   4.09, conf_loss:   4.08, prob_loss:   1.81, total_loss:   9.97
# epoch: 0 step:  222/675, lr:0.000016, giou_loss:   3.15, conf_loss:   4.36, prob_loss:   5.58, total_loss:  13.10
# epoch: 0 step:  223/675, lr:0.000017, giou_loss:   4.30, conf_loss:   6.25, prob_loss:   1.19, total_loss:  11.74
# epoch: 0 step:  224/675, lr:0.000017, giou_loss:   6.77, conf_loss:  12.24, prob_loss:   5.52, total_loss:  24.53
# epoch: 0 step:  225/675, lr:0.000017, giou_loss:   5.34, conf_loss:   5.89, prob_loss:   1.65, total_loss:  12.88
# epoch: 0 step:  226/675, lr:0.000017, giou_loss:   3.35, conf_loss:   3.37, prob_loss:   1.16, total_loss:   7.88
# epoch: 0 step:  227/675, lr:0.000017, giou_loss:   3.38, conf_loss:   4.04, prob_loss:   1.80, total_loss:   9.22
# epoch: 0 step:  228/675, lr:0.000017, giou_loss:   3.86, conf_loss:   4.34, prob_loss:   0.94, total_loss:   9.15
# epoch: 0 step:  229/675, lr:0.000017, giou_loss:   5.36, conf_loss:   5.50, prob_loss:   1.83, total_loss:  12.70
# epoch: 0 step:  230/675, lr:0.000017, giou_loss:   5.02, conf_loss:   3.80, prob_loss:   2.04, total_loss:  10.86
# epoch: 0 step:  231/675, lr:0.000017, giou_loss:   3.76, conf_loss:   4.25, prob_loss:   1.00, total_loss:   9.01
# epoch: 0 step:  232/675, lr:0.000017, giou_loss:   6.53, conf_loss:   7.20, prob_loss:   4.97, total_loss:  18.70
# epoch: 0 step:  233/675, lr:0.000017, giou_loss:   4.82, conf_loss:   4.32, prob_loss:   1.70, total_loss:  10.84
# epoch: 0 step:  234/675, lr:0.000017, giou_loss:   4.69, conf_loss:   4.61, prob_loss:   1.18, total_loss:  10.48
# epoch: 0 step:  235/675, lr:0.000017, giou_loss:   5.03, conf_loss:   6.45, prob_loss:   7.64, total_loss:  19.11
# epoch: 0 step:  236/675, lr:0.000017, giou_loss:   5.96, conf_loss:   5.84, prob_loss:   2.70, total_loss:  14.49
# epoch: 0 step:  237/675, lr:0.000018, giou_loss:   3.17, conf_loss:   3.34, prob_loss:   0.91, total_loss:   7.42
# epoch: 0 step:  238/675, lr:0.000018, giou_loss:   3.86, conf_loss:   3.69, prob_loss:   1.70, total_loss:   9.26
# epoch: 0 step:  239/675, lr:0.000018, giou_loss:   2.80, conf_loss:   2.42, prob_loss:   1.27, total_loss:   6.49
# epoch: 0 step:  240/675, lr:0.000018, giou_loss:   4.90, conf_loss:   4.39, prob_loss:   1.69, total_loss:  10.98
# epoch: 0 step:  241/675, lr:0.000018, giou_loss:   1.90, conf_loss:   4.03, prob_loss:   6.25, total_loss:  12.18
# epoch: 0 step:  242/675, lr:0.000018, giou_loss:   2.32, conf_loss:   2.56, prob_loss:   4.38, total_loss:   9.26
# epoch: 0 step:  243/675, lr:0.000018, giou_loss:   3.95, conf_loss:  14.47, prob_loss:   2.92, total_loss:  21.34
# epoch: 0 step:  244/675, lr:0.000018, giou_loss:   4.32, conf_loss:   9.80, prob_loss:   1.64, total_loss:  15.76
# epoch: 0 step:  245/675, lr:0.000018, giou_loss:   2.63, conf_loss:   2.80, prob_loss:   0.60, total_loss:   6.02
# epoch: 0 step:  246/675, lr:0.000018, giou_loss:   1.71, conf_loss:   2.20, prob_loss:   4.06, total_loss:   7.97
# epoch: 0 step:  247/675, lr:0.000018, giou_loss:   6.25, conf_loss:   3.55, prob_loss:   1.56, total_loss:  11.35
# epoch: 0 step:  248/675, lr:0.000018, giou_loss:   3.98, conf_loss:   5.33, prob_loss:   1.22, total_loss:  10.53
# epoch: 0 step:  249/675, lr:0.000018, giou_loss:   4.15, conf_loss:   6.76, prob_loss:   1.68, total_loss:  12.60
# epoch: 0 step:  250/675, lr:0.000019, giou_loss:   5.30, conf_loss:  11.64, prob_loss:   1.68, total_loss:  18.62
# epoch: 0 step:  251/675, lr:0.000019, giou_loss:   6.81, conf_loss:   7.55, prob_loss:   4.78, total_loss:  19.13
# epoch: 0 step:  252/675, lr:0.000019, giou_loss:   3.93, conf_loss:   3.52, prob_loss:   3.54, total_loss:  10.99
# epoch: 0 step:  253/675, lr:0.000019, giou_loss:   6.30, conf_loss:   7.23, prob_loss:   1.82, total_loss:  15.34
# epoch: 0 step:  254/675, lr:0.000019, giou_loss:   5.49, conf_loss:   6.18, prob_loss:   2.65, total_loss:  14.33
# epoch: 0 step:  255/675, lr:0.000019, giou_loss:  13.57, conf_loss:  29.42, prob_loss:  12.17, total_loss:  55.16
# epoch: 0 step:  256/675, lr:0.000019, giou_loss:   4.00, conf_loss:   3.45, prob_loss:   1.10, total_loss:   8.55
# epoch: 0 step:  257/675, lr:0.000019, giou_loss:   3.99, conf_loss:   3.75, prob_loss:   9.32, total_loss:  17.07
# epoch: 0 step:  258/675, lr:0.000019, giou_loss:   6.19, conf_loss:   9.33, prob_loss:   5.83, total_loss:  21.35
# epoch: 0 step:  259/675, lr:0.000019, giou_loss:   5.86, conf_loss:   6.13, prob_loss:   5.65, total_loss:  17.64
# epoch: 0 step:  260/675, lr:0.000019, giou_loss:   1.74, conf_loss:   2.44, prob_loss:   0.35, total_loss:   4.53
# epoch: 0 step:  261/675, lr:0.000019, giou_loss:   3.09, conf_loss:   3.85, prob_loss:   2.19, total_loss:   9.13
# epoch: 0 step:  262/675, lr:0.000019, giou_loss:   4.72, conf_loss:   5.81, prob_loss:   2.78, total_loss:  13.31
# epoch: 0 step:  263/675, lr:0.000019, giou_loss:   6.29, conf_loss:   5.23, prob_loss:   5.26, total_loss:  16.78
# epoch: 0 step:  264/675, lr:0.000020, giou_loss:   3.49, conf_loss:   3.42, prob_loss:   0.87, total_loss:   7.78
# epoch: 0 step:  265/675, lr:0.000020, giou_loss:   3.52, conf_loss:   4.32, prob_loss:   1.24, total_loss:   9.07
# epoch: 0 step:  266/675, lr:0.000020, giou_loss:   1.84, conf_loss:   2.59, prob_loss:   0.39, total_loss:   4.83
# epoch: 0 step:  267/675, lr:0.000020, giou_loss:   4.65, conf_loss:   5.14, prob_loss:   3.50, total_loss:  13.29
# epoch: 0 step:  268/675, lr:0.000020, giou_loss:   4.03, conf_loss:   3.48, prob_loss:   1.02, total_loss:   8.52
# epoch: 0 step:  269/675, lr:0.000020, giou_loss:   3.11, conf_loss:   3.48, prob_loss:   7.98, total_loss:  14.57
# epoch: 0 step:  270/675, lr:0.000020, giou_loss:   4.33, conf_loss:   3.86, prob_loss:   1.24, total_loss:   9.43
# epoch: 0 step:  271/675, lr:0.000020, giou_loss:   5.15, conf_loss:   5.20, prob_loss:   1.42, total_loss:  11.76
# epoch: 0 step:  272/675, lr:0.000020, giou_loss:   2.10, conf_loss:   4.03, prob_loss:   0.88, total_loss:   7.01
# epoch: 0 step:  273/675, lr:0.000020, giou_loss:   3.71, conf_loss:   3.55, prob_loss:   3.15, total_loss:  10.42
# epoch: 0 step:  274/675, lr:0.000020, giou_loss:   4.68, conf_loss:   5.48, prob_loss:   7.20, total_loss:  17.36
# epoch: 0 step:  275/675, lr:0.000020, giou_loss:   5.75, conf_loss:   6.89, prob_loss:   1.53, total_loss:  14.17
# epoch: 0 step:  276/675, lr:0.000020, giou_loss:   3.15, conf_loss:   4.68, prob_loss:   0.55, total_loss:   8.38
# epoch: 0 step:  277/675, lr:0.000021, giou_loss:   6.42, conf_loss:   8.16, prob_loss:   1.54, total_loss:  16.12
# epoch: 0 step:  278/675, lr:0.000021, giou_loss:   1.18, conf_loss:   1.55, prob_loss:   0.22, total_loss:   2.95
# epoch: 0 step:  279/675, lr:0.000021, giou_loss:   7.76, conf_loss:  12.40, prob_loss:   5.28, total_loss:  25.43
# epoch: 0 step:  280/675, lr:0.000021, giou_loss:   4.61, conf_loss:   5.04, prob_loss:   1.30, total_loss:  10.95
# epoch: 0 step:  281/675, lr:0.000021, giou_loss:   1.96, conf_loss:   3.08, prob_loss:   0.93, total_loss:   5.96
# epoch: 0 step:  282/675, lr:0.000021, giou_loss:   4.33, conf_loss:   9.92, prob_loss:   9.10, total_loss:  23.36
# epoch: 0 step:  283/675, lr:0.000021, giou_loss:   2.59, conf_loss:   2.70, prob_loss:   0.36, total_loss:   5.66
# epoch: 0 step:  284/675, lr:0.000021, giou_loss:   4.84, conf_loss:   5.61, prob_loss:   1.11, total_loss:  11.56
# epoch: 0 step:  285/675, lr:0.000021, giou_loss:   3.30, conf_loss:   2.11, prob_loss:   0.82, total_loss:   6.23
# epoch: 0 step:  286/675, lr:0.000021, giou_loss:   2.93, conf_loss:   5.81, prob_loss:   3.46, total_loss:  12.19
# epoch: 0 step:  287/675, lr:0.000021, giou_loss:   3.78, conf_loss:   3.03, prob_loss:   0.66, total_loss:   7.47
# epoch: 0 step:  288/675, lr:0.000021, giou_loss:   7.43, conf_loss:   4.93, prob_loss:   1.93, total_loss:  14.29
# epoch: 0 step:  289/675, lr:0.000021, giou_loss:   5.50, conf_loss:   7.57, prob_loss:   3.27, total_loss:  16.34
# epoch: 0 step:  290/675, lr:0.000021, giou_loss:   6.82, conf_loss:  10.75, prob_loss:   6.21, total_loss:  23.79
# epoch: 0 step:  291/675, lr:0.000022, giou_loss:   5.31, conf_loss:   9.85, prob_loss:   2.09, total_loss:  17.25
# epoch: 0 step:  292/675, lr:0.000022, giou_loss:   3.53, conf_loss:   3.36, prob_loss:   2.21, total_loss:   9.11
# epoch: 0 step:  293/675, lr:0.000022, giou_loss:   5.99, conf_loss:   9.85, prob_loss:   3.89, total_loss:  19.73
# epoch: 0 step:  294/675, lr:0.000022, giou_loss:   6.04, conf_loss:   6.30, prob_loss:   1.57, total_loss:  13.92
# epoch: 0 step:  295/675, lr:0.000022, giou_loss:   4.73, conf_loss:   6.43, prob_loss:   1.88, total_loss:  13.04
# epoch: 0 step:  296/675, lr:0.000022, giou_loss:   3.69, conf_loss:   3.09, prob_loss:   1.12, total_loss:   7.90
# epoch: 0 step:  297/675, lr:0.000022, giou_loss:   8.30, conf_loss:   8.61, prob_loss:   4.39, total_loss:  21.30
# epoch: 0 step:  298/675, lr:0.000022, giou_loss:   5.34, conf_loss:   5.43, prob_loss:   1.58, total_loss:  12.34
# epoch: 0 step:  299/675, lr:0.000022, giou_loss:   1.62, conf_loss:   2.13, prob_loss:   0.31, total_loss:   4.07
# epoch: 0 step:  300/675, lr:0.000022, giou_loss:   3.98, conf_loss:   5.89, prob_loss:   2.09, total_loss:  11.96
# epoch: 0 step:  301/675, lr:0.000022, giou_loss:   3.64, conf_loss:   5.33, prob_loss:   0.78, total_loss:   9.74
# epoch: 0 step:  302/675, lr:0.000022, giou_loss:   5.44, conf_loss:   5.83, prob_loss:   3.52, total_loss:  14.80
# epoch: 0 step:  303/675, lr:0.000022, giou_loss:   2.61, conf_loss:   5.46, prob_loss:   2.97, total_loss:  11.04
# epoch: 0 step:  304/675, lr:0.000023, giou_loss:   2.39, conf_loss:   3.20, prob_loss:   0.36, total_loss:   5.96
# epoch: 0 step:  305/675, lr:0.000023, giou_loss:   4.05, conf_loss:   7.84, prob_loss:   4.26, total_loss:  16.15
# epoch: 0 step:  306/675, lr:0.000023, giou_loss:   3.01, conf_loss:   5.19, prob_loss:   1.20, total_loss:   9.41
# epoch: 0 step:  307/675, lr:0.000023, giou_loss:   1.71, conf_loss:   3.02, prob_loss:   3.95, total_loss:   8.68
# epoch: 0 step:  308/675, lr:0.000023, giou_loss:   3.44, conf_loss:   3.68, prob_loss:   3.78, total_loss:  10.89
# epoch: 0 step:  309/675, lr:0.000023, giou_loss:   5.00, conf_loss:   3.96, prob_loss:   5.98, total_loss:  14.93
# epoch: 0 step:  310/675, lr:0.000023, giou_loss:   2.85, conf_loss:   4.79, prob_loss:   3.82, total_loss:  11.46
# epoch: 0 step:  311/675, lr:0.000023, giou_loss:   5.25, conf_loss:   6.92, prob_loss:   1.67, total_loss:  13.84
# epoch: 0 step:  312/675, lr:0.000023, giou_loss:   5.23, conf_loss:   4.89, prob_loss:   2.76, total_loss:  12.88
# epoch: 0 step:  313/675, lr:0.000023, giou_loss:   1.65, conf_loss:   1.21, prob_loss:   0.20, total_loss:   3.06
# epoch: 0 step:  314/675, lr:0.000023, giou_loss:   4.28, conf_loss:   4.15, prob_loss:   1.00, total_loss:   9.43
# epoch: 0 step:  315/675, lr:0.000023, giou_loss:   7.08, conf_loss:   9.29, prob_loss:   7.55, total_loss:  23.92
# epoch: 0 step:  316/675, lr:0.000023, giou_loss:   2.40, conf_loss:   3.09, prob_loss:   2.18, total_loss:   7.67
# epoch: 0 step:  317/675, lr:0.000023, giou_loss:   4.32, conf_loss:   3.21, prob_loss:   1.51, total_loss:   9.05
# epoch: 0 step:  318/675, lr:0.000024, giou_loss:   2.31, conf_loss:   3.30, prob_loss:   0.36, total_loss:   5.97
# epoch: 0 step:  319/675, lr:0.000024, giou_loss:   2.95, conf_loss:   3.73, prob_loss:   0.45, total_loss:   7.12
# epoch: 0 step:  320/675, lr:0.000024, giou_loss:   2.37, conf_loss:   1.91, prob_loss:   0.36, total_loss:   4.63
# epoch: 0 step:  321/675, lr:0.000024, giou_loss:   2.37, conf_loss:   4.09, prob_loss:   0.45, total_loss:   6.91
# epoch: 0 step:  322/675, lr:0.000024, giou_loss:   2.45, conf_loss:   1.89, prob_loss:   0.44, total_loss:   4.78
# epoch: 0 step:  323/675, lr:0.000024, giou_loss:   4.65, conf_loss:   4.19, prob_loss:   0.95, total_loss:   9.80
# epoch: 0 step:  324/675, lr:0.000024, giou_loss:   3.86, conf_loss:   6.21, prob_loss:   2.50, total_loss:  12.57
# epoch: 0 step:  325/675, lr:0.000024, giou_loss:   3.56, conf_loss:   3.30, prob_loss:   4.62, total_loss:  11.48
# epoch: 0 step:  326/675, lr:0.000024, giou_loss:   5.08, conf_loss:   5.72, prob_loss:   3.23, total_loss:  14.03
# epoch: 0 step:  327/675, lr:0.000024, giou_loss:   3.51, conf_loss:   1.99, prob_loss:   0.84, total_loss:   6.34
# epoch: 0 step:  328/675, lr:0.000024, giou_loss:   1.65, conf_loss:   3.55, prob_loss:   0.36, total_loss:   5.56
# epoch: 0 step:  329/675, lr:0.000024, giou_loss:   2.45, conf_loss:   3.04, prob_loss:   0.44, total_loss:   5.93
# epoch: 0 step:  330/675, lr:0.000024, giou_loss:   5.53, conf_loss:   7.34, prob_loss:  14.55, total_loss:  27.42
# epoch: 0 step:  331/675, lr:0.000025, giou_loss:   3.94, conf_loss:   2.57, prob_loss:   1.53, total_loss:   8.04
# epoch: 0 step:  332/675, lr:0.000025, giou_loss:   2.86, conf_loss:   2.64, prob_loss:   1.38, total_loss:   6.88
# epoch: 0 step:  333/675, lr:0.000025, giou_loss:   2.84, conf_loss:   2.05, prob_loss:   0.81, total_loss:   5.71
# epoch: 0 step:  334/675, lr:0.000025, giou_loss:   2.83, conf_loss:   4.54, prob_loss:   1.20, total_loss:   8.57
# epoch: 0 step:  335/675, lr:0.000025, giou_loss:   3.01, conf_loss:   2.09, prob_loss:   0.70, total_loss:   5.81
# epoch: 0 step:  336/675, lr:0.000025, giou_loss:   5.82, conf_loss:   2.96, prob_loss:   1.21, total_loss:   9.98
# epoch: 0 step:  337/675, lr:0.000025, giou_loss:   2.77, conf_loss:   3.01, prob_loss:   0.78, total_loss:   6.56
# epoch: 0 step:  338/675, lr:0.000025, giou_loss:   1.20, conf_loss:   0.83, prob_loss:   0.36, total_loss:   2.39
# epoch: 0 step:  339/675, lr:0.000025, giou_loss:   0.79, conf_loss:   1.14, prob_loss:   0.18, total_loss:   2.11
# epoch: 0 step:  340/675, lr:0.000025, giou_loss:   5.53, conf_loss:   6.90, prob_loss:   1.57, total_loss:  14.00
# epoch: 0 step:  341/675, lr:0.000025, giou_loss:   3.30, conf_loss:   4.84, prob_loss:   0.66, total_loss:   8.80
# epoch: 0 step:  342/675, lr:0.000025, giou_loss:   8.19, conf_loss:   9.24, prob_loss:  14.45, total_loss:  31.88
# epoch: 0 step:  343/675, lr:0.000025, giou_loss:   3.77, conf_loss:   3.31, prob_loss:   7.16, total_loss:  14.23
# epoch: 0 step:  344/675, lr:0.000025, giou_loss:   5.00, conf_loss:   9.40, prob_loss:   1.65, total_loss:  16.05
# epoch: 0 step:  345/675, lr:0.000026, giou_loss:   2.79, conf_loss:   2.35, prob_loss:   0.60, total_loss:   5.74
# epoch: 0 step:  346/675, lr:0.000026, giou_loss:   4.59, conf_loss:   4.07, prob_loss:   2.39, total_loss:  11.05
# epoch: 0 step:  347/675, lr:0.000026, giou_loss:   1.44, conf_loss:   1.06, prob_loss:   1.24, total_loss:   3.74
# epoch: 0 step:  348/675, lr:0.000026, giou_loss:   3.38, conf_loss:   2.03, prob_loss:   0.55, total_loss:   5.96
# epoch: 0 step:  349/675, lr:0.000026, giou_loss:   4.23, conf_loss:   3.10, prob_loss:   7.72, total_loss:  15.04
# epoch: 0 step:  350/675, lr:0.000026, giou_loss:   4.23, conf_loss:   5.41, prob_loss:   2.19, total_loss:  11.83
# epoch: 0 step:  351/675, lr:0.000026, giou_loss:   4.07, conf_loss:   3.65, prob_loss:   0.74, total_loss:   8.47
# epoch: 0 step:  352/675, lr:0.000026, giou_loss:   3.48, conf_loss:   2.61, prob_loss:   0.81, total_loss:   6.89
# epoch: 0 step:  353/675, lr:0.000026, giou_loss:   4.50, conf_loss:   4.48, prob_loss:   6.85, total_loss:  15.83
# epoch: 0 step:  354/675, lr:0.000026, giou_loss:   2.79, conf_loss:   1.57, prob_loss:   0.45, total_loss:   4.81
# epoch: 0 step:  355/675, lr:0.000026, giou_loss:   3.56, conf_loss:   4.68, prob_loss:   0.81, total_loss:   9.06
# epoch: 0 step:  356/675, lr:0.000026, giou_loss:   1.12, conf_loss:   1.77, prob_loss:   3.70, total_loss:   6.58
# epoch: 0 step:  357/675, lr:0.000026, giou_loss:   6.41, conf_loss:   5.14, prob_loss:   1.25, total_loss:  12.80
# epoch: 0 step:  358/675, lr:0.000027, giou_loss:   2.86, conf_loss:   1.59, prob_loss:   0.78, total_loss:   5.23
# epoch: 0 step:  359/675, lr:0.000027, giou_loss:   5.22, conf_loss:   5.53, prob_loss:   1.82, total_loss:  12.57
# epoch: 0 step:  360/675, lr:0.000027, giou_loss:   3.23, conf_loss:   2.54, prob_loss:   0.66, total_loss:   6.43
# epoch: 0 step:  361/675, lr:0.000027, giou_loss:   3.90, conf_loss:   3.21, prob_loss:   1.29, total_loss:   8.40
# epoch: 0 step:  362/675, lr:0.000027, giou_loss:   5.00, conf_loss:   3.96, prob_loss:   1.17, total_loss:  10.14
# epoch: 0 step:  363/675, lr:0.000027, giou_loss:   4.64, conf_loss:   3.63, prob_loss:   2.70, total_loss:  10.97
# epoch: 0 step:  364/675, lr:0.000027, giou_loss:   2.93, conf_loss:   3.57, prob_loss:   4.13, total_loss:  10.63
# epoch: 0 step:  365/675, lr:0.000027, giou_loss:   2.24, conf_loss:   1.63, prob_loss:   0.40, total_loss:   4.27
# epoch: 0 step:  366/675, lr:0.000027, giou_loss:   4.50, conf_loss:   5.97, prob_loss:   1.74, total_loss:  12.21
# epoch: 0 step:  367/675, lr:0.000027, giou_loss:   3.24, conf_loss:   2.97, prob_loss:   0.52, total_loss:   6.73
# epoch: 0 step:  368/675, lr:0.000027, giou_loss:   4.73, conf_loss:   4.61, prob_loss:   1.12, total_loss:  10.46
# epoch: 0 step:  369/675, lr:0.000027, giou_loss:   4.81, conf_loss:   2.52, prob_loss:   0.90, total_loss:   8.23
# epoch: 0 step:  370/675, lr:0.000027, giou_loss:   1.86, conf_loss:   2.26, prob_loss:   0.43, total_loss:   4.56
# epoch: 0 step:  371/675, lr:0.000027, giou_loss:   2.17, conf_loss:   2.09, prob_loss:   2.85, total_loss:   7.11
# epoch: 0 step:  372/675, lr:0.000028, giou_loss:   3.25, conf_loss:   4.01, prob_loss:   2.83, total_loss:  10.10
# epoch: 0 step:  373/675, lr:0.000028, giou_loss:   2.70, conf_loss:   2.21, prob_loss:   0.63, total_loss:   5.54
# epoch: 0 step:  374/675, lr:0.000028, giou_loss:   4.12, conf_loss:   3.47, prob_loss:   0.68, total_loss:   8.27
# epoch: 0 step:  375/675, lr:0.000028, giou_loss:   5.26, conf_loss:   6.26, prob_loss:   1.22, total_loss:  12.73
# epoch: 0 step:  376/675, lr:0.000028, giou_loss:   5.99, conf_loss:  14.40, prob_loss:   9.09, total_loss:  29.48
# epoch: 0 step:  377/675, lr:0.000028, giou_loss:   4.74, conf_loss:   4.54, prob_loss:   3.22, total_loss:  12.51
# epoch: 0 step:  378/675, lr:0.000028, giou_loss:   1.60, conf_loss:   2.96, prob_loss:   1.94, total_loss:   6.50
# epoch: 0 step:  379/675, lr:0.000028, giou_loss:   9.78, conf_loss:  18.57, prob_loss:  11.25, total_loss:  39.60
# epoch: 0 step:  380/675, lr:0.000028, giou_loss:   5.01, conf_loss:   7.00, prob_loss:   1.64, total_loss:  13.66
# epoch: 0 step:  381/675, lr:0.000028, giou_loss:   3.21, conf_loss:   3.96, prob_loss:   3.67, total_loss:  10.84
# epoch: 0 step:  382/675, lr:0.000028, giou_loss:   3.86, conf_loss:   4.54, prob_loss:   1.04, total_loss:   9.44
# epoch: 0 step:  383/675, lr:0.000028, giou_loss:   4.49, conf_loss:   4.93, prob_loss:   1.51, total_loss:  10.94
# epoch: 0 step:  384/675, lr:0.000028, giou_loss:   5.25, conf_loss:   4.00, prob_loss:   1.75, total_loss:  11.01
# epoch: 0 step:  385/675, lr:0.000029, giou_loss:   4.15, conf_loss:   2.90, prob_loss:   0.74, total_loss:   7.79
# epoch: 0 step:  386/675, lr:0.000029, giou_loss:   3.23, conf_loss:   3.06, prob_loss:   0.90, total_loss:   7.19
# epoch: 0 step:  387/675, lr:0.000029, giou_loss:   4.89, conf_loss:   9.21, prob_loss:   1.13, total_loss:  15.24
# epoch: 0 step:  388/675, lr:0.000029, giou_loss:   2.46, conf_loss:   3.64, prob_loss:   8.75, total_loss:  14.85
# epoch: 0 step:  389/675, lr:0.000029, giou_loss:   1.80, conf_loss:   3.72, prob_loss:   2.14, total_loss:   7.66
# epoch: 0 step:  390/675, lr:0.000029, giou_loss:   2.69, conf_loss:   2.83, prob_loss:   0.92, total_loss:   6.44
# epoch: 0 step:  391/675, lr:0.000029, giou_loss:   1.83, conf_loss:   2.37, prob_loss:   0.98, total_loss:   5.18
# epoch: 0 step:  392/675, lr:0.000029, giou_loss:   5.04, conf_loss:   5.47, prob_loss:   5.04, total_loss:  15.55
# epoch: 0 step:  393/675, lr:0.000029, giou_loss:   3.82, conf_loss:   8.13, prob_loss:   1.96, total_loss:  13.91
# epoch: 0 step:  394/675, lr:0.000029, giou_loss:   1.91, conf_loss:   2.39, prob_loss:   1.12, total_loss:   5.42
# epoch: 0 step:  395/675, lr:0.000029, giou_loss:   2.38, conf_loss:   3.00, prob_loss:   0.47, total_loss:   5.85
# epoch: 0 step:  396/675, lr:0.000029, giou_loss:   3.14, conf_loss:   1.43, prob_loss:   0.65, total_loss:   5.22
# epoch: 0 step:  397/675, lr:0.000029, giou_loss:   3.44, conf_loss:   3.41, prob_loss:   0.90, total_loss:   7.74
# epoch: 0 step:  398/675, lr:0.000029, giou_loss:   3.26, conf_loss:   3.51, prob_loss:   0.59, total_loss:   7.37
# epoch: 0 step:  399/675, lr:0.000030, giou_loss:   4.15, conf_loss:   2.79, prob_loss:   0.61, total_loss:   7.56
# epoch: 0 step:  400/675, lr:0.000030, giou_loss:   1.74, conf_loss:   2.75, prob_loss:   0.31, total_loss:   4.80
# epoch: 0 step:  401/675, lr:0.000030, giou_loss:   3.53, conf_loss:   5.71, prob_loss:   1.41, total_loss:  10.65
# epoch: 0 step:  402/675, lr:0.000030, giou_loss:   4.20, conf_loss:   4.94, prob_loss:   1.11, total_loss:  10.25
# epoch: 0 step:  403/675, lr:0.000030, giou_loss:   3.35, conf_loss:   4.75, prob_loss:   5.65, total_loss:  13.74
# epoch: 0 step:  404/675, lr:0.000030, giou_loss:   3.62, conf_loss:   4.71, prob_loss:   0.56, total_loss:   8.89
# epoch: 0 step:  405/675, lr:0.000030, giou_loss:   4.74, conf_loss:   4.03, prob_loss:   1.21, total_loss:   9.98
# epoch: 0 step:  406/675, lr:0.000030, giou_loss:   4.76, conf_loss:   4.59, prob_loss:   0.67, total_loss:  10.02
# epoch: 0 step:  407/675, lr:0.000030, giou_loss:   4.04, conf_loss:   4.18, prob_loss:   0.89, total_loss:   9.11
# epoch: 0 step:  408/675, lr:0.000030, giou_loss:   2.18, conf_loss:   2.11, prob_loss:   0.85, total_loss:   5.15
# epoch: 0 step:  409/675, lr:0.000030, giou_loss:   3.68, conf_loss:   2.98, prob_loss:   1.60, total_loss:   8.25
# epoch: 0 step:  410/675, lr:0.000030, giou_loss:   3.82, conf_loss:   3.19, prob_loss:   0.86, total_loss:   7.87
# epoch: 0 step:  411/675, lr:0.000030, giou_loss:   3.90, conf_loss:   3.58, prob_loss:   1.09, total_loss:   8.56
# epoch: 0 step:  412/675, lr:0.000031, giou_loss:   1.61, conf_loss:   2.33, prob_loss:   4.57, total_loss:   8.51
# epoch: 0 step:  413/675, lr:0.000031, giou_loss:   4.55, conf_loss:   2.79, prob_loss:   3.57, total_loss:  10.91
# epoch: 0 step:  414/675, lr:0.000031, giou_loss:   3.92, conf_loss:   4.45, prob_loss:   0.81, total_loss:   9.18
# epoch: 0 step:  415/675, lr:0.000031, giou_loss:   2.52, conf_loss:   3.00, prob_loss:   0.91, total_loss:   6.43
# epoch: 0 step:  416/675, lr:0.000031, giou_loss:   2.03, conf_loss:   1.39, prob_loss:   0.59, total_loss:   4.00
# epoch: 0 step:  417/675, lr:0.000031, giou_loss:   4.05, conf_loss:   6.46, prob_loss:   2.32, total_loss:  12.83
# ...
# epoch:31 step:  537/675, lr:0.000032, giou_loss:   0.74, conf_loss:   0.00, prob_loss:   0.32, total_loss:   1.06
# epoch:31 step:  538/675, lr:0.000032, giou_loss:   1.89, conf_loss:   0.03, prob_loss:   0.68, total_loss:   2.60
# epoch:31 step:  539/675, lr:0.000032, giou_loss:   1.17, conf_loss:   0.03, prob_loss:   0.39, total_loss:   1.59
# epoch:31 step:  540/675, lr:0.000032, giou_loss:   1.54, conf_loss:   1.72, prob_loss:   0.49, total_loss:   3.76
# epoch:31 step:  541/675, lr:0.000032, giou_loss:   2.02, conf_loss:   0.13, prob_loss:   0.45, total_loss:   2.60
# epoch:31 step:  542/675, lr:0.000032, giou_loss:   0.66, conf_loss:   0.01, prob_loss:   0.30, total_loss:   0.97
# epoch:31 step:  543/675, lr:0.000032, giou_loss:   0.79, conf_loss:   0.03, prob_loss:   0.29, total_loss:   1.11
# epoch:31 step:  544/675, lr:0.000032, giou_loss:   1.74, conf_loss:   0.01, prob_loss:   0.62, total_loss:   2.37
# epoch:31 step:  545/675, lr:0.000032, giou_loss:   1.96, conf_loss:   0.06, prob_loss:   0.61, total_loss:   2.63
# epoch:31 step:  546/675, lr:0.000032, giou_loss:   1.13, conf_loss:   0.01, prob_loss:   0.34, total_loss:   1.48
# epoch:31 step:  547/675, lr:0.000032, giou_loss:   0.82, conf_loss:   0.01, prob_loss:   0.38, total_loss:   1.20
# epoch:31 step:  548/675, lr:0.000032, giou_loss:   1.17, conf_loss:   0.01, prob_loss:   0.41, total_loss:   1.60
# epoch:31 step:  549/675, lr:0.000032, giou_loss:   1.10, conf_loss:   0.01, prob_loss:   0.30, total_loss:   1.41
# epoch:31 step:  550/675, lr:0.000032, giou_loss:   1.52, conf_loss:   0.03, prob_loss:   0.51, total_loss:   2.06
# epoch:31 step:  551/675, lr:0.000032, giou_loss:   1.51, conf_loss:   1.05, prob_loss:   0.45, total_loss:   3.01
# epoch:31 step:  552/675, lr:0.000032, giou_loss:   1.49, conf_loss:   0.40, prob_loss:   0.42, total_loss:   2.31
# epoch:31 step:  553/675, lr:0.000032, giou_loss:   0.70, conf_loss:   0.01, prob_loss:   0.37, total_loss:   1.07
# epoch:31 step:  554/675, lr:0.000032, giou_loss:   0.74, conf_loss:   0.00, prob_loss:   0.33, total_loss:   1.08
# epoch:31 step:  555/675, lr:0.000032, giou_loss:   1.90, conf_loss:   0.04, prob_loss:   0.64, total_loss:   2.57
# epoch:31 step:  556/675, lr:0.000032, giou_loss:   0.99, conf_loss:   0.01, prob_loss:   0.43, total_loss:   1.42
# epoch:31 step:  557/675, lr:0.000032, giou_loss:   0.96, conf_loss:   0.01, prob_loss:   0.39, total_loss:   1.37
# epoch:31 step:  558/675, lr:0.000032, giou_loss:   2.00, conf_loss:   0.18, prob_loss:   0.72, total_loss:   2.90
# epoch:31 step:  559/675, lr:0.000032, giou_loss:   1.93, conf_loss:   0.05, prob_loss:   0.53, total_loss:   2.52
# epoch:31 step:  560/675, lr:0.000032, giou_loss:   0.77, conf_loss:   0.00, prob_loss:   0.30, total_loss:   1.07
# epoch:31 step:  561/675, lr:0.000032, giou_loss:   2.20, conf_loss:   0.01, prob_loss:   0.73, total_loss:   2.94
# epoch:31 step:  562/675, lr:0.000032, giou_loss:   0.91, conf_loss:   0.01, prob_loss:   0.31, total_loss:   1.23
# epoch:31 step:  563/675, lr:0.000032, giou_loss:   1.66, conf_loss:   0.00, prob_loss:   0.41, total_loss:   2.07
# epoch:31 step:  564/675, lr:0.000032, giou_loss:   0.79, conf_loss:   0.02, prob_loss:   0.40, total_loss:   1.22
# epoch:31 step:  565/675, lr:0.000032, giou_loss:   1.64, conf_loss:   0.11, prob_loss:   0.41, total_loss:   2.16
# epoch:31 step:  566/675, lr:0.000032, giou_loss:   0.91, conf_loss:   0.01, prob_loss:   0.35, total_loss:   1.26
# epoch:31 step:  567/675, lr:0.000032, giou_loss:   1.09, conf_loss:   0.01, prob_loss:   0.51, total_loss:   1.61
# epoch:31 step:  568/675, lr:0.000032, giou_loss:   0.52, conf_loss:   0.00, prob_loss:   0.25, total_loss:   0.78
# epoch:31 step:  569/675, lr:0.000032, giou_loss:   1.92, conf_loss:   0.43, prob_loss:   0.44, total_loss:   2.79
# epoch:31 step:  570/675, lr:0.000032, giou_loss:   1.62, conf_loss:   1.59, prob_loss:   0.32, total_loss:   3.52
# epoch:31 step:  571/675, lr:0.000032, giou_loss:   0.90, conf_loss:   0.01, prob_loss:   0.40, total_loss:   1.31
# epoch:31 step:  572/675, lr:0.000032, giou_loss:   1.34, conf_loss:   0.02, prob_loss:   0.37, total_loss:   1.74
# epoch:31 step:  573/675, lr:0.000032, giou_loss:   1.85, conf_loss:   0.01, prob_loss:   0.69, total_loss:   2.55
# epoch:31 step:  574/675, lr:0.000032, giou_loss:   0.69, conf_loss:   0.01, prob_loss:   0.21, total_loss:   0.90
# epoch:31 step:  575/675, lr:0.000032, giou_loss:   0.80, conf_loss:   0.01, prob_loss:   0.30, total_loss:   1.12
# epoch:31 step:  576/675, lr:0.000032, giou_loss:   1.47, conf_loss:   0.02, prob_loss:   0.59, total_loss:   2.07
# epoch:31 step:  577/675, lr:0.000032, giou_loss:   0.74, conf_loss:   0.01, prob_loss:   0.21, total_loss:   0.95
# epoch:31 step:  578/675, lr:0.000032, giou_loss:   1.39, conf_loss:   0.02, prob_loss:   0.45, total_loss:   1.87
# epoch:31 step:  579/675, lr:0.000032, giou_loss:   1.19, conf_loss:   0.00, prob_loss:   0.34, total_loss:   1.53
# epoch:31 step:  580/675, lr:0.000032, giou_loss:   1.51, conf_loss:   0.09, prob_loss:   0.53, total_loss:   2.13
# epoch:31 step:  581/675, lr:0.000032, giou_loss:   1.25, conf_loss:   1.21, prob_loss:   0.39, total_loss:   2.84
# epoch:31 step:  582/675, lr:0.000032, giou_loss:   0.50, conf_loss:   0.00, prob_loss:   0.22, total_loss:   0.73
# epoch:31 step:  583/675, lr:0.000032, giou_loss:   2.26, conf_loss:   0.09, prob_loss:   0.48, total_loss:   2.82
# epoch:31 step:  584/675, lr:0.000032, giou_loss:   2.61, conf_loss:   0.95, prob_loss:   0.65, total_loss:   4.21
# epoch:31 step:  585/675, lr:0.000032, giou_loss:   0.82, conf_loss:   0.00, prob_loss:   0.27, total_loss:   1.10
# epoch:31 step:  586/675, lr:0.000032, giou_loss:   0.77, conf_loss:   0.00, prob_loss:   0.27, total_loss:   1.05
# epoch:31 step:  587/675, lr:0.000032, giou_loss:   1.25, conf_loss:   0.04, prob_loss:   0.40, total_loss:   1.69
# epoch:31 step:  588/675, lr:0.000032, giou_loss:   1.84, conf_loss:   0.03, prob_loss:   0.59, total_loss:   2.46
# epoch:31 step:  589/675, lr:0.000032, giou_loss:   2.11, conf_loss:   0.98, prob_loss:   0.53, total_loss:   3.62
# epoch:31 step:  590/675, lr:0.000032, giou_loss:   0.71, conf_loss:   0.01, prob_loss:   0.32, total_loss:   1.03
# epoch:31 step:  591/675, lr:0.000032, giou_loss:   2.02, conf_loss:   0.02, prob_loss:   0.69, total_loss:   2.73
# epoch:31 step:  592/675, lr:0.000032, giou_loss:   1.74, conf_loss:   0.01, prob_loss:   0.45, total_loss:   2.21
# epoch:31 step:  593/675, lr:0.000032, giou_loss:   1.22, conf_loss:   0.00, prob_loss:   0.37, total_loss:   1.59
# epoch:31 step:  594/675, lr:0.000032, giou_loss:   0.99, conf_loss:   0.00, prob_loss:   0.32, total_loss:   1.31
# epoch:31 step:  595/675, lr:0.000032, giou_loss:   0.66, conf_loss:   0.00, prob_loss:   0.32, total_loss:   0.98
# epoch:31 step:  596/675, lr:0.000032, giou_loss:   1.89, conf_loss:   0.07, prob_loss:   0.51, total_loss:   2.48
# epoch:31 step:  597/675, lr:0.000032, giou_loss:   2.15, conf_loss:   0.09, prob_loss:   0.65, total_loss:   2.89
# epoch:31 step:  598/675, lr:0.000032, giou_loss:   1.32, conf_loss:   0.09, prob_loss:   0.48, total_loss:   1.89
# epoch:31 step:  599/675, lr:0.000032, giou_loss:   0.92, conf_loss:   0.01, prob_loss:   0.31, total_loss:   1.24
# epoch:31 step:  600/675, lr:0.000032, giou_loss:   0.97, conf_loss:   0.01, prob_loss:   0.35, total_loss:   1.33
# epoch:31 step:  601/675, lr:0.000032, giou_loss:   1.32, conf_loss:   0.05, prob_loss:   0.44, total_loss:   1.81
# epoch:31 step:  602/675, lr:0.000032, giou_loss:   1.03, conf_loss:   0.03, prob_loss:   0.42, total_loss:   1.47
# epoch:31 step:  603/675, lr:0.000032, giou_loss:   0.57, conf_loss:   0.03, prob_loss:   0.19, total_loss:   0.79
# epoch:31 step:  604/675, lr:0.000032, giou_loss:   0.71, conf_loss:   0.00, prob_loss:   0.19, total_loss:   0.91
# epoch:31 step:  605/675, lr:0.000032, giou_loss:   1.02, conf_loss:   0.02, prob_loss:   0.32, total_loss:   1.36
# epoch:31 step:  606/675, lr:0.000032, giou_loss:   0.88, conf_loss:   0.03, prob_loss:   0.34, total_loss:   1.25
# epoch:31 step:  607/675, lr:0.000032, giou_loss:   0.74, conf_loss:   0.05, prob_loss:   0.21, total_loss:   1.00
# epoch:31 step:  608/675, lr:0.000032, giou_loss:   3.32, conf_loss:   0.14, prob_loss:   0.79, total_loss:   4.24
# epoch:31 step:  609/675, lr:0.000032, giou_loss:   0.96, conf_loss:   0.03, prob_loss:   0.40, total_loss:   1.39
# epoch:31 step:  610/675, lr:0.000032, giou_loss:   0.83, conf_loss:   0.01, prob_loss:   0.24, total_loss:   1.08
# epoch:31 step:  611/675, lr:0.000032, giou_loss:   1.10, conf_loss:   0.03, prob_loss:   0.42, total_loss:   1.55
# epoch:31 step:  612/675, lr:0.000032, giou_loss:   0.59, conf_loss:   0.00, prob_loss:   0.23, total_loss:   0.82
# epoch:31 step:  613/675, lr:0.000032, giou_loss:   1.64, conf_loss:   0.02, prob_loss:   0.50, total_loss:   2.15
# epoch:31 step:  614/675, lr:0.000032, giou_loss:   1.61, conf_loss:   0.01, prob_loss:   0.56, total_loss:   2.17
# epoch:31 step:  615/675, lr:0.000032, giou_loss:   1.50, conf_loss:   0.02, prob_loss:   0.48, total_loss:   2.01
# epoch:31 step:  616/675, lr:0.000032, giou_loss:   0.53, conf_loss:   0.02, prob_loss:   0.31, total_loss:   0.85
# epoch:31 step:  617/675, lr:0.000032, giou_loss:   0.39, conf_loss:   0.00, prob_loss:   0.22, total_loss:   0.61
# epoch:31 step:  618/675, lr:0.000032, giou_loss:   1.76, conf_loss:   0.48, prob_loss:   0.43, total_loss:   2.67
# epoch:31 step:  619/675, lr:0.000032, giou_loss:   1.13, conf_loss:   0.00, prob_loss:   0.41, total_loss:   1.55
# epoch:31 step:  620/675, lr:0.000032, giou_loss:   1.31, conf_loss:   0.02, prob_loss:   0.59, total_loss:   1.92
# epoch:31 step:  621/675, lr:0.000032, giou_loss:   1.32, conf_loss:   0.02, prob_loss:   0.32, total_loss:   1.66
# epoch:31 step:  622/675, lr:0.000032, giou_loss:   0.62, conf_loss:   0.00, prob_loss:   0.24, total_loss:   0.87
# epoch:31 step:  623/675, lr:0.000032, giou_loss:   1.38, conf_loss:   0.01, prob_loss:   0.51, total_loss:   1.89
# epoch:31 step:  624/675, lr:0.000032, giou_loss:   1.70, conf_loss:   0.02, prob_loss:   0.62, total_loss:   2.34
# epoch:31 step:  625/675, lr:0.000032, giou_loss:   1.18, conf_loss:   0.01, prob_loss:   0.35, total_loss:   1.53
# epoch:31 step:  626/675, lr:0.000032, giou_loss:   1.00, conf_loss:   0.00, prob_loss:   0.33, total_loss:   1.33
# epoch:31 step:  627/675, lr:0.000032, giou_loss:   1.03, conf_loss:   0.02, prob_loss:   0.41, total_loss:   1.46
# epoch:31 step:  628/675, lr:0.000032, giou_loss:   0.78, conf_loss:   0.01, prob_loss:   0.29, total_loss:   1.08
# epoch:31 step:  629/675, lr:0.000032, giou_loss:   0.94, conf_loss:   0.02, prob_loss:   0.35, total_loss:   1.31
# epoch:31 step:  630/675, lr:0.000032, giou_loss:   2.44, conf_loss:   0.45, prob_loss:   0.64, total_loss:   3.54
# epoch:31 step:  631/675, lr:0.000032, giou_loss:   0.43, conf_loss:   0.00, prob_loss:   0.19, total_loss:   0.62
# epoch:31 step:  632/675, lr:0.000032, giou_loss:   1.59, conf_loss:   0.06, prob_loss:   0.55, total_loss:   2.21
# epoch:31 step:  633/675, lr:0.000032, giou_loss:   1.22, conf_loss:   0.57, prob_loss:   0.40, total_loss:   2.19
# epoch:31 step:  634/675, lr:0.000032, giou_loss:   0.98, conf_loss:   0.03, prob_loss:   0.40, total_loss:   1.41
# epoch:31 step:  635/675, lr:0.000032, giou_loss:   0.54, conf_loss:   0.00, prob_loss:   0.19, total_loss:   0.73
# epoch:31 step:  636/675, lr:0.000032, giou_loss:   1.32, conf_loss:   0.03, prob_loss:   0.40, total_loss:   1.75
# epoch:31 step:  637/675, lr:0.000032, giou_loss:   0.96, conf_loss:   0.01, prob_loss:   0.33, total_loss:   1.30
# epoch:31 step:  638/675, lr:0.000032, giou_loss:   1.54, conf_loss:   0.03, prob_loss:   0.49, total_loss:   2.06
# epoch:31 step:  639/675, lr:0.000032, giou_loss:   0.44, conf_loss:   0.01, prob_loss:   0.21, total_loss:   0.66
# epoch:31 step:  640/675, lr:0.000032, giou_loss:   0.85, conf_loss:   0.01, prob_loss:   0.42, total_loss:   1.28
# epoch:31 step:  641/675, lr:0.000032, giou_loss:   0.96, conf_loss:   0.00, prob_loss:   0.26, total_loss:   1.22
# epoch:31 step:  642/675, lr:0.000032, giou_loss:   0.83, conf_loss:   0.01, prob_loss:   0.37, total_loss:   1.20
# epoch:31 step:  643/675, lr:0.000032, giou_loss:   1.39, conf_loss:   0.14, prob_loss:   0.41, total_loss:   1.94
# epoch:31 step:  644/675, lr:0.000032, giou_loss:   1.06, conf_loss:   0.02, prob_loss:   0.38, total_loss:   1.47
# epoch:31 step:  645/675, lr:0.000032, giou_loss:   1.00, conf_loss:   0.02, prob_loss:   0.40, total_loss:   1.41
# epoch:31 step:  646/675, lr:0.000032, giou_loss:   0.68, conf_loss:   0.00, prob_loss:   0.30, total_loss:   0.99
# epoch:31 step:  647/675, lr:0.000032, giou_loss:   2.49, conf_loss:   0.46, prob_loss:   0.58, total_loss:   3.53
# epoch:31 step:  648/675, lr:0.000032, giou_loss:   1.21, conf_loss:   0.03, prob_loss:   0.33, total_loss:   1.57
# epoch:31 step:  649/675, lr:0.000032, giou_loss:   0.69, conf_loss:   0.02, prob_loss:   0.22, total_loss:   0.93
# epoch:31 step:  650/675, lr:0.000032, giou_loss:   0.75, conf_loss:   0.00, prob_loss:   0.24, total_loss:   0.99
# epoch:31 step:  651/675, lr:0.000032, giou_loss:   1.55, conf_loss:   0.04, prob_loss:   0.44, total_loss:   2.03
# epoch:31 step:  652/675, lr:0.000032, giou_loss:   0.44, conf_loss:   0.00, prob_loss:   0.19, total_loss:   0.63
# epoch:31 step:  653/675, lr:0.000032, giou_loss:   1.33, conf_loss:   0.00, prob_loss:   0.39, total_loss:   1.72
# epoch:31 step:  654/675, lr:0.000032, giou_loss:   1.18, conf_loss:   0.02, prob_loss:   0.46, total_loss:   1.67
# epoch:31 step:  655/675, lr:0.000032, giou_loss:   1.66, conf_loss:   0.01, prob_loss:   0.69, total_loss:   2.35
# epoch:31 step:  656/675, lr:0.000032, giou_loss:   0.94, conf_loss:   0.05, prob_loss:   0.32, total_loss:   1.31
# epoch:31 step:  657/675, lr:0.000032, giou_loss:   2.16, conf_loss:   0.02, prob_loss:   0.59, total_loss:   2.76
# epoch:31 step:  658/675, lr:0.000032, giou_loss:   0.60, conf_loss:   0.00, prob_loss:   0.25, total_loss:   0.85
# epoch:31 step:  659/675, lr:0.000032, giou_loss:   0.48, conf_loss:   0.02, prob_loss:   0.17, total_loss:   0.67
# epoch:31 step:  660/675, lr:0.000032, giou_loss:   0.94, conf_loss:   0.03, prob_loss:   0.47, total_loss:   1.43
# epoch:31 step:  661/675, lr:0.000032, giou_loss:   0.61, conf_loss:   0.02, prob_loss:   0.33, total_loss:   0.97
# epoch:31 step:  662/675, lr:0.000032, giou_loss:   0.63, conf_loss:   0.01, prob_loss:   0.21, total_loss:   0.85
# epoch:31 step:  663/675, lr:0.000032, giou_loss:   0.62, conf_loss:   0.00, prob_loss:   0.23, total_loss:   0.85
# epoch:31 step:  664/675, lr:0.000032, giou_loss:   1.62, conf_loss:   0.02, prob_loss:   0.55, total_loss:   2.19
# epoch:31 step:  665/675, lr:0.000032, giou_loss:   1.04, conf_loss:   0.02, prob_loss:   0.37, total_loss:   1.43
# epoch:31 step:  666/675, lr:0.000032, giou_loss:   1.30, conf_loss:   0.01, prob_loss:   0.38, total_loss:   1.69
# epoch:31 step:  667/675, lr:0.000032, giou_loss:   1.71, conf_loss:   0.03, prob_loss:   0.49, total_loss:   2.23
# epoch:31 step:  668/675, lr:0.000032, giou_loss:   0.67, conf_loss:   0.02, prob_loss:   0.24, total_loss:   0.94
# epoch:31 step:  669/675, lr:0.000032, giou_loss:   1.25, conf_loss:   0.01, prob_loss:   0.36, total_loss:   1.62
# epoch:31 step:  670/675, lr:0.000032, giou_loss:   1.86, conf_loss:   1.05, prob_loss:   0.48, total_loss:   3.39
# epoch:31 step:  671/675, lr:0.000032, giou_loss:   1.36, conf_loss:   0.09, prob_loss:   0.46, total_loss:   1.91
# epoch:31 step:  672/675, lr:0.000032, giou_loss:   0.67, conf_loss:   0.05, prob_loss:   0.32, total_loss:   1.04
# epoch:31 step:  673/675, lr:0.000032, giou_loss:   1.43, conf_loss:   0.09, prob_loss:   0.48, total_loss:   2.00
# epoch:31 step:  674/675, lr:0.000032, giou_loss:   1.30, conf_loss:   0.00, prob_loss:   0.48, total_loss:   1.78
# epoch:31 step:    0/675, lr:0.000032, giou_loss:   1.46, conf_loss:   0.03, prob_loss:   0.54, total_loss:   2.03
# epoch:31 step:    1/675, lr:0.000032, giou_loss:   1.20, conf_loss:   0.02, prob_loss:   0.32, total_loss:   1.54

# %%
import numpy
import sklearn.metrics

def precision_recall_curve(y_true, pred_scores, thresholds):
    precisions = []
    recalls = []
    
    for threshold in thresholds:
        y_pred = ["positive" if score >= threshold else "negative" for score in pred_scores]

        precision = sklearn.metrics.precision_score(y_true=y_true, y_pred=y_pred, pos_label="positive")
        recall = sklearn.metrics.recall_score(y_true=y_true, y_pred=y_pred, pos_label="positive")
        
        precisions.append(precision)
        recalls.append(recall)

    return precisions, recalls

# %%
y_true = ["positive", "negative", "negative", "positive", "positive", "positive", "negative", "positive", "negative", "positive", "positive", "positive", "positive", "negative", "negative", "negative"]
pred_scores = [0.7, 0.3, 0.5, 0.6, 0.55, 0.9, 0.4, 0.2, 0.4, 0.3, 0.7, 0.5, 0.8, 0.2, 0.3, 0.35]
thresholds=numpy.arange(start=0.2, stop=0.7, step=0.05)

precisions, recalls = precision_recall_curve(y_true=y_true, 
                                             pred_scores=pred_scores, 
                                             thresholds=thresholds)

precisions.append(1)
recalls.append(0)

precisions = numpy.array(precisions)
recalls = numpy.array(recalls)

AP = numpy.sum((recalls[:-1] - recalls[1:]) * precisions[:-1])
print(AP)
# Out:
# 0.8898809523809523

# %%
y_true = ["positive", "negative", "positive", "negative", "positive", "positive", "positive", "negative", "positive", "negative"]

pred_scores = [0.7, 0.3, 0.5, 0.6, 0.55, 0.9, 0.75, 0.2, 0.8, 0.3]

# %%
thresholds = numpy.arange(start=0.2, stop=0.9, step=0.05)

# %%
import matplotlib.pyplot

# %%
precisions, recalls = precision_recall_curve(y_true=y_true, 
                                             pred_scores=pred_scores, 
                                             thresholds=thresholds)

matplotlib.pyplot.plot(recalls, precisions, linewidth=4, color="red", zorder=0)

matplotlib.pyplot.xlabel("Recall", fontsize=12, fontweight='bold')
matplotlib.pyplot.ylabel("Precision", fontsize=12, fontweight='bold')
matplotlib.pyplot.title("Precision-Recall Curve", fontsize=15, fontweight="bold")
matplotlib.pyplot.show()

precisions.append(1)
recalls.append(0)

precisions = numpy.array(precisions)
recalls = numpy.array(recalls)

AP = numpy.sum((recalls[:-1] - recalls[1:]) * precisions[:-1])
print(AP)
# Out:
# 0.9484126984126984

# %%
y_true = ["negative", "positive", "positive", "negative", "negative", "positive", "positive", "positive", "negative", "positive"]

pred_scores = [0.32, 0.9, 0.5, 0.1, 0.25, 0.9, 0.55, 0.3, 0.35, 0.85]

# %%
precisions, recalls = precision_recall_curve(y_true=y_true, 
                                             pred_scores=pred_scores, 
                                             thresholds=thresholds)

matplotlib.pyplot.plot(recalls, precisions, linewidth=4, color="red", zorder=0)

matplotlib.pyplot.xlabel("Recall", fontsize=12, fontweight='bold')
matplotlib.pyplot.ylabel("Precision", fontsize=12, fontweight='bold')
matplotlib.pyplot.title("Precision-Recall Curve", fontsize=15, fontweight="bold")
matplotlib.pyplot.show()

precisions.append(1)
recalls.append(0)

precisions = numpy.array(precisions)
recalls = numpy.array(recalls)

AP = numpy.sum((recalls[:-1] - recalls[1:]) * precisions[:-1])
print(AP)
# Out:
# 0.8898809523809526

# %% [markdown]
# test

# %%
import os
import cv2
import numpy as np
import random
import time
import tensorflow as tf
# from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt


YOLO_INPUT_SIZE = 416
input_size=YOLO_INPUT_SIZE

image_path ="yb2.png" #image_info[0]

yolo = Create_Yolov3(input_size=input_size, CLASSES=TRAIN_CLASSES)
yolo.load_weights("./checkpoints2/yolov3_custom")

# image = cv2.imread('./yb3.png')
# cv2.cvtColor(image, cv2.COLOR_BGR2RGB, dst=image)
# plt.imshow(image)

img = detect_image(yolo, image_path, "", input_size=input_size, show=True, CLASSES=TRAIN_CLASSES, rectangle_colors=(255,0,0))
plt.imshow(img)
# Out:
# 1/1 [==============================] - 1s 938ms/step

# %%
yolo.save('my_model3.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
loaded_model = tf.keras.models.load_model('my_model3.h5')

loaded_model.load_weights("./checkpoints2/yolov3_custom")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
#loaded_model.summary()
img = detect_image(loaded_model, image_path, "", input_size=input_size, show=True, CLASSES=TRAIN_CLASSES, rectangle_colors=(255,0,0))
plt.imshow(img)
# Out:
# 1/1 [==============================] - 1s 624ms/step
