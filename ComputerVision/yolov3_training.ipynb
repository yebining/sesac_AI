# %% [markdown]
# config

# %%
# YOLO options
YOLO_DARKNET_WEIGHTS        = "yolov3.weights"
YOLO_COCO_CLASSES           = "helmet.names"
YOLO_STRIDES                = [8, 16, 32]
YOLO_IOU_LOSS_THRESH        = 0.5
YOLO_ANCHOR_PER_SCALE       = 3
YOLO_MAX_BBOX_PER_SCALE     = 100
YOLO_INPUT_SIZE             = 416
YOLO_ANCHORS                = [[[10,  13], [16,   30], [33,   23]],
                               [[30,  61], [62,   45], [59,  119]],
                               [[116, 90], [156, 198], [373, 326]]]
# Train options
TRAIN_CLASSES               = "helmet.names"
TRAIN_ANNOT_PATH            = "train.txt"
TRAIN_BATCH_SIZE            = 4
TRAIN_INPUT_SIZE            = 416
TRAIN_DATA_AUG              = True
TRAIN_TRANSFER              = False
TRAIN_FROM_CHECKPOINT       = "yolov3_custom"

TRAIN_LR_INIT               = 1e-4
TRAIN_LR_END                = 1e-6
TRAIN_WARMUP_EPOCHS         = 2
TRAIN_EPOCHS                = 100

# TEST options
TEST_ANNOT_PATH             = "val.txt"
TEST_BATCH_SIZE             = 4
TEST_INPUT_SIZE             = 416
TEST_DATA_AUG               = False

# %%
import cv2
import time
import random
import colorsys
import numpy as np
import tensorflow as tf

# %% [markdown]
# utils

# %%
def load_yolo_weights(model, weights_file):
    tf.keras.backend.clear_session() # used to reset layer names
    # load Darknet original weights to Keras model
    with open(weights_file, 'rb') as wf:
        major, minor, revision, seen, _ = np.fromfile(wf, dtype=np.int32, count=5)

        j = 0
        for i in range(75):
            if i > 0:
                conv_layer_name = 'conv2d_%d' %i
            else:
                conv_layer_name = 'conv2d'
                
            if j > 0:
                bn_layer_name = 'batch_normalization_%d' %j
            else:
                bn_layer_name = 'batch_normalization'
            
            conv_layer = model.get_layer(conv_layer_name)
            filters = conv_layer.filters
            k_size = conv_layer.kernel_size[0]
            in_dim = conv_layer.input_shape[-1]

            if i not in [58, 66, 74]:
                # darknet weights: [beta, gamma, mean, variance]
                bn_weights = np.fromfile(wf, dtype=np.float32, count=4 * filters)
                # tf weights: [gamma, beta, mean, variance]
                bn_weights = bn_weights.reshape((4, filters))[[1, 0, 2, 3]]
                bn_layer = model.get_layer(bn_layer_name)
                j += 1
            else:
                conv_bias = np.fromfile(wf, dtype=np.float32, count=filters)

            # darknet shape (out_dim, in_dim, height, width)
            conv_shape = (filters, in_dim, k_size, k_size)
            conv_weights = np.fromfile(wf, dtype=np.float32, count=np.product(conv_shape))
            # tf shape (height, width, in_dim, out_dim)
            conv_weights = conv_weights.reshape(conv_shape).transpose([2, 3, 1, 0])

            if i not in [58, 66, 74]:
                conv_layer.set_weights([conv_weights])
                bn_layer.set_weights(bn_weights)
            else:
                conv_layer.set_weights([conv_weights, conv_bias])

# %%
def read_class_names(class_file_name):
    # loads class name from a file
    #print(class_file_name)
    names = {}
    with open(class_file_name, 'r') as data:
        for ID, name in enumerate(data):
            names[ID] = name.strip('\n')
    return names

# %%
def image_preprocess(image, target_size, gt_boxes=None):
    ih, iw    = target_size
    h,  w, _  = image.shape

    scale = min(iw/w, ih/h)
    nw, nh  = int(scale * w), int(scale * h)
    image_resized = cv2.resize(image, (nw, nh))

    image_paded = np.full(shape=[ih, iw, 3], fill_value=128.0)
    dw, dh = (iw - nw) // 2, (ih-nh) // 2
    image_paded[dh:nh+dh, dw:nw+dw, :] = image_resized
    image_paded = image_paded / 255.

    if gt_boxes is None:
        return image_paded

    else:
        gt_boxes[:, [0, 2]] = gt_boxes[:, [0, 2]] * scale + dw
        gt_boxes[:, [1, 3]] = gt_boxes[:, [1, 3]] * scale + dh
        return image_paded, gt_boxes

# %%
def draw_bbox(image, bboxes, CLASSES=YOLO_COCO_CLASSES, show_label=True, show_confidence = True, Text_colors=(255,255,0), rectangle_colors=''):   
    NUM_CLASS = read_class_names(CLASSES)
    num_classes = len(NUM_CLASS)
    image_h, image_w, _ = image.shape
    hsv_tuples = [(1.0 * x / num_classes, 1., 1.) for x in range(num_classes)]
    #print("hsv_tuples", hsv_tuples)
    colors = list(map(lambda x: colorsys.hsv_to_rgb(*x), hsv_tuples))
    colors = list(map(lambda x: (int(x[0] * 255), int(x[1] * 255), int(x[2] * 255)), colors))

    random.seed(0)
    random.shuffle(colors)
    random.seed(None)

    for i, bbox in enumerate(bboxes):
        coor = np.array(bbox[:4], dtype=np.int32)
        score = bbox[4]
        class_ind = int(bbox[5])
        bbox_color = rectangle_colors if rectangle_colors != ''else colors[class_ind]
        bbox_thick = int(0.6 * (image_h + image_w) / 1000)
        if bbox_thick < 1: bbox_thick = 1
        #print(image_h, image_w, bbox_thick)
        fontScale = 0.75 * bbox_thick
        (x1, y1), (x2, y2) = (coor[0], coor[1]), (coor[2], coor[3])

        # put object rectangle
        cv2.rectangle(image, (x1, y1), (x2, y2), bbox_color, bbox_thick*2)

        if show_label:
            # get text label
            score_str = f' {score:.2f}' if show_confidence else '' 
            label = f'{NUM_CLASS[class_ind]}' + score_str

            # get text size
            (text_width, text_height), baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_COMPLEX_SMALL,
                                                                  fontScale, thickness=bbox_thick)
            # put filled text rectangle
            cv2.rectangle(image, (x1, y1), (x1 + text_width, y1 - text_height - baseline), bbox_color, thickness=cv2.FILLED)

            # put text above rectangle
            cv2.putText(image, label, (x1, y1-4), cv2.FONT_HERSHEY_COMPLEX_SMALL,
                        fontScale, Text_colors, bbox_thick, lineType=cv2.LINE_AA)

    print()
    return image

# %%
def bboxes_iou(boxes1, boxes2):
    boxes1 = np.array(boxes1)
    boxes2 = np.array(boxes2)

    boxes1_area = (boxes1[..., 2] - boxes1[..., 0]) * (boxes1[..., 3] - boxes1[..., 1])
    boxes2_area = (boxes2[..., 2] - boxes2[..., 0]) * (boxes2[..., 3] - boxes2[..., 1])

    left_up       = np.maximum(boxes1[..., :2], boxes2[..., :2])
    right_down    = np.minimum(boxes1[..., 2:], boxes2[..., 2:])

    inter_section = np.maximum(right_down - left_up, 0.0)
    inter_area    = inter_section[..., 0] * inter_section[..., 1]
    union_area    = boxes1_area + boxes2_area - inter_area
    ious          = np.maximum(1.0 * inter_area / union_area, np.finfo(np.float32).eps)

    return ious

# %%
def nms(bboxes, iou_threshold, sigma=0.3):

    classes_in_img = list(set(bboxes[:, 5]))
    best_bboxes = []

    for cls in classes_in_img:
        cls_mask = (bboxes[:, 5] == cls)
        cls_bboxes = bboxes[cls_mask]
        # Process 1: Determine whether the number of bounding boxes is greater than 0 
        while len(cls_bboxes) > 0:
            # Process 2: Select the bounding box with the highest score according to socre order A
            max_ind = np.argmax(cls_bboxes[:, 4])
            best_bbox = cls_bboxes[max_ind]
            best_bboxes.append(best_bbox)
            cls_bboxes = np.concatenate([cls_bboxes[: max_ind], cls_bboxes[max_ind + 1:]])
            # Process 3: Calculate this bounding box A and
            # Remain all iou of the bounding box and remove those bounding boxes whose iou value is higher than the threshold 
            iou = bboxes_iou(best_bbox[np.newaxis, :4], cls_bboxes[:, :4])
            weight = np.ones((len(iou),), dtype=np.float32)

            iou_mask = iou > iou_threshold
            weight[iou_mask] = 0.0

            cls_bboxes[:, 4] = cls_bboxes[:, 4] * weight
            score_mask = cls_bboxes[:, 4] > 0.
            cls_bboxes = cls_bboxes[score_mask]
            print(best_bboxes)

    return best_bboxes

# %%
def postprocess_boxes(pred_bbox, original_image, input_size, score_threshold):
    valid_scale=[0, np.inf]
    pred_bbox = np.array(pred_bbox)

    pred_xywh = pred_bbox[:, 0:4]
    pred_conf = pred_bbox[:, 4]
    pred_prob = pred_bbox[:, 5:]

    # 1. (x, y, w, h) --> (xmin, ymin, xmax, ymax)
    pred_coor = np.concatenate([pred_xywh[:, :2] - pred_xywh[:, 2:] * 0.5,
                                pred_xywh[:, :2] + pred_xywh[:, 2:] * 0.5], axis=-1)
    # 2. (xmin, ymin, xmax, ymax) -> (xmin_org, ymin_org, xmax_org, ymax_org)
    org_h, org_w = original_image.shape[:2]
    resize_ratio = min(input_size / org_w, input_size / org_h)

    dw = (input_size - resize_ratio * org_w) / 2
    dh = (input_size - resize_ratio * org_h) / 2

    pred_coor[:, 0::2] = 1.0 * (pred_coor[:, 0::2] - dw) / resize_ratio
    pred_coor[:, 1::2] = 1.0 * (pred_coor[:, 1::2] - dh) / resize_ratio

    # 3. clip some boxes those are out of range
    pred_coor = np.concatenate([np.maximum(pred_coor[:, :2], [0, 0]),
                                np.minimum(pred_coor[:, 2:], [org_w - 1, org_h - 1])], axis=-1)
    invalid_mask = np.logical_or((pred_coor[:, 0] > pred_coor[:, 2]), (pred_coor[:, 1] > pred_coor[:, 3]))
    pred_coor[invalid_mask] = 0

    # 4. discard some invalid boxes
    bboxes_scale = np.sqrt(np.multiply.reduce(pred_coor[:, 2:4] - pred_coor[:, 0:2], axis=-1))
    scale_mask = np.logical_and((valid_scale[0] < bboxes_scale), (bboxes_scale < valid_scale[1]))

    # 5. discard boxes with low scores
    classes = np.argmax(pred_prob, axis=-1)
    scores = pred_conf * pred_prob[np.arange(len(pred_coor)), classes]
    score_mask = scores > score_threshold
    mask = np.logical_and(scale_mask, score_mask)
    coors, scores, classes = pred_coor[mask], scores[mask], classes[mask]
    #print(coors)

    #print(coors[0])
    return np.concatenate([coors, scores[:, np.newaxis], classes[:, np.newaxis]], axis=-1)

# %%
def detect_image(YoloV3, image_path, output_path, input_size=416, show=False, CLASSES=YOLO_COCO_CLASSES, score_threshold=0.3, iou_threshold=0.45, rectangle_colors=''):
    original_image      = cv2.imread(image_path)
    original_image      = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
    original_image      = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

    image_data = image_preprocess(np.copy(original_image), [input_size, input_size])
    image_data = tf.expand_dims(image_data, 0)

    pred_bbox = YoloV3.predict(image_data)
    pred_bbox = [tf.reshape(x, (-1, tf.shape(x)[-1])) for x in pred_bbox]
    pred_bbox = tf.concat(pred_bbox, axis=0)
    
    bboxes = postprocess_boxes(pred_bbox, original_image, input_size, score_threshold)
    #xx=np.array(bboxes)
    #print(xx.shape)

    bboxes = nms(bboxes, iou_threshold)
    image = draw_bbox(original_image, bboxes, CLASSES=CLASSES, rectangle_colors=rectangle_colors)
    #cv2.imwrite('./output.jpg', image)
    print(bboxes)  
      
    return image

# %% [markdown]
# model

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Input, LeakyReLU, ZeroPadding2D, BatchNormalization
from tensorflow.keras.regularizers import l2



STRIDES         = np.array(YOLO_STRIDES)
ANCHORS         = (np.array(YOLO_ANCHORS).T/STRIDES).T
IOU_LOSS_THRESH = YOLO_IOU_LOSS_THRESH

# %%
class BatchNormalization(BatchNormalization):
    # "Frozen state" and "inference mode" are two separate concepts.
    # `layer.trainable = False` is to freeze the layer, so the layer will use
    # stored moving `var` and `mean` in the "inference mode", and both `gama`
    # and `beta` will not be updated !
    def call(self, x, training=False):
        if not training:
            training = tf.constant(False)
        training = tf.logical_and(training, self.trainable)
        return super().call(x, training)

def convolutional(input_layer, filters_shape, downsample=False, activate=True, bn=True):
    if downsample:
        input_layer = ZeroPadding2D(((1, 0), (1, 0)))(input_layer)
        padding = 'valid'
        strides = 2
    else:
        strides = 1
        padding = 'same'

    conv = Conv2D(filters=filters_shape[-1], kernel_size = filters_shape[0], strides=strides,
                  padding=padding, use_bias=not bn, kernel_regularizer=l2(0.0005),
                  kernel_initializer=tf.random_normal_initializer(stddev=0.01),
                  bias_initializer=tf.constant_initializer(0.))(input_layer)
    if bn:
        conv = BatchNormalization()(conv)
    if activate == True:
        conv = LeakyReLU(alpha=0.1)(conv)

    return conv

def residual_block(input_layer, input_channel, filter_num1, filter_num2):
    short_cut = input_layer
    conv = convolutional(input_layer, filters_shape=(1, 1, input_channel, filter_num1))
    conv = convolutional(conv       , filters_shape=(3, 3, filter_num1,   filter_num2))

    residual_output = short_cut + conv
    return residual_output

def upsample(input_layer):
    return tf.image.resize(input_layer, (input_layer.shape[1] * 2, input_layer.shape[2] * 2), method='nearest')


def darknet53(input_data):
    input_data = convolutional(input_data, (3, 3,  3,  32))
    input_data = convolutional(input_data, (3, 3, 32,  64), downsample=True)

    for i in range(1):
        input_data = residual_block(input_data,  64,  32, 64)

    input_data = convolutional(input_data, (3, 3,  64, 128), downsample=True)

    for i in range(2):
        input_data = residual_block(input_data, 128,  64, 128)

    input_data = convolutional(input_data, (3, 3, 128, 256), downsample=True)

    for i in range(8):
        input_data = residual_block(input_data, 256, 128, 256)

    route_1 = input_data
    input_data = convolutional(input_data, (3, 3, 256, 512), downsample=True)

    for i in range(8):
        input_data = residual_block(input_data, 512, 256, 512)

    route_2 = input_data
    input_data = convolutional(input_data, (3, 3, 512, 1024), downsample=True)

    for i in range(4):
        input_data = residual_block(input_data, 1024, 512, 1024)

    return route_1, route_2, input_data

def YOLOv3(input_layer, NUM_CLASS):
    # After the input layer enters the Darknet-53 network, we get three branches
    route_1, route_2, conv = darknet53(input_layer)
    # See the orange module (DBL) in the figure above, a total of 5 Subconvolution operation
    conv = convolutional(conv, (1, 1, 1024,  512))
    conv = convolutional(conv, (3, 3,  512, 1024))
    conv = convolutional(conv, (1, 1, 1024,  512))
    conv = convolutional(conv, (3, 3,  512, 1024))
    conv = convolutional(conv, (1, 1, 1024,  512))
    conv_lobj_branch = convolutional(conv, (3, 3, 512, 1024))
    
    # conv_lbbox is used to predict large-sized objects , Shape = [None, 13, 13, 255] 
    conv_lbbox = convolutional(conv_lobj_branch, (1, 1, 1024, 3*(NUM_CLASS + 5)), activate=False, bn=False)

    conv = convolutional(conv, (1, 1,  512,  256))
    # upsample here uses the nearest neighbor interpolation method, which has the advantage that the
    # upsampling process does not need to learn, thereby reducing the network parameter  
    conv = upsample(conv)

    conv = tf.concat([conv, route_2], axis=-1)
    conv = convolutional(conv, (1, 1, 768, 256))
    conv = convolutional(conv, (3, 3, 256, 512))
    conv = convolutional(conv, (1, 1, 512, 256))
    conv = convolutional(conv, (3, 3, 256, 512))
    conv = convolutional(conv, (1, 1, 512, 256))
    conv_mobj_branch = convolutional(conv, (3, 3, 256, 512))

    # conv_mbbox is used to predict medium-sized objects, shape = [None, 26, 26, 255]
    conv_mbbox = convolutional(conv_mobj_branch, (1, 1, 512, 3*(NUM_CLASS + 5)), activate=False, bn=False)

    conv = convolutional(conv, (1, 1, 256, 128))
    conv = upsample(conv)

    conv = tf.concat([conv, route_1], axis=-1)
    conv = convolutional(conv, (1, 1, 384, 128))
    conv = convolutional(conv, (3, 3, 128, 256))
    conv = convolutional(conv, (1, 1, 256, 128))
    conv = convolutional(conv, (3, 3, 128, 256))
    conv = convolutional(conv, (1, 1, 256, 128))
    conv_sobj_branch = convolutional(conv, (3, 3, 128, 256))
    
    # conv_sbbox is used to predict small size objects, shape = [None, 52, 52, 255]
    conv_sbbox = convolutional(conv_sobj_branch, (1, 1, 256, 3*(NUM_CLASS +5)), activate=False, bn=False)
        
    return [conv_sbbox, conv_mbbox, conv_lbbox]

def Create_Yolov3(input_size=416, channels=3, training=False, CLASSES=YOLO_COCO_CLASSES):
    NUM_CLASS = len(read_class_names(CLASSES))
    input_layer  = Input([input_size, input_size, channels])

    conv_tensors = YOLOv3(input_layer, NUM_CLASS)

    output_tensors = []
    for i, conv_tensor in enumerate(conv_tensors):
        pred_tensor = decode(conv_tensor, NUM_CLASS, i)
        if training: output_tensors.append(conv_tensor)
        output_tensors.append(pred_tensor)

    YoloV3 = tf.keras.Model(input_layer, output_tensors)
    return YoloV3

def decode(conv_output, NUM_CLASS, i=0):
    # where i = 0, 1 or 2 to correspond to the three grid scales  
    conv_shape       = tf.shape(conv_output)
    batch_size       = conv_shape[0]
    output_size      = conv_shape[1]

    conv_output = tf.reshape(conv_output, (batch_size, output_size, output_size, 3, 5 + NUM_CLASS))

    conv_raw_dxdy = conv_output[:, :, :, :, 0:2] # offset of center position     
    conv_raw_dwdh = conv_output[:, :, :, :, 2:4] # Prediction box length and width offset
    conv_raw_conf = conv_output[:, :, :, :, 4:5] # confidence of the prediction box
    conv_raw_prob = conv_output[:, :, :, :, 5: ] # category probability of the prediction box 

    # next need Draw the grid. Where output_size is equal to 13, 26 or 52  
    y = tf.range(output_size, dtype=tf.int32)
    y = tf.expand_dims(y, -1)
    y = tf.tile(y, [1, output_size])
    x = tf.range(output_size,dtype=tf.int32)
    x = tf.expand_dims(x, 0)
    x = tf.tile(x, [output_size, 1])

    xy_grid = tf.concat([x[:, :, tf.newaxis], y[:, :, tf.newaxis]], axis=-1)
    xy_grid = tf.tile(xy_grid[tf.newaxis, :, :, tf.newaxis, :], [batch_size, 1, 1, 3, 1])
    xy_grid = tf.cast(xy_grid, tf.float32)

    # Calculate the center position of the prediction box:
    pred_xy = (tf.sigmoid(conv_raw_dxdy) + xy_grid) * STRIDES[i]
    # Calculate the length and width of the prediction box:
    pred_wh = (tf.exp(conv_raw_dwdh) * ANCHORS[i]) * STRIDES[i]

    pred_xywh = tf.concat([pred_xy, pred_wh], axis=-1)
    pred_conf = tf.sigmoid(conv_raw_conf) # object box calculates the predicted confidence
    pred_prob = tf.sigmoid(conv_raw_prob) # calculating the predicted probability category box object

    # calculating the predicted probability category box object
    return tf.concat([pred_xywh, pred_conf, pred_prob], axis=-1)

def bbox_iou(boxes1, boxes2):
    boxes1_area = boxes1[..., 2] * boxes1[..., 3]
    boxes2_area = boxes2[..., 2] * boxes2[..., 3]

    boxes1 = tf.concat([boxes1[..., :2] - boxes1[..., 2:] * 0.5,
                        boxes1[..., :2] + boxes1[..., 2:] * 0.5], axis=-1)
    boxes2 = tf.concat([boxes2[..., :2] - boxes2[..., 2:] * 0.5,
                        boxes2[..., :2] + boxes2[..., 2:] * 0.5], axis=-1)

    left_up = tf.maximum(boxes1[..., :2], boxes2[..., :2])
    right_down = tf.minimum(boxes1[..., 2:], boxes2[..., 2:])

    inter_section = tf.maximum(right_down - left_up, 0.0)
    inter_area = inter_section[..., 0] * inter_section[..., 1]
    union_area = boxes1_area + boxes2_area - inter_area

    return 1.0 * inter_area / union_area

def bbox_giou(boxes1, boxes2):
    boxes1 = tf.concat([boxes1[..., :2] - boxes1[..., 2:] * 0.5,
                        boxes1[..., :2] + boxes1[..., 2:] * 0.5], axis=-1)
    boxes2 = tf.concat([boxes2[..., :2] - boxes2[..., 2:] * 0.5,
                        boxes2[..., :2] + boxes2[..., 2:] * 0.5], axis=-1)

    boxes1 = tf.concat([tf.minimum(boxes1[..., :2], boxes1[..., 2:]),
                        tf.maximum(boxes1[..., :2], boxes1[..., 2:])], axis=-1)
    boxes2 = tf.concat([tf.minimum(boxes2[..., :2], boxes2[..., 2:]),
                        tf.maximum(boxes2[..., :2], boxes2[..., 2:])], axis=-1)

    boxes1_area = (boxes1[..., 2] - boxes1[..., 0]) * (boxes1[..., 3] - boxes1[..., 1])
    boxes2_area = (boxes2[..., 2] - boxes2[..., 0]) * (boxes2[..., 3] - boxes2[..., 1])

    left_up = tf.maximum(boxes1[..., :2], boxes2[..., :2])
    right_down = tf.minimum(boxes1[..., 2:], boxes2[..., 2:])

    inter_section = tf.maximum(right_down - left_up, 0.0)
    inter_area = inter_section[..., 0] * inter_section[..., 1]
    union_area = boxes1_area + boxes2_area - inter_area
    iou = inter_area / union_area

    enclose_left_up = tf.minimum(boxes1[..., :2], boxes2[..., :2])
    enclose_right_down = tf.maximum(boxes1[..., 2:], boxes2[..., 2:])
    enclose = tf.maximum(enclose_right_down - enclose_left_up, 0.0)
    enclose_area = enclose[..., 0] * enclose[..., 1]
    giou = iou - 1.0 * (enclose_area - union_area) / enclose_area

    return giou


def compute_loss(pred, conv, label, bboxes, i=0, CLASSES=YOLO_COCO_CLASSES):
    NUM_CLASS = len(read_class_names(CLASSES))
    conv_shape  = tf.shape(conv)
    batch_size  = conv_shape[0]
    output_size = conv_shape[1]
    input_size  = STRIDES[i] * output_size
    conv = tf.reshape(conv, (batch_size, output_size, output_size, 3, 5 + NUM_CLASS))

    conv_raw_conf = conv[:, :, :, :, 4:5]
    conv_raw_prob = conv[:, :, :, :, 5:]

    pred_xywh     = pred[:, :, :, :, 0:4]
    pred_conf     = pred[:, :, :, :, 4:5]

    label_xywh    = label[:, :, :, :, 0:4]
    respond_bbox  = label[:, :, :, :, 4:5]
    label_prob    = label[:, :, :, :, 5:]

    giou = tf.expand_dims(bbox_giou(pred_xywh, label_xywh), axis=-1)
    input_size = tf.cast(input_size, tf.float32)

    bbox_loss_scale = 2.0 - 1.0 * label_xywh[:, :, :, :, 2:3] * label_xywh[:, :, :, :, 3:4] / (input_size ** 2)
    giou_loss = respond_bbox * bbox_loss_scale * (1- giou)

    iou = bbox_iou(pred_xywh[:, :, :, :, np.newaxis, :], bboxes[:, np.newaxis, np.newaxis, np.newaxis, :, :])
    max_iou = tf.expand_dims(tf.reduce_max(iou, axis=-1), axis=-1)

    respond_bgd = (1.0 - respond_bbox) * tf.cast( max_iou < IOU_LOSS_THRESH, tf.float32 )

    conf_focal = tf.pow(respond_bbox - pred_conf, 2)

    conf_loss = conf_focal * (
            respond_bbox * tf.nn.sigmoid_cross_entropy_with_logits(labels=respond_bbox, logits=conv_raw_conf)
            +
            respond_bgd * tf.nn.sigmoid_cross_entropy_with_logits(labels=respond_bbox, logits=conv_raw_conf)
    )

    prob_loss = respond_bbox * tf.nn.sigmoid_cross_entropy_with_logits(labels=label_prob, logits=conv_raw_prob)

    giou_loss = tf.reduce_mean(tf.reduce_sum(giou_loss, axis=[1,2,3,4]))
    conf_loss = tf.reduce_mean(tf.reduce_sum(conf_loss, axis=[1,2,3,4]))
    prob_loss = tf.reduce_mean(tf.reduce_sum(prob_loss, axis=[1,2,3,4]))

    return giou_loss, conf_loss, prob_loss

# %% [markdown]
# dataset

# %%
import os
import cv2
import random
import numpy as np
import tensorflow as tf



class Dataset(object):
    # Dataset preprocess implementation
    def __init__(self, dataset_type):
        self.annot_path  = TRAIN_ANNOT_PATH if dataset_type == 'train' else TEST_ANNOT_PATH
        self.input_sizes = TRAIN_INPUT_SIZE if dataset_type == 'train' else TEST_INPUT_SIZE
        self.batch_size  = TRAIN_BATCH_SIZE if dataset_type == 'train' else TEST_BATCH_SIZE
        self.data_aug    = TRAIN_DATA_AUG   if dataset_type == 'train' else TEST_DATA_AUG

        self.train_input_sizes = TRAIN_INPUT_SIZE
        self.strides = np.array(YOLO_STRIDES)
        self.classes = read_class_names(TRAIN_CLASSES)
        self.num_classes = len(self.classes)
        self.anchors = (np.array(YOLO_ANCHORS).T/self.strides).T
        self.anchor_per_scale = YOLO_ANCHOR_PER_SCALE
        self.max_bbox_per_scale = YOLO_MAX_BBOX_PER_SCALE

        self.annotations = self.load_annotations(dataset_type)
        self.num_samples = len(self.annotations)
        self.num_batchs = int(np.ceil(self.num_samples / self.batch_size))
        self.batch_count = 0


    def load_annotations(self, dataset_type):
        final_annotations = []
        with open(self.annot_path, 'r') as f:
            txt = f.readlines()
            annotations = [line.strip() for line in txt if len(line.strip().split()[1:]) != 0]
        np.random.shuffle(annotations)
        
        for annotation in annotations:
            # fully parse annotations
            line = annotation.split()
            image_path, index = "", 1
            for i, one_line in enumerate(line):
                if not one_line.replace(",","").isnumeric():
                    if image_path != "": image_path += " "
                    image_path += one_line
                else:
                    index = i
                    break
            if not os.path.exists(image_path):
                raise KeyError("%s does not exist ... " %image_path)

            final_annotations.append([image_path, line[index:]])

        return final_annotations

    def __iter__(self):
        return self

    def __next__(self):
        with tf.device('/cpu:0'):
            self.train_input_size = random.choice([self.train_input_sizes])
            self.train_output_sizes = self.train_input_size // self.strides

            batch_image = np.zeros((self.batch_size, self.train_input_size, self.train_input_size, 3), dtype=np.float32)

            batch_label_sbbox = np.zeros((self.batch_size, self.train_output_sizes[0], self.train_output_sizes[0],
                                          self.anchor_per_scale, 5 + self.num_classes), dtype=np.float32)
            batch_label_mbbox = np.zeros((self.batch_size, self.train_output_sizes[1], self.train_output_sizes[1],
                                          self.anchor_per_scale, 5 + self.num_classes), dtype=np.float32)
            batch_label_lbbox = np.zeros((self.batch_size, self.train_output_sizes[2], self.train_output_sizes[2],
                                          self.anchor_per_scale, 5 + self.num_classes), dtype=np.float32)

            batch_sbboxes = np.zeros((self.batch_size, self.max_bbox_per_scale, 4), dtype=np.float32)
            batch_mbboxes = np.zeros((self.batch_size, self.max_bbox_per_scale, 4), dtype=np.float32)
            batch_lbboxes = np.zeros((self.batch_size, self.max_bbox_per_scale, 4), dtype=np.float32)

            num = 0
            if self.batch_count < self.num_batchs:
                while num < self.batch_size:
                    index = self.batch_count * self.batch_size + num
                    if index >= self.num_samples: index -= self.num_samples
                    annotation = self.annotations[index]
                    image, bboxes = self.parse_annotation(annotation)
                    label_sbbox, label_mbbox, label_lbbox, sbboxes, mbboxes, lbboxes = self.preprocess_true_boxes(bboxes)

                    batch_image[num, :, :, :] = image
                    batch_label_sbbox[num, :, :, :, :] = label_sbbox
                    batch_label_mbbox[num, :, :, :, :] = label_mbbox
                    batch_label_lbbox[num, :, :, :, :] = label_lbbox
                    batch_sbboxes[num, :, :] = sbboxes
                    batch_mbboxes[num, :, :] = mbboxes
                    batch_lbboxes[num, :, :] = lbboxes
                    num += 1
                self.batch_count += 1
                batch_smaller_target = batch_label_sbbox, batch_sbboxes
                batch_medium_target  = batch_label_mbbox, batch_mbboxes
                batch_larger_target  = batch_label_lbbox, batch_lbboxes

                return batch_image, (batch_smaller_target, batch_medium_target, batch_larger_target)
            else:
                self.batch_count = 0
                np.random.shuffle(self.annotations)
                raise StopIteration

    def random_horizontal_flip(self, image, bboxes):
        if random.random() < 0.5:
            _, w, _ = image.shape
            image = image[:, ::-1, :]
            bboxes[:, [0,2]] = w - bboxes[:, [2,0]]

        return image, bboxes

    def random_crop(self, image, bboxes):
        if random.random() < 0.5:
            h, w, _ = image.shape
            max_bbox = np.concatenate([np.min(bboxes[:, 0:2], axis=0), np.max(bboxes[:, 2:4], axis=0)], axis=-1)

            max_l_trans = max_bbox[0]
            max_u_trans = max_bbox[1]
            max_r_trans = w - max_bbox[2]
            max_d_trans = h - max_bbox[3]

            crop_xmin = max(0, int(max_bbox[0] - random.uniform(0, max_l_trans)))
            crop_ymin = max(0, int(max_bbox[1] - random.uniform(0, max_u_trans)))
            crop_xmax = max(w, int(max_bbox[2] + random.uniform(0, max_r_trans)))
            crop_ymax = max(h, int(max_bbox[3] + random.uniform(0, max_d_trans)))

            image = image[crop_ymin : crop_ymax, crop_xmin : crop_xmax]

            bboxes[:, [0, 2]] = bboxes[:, [0, 2]] - crop_xmin
            bboxes[:, [1, 3]] = bboxes[:, [1, 3]] - crop_ymin

        return image, bboxes

    def random_translate(self, image, bboxes):
        if random.random() < 0.5:
            h, w, _ = image.shape
            max_bbox = np.concatenate([np.min(bboxes[:, 0:2], axis=0), np.max(bboxes[:, 2:4], axis=0)], axis=-1)

            max_l_trans = max_bbox[0]
            max_u_trans = max_bbox[1]
            max_r_trans = w - max_bbox[2]
            max_d_trans = h - max_bbox[3]

            tx = random.uniform(-(max_l_trans - 1), (max_r_trans - 1))
            ty = random.uniform(-(max_u_trans - 1), (max_d_trans - 1))

            M = np.array([[1, 0, tx], [0, 1, ty]])
            image = cv2.warpAffine(image, M, (w, h))

            bboxes[:, [0, 2]] = bboxes[:, [0, 2]] + tx
            bboxes[:, [1, 3]] = bboxes[:, [1, 3]] + ty

        return image, bboxes

    def parse_annotation(self, annotation):

        image_path = annotation[0]
        image = cv2.imread(image_path)
            
        bboxes = np.array([list(map(int, box.split(','))) for box in annotation[1]])

        if self.data_aug:
            image, bboxes = self.random_horizontal_flip(np.copy(image), np.copy(bboxes))
            image, bboxes = self.random_crop(np.copy(image), np.copy(bboxes))
            image, bboxes = self.random_translate(np.copy(image), np.copy(bboxes))

        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image, bboxes = image_preprocess(np.copy(image), [self.train_input_size, self.train_input_size], np.copy(bboxes))
        return image, bboxes

    def preprocess_true_boxes(self, bboxes):
        label = [np.zeros((self.train_output_sizes[i], self.train_output_sizes[i], self.anchor_per_scale,
                           5 + self.num_classes)) for i in range(3)]
        bboxes_xywh = [np.zeros((self.max_bbox_per_scale, 4)) for _ in range(3)]
        bbox_count = np.zeros((3,))

        for bbox in bboxes:
            bbox_coor = bbox[:4]
            bbox_class_ind = bbox[4]

            onehot = np.zeros(self.num_classes, dtype=np.float)
            onehot[bbox_class_ind] = 1.0
            uniform_distribution = np.full(self.num_classes, 1.0 / self.num_classes)
            deta = 0.01
            smooth_onehot = onehot * (1 - deta) + deta * uniform_distribution

            bbox_xywh = np.concatenate([(bbox_coor[2:] + bbox_coor[:2]) * 0.5, bbox_coor[2:] - bbox_coor[:2]], axis=-1)
            bbox_xywh_scaled = 1.0 * bbox_xywh[np.newaxis, :] / self.strides[:, np.newaxis]

            iou = []
            exist_positive = False
            for i in range(3):
                anchors_xywh = np.zeros((self.anchor_per_scale, 4))
                anchors_xywh[:, 0:2] = np.floor(bbox_xywh_scaled[i, 0:2]).astype(np.int32) + 0.5
                anchors_xywh[:, 2:4] = self.anchors[i]

                iou_scale = bbox_iou(bbox_xywh_scaled[i][np.newaxis, :], anchors_xywh)
                iou.append(iou_scale)
                iou_mask = iou_scale > 0.3

                if np.any(iou_mask):
                    xind, yind = np.floor(bbox_xywh_scaled[i, 0:2]).astype(np.int32)

                    label[i][yind, xind, iou_mask, :] = 0
                    label[i][yind, xind, iou_mask, 0:4] = bbox_xywh
                    label[i][yind, xind, iou_mask, 4:5] = 1.0
                    label[i][yind, xind, iou_mask, 5:] = smooth_onehot

                    bbox_ind = int(bbox_count[i] % self.max_bbox_per_scale)
                    bboxes_xywh[i][bbox_ind, :4] = bbox_xywh
                    bbox_count[i] += 1

                    exist_positive = True

            if not exist_positive:
                best_anchor_ind = np.argmax(np.array(iou).reshape(-1), axis=-1)
                best_detect = int(best_anchor_ind / self.anchor_per_scale)
                best_anchor = int(best_anchor_ind % self.anchor_per_scale)
                xind, yind = np.floor(bbox_xywh_scaled[best_detect, 0:2]).astype(np.int32)

                label[best_detect][yind, xind, best_anchor, :] = 0
                label[best_detect][yind, xind, best_anchor, 0:4] = bbox_xywh
                label[best_detect][yind, xind, best_anchor, 4:5] = 1.0
                label[best_detect][yind, xind, best_anchor, 5:] = smooth_onehot
                
                bbox_ind = int(bbox_count[best_detect] % self.max_bbox_per_scale)
                bboxes_xywh[best_detect][bbox_ind, :4] = bbox_xywh
                bbox_count[best_detect] += 1

        label_sbbox, label_mbbox, label_lbbox = label
        sbboxes, mbboxes, lbboxes = bboxes_xywh
        return label_sbbox, label_mbbox, label_lbbox, sbboxes, mbboxes, lbboxes

    def __len__(self):
        return self.num_batchs

# %% [markdown]
# training

# %%
import os
import shutil
import numpy as np
import tensorflow as tf

global TRAIN_FROM_CHECKPOINT
input_size = YOLO_INPUT_SIZE
Darknet_weights = YOLO_DARKNET_WEIGHTS


save_best_only = True # saves only best model according validation loss
save_checkpoints = False # saves all best validated checkpoints in training process (may require a lot disk space)


trainset = Dataset('train.txt')
testset = Dataset('val.txt')

steps_per_epoch = len(trainset)
global_steps = tf.Variable(1, trainable=False, dtype=tf.int64)
warmup_steps = TRAIN_WARMUP_EPOCHS * steps_per_epoch
total_steps = TRAIN_EPOCHS * steps_per_epoch

if TRAIN_TRANSFER:
    Darknet = Create_Yolov3(input_size=input_size)
    load_yolo_weights(Darknet, Darknet_weights) # use darknet weights

yolo = Create_Yolov3(input_size=input_size, training=True, CLASSES=TRAIN_CLASSES)

TRAIN_FROM_CHECKPOINT = False
if TRAIN_FROM_CHECKPOINT:
    yolo.load_weights(TRAIN_FROM_CHECKPOINT)

# transfer && Not use checkpoint
if TRAIN_TRANSFER and not TRAIN_FROM_CHECKPOINT:
    for i, l in enumerate(Darknet.layers):
        layer_weights = l.get_weights()
        if layer_weights != []:
            try:
                yolo.layers[i].set_weights(layer_weights)
            except:
                print("skipping", yolo.layers[i].name)

optimizer = tf.keras.optimizers.Adam()

def train_step(image_data, target):
    with tf.GradientTape() as tape:
        pred_result = yolo(image_data, training=True)
        giou_loss=conf_loss=prob_loss=0
        # optimizing process
        for i in range(3):
            conv, pred = pred_result[i*2], pred_result[i*2+1]
            loss_items = compute_loss(pred, conv, *target[i], i, CLASSES=TRAIN_CLASSES)
            giou_loss += loss_items[0]
            conf_loss += loss_items[1]
            prob_loss += loss_items[2]
        total_loss = giou_loss + conf_loss + prob_loss
        gradients = tape.gradient(total_loss, yolo.trainable_variables)
        optimizer.apply_gradients(zip(gradients, yolo.trainable_variables))


        # update learning rate
        global_steps.assign_add(1)
        if global_steps < warmup_steps:# and not TRAIN_TRANSFER:
            lr = global_steps / warmup_steps * TRAIN_LR_INIT
        else:
            lr = TRAIN_LR_END + 0.5 * (TRAIN_LR_INIT - TRAIN_LR_END)*(
                (1 + tf.cos((global_steps - warmup_steps) / (total_steps - warmup_steps) * np.pi)))
        optimizer.lr.assign(lr.numpy())

    return global_steps.numpy(), optimizer.lr.numpy(), giou_loss.numpy(), conf_loss.numpy(), prob_loss.numpy(), total_loss.numpy()



def validate_step(image_data, target):
    with tf.GradientTape() as tape:
        pred_result = yolo(image_data, training=False)
        giou_loss=conf_loss=prob_loss=0

        # optimizing process
        for i in range(3):
            conv, pred = pred_result[i*2], pred_result[i*2+1]
            loss_items = compute_loss(pred, conv, *target[i], i, CLASSES=TRAIN_CLASSES)
            giou_loss += loss_items[0]
            conf_loss += loss_items[1]
            prob_loss += loss_items[2]

        total_loss = giou_loss + conf_loss + prob_loss
        
    return giou_loss.numpy(), conf_loss.numpy(), prob_loss.numpy(), total_loss.numpy()


best_val_loss = 1000 # should be large at start


for epoch in range(TRAIN_EPOCHS):
    for image_data, target in trainset:
        results = train_step(image_data, target)
        cur_step = results[0]%steps_per_epoch
        print("epoch:{:2.0f} step:{:5.0f}/{}, lr:{:.6f}, giou_loss:{:7.2f}, conf_loss:{:7.2f}, prob_loss:{:7.2f}, total_loss:{:7.2f}"
                  .format(epoch, cur_step, steps_per_epoch, results[1], results[2], results[3], results[4], results[5]))
        
    count, giou_val, conf_val, prob_val, total_val = 0., 0, 0, 0, 0
    for image_data, target in testset:
        results = validate_step(image_data, target)
        count += 1
        giou_val += results[0]
        conf_val += results[1]
        prob_val += results[2]
        total_val += results[3]

        
    print("\n\ngiou_val_loss:{:7.2f}, conf_val_loss:{:7.2f}, prob_val_loss:{:7.2f}, total_val_loss:{:7.2f}\n\n".
          format(giou_val/count, conf_val/count, prob_val/count, total_val/count))

    if save_best_only and best_val_loss > total_val/count: 
        yolo.save_weights("yolov3_custom")
        best_val_loss = total_val/count
# Out:
# C:\Users\SBAUser\AppData\Local\Temp\ipykernel_384\2722776313.py:182: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   onehot = np.zeros(self.num_classes, dtype=np.float)
# epoch: 0 step:    2/125, lr:0.000001, giou_loss:   4.94, conf_loss:1788.72, prob_loss:   6.00, total_loss:1799.66
# epoch: 0 step:    3/125, lr:0.000001, giou_loss:   4.28, conf_loss:1781.97, prob_loss:   5.85, total_loss:1792.10
# epoch: 0 step:    4/125, lr:0.000002, giou_loss:   5.56, conf_loss:1796.04, prob_loss:   7.76, total_loss:1809.36
# epoch: 0 step:    5/125, lr:0.000002, giou_loss:   5.64, conf_loss:1803.87, prob_loss:   7.27, total_loss:1816.79
# epoch: 0 step:    6/125, lr:0.000002, giou_loss:   4.10, conf_loss:1768.25, prob_loss:   5.87, total_loss:1778.22
# epoch: 0 step:    7/125, lr:0.000003, giou_loss:   7.79, conf_loss:1780.82, prob_loss:  10.49, total_loss:1799.10
# epoch: 0 step:    8/125, lr:0.000003, giou_loss:   4.55, conf_loss:1753.86, prob_loss:   6.20, total_loss:1764.62
# epoch: 0 step:    9/125, lr:0.000004, giou_loss:   6.89, conf_loss:1744.72, prob_loss:   9.00, total_loss:1760.61
# epoch: 0 step:   10/125, lr:0.000004, giou_loss:   4.07, conf_loss:1734.22, prob_loss:   5.59, total_loss:1743.88
# epoch: 0 step:   11/125, lr:0.000004, giou_loss:   6.53, conf_loss:1712.20, prob_loss:   8.71, total_loss:1727.44
# epoch: 0 step:   12/125, lr:0.000005, giou_loss:  12.03, conf_loss:1697.39, prob_loss:  15.89, total_loss:1725.30
# epoch: 0 step:   13/125, lr:0.000005, giou_loss:   3.47, conf_loss:1693.69, prob_loss:   4.85, total_loss:1702.01
# epoch: 0 step:   14/125, lr:0.000006, giou_loss:   5.74, conf_loss:1663.76, prob_loss:   7.62, total_loss:1677.11
# epoch: 0 step:   15/125, lr:0.000006, giou_loss:   6.04, conf_loss:1655.49, prob_loss:   7.62, total_loss:1669.15
# epoch: 0 step:   16/125, lr:0.000006, giou_loss:   3.30, conf_loss:1648.37, prob_loss:   4.48, total_loss:1656.14
# epoch: 0 step:   17/125, lr:0.000007, giou_loss:   4.61, conf_loss:1636.33, prob_loss:   6.25, total_loss:1647.19
# epoch: 0 step:   18/125, lr:0.000007, giou_loss:   3.41, conf_loss:1626.22, prob_loss:   4.85, total_loss:1634.48
# epoch: 0 step:   19/125, lr:0.000008, giou_loss:   4.25, conf_loss:1607.19, prob_loss:   5.87, total_loss:1617.31
# epoch: 0 step:   20/125, lr:0.000008, giou_loss:   3.58, conf_loss:1591.21, prob_loss:   5.19, total_loss:1599.98
# epoch: 0 step:   21/125, lr:0.000008, giou_loss:   5.62, conf_loss:1568.85, prob_loss:   7.88, total_loss:1582.35
# epoch: 0 step:   22/125, lr:0.000009, giou_loss:   3.98, conf_loss:1554.82, prob_loss:   5.48, total_loss:1564.29
# epoch: 0 step:   23/125, lr:0.000009, giou_loss:   4.81, conf_loss:1543.71, prob_loss:   6.13, total_loss:1554.65
# epoch: 0 step:   24/125, lr:0.000010, giou_loss:   8.45, conf_loss:1515.00, prob_loss:  11.43, total_loss:1534.88
# epoch: 0 step:   25/125, lr:0.000010, giou_loss:   4.21, conf_loss:1499.10, prob_loss:   5.67, total_loss:1508.98
# epoch: 0 step:   26/125, lr:0.000010, giou_loss:  14.05, conf_loss:1484.52, prob_loss:  17.20, total_loss:1515.77
# epoch: 0 step:   27/125, lr:0.000011, giou_loss:   5.03, conf_loss:1461.91, prob_loss:   6.98, total_loss:1473.92
# epoch: 0 step:   28/125, lr:0.000011, giou_loss:   7.69, conf_loss:1448.17, prob_loss:  10.13, total_loss:1465.99
# epoch: 0 step:   29/125, lr:0.000012, giou_loss:   6.21, conf_loss:1430.39, prob_loss:   8.37, total_loss:1444.97
# epoch: 0 step:   30/125, lr:0.000012, giou_loss:   7.43, conf_loss:1410.82, prob_loss:  10.06, total_loss:1428.31
# epoch: 0 step:   31/125, lr:0.000012, giou_loss:   3.98, conf_loss:1404.72, prob_loss:   5.16, total_loss:1413.86
# epoch: 0 step:   32/125, lr:0.000013, giou_loss:   7.74, conf_loss:1384.61, prob_loss:   9.62, total_loss:1401.96
# epoch: 0 step:   33/125, lr:0.000013, giou_loss:   4.45, conf_loss:1362.40, prob_loss:   6.14, total_loss:1372.99
# epoch: 0 step:   34/125, lr:0.000014, giou_loss:   6.00, conf_loss:1360.32, prob_loss:   7.79, total_loss:1374.11
# epoch: 0 step:   35/125, lr:0.000014, giou_loss:   8.88, conf_loss:1334.88, prob_loss:  11.16, total_loss:1354.93
# epoch: 0 step:   36/125, lr:0.000014, giou_loss:   8.19, conf_loss:1317.73, prob_loss:  10.72, total_loss:1336.64
# epoch: 0 step:   37/125, lr:0.000015, giou_loss:   5.77, conf_loss:1307.08, prob_loss:   7.54, total_loss:1320.39
# epoch: 0 step:   38/125, lr:0.000015, giou_loss:   4.44, conf_loss:1289.94, prob_loss:   6.16, total_loss:1300.54
# epoch: 0 step:   39/125, lr:0.000016, giou_loss:   5.99, conf_loss:1278.96, prob_loss:   6.65, total_loss:1291.60
# epoch: 0 step:   40/125, lr:0.000016, giou_loss:   4.75, conf_loss:1273.46, prob_loss:   6.32, total_loss:1284.53
# epoch: 0 step:   41/125, lr:0.000016, giou_loss:   4.40, conf_loss:1251.06, prob_loss:   6.09, total_loss:1261.55
# epoch: 0 step:   42/125, lr:0.000017, giou_loss:   4.72, conf_loss:1244.73, prob_loss:   6.20, total_loss:1255.65
# epoch: 0 step:   43/125, lr:0.000017, giou_loss:   3.47, conf_loss:1244.46, prob_loss:   4.46, total_loss:1252.39
# epoch: 0 step:   44/125, lr:0.000018, giou_loss:   7.81, conf_loss:1225.87, prob_loss:  10.59, total_loss:1244.27
# epoch: 0 step:   45/125, lr:0.000018, giou_loss:   8.95, conf_loss:1210.76, prob_loss:  12.23, total_loss:1231.94
# epoch: 0 step:   46/125, lr:0.000018, giou_loss:   5.81, conf_loss:1187.78, prob_loss:   8.90, total_loss:1202.48
# epoch: 0 step:   47/125, lr:0.000019, giou_loss:   7.51, conf_loss:1169.78, prob_loss:   9.33, total_loss:1186.62
# epoch: 0 step:   48/125, lr:0.000019, giou_loss:   6.72, conf_loss:1165.56, prob_loss:   9.04, total_loss:1181.33
# epoch: 0 step:   49/125, lr:0.000020, giou_loss:   3.66, conf_loss:1138.96, prob_loss:   4.84, total_loss:1147.45
# epoch: 0 step:   50/125, lr:0.000020, giou_loss:   5.39, conf_loss:1140.26, prob_loss:   7.34, total_loss:1152.99
# epoch: 0 step:   51/125, lr:0.000020, giou_loss:   5.35, conf_loss:1124.23, prob_loss:   6.97, total_loss:1136.55
# epoch: 0 step:   52/125, lr:0.000021, giou_loss:   4.43, conf_loss:1102.63, prob_loss:   6.21, total_loss:1113.27
# epoch: 0 step:   53/125, lr:0.000021, giou_loss:   7.30, conf_loss:1092.04, prob_loss:  10.18, total_loss:1109.51
# epoch: 0 step:   54/125, lr:0.000022, giou_loss:   6.13, conf_loss:1082.70, prob_loss:   8.46, total_loss:1097.29
# epoch: 0 step:   55/125, lr:0.000022, giou_loss:   5.38, conf_loss:1079.07, prob_loss:   7.27, total_loss:1091.72
# epoch: 0 step:   56/125, lr:0.000022, giou_loss:   7.26, conf_loss:1080.41, prob_loss:  10.13, total_loss:1097.79
# epoch: 0 step:   57/125, lr:0.000023, giou_loss:   3.71, conf_loss:1068.76, prob_loss:   5.13, total_loss:1077.60
# epoch: 0 step:   58/125, lr:0.000023, giou_loss:   3.46, conf_loss:1070.74, prob_loss:   4.81, total_loss:1079.01
# epoch: 0 step:   59/125, lr:0.000024, giou_loss:   8.16, conf_loss:1040.90, prob_loss:  11.26, total_loss:1060.33
# epoch: 0 step:   60/125, lr:0.000024, giou_loss:   7.63, conf_loss:1032.64, prob_loss:  11.03, total_loss:1051.31
# epoch: 0 step:   61/125, lr:0.000024, giou_loss:   3.80, conf_loss:1023.03, prob_loss:   6.24, total_loss:1033.07
# epoch: 0 step:   62/125, lr:0.000025, giou_loss:   6.59, conf_loss: 993.68, prob_loss:   9.24, total_loss:1009.50
# epoch: 0 step:   63/125, lr:0.000025, giou_loss:   3.41, conf_loss:1004.51, prob_loss:   4.82, total_loss:1012.74
# epoch: 0 step:   64/125, lr:0.000026, giou_loss:   5.85, conf_loss:1014.40, prob_loss:   8.24, total_loss:1028.49
# epoch: 0 step:   65/125, lr:0.000026, giou_loss:   4.46, conf_loss: 981.18, prob_loss:   6.17, total_loss: 991.81
# epoch: 0 step:   66/125, lr:0.000026, giou_loss:   4.83, conf_loss: 972.22, prob_loss:   6.41, total_loss: 983.46
# epoch: 0 step:   67/125, lr:0.000027, giou_loss:   4.25, conf_loss: 966.96, prob_loss:   6.19, total_loss: 977.41
# epoch: 0 step:   68/125, lr:0.000027, giou_loss:   3.94, conf_loss: 958.87, prob_loss:   5.73, total_loss: 968.55
# epoch: 0 step:   69/125, lr:0.000028, giou_loss:   2.97, conf_loss: 934.99, prob_loss:   4.15, total_loss: 942.12
# epoch: 0 step:   70/125, lr:0.000028, giou_loss:   3.29, conf_loss: 933.83, prob_loss:   4.79, total_loss: 941.91
# epoch: 0 step:   71/125, lr:0.000028, giou_loss:   2.55, conf_loss: 924.91, prob_loss:   4.04, total_loss: 931.50
# epoch: 0 step:   72/125, lr:0.000029, giou_loss:   7.31, conf_loss: 937.35, prob_loss:  11.23, total_loss: 955.90
# epoch: 0 step:   73/125, lr:0.000029, giou_loss:   8.12, conf_loss: 916.34, prob_loss:  11.59, total_loss: 936.05
# epoch: 0 step:   74/125, lr:0.000030, giou_loss:   4.94, conf_loss: 894.88, prob_loss:   6.48, total_loss: 906.30
# epoch: 0 step:   75/125, lr:0.000030, giou_loss:   3.19, conf_loss: 896.13, prob_loss:   4.15, total_loss: 903.47
# epoch: 0 step:   76/125, lr:0.000030, giou_loss:   3.97, conf_loss: 876.24, prob_loss:   5.62, total_loss: 885.83
# epoch: 0 step:   77/125, lr:0.000031, giou_loss:   6.89, conf_loss: 885.50, prob_loss:   9.79, total_loss: 902.18
# epoch: 0 step:   78/125, lr:0.000031, giou_loss:   4.40, conf_loss: 878.48, prob_loss:   5.98, total_loss: 888.86
# epoch: 0 step:   79/125, lr:0.000032, giou_loss:   5.22, conf_loss: 864.40, prob_loss:   7.18, total_loss: 876.80
# epoch: 0 step:   80/125, lr:0.000032, giou_loss:   3.12, conf_loss: 847.55, prob_loss:   4.39, total_loss: 855.06
# epoch: 0 step:   81/125, lr:0.000032, giou_loss:   6.29, conf_loss: 853.54, prob_loss:   8.10, total_loss: 867.93
# epoch: 0 step:   82/125, lr:0.000033, giou_loss:   3.48, conf_loss: 839.55, prob_loss:   5.88, total_loss: 848.91
# epoch: 0 step:   83/125, lr:0.000033, giou_loss:   2.67, conf_loss: 829.87, prob_loss:   3.66, total_loss: 836.19
# epoch: 0 step:   84/125, lr:0.000034, giou_loss:   4.83, conf_loss: 844.70, prob_loss:   6.92, total_loss: 856.45
# epoch: 0 step:   85/125, lr:0.000034, giou_loss:   5.01, conf_loss: 830.20, prob_loss:   7.20, total_loss: 842.42
# epoch: 0 step:   86/125, lr:0.000034, giou_loss:   5.58, conf_loss: 815.65, prob_loss:   8.62, total_loss: 829.85
# epoch: 0 step:   87/125, lr:0.000035, giou_loss:   7.07, conf_loss: 818.25, prob_loss:  10.23, total_loss: 835.54
# epoch: 0 step:   88/125, lr:0.000035, giou_loss:   5.41, conf_loss: 810.23, prob_loss:   8.32, total_loss: 823.96
# epoch: 0 step:   89/125, lr:0.000036, giou_loss:   2.95, conf_loss: 797.41, prob_loss:   4.59, total_loss: 804.95
# epoch: 0 step:   90/125, lr:0.000036, giou_loss:   3.54, conf_loss: 788.31, prob_loss:   5.34, total_loss: 797.19
# epoch: 0 step:   91/125, lr:0.000036, giou_loss:   4.05, conf_loss: 787.20, prob_loss:   6.26, total_loss: 797.51
# epoch: 0 step:   92/125, lr:0.000037, giou_loss:   7.15, conf_loss: 783.28, prob_loss:  10.22, total_loss: 800.65
# epoch: 0 step:   93/125, lr:0.000037, giou_loss:   2.54, conf_loss: 763.69, prob_loss:   3.37, total_loss: 769.60
# epoch: 0 step:   94/125, lr:0.000038, giou_loss:   8.79, conf_loss: 768.89, prob_loss:  11.86, total_loss: 789.54
# epoch: 0 step:   95/125, lr:0.000038, giou_loss:   7.32, conf_loss: 762.76, prob_loss:  10.37, total_loss: 780.46
# epoch: 0 step:   96/125, lr:0.000038, giou_loss:   5.95, conf_loss: 747.95, prob_loss:   9.10, total_loss: 763.00
# epoch: 0 step:   97/125, lr:0.000039, giou_loss:   4.81, conf_loss: 760.76, prob_loss:   7.34, total_loss: 772.92
# epoch: 0 step:   98/125, lr:0.000039, giou_loss:   3.32, conf_loss: 743.37, prob_loss:   4.94, total_loss: 751.63
# epoch: 0 step:   99/125, lr:0.000040, giou_loss:   4.84, conf_loss: 736.66, prob_loss:   7.51, total_loss: 749.01
# epoch: 0 step:  100/125, lr:0.000040, giou_loss:   3.19, conf_loss: 724.97, prob_loss:   5.01, total_loss: 733.17
# epoch: 0 step:  101/125, lr:0.000040, giou_loss:   6.97, conf_loss: 734.36, prob_loss:   9.80, total_loss: 751.12
# epoch: 0 step:  102/125, lr:0.000041, giou_loss:   5.75, conf_loss: 716.35, prob_loss:   8.42, total_loss: 730.51
# epoch: 0 step:  103/125, lr:0.000041, giou_loss:   5.00, conf_loss: 715.40, prob_loss:   7.11, total_loss: 727.50
# epoch: 0 step:  104/125, lr:0.000042, giou_loss:   4.69, conf_loss: 710.86, prob_loss:   6.02, total_loss: 721.57
# epoch: 0 step:  105/125, lr:0.000042, giou_loss:   2.99, conf_loss: 703.05, prob_loss:   5.13, total_loss: 711.17
# epoch: 0 step:  106/125, lr:0.000042, giou_loss:   6.89, conf_loss: 697.23, prob_loss:   9.57, total_loss: 713.70
# epoch: 0 step:  107/125, lr:0.000043, giou_loss:   5.92, conf_loss: 699.95, prob_loss:   9.29, total_loss: 715.16
# epoch: 0 step:  108/125, lr:0.000043, giou_loss:   7.16, conf_loss: 690.47, prob_loss:  10.48, total_loss: 708.11
# epoch: 0 step:  109/125, lr:0.000044, giou_loss:   7.77, conf_loss: 685.23, prob_loss:  12.21, total_loss: 705.21
# epoch: 0 step:  110/125, lr:0.000044, giou_loss:   4.74, conf_loss: 675.24, prob_loss:   6.85, total_loss: 686.83
# epoch: 0 step:  111/125, lr:0.000044, giou_loss:   3.39, conf_loss: 671.88, prob_loss:   5.48, total_loss: 680.75
# epoch: 0 step:  112/125, lr:0.000045, giou_loss:   8.03, conf_loss: 663.76, prob_loss:  11.33, total_loss: 683.13
# epoch: 0 step:  113/125, lr:0.000045, giou_loss:   4.88, conf_loss: 657.42, prob_loss:   7.35, total_loss: 669.65
# epoch: 0 step:  114/125, lr:0.000046, giou_loss:   7.24, conf_loss: 656.43, prob_loss:  10.01, total_loss: 673.68
# epoch: 0 step:  115/125, lr:0.000046, giou_loss:   3.17, conf_loss: 652.68, prob_loss:   4.94, total_loss: 660.79
# epoch: 0 step:  116/125, lr:0.000046, giou_loss:   8.45, conf_loss: 652.40, prob_loss:  13.37, total_loss: 674.22
# epoch: 0 step:  117/125, lr:0.000047, giou_loss:   3.52, conf_loss: 633.68, prob_loss:   5.82, total_loss: 643.01
# epoch: 0 step:  118/125, lr:0.000047, giou_loss:   4.54, conf_loss: 636.43, prob_loss:   6.44, total_loss: 647.40
# epoch: 0 step:  119/125, lr:0.000048, giou_loss:   3.18, conf_loss: 628.64, prob_loss:   4.15, total_loss: 635.97
# epoch: 0 step:  120/125, lr:0.000048, giou_loss:   4.43, conf_loss: 630.16, prob_loss:   7.26, total_loss: 641.85
# epoch: 0 step:  121/125, lr:0.000048, giou_loss:   4.30, conf_loss: 625.54, prob_loss:   6.17, total_loss: 636.02
# epoch: 0 step:  122/125, lr:0.000049, giou_loss:   5.36, conf_loss: 616.40, prob_loss:   6.58, total_loss: 628.33
# epoch: 0 step:  123/125, lr:0.000049, giou_loss:   3.88, conf_loss: 612.60, prob_loss:   5.93, total_loss: 622.41
# epoch: 0 step:  124/125, lr:0.000050, giou_loss:   3.35, conf_loss: 611.40, prob_loss:   5.38, total_loss: 620.13
# epoch: 0 step:    0/125, lr:0.000050, giou_loss:   6.34, conf_loss: 605.35, prob_loss:   8.94, total_loss: 620.63
# epoch: 0 step:    1/125, lr:0.000050, giou_loss:   5.67, conf_loss: 592.11, prob_loss:   9.34, total_loss: 607.12
#
#
# giou_val_loss:   5.49, conf_val_loss:1587.32, prob_val_loss:   7.62, total_val_loss:1600.42
#
#
# epoch: 1 step:    2/125, lr:0.000051, giou_loss:   3.36, conf_loss: 590.68, prob_loss:   4.68, total_loss: 598.72
# epoch: 1 step:    3/125, lr:0.000051, giou_loss:   6.53, conf_loss: 584.72, prob_loss:   9.45, total_loss: 600.69
# epoch: 1 step:    4/125, lr:0.000052, giou_loss:   2.77, conf_loss: 581.71, prob_loss:   4.70, total_loss: 589.18
# epoch: 1 step:    5/125, lr:0.000052, giou_loss:   5.42, conf_loss: 581.37, prob_loss:   8.89, total_loss: 595.67
# epoch: 1 step:    6/125, lr:0.000052, giou_loss:   9.07, conf_loss: 575.85, prob_loss:  14.55, total_loss: 599.46
# epoch: 1 step:    7/125, lr:0.000053, giou_loss:  11.22, conf_loss: 569.32, prob_loss:  15.06, total_loss: 595.60
# epoch: 1 step:    8/125, lr:0.000053, giou_loss:   3.92, conf_loss: 560.83, prob_loss:   5.80, total_loss: 570.55
# epoch: 1 step:    9/125, lr:0.000054, giou_loss:   4.53, conf_loss: 559.40, prob_loss:   7.18, total_loss: 571.11
# epoch: 1 step:   10/125, lr:0.000054, giou_loss:   6.95, conf_loss: 555.71, prob_loss:  10.45, total_loss: 573.12
# epoch: 1 step:   11/125, lr:0.000054, giou_loss:   4.65, conf_loss: 550.57, prob_loss:   8.44, total_loss: 563.67
# epoch: 1 step:   12/125, lr:0.000055, giou_loss:   4.00, conf_loss: 539.99, prob_loss:   5.78, total_loss: 549.77
# epoch: 1 step:   13/125, lr:0.000055, giou_loss:   3.95, conf_loss: 543.73, prob_loss:   7.56, total_loss: 555.25
# epoch: 1 step:   14/125, lr:0.000056, giou_loss:   3.65, conf_loss: 536.22, prob_loss:   5.85, total_loss: 545.72
# epoch: 1 step:   15/125, lr:0.000056, giou_loss:   5.24, conf_loss: 534.81, prob_loss:   7.38, total_loss: 547.44
# epoch: 1 step:   16/125, lr:0.000056, giou_loss:   5.51, conf_loss: 531.45, prob_loss:   9.66, total_loss: 546.62
# epoch: 1 step:   17/125, lr:0.000057, giou_loss:   4.67, conf_loss: 524.02, prob_loss:   8.62, total_loss: 537.31
# epoch: 1 step:   18/125, lr:0.000057, giou_loss:   5.66, conf_loss: 520.10, prob_loss:   9.18, total_loss: 534.94
# epoch: 1 step:   19/125, lr:0.000058, giou_loss:   2.94, conf_loss: 518.49, prob_loss:   4.86, total_loss: 526.29
# epoch: 1 step:   20/125, lr:0.000058, giou_loss:   2.98, conf_loss: 506.53, prob_loss:   4.99, total_loss: 514.51
# epoch: 1 step:   21/125, lr:0.000058, giou_loss:   7.16, conf_loss: 510.28, prob_loss:  11.17, total_loss: 528.62
# epoch: 1 step:   22/125, lr:0.000059, giou_loss:   6.03, conf_loss: 510.88, prob_loss:   9.08, total_loss: 525.99
# epoch: 1 step:   23/125, lr:0.000059, giou_loss:   3.65, conf_loss: 494.37, prob_loss:   5.95, total_loss: 503.97
# epoch: 1 step:   24/125, lr:0.000060, giou_loss:   5.14, conf_loss: 494.44, prob_loss:   7.58, total_loss: 507.15
# epoch: 1 step:   25/125, lr:0.000060, giou_loss:   4.48, conf_loss: 490.74, prob_loss:   6.16, total_loss: 501.38
# epoch: 1 step:   26/125, lr:0.000060, giou_loss:   4.03, conf_loss: 489.00, prob_loss:   6.69, total_loss: 499.72
# epoch: 1 step:   27/125, lr:0.000061, giou_loss:   4.10, conf_loss: 479.09, prob_loss:   6.15, total_loss: 489.35
# epoch: 1 step:   28/125, lr:0.000061, giou_loss:   6.64, conf_loss: 480.93, prob_loss:   9.44, total_loss: 497.02
# epoch: 1 step:   29/125, lr:0.000062, giou_loss:   6.09, conf_loss: 472.20, prob_loss:   9.67, total_loss: 487.95
# epoch: 1 step:   30/125, lr:0.000062, giou_loss:   4.01, conf_loss: 462.50, prob_loss:   6.57, total_loss: 473.08
# epoch: 1 step:   31/125, lr:0.000062, giou_loss:   5.16, conf_loss: 459.19, prob_loss:   8.78, total_loss: 473.13
# epoch: 1 step:   32/125, lr:0.000063, giou_loss:   4.42, conf_loss: 460.57, prob_loss:   7.14, total_loss: 472.13
# epoch: 1 step:   33/125, lr:0.000063, giou_loss:   2.78, conf_loss: 451.20, prob_loss:   3.85, total_loss: 457.83
# epoch: 1 step:   34/125, lr:0.000064, giou_loss:   4.33, conf_loss: 454.07, prob_loss:   7.13, total_loss: 465.54
# epoch: 1 step:   35/125, lr:0.000064, giou_loss:   6.85, conf_loss: 450.78, prob_loss:   9.89, total_loss: 467.52
# epoch: 1 step:   36/125, lr:0.000064, giou_loss:   4.31, conf_loss: 440.94, prob_loss:   6.62, total_loss: 451.87
# epoch: 1 step:   37/125, lr:0.000065, giou_loss:   6.73, conf_loss: 443.46, prob_loss:   9.07, total_loss: 459.27
# epoch: 1 step:   38/125, lr:0.000065, giou_loss:   3.11, conf_loss: 431.20, prob_loss:   5.76, total_loss: 440.07
# epoch: 1 step:   39/125, lr:0.000066, giou_loss:   4.63, conf_loss: 431.98, prob_loss:   6.32, total_loss: 442.93
# epoch: 1 step:   40/125, lr:0.000066, giou_loss:   3.24, conf_loss: 421.34, prob_loss:   4.80, total_loss: 429.38
# epoch: 1 step:   41/125, lr:0.000066, giou_loss:   4.75, conf_loss: 420.79, prob_loss:   7.15, total_loss: 432.68
# epoch: 1 step:   42/125, lr:0.000067, giou_loss:   4.23, conf_loss: 417.66, prob_loss:   7.67, total_loss: 429.55
# epoch: 1 step:   43/125, lr:0.000067, giou_loss:   5.62, conf_loss: 413.45, prob_loss:   9.65, total_loss: 428.72
# epoch: 1 step:   44/125, lr:0.000068, giou_loss:   3.36, conf_loss: 419.13, prob_loss:   5.47, total_loss: 427.96
# epoch: 1 step:   45/125, lr:0.000068, giou_loss:   2.66, conf_loss: 404.32, prob_loss:   5.19, total_loss: 412.18
# epoch: 1 step:   46/125, lr:0.000068, giou_loss:   3.55, conf_loss: 402.70, prob_loss:   5.54, total_loss: 411.79
# epoch: 1 step:   47/125, lr:0.000069, giou_loss:   3.88, conf_loss: 398.73, prob_loss:   7.36, total_loss: 409.98
# epoch: 1 step:   48/125, lr:0.000069, giou_loss:   4.57, conf_loss: 396.84, prob_loss:   5.63, total_loss: 407.04
# epoch: 1 step:   49/125, lr:0.000070, giou_loss:   3.74, conf_loss: 392.58, prob_loss:   6.10, total_loss: 402.43
# epoch: 1 step:   50/125, lr:0.000070, giou_loss:   4.21, conf_loss: 387.29, prob_loss:   6.53, total_loss: 398.03
# epoch: 1 step:   51/125, lr:0.000070, giou_loss:  10.26, conf_loss: 388.50, prob_loss:  14.09, total_loss: 412.85
# epoch: 1 step:   52/125, lr:0.000071, giou_loss:   5.10, conf_loss: 383.65, prob_loss:   8.13, total_loss: 396.88
# epoch: 1 step:   53/125, lr:0.000071, giou_loss:   3.73, conf_loss: 376.39, prob_loss:   5.49, total_loss: 385.60
# epoch: 1 step:   54/125, lr:0.000072, giou_loss:   4.53, conf_loss: 373.62, prob_loss:   6.30, total_loss: 384.45
# epoch: 1 step:   55/125, lr:0.000072, giou_loss:   2.95, conf_loss: 366.78, prob_loss:   4.64, total_loss: 374.38
# epoch: 1 step:   56/125, lr:0.000072, giou_loss:   5.99, conf_loss: 369.72, prob_loss:   7.78, total_loss: 383.49
# epoch: 1 step:   57/125, lr:0.000073, giou_loss:   4.61, conf_loss: 361.45, prob_loss:   7.09, total_loss: 373.16
# epoch: 1 step:   58/125, lr:0.000073, giou_loss:   5.30, conf_loss: 361.89, prob_loss:   6.60, total_loss: 373.80
# epoch: 1 step:   59/125, lr:0.000074, giou_loss:   5.49, conf_loss: 358.74, prob_loss:   8.39, total_loss: 372.62
# epoch: 1 step:   60/125, lr:0.000074, giou_loss:   2.90, conf_loss: 349.70, prob_loss:   4.27, total_loss: 356.87
# epoch: 1 step:   61/125, lr:0.000074, giou_loss:   6.99, conf_loss: 355.40, prob_loss:   9.98, total_loss: 372.37
# epoch: 1 step:   62/125, lr:0.000075, giou_loss:   4.29, conf_loss: 345.67, prob_loss:   8.05, total_loss: 358.01
# epoch: 1 step:   63/125, lr:0.000075, giou_loss:   2.87, conf_loss: 341.33, prob_loss:   2.75, total_loss: 346.94
# epoch: 1 step:   64/125, lr:0.000076, giou_loss:   4.27, conf_loss: 339.27, prob_loss:   6.76, total_loss: 350.30
# epoch: 1 step:   65/125, lr:0.000076, giou_loss:   5.38, conf_loss: 335.09, prob_loss:   6.73, total_loss: 347.19
# epoch: 1 step:   66/125, lr:0.000076, giou_loss:   6.10, conf_loss: 340.73, prob_loss:  10.77, total_loss: 357.60
# epoch: 1 step:   67/125, lr:0.000077, giou_loss:   5.02, conf_loss: 330.65, prob_loss:   7.81, total_loss: 343.48
# epoch: 1 step:   68/125, lr:0.000077, giou_loss:   7.26, conf_loss: 331.81, prob_loss:  12.39, total_loss: 351.46
# epoch: 1 step:   69/125, lr:0.000078, giou_loss:   3.27, conf_loss: 328.27, prob_loss:   5.50, total_loss: 337.03
# epoch: 1 step:   70/125, lr:0.000078, giou_loss:   5.55, conf_loss: 322.53, prob_loss:   7.63, total_loss: 335.71
# epoch: 1 step:   71/125, lr:0.000078, giou_loss:   4.58, conf_loss: 317.44, prob_loss:   7.61, total_loss: 329.64
# epoch: 1 step:   72/125, lr:0.000079, giou_loss:   3.76, conf_loss: 312.85, prob_loss:   5.59, total_loss: 322.20
# epoch: 1 step:   73/125, lr:0.000079, giou_loss:   4.61, conf_loss: 312.49, prob_loss:   8.34, total_loss: 325.43
# epoch: 1 step:   74/125, lr:0.000080, giou_loss:   4.24, conf_loss: 307.95, prob_loss:   8.46, total_loss: 320.65
# epoch: 1 step:   75/125, lr:0.000080, giou_loss:   4.33, conf_loss: 305.41, prob_loss:   5.51, total_loss: 315.24
# epoch: 1 step:   76/125, lr:0.000080, giou_loss:   3.50, conf_loss: 300.66, prob_loss:   5.29, total_loss: 309.45
# epoch: 1 step:   77/125, lr:0.000081, giou_loss:   4.30, conf_loss: 302.00, prob_loss:   8.74, total_loss: 315.04
# epoch: 1 step:   78/125, lr:0.000081, giou_loss:   4.79, conf_loss: 296.42, prob_loss:   7.79, total_loss: 309.00
# epoch: 1 step:   79/125, lr:0.000082, giou_loss:   3.87, conf_loss: 291.33, prob_loss:   5.02, total_loss: 300.21
# epoch: 1 step:   80/125, lr:0.000082, giou_loss:   2.76, conf_loss: 288.76, prob_loss:   3.80, total_loss: 295.33
# epoch: 1 step:   81/125, lr:0.000082, giou_loss:   9.64, conf_loss: 292.37, prob_loss:  14.60, total_loss: 316.61
# epoch: 1 step:   82/125, lr:0.000083, giou_loss:   5.42, conf_loss: 286.39, prob_loss:   9.83, total_loss: 301.63
# epoch: 1 step:   83/125, lr:0.000083, giou_loss:   4.76, conf_loss: 280.06, prob_loss:   7.22, total_loss: 292.04
# epoch: 1 step:   84/125, lr:0.000084, giou_loss:   2.97, conf_loss: 279.29, prob_loss:   4.70, total_loss: 286.96
# epoch: 1 step:   85/125, lr:0.000084, giou_loss:   5.65, conf_loss: 278.38, prob_loss:   7.42, total_loss: 291.45
# epoch: 1 step:   86/125, lr:0.000084, giou_loss:   4.90, conf_loss: 275.01, prob_loss:   7.31, total_loss: 287.22
# epoch: 1 step:   87/125, lr:0.000085, giou_loss:   4.09, conf_loss: 272.95, prob_loss:   8.25, total_loss: 285.28
# epoch: 1 step:   88/125, lr:0.000085, giou_loss:   6.43, conf_loss: 271.61, prob_loss:   9.55, total_loss: 287.58
# epoch: 1 step:   89/125, lr:0.000086, giou_loss:   4.16, conf_loss: 269.39, prob_loss:   8.27, total_loss: 281.83
# epoch: 1 step:   90/125, lr:0.000086, giou_loss:   5.71, conf_loss: 266.98, prob_loss:   6.83, total_loss: 279.52
# epoch: 1 step:   91/125, lr:0.000086, giou_loss:   3.63, conf_loss: 260.77, prob_loss:   6.10, total_loss: 270.51
# epoch: 1 step:   92/125, lr:0.000087, giou_loss:   5.22, conf_loss: 259.61, prob_loss:   8.98, total_loss: 273.81
# epoch: 1 step:   93/125, lr:0.000087, giou_loss:   3.86, conf_loss: 256.49, prob_loss:   6.83, total_loss: 267.18
# epoch: 1 step:   94/125, lr:0.000088, giou_loss:   4.84, conf_loss: 256.69, prob_loss:   8.57, total_loss: 270.11
# epoch: 1 step:   95/125, lr:0.000088, giou_loss:   3.31, conf_loss: 251.55, prob_loss:   5.52, total_loss: 260.38
# epoch: 1 step:   96/125, lr:0.000088, giou_loss:   6.01, conf_loss: 249.66, prob_loss:   9.16, total_loss: 264.83
# epoch: 1 step:   97/125, lr:0.000089, giou_loss:   4.59, conf_loss: 244.70, prob_loss:   7.36, total_loss: 256.65
# epoch: 1 step:   98/125, lr:0.000089, giou_loss:   4.41, conf_loss: 243.06, prob_loss:   5.87, total_loss: 253.34
# epoch: 1 step:   99/125, lr:0.000090, giou_loss:   3.28, conf_loss: 242.91, prob_loss:   5.95, total_loss: 252.14
# epoch: 1 step:  100/125, lr:0.000090, giou_loss:   5.78, conf_loss: 242.06, prob_loss:  11.99, total_loss: 259.83
# epoch: 1 step:  101/125, lr:0.000090, giou_loss:   3.64, conf_loss: 237.87, prob_loss:   4.77, total_loss: 246.28
# epoch: 1 step:  102/125, lr:0.000091, giou_loss:   4.13, conf_loss: 234.78, prob_loss:   7.32, total_loss: 246.24
# epoch: 1 step:  103/125, lr:0.000091, giou_loss:   2.98, conf_loss: 230.80, prob_loss:   6.48, total_loss: 240.26
# epoch: 1 step:  104/125, lr:0.000092, giou_loss:   3.30, conf_loss: 229.35, prob_loss:   4.85, total_loss: 237.49
# epoch: 1 step:  105/125, lr:0.000092, giou_loss:   4.64, conf_loss: 226.86, prob_loss:   6.50, total_loss: 238.01
# epoch: 1 step:  106/125, lr:0.000092, giou_loss:   3.49, conf_loss: 226.43, prob_loss:   5.16, total_loss: 235.07
# epoch: 1 step:  107/125, lr:0.000093, giou_loss:   3.00, conf_loss: 226.83, prob_loss:   4.21, total_loss: 234.04
# epoch: 1 step:  108/125, lr:0.000093, giou_loss:   2.23, conf_loss: 219.08, prob_loss:   4.02, total_loss: 225.33
# epoch: 1 step:  109/125, lr:0.000094, giou_loss:   2.60, conf_loss: 216.62, prob_loss:   4.68, total_loss: 223.89
# epoch: 1 step:  110/125, lr:0.000094, giou_loss:   2.87, conf_loss: 213.48, prob_loss:   4.64, total_loss: 220.99
# epoch: 1 step:  111/125, lr:0.000094, giou_loss:   4.42, conf_loss: 215.76, prob_loss:   7.38, total_loss: 227.56
# epoch: 1 step:  112/125, lr:0.000095, giou_loss:   2.96, conf_loss: 212.53, prob_loss:   4.48, total_loss: 219.96
# epoch: 1 step:  113/125, lr:0.000095, giou_loss:   6.12, conf_loss: 211.88, prob_loss:  10.96, total_loss: 228.96
# epoch: 1 step:  114/125, lr:0.000096, giou_loss:   5.64, conf_loss: 212.48, prob_loss:   9.23, total_loss: 227.34
# epoch: 1 step:  115/125, lr:0.000096, giou_loss:   3.95, conf_loss: 205.32, prob_loss:   6.20, total_loss: 215.47
# epoch: 1 step:  116/125, lr:0.000096, giou_loss:   4.92, conf_loss: 204.69, prob_loss:   6.75, total_loss: 216.36
# epoch: 1 step:  117/125, lr:0.000097, giou_loss:   6.49, conf_loss: 204.86, prob_loss:   8.33, total_loss: 219.67
# epoch: 1 step:  118/125, lr:0.000097, giou_loss:   4.30, conf_loss: 202.13, prob_loss:   6.83, total_loss: 213.26
# epoch: 1 step:  119/125, lr:0.000098, giou_loss:   4.70, conf_loss: 201.77, prob_loss:   7.08, total_loss: 213.55
# epoch: 1 step:  120/125, lr:0.000098, giou_loss:   5.21, conf_loss: 197.54, prob_loss:   8.11, total_loss: 210.86
# epoch: 1 step:  121/125, lr:0.000098, giou_loss:   4.32, conf_loss: 196.73, prob_loss:   6.83, total_loss: 207.88
# epoch: 1 step:  122/125, lr:0.000099, giou_loss:   3.27, conf_loss: 193.20, prob_loss:   4.89, total_loss: 201.35
# epoch: 1 step:  123/125, lr:0.000099, giou_loss:   4.51, conf_loss: 191.99, prob_loss:   5.80, total_loss: 202.29
# epoch: 1 step:  124/125, lr:0.000100, giou_loss:   4.65, conf_loss: 191.93, prob_loss:   8.56, total_loss: 205.15
# epoch: 1 step:    0/125, lr:0.000100, giou_loss:   4.43, conf_loss: 188.40, prob_loss:   7.38, total_loss: 200.21
# epoch: 1 step:    1/125, lr:0.000100, giou_loss:   2.83, conf_loss: 186.07, prob_loss:   3.81, total_loss: 192.70
#
#
# giou_val_loss:   4.92, conf_val_loss: 678.52, prob_val_loss:   7.58, total_val_loss: 691.02
#
#
# epoch: 2 step:    2/125, lr:0.000100, giou_loss:   2.87, conf_loss: 183.50, prob_loss:   4.79, total_loss: 191.16
# epoch: 2 step:    3/125, lr:0.000100, giou_loss:   4.59, conf_loss: 184.82, prob_loss:   6.44, total_loss: 195.84
# epoch: 2 step:    4/125, lr:0.000100, giou_loss:   4.94, conf_loss: 184.00, prob_loss:   7.87, total_loss: 196.82
# epoch: 2 step:    5/125, lr:0.000100, giou_loss:   3.80, conf_loss: 178.05, prob_loss:   4.75, total_loss: 186.61
# epoch: 2 step:    6/125, lr:0.000100, giou_loss:   3.90, conf_loss: 179.68, prob_loss:   7.35, total_loss: 190.93
# epoch: 2 step:    7/125, lr:0.000100, giou_loss:   2.37, conf_loss: 173.08, prob_loss:   2.66, total_loss: 178.11
# epoch: 2 step:    8/125, lr:0.000100, giou_loss:   7.64, conf_loss: 178.08, prob_loss:  13.56, total_loss: 199.27
# epoch: 2 step:    9/125, lr:0.000100, giou_loss:   5.31, conf_loss: 175.11, prob_loss:  10.24, total_loss: 190.67
# epoch: 2 step:   10/125, lr:0.000100, giou_loss:   4.73, conf_loss: 170.86, prob_loss:   7.92, total_loss: 183.51
# epoch: 2 step:   11/125, lr:0.000100, giou_loss:   1.66, conf_loss: 167.31, prob_loss:   2.26, total_loss: 171.22
# epoch: 2 step:   12/125, lr:0.000100, giou_loss:   4.06, conf_loss: 169.32, prob_loss:   4.88, total_loss: 178.26
# epoch: 2 step:   13/125, lr:0.000100, giou_loss:   3.43, conf_loss: 165.14, prob_loss:   5.12, total_loss: 173.69
# epoch: 2 step:   14/125, lr:0.000100, giou_loss:   3.24, conf_loss: 164.46, prob_loss:   4.18, total_loss: 171.88
# epoch: 2 step:   15/125, lr:0.000100, giou_loss:   4.49, conf_loss: 163.99, prob_loss:   6.68, total_loss: 175.17
# epoch: 2 step:   16/125, lr:0.000100, giou_loss:   4.30, conf_loss: 162.95, prob_loss:   5.61, total_loss: 172.85
# epoch: 2 step:   17/125, lr:0.000100, giou_loss:   4.91, conf_loss: 161.71, prob_loss:   8.82, total_loss: 175.44
# epoch: 2 step:   18/125, lr:0.000100, giou_loss:   3.63, conf_loss: 159.68, prob_loss:   5.93, total_loss: 169.24
# epoch: 2 step:   19/125, lr:0.000100, giou_loss:   5.46, conf_loss: 160.74, prob_loss:   6.76, total_loss: 172.95
# epoch: 2 step:   20/125, lr:0.000100, giou_loss:   5.76, conf_loss: 159.73, prob_loss:   8.37, total_loss: 173.86
# epoch: 2 step:   21/125, lr:0.000100, giou_loss:   6.39, conf_loss: 159.29, prob_loss:   8.22, total_loss: 173.90
# epoch: 2 step:   22/125, lr:0.000100, giou_loss:   3.74, conf_loss: 153.67, prob_loss:   4.60, total_loss: 162.02
# epoch: 2 step:   23/125, lr:0.000100, giou_loss:   5.70, conf_loss: 157.55, prob_loss:  11.30, total_loss: 174.56
# epoch: 2 step:   24/125, lr:0.000100, giou_loss:   3.65, conf_loss: 151.96, prob_loss:   5.31, total_loss: 160.92
# epoch: 2 step:   25/125, lr:0.000100, giou_loss:   4.61, conf_loss: 151.13, prob_loss:   6.46, total_loss: 162.20
# epoch: 2 step:   26/125, lr:0.000100, giou_loss:   5.30, conf_loss: 149.00, prob_loss:   7.64, total_loss: 161.95
# epoch: 2 step:   27/125, lr:0.000100, giou_loss:   6.40, conf_loss: 151.09, prob_loss:  12.08, total_loss: 169.56
# epoch: 2 step:   28/125, lr:0.000100, giou_loss:   3.72, conf_loss: 145.90, prob_loss:   5.82, total_loss: 155.44
# epoch: 2 step:   29/125, lr:0.000100, giou_loss:   2.07, conf_loss: 144.22, prob_loss:   3.38, total_loss: 149.67
# epoch: 2 step:   30/125, lr:0.000100, giou_loss:   3.92, conf_loss: 143.68, prob_loss:   3.78, total_loss: 151.38
# epoch: 2 step:   31/125, lr:0.000100, giou_loss:   5.60, conf_loss: 145.39, prob_loss:   7.16, total_loss: 158.16
# epoch: 2 step:   32/125, lr:0.000100, giou_loss:   4.78, conf_loss: 142.88, prob_loss:   7.03, total_loss: 154.69
# epoch: 2 step:   33/125, lr:0.000100, giou_loss:   5.49, conf_loss: 145.12, prob_loss:   9.89, total_loss: 160.50
# epoch: 2 step:   34/125, lr:0.000100, giou_loss:   4.51, conf_loss: 141.14, prob_loss:   6.79, total_loss: 152.43
# epoch: 2 step:   35/125, lr:0.000100, giou_loss:   5.00, conf_loss: 139.75, prob_loss:   6.84, total_loss: 151.59
# epoch: 2 step:   36/125, lr:0.000100, giou_loss:   4.39, conf_loss: 139.36, prob_loss:   6.34, total_loss: 150.08
# epoch: 2 step:   37/125, lr:0.000100, giou_loss:   3.58, conf_loss: 135.89, prob_loss:   4.63, total_loss: 144.11
# epoch: 2 step:   38/125, lr:0.000100, giou_loss:   4.65, conf_loss: 137.88, prob_loss:   9.76, total_loss: 152.29
# epoch: 2 step:   39/125, lr:0.000100, giou_loss:   6.09, conf_loss: 137.15, prob_loss:   7.52, total_loss: 150.75
# epoch: 2 step:   40/125, lr:0.000100, giou_loss:   5.13, conf_loss: 136.51, prob_loss:   8.69, total_loss: 150.33
# epoch: 2 step:   41/125, lr:0.000100, giou_loss:   3.56, conf_loss: 131.32, prob_loss:   4.76, total_loss: 139.65
# epoch: 2 step:   42/125, lr:0.000100, giou_loss:   2.66, conf_loss: 127.94, prob_loss:   3.26, total_loss: 133.86
# epoch: 2 step:   43/125, lr:0.000100, giou_loss:   2.60, conf_loss: 130.70, prob_loss:   3.71, total_loss: 137.00
# epoch: 2 step:   44/125, lr:0.000100, giou_loss:   3.58, conf_loss: 130.15, prob_loss:   5.04, total_loss: 138.77
# epoch: 2 step:   45/125, lr:0.000100, giou_loss:   5.79, conf_loss: 131.85, prob_loss:   9.20, total_loss: 146.84
# epoch: 2 step:   46/125, lr:0.000100, giou_loss:   5.27, conf_loss: 127.20, prob_loss:   7.66, total_loss: 140.14
# epoch: 2 step:   47/125, lr:0.000100, giou_loss:   6.10, conf_loss: 129.85, prob_loss:   9.14, total_loss: 145.09
# epoch: 2 step:   48/125, lr:0.000100, giou_loss:   4.72, conf_loss: 126.38, prob_loss:   6.80, total_loss: 137.90
# epoch: 2 step:   49/125, lr:0.000100, giou_loss:   3.33, conf_loss: 124.45, prob_loss:   6.62, total_loss: 134.41
# epoch: 2 step:   50/125, lr:0.000100, giou_loss:   3.71, conf_loss: 124.66, prob_loss:   5.21, total_loss: 133.58
# epoch: 2 step:   51/125, lr:0.000100, giou_loss:   4.46, conf_loss: 123.64, prob_loss:  10.08, total_loss: 138.19
# epoch: 2 step:   52/125, lr:0.000100, giou_loss:   4.40, conf_loss: 122.77, prob_loss:   9.97, total_loss: 137.14
# epoch: 2 step:   53/125, lr:0.000100, giou_loss:   5.81, conf_loss: 122.62, prob_loss:   9.02, total_loss: 137.45
# epoch: 2 step:   54/125, lr:0.000100, giou_loss:   4.27, conf_loss: 120.48, prob_loss:   7.90, total_loss: 132.65
# epoch: 2 step:   55/125, lr:0.000100, giou_loss:   3.43, conf_loss: 121.00, prob_loss:   6.39, total_loss: 130.82
# epoch: 2 step:   56/125, lr:0.000100, giou_loss:   4.31, conf_loss: 118.96, prob_loss:   7.61, total_loss: 130.87
# epoch: 2 step:   57/125, lr:0.000100, giou_loss:   3.30, conf_loss: 114.37, prob_loss:   5.53, total_loss: 123.20
# epoch: 2 step:   58/125, lr:0.000100, giou_loss:   2.54, conf_loss: 115.26, prob_loss:   5.40, total_loss: 123.21
# epoch: 2 step:   59/125, lr:0.000100, giou_loss:   4.44, conf_loss: 115.48, prob_loss:   7.97, total_loss: 127.89
# epoch: 2 step:   60/125, lr:0.000100, giou_loss:   7.18, conf_loss: 119.74, prob_loss:  14.77, total_loss: 141.69
# epoch: 2 step:   61/125, lr:0.000100, giou_loss:   4.97, conf_loss: 116.27, prob_loss:   7.51, total_loss: 128.75
# epoch: 2 step:   62/125, lr:0.000100, giou_loss:   2.22, conf_loss: 112.42, prob_loss:   3.48, total_loss: 118.11
# epoch: 2 step:   63/125, lr:0.000100, giou_loss:   3.50, conf_loss: 111.39, prob_loss:   5.43, total_loss: 120.32
# epoch: 2 step:   64/125, lr:0.000100, giou_loss:   3.12, conf_loss: 109.47, prob_loss:   4.08, total_loss: 116.68
# epoch: 2 step:   65/125, lr:0.000100, giou_loss:   3.07, conf_loss: 110.89, prob_loss:   6.58, total_loss: 120.53
# epoch: 2 step:   66/125, lr:0.000100, giou_loss:   3.32, conf_loss: 110.20, prob_loss:   4.98, total_loss: 118.49
# epoch: 2 step:   67/125, lr:0.000100, giou_loss:   6.61, conf_loss: 112.14, prob_loss:  11.57, total_loss: 130.31
# epoch: 2 step:   68/125, lr:0.000100, giou_loss:   3.93, conf_loss: 108.13, prob_loss:   4.75, total_loss: 116.82
# epoch: 2 step:   69/125, lr:0.000100, giou_loss:   5.52, conf_loss: 112.15, prob_loss:   6.97, total_loss: 124.65
# epoch: 2 step:   70/125, lr:0.000100, giou_loss:   5.41, conf_loss: 109.60, prob_loss:   9.31, total_loss: 124.31
# epoch: 2 step:   71/125, lr:0.000100, giou_loss:   4.79, conf_loss: 109.53, prob_loss:   6.91, total_loss: 121.23
# epoch: 2 step:   72/125, lr:0.000100, giou_loss:   4.71, conf_loss: 109.06, prob_loss:   6.56, total_loss: 120.34
# epoch: 2 step:   73/125, lr:0.000100, giou_loss:   2.93, conf_loss: 105.60, prob_loss:   6.30, total_loss: 114.83
# epoch: 2 step:   74/125, lr:0.000100, giou_loss:   7.79, conf_loss: 111.57, prob_loss:  12.65, total_loss: 132.01
# epoch: 2 step:   75/125, lr:0.000100, giou_loss:   4.52, conf_loss: 105.03, prob_loss:   7.18, total_loss: 116.73
# epoch: 2 step:   76/125, lr:0.000100, giou_loss:   4.46, conf_loss: 106.12, prob_loss:   6.28, total_loss: 116.86
# epoch: 2 step:   77/125, lr:0.000100, giou_loss:   4.06, conf_loss: 104.36, prob_loss:   7.30, total_loss: 115.72
# epoch: 2 step:   78/125, lr:0.000100, giou_loss:   4.10, conf_loss: 103.48, prob_loss:   5.72, total_loss: 113.30
# epoch: 2 step:   79/125, lr:0.000100, giou_loss:   5.26, conf_loss: 105.40, prob_loss:   7.25, total_loss: 117.90
# epoch: 2 step:   80/125, lr:0.000100, giou_loss:   2.15, conf_loss:  99.55, prob_loss:   4.25, total_loss: 105.95
# epoch: 2 step:   81/125, lr:0.000100, giou_loss:   3.94, conf_loss: 102.31, prob_loss:   7.07, total_loss: 113.32
# epoch: 2 step:   82/125, lr:0.000100, giou_loss:   3.35, conf_loss:  99.40, prob_loss:   3.08, total_loss: 105.84
# epoch: 2 step:   83/125, lr:0.000100, giou_loss:   6.57, conf_loss: 105.10, prob_loss:  12.13, total_loss: 123.80
# epoch: 2 step:   84/125, lr:0.000100, giou_loss:   5.55, conf_loss: 102.87, prob_loss:  10.09, total_loss: 118.51
# epoch: 2 step:   85/125, lr:0.000100, giou_loss:   3.35, conf_loss:  97.54, prob_loss:   5.78, total_loss: 106.66
# epoch: 2 step:   86/125, lr:0.000100, giou_loss:   3.39, conf_loss:  98.73, prob_loss:   6.85, total_loss: 108.97
# epoch: 2 step:   87/125, lr:0.000100, giou_loss:   3.98, conf_loss:  98.83, prob_loss:   6.04, total_loss: 108.85
# epoch: 2 step:   88/125, lr:0.000100, giou_loss:   4.84, conf_loss:  99.51, prob_loss:   7.00, total_loss: 111.35
# epoch: 2 step:   89/125, lr:0.000100, giou_loss:   4.29, conf_loss:  97.26, prob_loss:   7.42, total_loss: 108.97
# epoch: 2 step:   90/125, lr:0.000100, giou_loss:  11.47, conf_loss: 106.69, prob_loss:  14.17, total_loss: 132.32
# epoch: 2 step:   91/125, lr:0.000100, giou_loss:   4.77, conf_loss:  94.71, prob_loss:   8.26, total_loss: 107.73
# epoch: 2 step:   92/125, lr:0.000100, giou_loss:   3.56, conf_loss:  96.13, prob_loss:   6.13, total_loss: 105.83
# epoch: 2 step:   93/125, lr:0.000100, giou_loss:   3.09, conf_loss:  90.70, prob_loss:   6.48, total_loss: 100.27
# epoch: 2 step:   94/125, lr:0.000100, giou_loss:   4.42, conf_loss:  92.69, prob_loss:   7.12, total_loss: 104.24
# epoch: 2 step:   95/125, lr:0.000100, giou_loss:   4.33, conf_loss:  98.11, prob_loss:  10.13, total_loss: 112.57
# epoch: 2 step:   96/125, lr:0.000100, giou_loss:   6.15, conf_loss:  98.07, prob_loss:  10.20, total_loss: 114.42
# epoch: 2 step:   97/125, lr:0.000100, giou_loss:   3.14, conf_loss:  89.17, prob_loss:   3.79, total_loss:  96.10
# epoch: 2 step:   98/125, lr:0.000100, giou_loss:   4.49, conf_loss:  91.44, prob_loss:   7.13, total_loss: 103.06
# epoch: 2 step:   99/125, lr:0.000100, giou_loss:   3.16, conf_loss:  91.15, prob_loss:   5.75, total_loss: 100.06
# epoch: 2 step:  100/125, lr:0.000100, giou_loss:   2.90, conf_loss:  89.46, prob_loss:   5.74, total_loss:  98.10
# epoch: 2 step:  101/125, lr:0.000100, giou_loss:   2.79, conf_loss:  88.66, prob_loss:   3.37, total_loss:  94.82
# epoch: 2 step:  102/125, lr:0.000100, giou_loss:   4.33, conf_loss:  88.93, prob_loss:   6.01, total_loss:  99.27
# epoch: 2 step:  103/125, lr:0.000100, giou_loss:   5.19, conf_loss:  90.36, prob_loss:   9.79, total_loss: 105.34
# epoch: 2 step:  104/125, lr:0.000100, giou_loss:   3.40, conf_loss:  85.36, prob_loss:   3.95, total_loss:  92.70
# epoch: 2 step:  105/125, lr:0.000100, giou_loss:   2.64, conf_loss:  84.59, prob_loss:   4.44, total_loss:  91.67
# epoch: 2 step:  106/125, lr:0.000100, giou_loss:   6.38, conf_loss:  92.28, prob_loss:  10.82, total_loss: 109.47
# epoch: 2 step:  107/125, lr:0.000100, giou_loss:   7.83, conf_loss:  92.37, prob_loss:  10.15, total_loss: 110.36
# epoch: 2 step:  108/125, lr:0.000100, giou_loss:   3.25, conf_loss:  84.62, prob_loss:   6.41, total_loss:  94.28
# epoch: 2 step:  109/125, lr:0.000100, giou_loss:   4.80, conf_loss:  87.07, prob_loss:   6.65, total_loss:  98.52
# epoch: 2 step:  110/125, lr:0.000100, giou_loss:   2.80, conf_loss:  85.39, prob_loss:   4.78, total_loss:  92.97
# epoch: 2 step:  111/125, lr:0.000100, giou_loss:  10.15, conf_loss:  95.07, prob_loss:  15.96, total_loss: 121.19
# epoch: 2 step:  112/125, lr:0.000100, giou_loss:   3.83, conf_loss:  83.04, prob_loss:   3.91, total_loss:  90.78
# epoch: 2 step:  113/125, lr:0.000100, giou_loss:   5.55, conf_loss:  88.70, prob_loss:   9.17, total_loss: 103.42
# epoch: 2 step:  114/125, lr:0.000100, giou_loss:   4.48, conf_loss:  87.01, prob_loss:   6.66, total_loss:  98.15
# epoch: 2 step:  115/125, lr:0.000100, giou_loss:   4.91, conf_loss:  83.34, prob_loss:   6.43, total_loss:  94.69
# epoch: 2 step:  116/125, lr:0.000100, giou_loss:   7.92, conf_loss:  90.24, prob_loss:  12.06, total_loss: 110.22
# epoch: 2 step:  117/125, lr:0.000100, giou_loss:   7.88, conf_loss:  90.40, prob_loss:  16.46, total_loss: 114.74
# epoch: 2 step:  118/125, lr:0.000100, giou_loss:   4.59, conf_loss:  81.68, prob_loss:   7.40, total_loss:  93.67
# epoch: 2 step:  119/125, lr:0.000100, giou_loss:   5.82, conf_loss:  83.41, prob_loss:   6.65, total_loss:  95.88
# epoch: 2 step:  120/125, lr:0.000100, giou_loss:   3.55, conf_loss:  79.87, prob_loss:   5.15, total_loss:  88.57
# epoch: 2 step:  121/125, lr:0.000100, giou_loss:   4.17, conf_loss:  81.17, prob_loss:   6.42, total_loss:  91.76
# epoch: 2 step:  122/125, lr:0.000100, giou_loss:   4.11, conf_loss:  78.71, prob_loss:   6.40, total_loss:  89.23
# epoch: 2 step:  123/125, lr:0.000100, giou_loss:   4.13, conf_loss:  78.97, prob_loss:   6.68, total_loss:  89.79
# epoch: 2 step:  124/125, lr:0.000100, giou_loss:   3.14, conf_loss:  76.43, prob_loss:   4.33, total_loss:  83.90
# epoch: 2 step:    0/125, lr:0.000100, giou_loss:   2.93, conf_loss:  75.62, prob_loss:   3.67, total_loss:  82.23
# epoch: 2 step:    1/125, lr:0.000100, giou_loss:   4.90, conf_loss:  77.60, prob_loss:   7.54, total_loss:  90.04
#
#
# giou_val_loss:   4.54, conf_val_loss: 192.17, prob_val_loss:   7.69, total_val_loss: 204.39
#
#
# epoch: 3 step:    2/125, lr:0.000100, giou_loss:   6.18, conf_loss:  81.82, prob_loss:   8.87, total_loss:  96.87
# epoch: 3 step:    3/125, lr:0.000100, giou_loss:   4.53, conf_loss:  78.62, prob_loss:   6.26, total_loss:  89.41
# epoch: 3 step:    4/125, lr:0.000100, giou_loss:   4.20, conf_loss:  74.29, prob_loss:   4.82, total_loss:  83.31
# epoch: 3 step:    5/125, lr:0.000100, giou_loss:   6.69, conf_loss:  80.86, prob_loss:  14.89, total_loss: 102.44
# epoch: 3 step:    6/125, lr:0.000100, giou_loss:   5.70, conf_loss:  77.28, prob_loss:   8.11, total_loss:  91.08
# epoch: 3 step:    7/125, lr:0.000100, giou_loss:   3.54, conf_loss:  73.93, prob_loss:   6.65, total_loss:  84.12
# epoch: 3 step:    8/125, lr:0.000100, giou_loss:   4.27, conf_loss:  74.87, prob_loss:   6.98, total_loss:  86.12
# epoch: 3 step:    9/125, lr:0.000100, giou_loss:   6.09, conf_loss:  78.06, prob_loss:   9.33, total_loss:  93.47
# epoch: 3 step:   10/125, lr:0.000100, giou_loss:   3.88, conf_loss:  72.48, prob_loss:   7.15, total_loss:  83.51
# epoch: 3 step:   11/125, lr:0.000100, giou_loss:   5.16, conf_loss:  73.04, prob_loss:   5.78, total_loss:  83.98
# epoch: 3 step:   12/125, lr:0.000100, giou_loss:   3.31, conf_loss:  71.57, prob_loss:   5.23, total_loss:  80.12
# epoch: 3 step:   13/125, lr:0.000100, giou_loss:   7.41, conf_loss:  75.85, prob_loss:   9.16, total_loss:  92.42
# epoch: 3 step:   14/125, lr:0.000100, giou_loss:   5.51, conf_loss:  72.50, prob_loss:   9.66, total_loss:  87.67
# epoch: 3 step:   15/125, lr:0.000100, giou_loss:   3.50, conf_loss:  71.05, prob_loss:   7.56, total_loss:  82.11
# epoch: 3 step:   16/125, lr:0.000100, giou_loss:   4.32, conf_loss:  72.55, prob_loss:  10.01, total_loss:  86.88
# epoch: 3 step:   17/125, lr:0.000100, giou_loss:   3.46, conf_loss:  71.63, prob_loss:   5.45, total_loss:  80.55
# epoch: 3 step:   18/125, lr:0.000100, giou_loss:   3.05, conf_loss:  68.02, prob_loss:   2.42, total_loss:  73.49
# epoch: 3 step:   19/125, lr:0.000100, giou_loss:   3.97, conf_loss:  69.41, prob_loss:   4.69, total_loss:  78.07
# epoch: 3 step:   20/125, lr:0.000100, giou_loss:   8.04, conf_loss:  75.32, prob_loss:   9.36, total_loss:  92.72
# epoch: 3 step:   21/125, lr:0.000100, giou_loss:   3.86, conf_loss:  68.71, prob_loss:   4.90, total_loss:  77.46
# epoch: 3 step:   22/125, lr:0.000100, giou_loss:   4.44, conf_loss:  70.29, prob_loss:   7.22, total_loss:  81.95
# epoch: 3 step:   23/125, lr:0.000100, giou_loss:   3.67, conf_loss:  68.49, prob_loss:   7.01, total_loss:  79.17
# epoch: 3 step:   24/125, lr:0.000100, giou_loss:   6.52, conf_loss:  72.12, prob_loss:  11.91, total_loss:  90.56
# epoch: 3 step:   25/125, lr:0.000100, giou_loss:   3.49, conf_loss:  67.73, prob_loss:   7.70, total_loss:  78.91
# epoch: 3 step:   26/125, lr:0.000100, giou_loss:   2.92, conf_loss:  65.46, prob_loss:   4.26, total_loss:  72.64
# epoch: 3 step:   27/125, lr:0.000100, giou_loss:   5.87, conf_loss:  71.26, prob_loss:   8.51, total_loss:  85.64
# epoch: 3 step:   28/125, lr:0.000100, giou_loss:   5.72, conf_loss:  70.36, prob_loss:  10.90, total_loss:  86.98
# epoch: 3 step:   29/125, lr:0.000100, giou_loss:   5.06, conf_loss:  68.70, prob_loss:   8.73, total_loss:  82.49
# epoch: 3 step:   30/125, lr:0.000100, giou_loss:   4.33, conf_loss:  66.42, prob_loss:   6.10, total_loss:  76.85
# epoch: 3 step:   31/125, lr:0.000100, giou_loss:   4.02, conf_loss:  66.05, prob_loss:   5.65, total_loss:  75.72
# epoch: 3 step:   32/125, lr:0.000100, giou_loss:   3.18, conf_loss:  64.14, prob_loss:   5.62, total_loss:  72.94
# epoch: 3 step:   33/125, lr:0.000100, giou_loss:   2.59, conf_loss:  63.06, prob_loss:   4.37, total_loss:  70.02
# epoch: 3 step:   34/125, lr:0.000100, giou_loss:   5.19, conf_loss:  66.70, prob_loss:   6.60, total_loss:  78.48
# epoch: 3 step:   35/125, lr:0.000100, giou_loss:   4.36, conf_loss:  66.66, prob_loss:   7.92, total_loss:  78.95
# epoch: 3 step:   36/125, lr:0.000100, giou_loss:   3.68, conf_loss:  63.60, prob_loss:   5.36, total_loss:  72.64
# epoch: 3 step:   37/125, lr:0.000100, giou_loss:   4.06, conf_loss:  65.09, prob_loss:   7.35, total_loss:  76.51
# epoch: 3 step:   38/125, lr:0.000100, giou_loss:   4.59, conf_loss:  62.22, prob_loss:   5.86, total_loss:  72.68
# epoch: 3 step:   39/125, lr:0.000100, giou_loss:   4.28, conf_loss:  63.64, prob_loss:   5.57, total_loss:  73.49
# epoch: 3 step:   40/125, lr:0.000100, giou_loss:   4.58, conf_loss:  63.88, prob_loss:   7.08, total_loss:  75.55
# ...
# epoch:98 step:  114/125, lr:0.000001, giou_loss:   0.22, conf_loss:   0.03, prob_loss:   0.35, total_loss:   0.60
# epoch:98 step:  115/125, lr:0.000001, giou_loss:   0.22, conf_loss:   0.04, prob_loss:   0.33, total_loss:   0.59
# epoch:98 step:  116/125, lr:0.000001, giou_loss:   0.38, conf_loss:   0.04, prob_loss:   0.62, total_loss:   1.04
# epoch:98 step:  117/125, lr:0.000001, giou_loss:   0.27, conf_loss:   0.04, prob_loss:   0.32, total_loss:   0.62
# epoch:98 step:  118/125, lr:0.000001, giou_loss:   0.27, conf_loss:   0.05, prob_loss:   0.40, total_loss:   0.72
# epoch:98 step:  119/125, lr:0.000001, giou_loss:   0.21, conf_loss:   0.04, prob_loss:   0.30, total_loss:   0.56
# epoch:98 step:  120/125, lr:0.000001, giou_loss:   0.23, conf_loss:   0.04, prob_loss:   0.30, total_loss:   0.58
# epoch:98 step:  121/125, lr:0.000001, giou_loss:   0.20, conf_loss:   0.04, prob_loss:   0.30, total_loss:   0.55
# epoch:98 step:  122/125, lr:0.000001, giou_loss:   0.25, conf_loss:   0.04, prob_loss:   0.25, total_loss:   0.54
# epoch:98 step:  123/125, lr:0.000001, giou_loss:   0.27, conf_loss:   0.04, prob_loss:   0.38, total_loss:   0.69
# epoch:98 step:  124/125, lr:0.000001, giou_loss:   0.32, conf_loss:   0.04, prob_loss:   0.33, total_loss:   0.69
# epoch:98 step:    0/125, lr:0.000001, giou_loss:   0.25, conf_loss:   0.05, prob_loss:   0.40, total_loss:   0.70
# epoch:98 step:    1/125, lr:0.000001, giou_loss:   0.19, conf_loss:   0.04, prob_loss:   0.24, total_loss:   0.46
#
#
# giou_val_loss:   0.26, conf_val_loss:   0.05, prob_val_loss:   0.35, total_val_loss:   0.66
#
#
# epoch:99 step:    2/125, lr:0.000001, giou_loss:   0.18, conf_loss:   0.05, prob_loss:   0.33, total_loss:   0.56
# epoch:99 step:    3/125, lr:0.000001, giou_loss:   0.29, conf_loss:   0.04, prob_loss:   0.49, total_loss:   0.82
# epoch:99 step:    4/125, lr:0.000001, giou_loss:   0.19, conf_loss:   0.04, prob_loss:   0.29, total_loss:   0.51
# epoch:99 step:    5/125, lr:0.000001, giou_loss:   0.50, conf_loss:   0.05, prob_loss:   0.51, total_loss:   1.07
# epoch:99 step:    6/125, lr:0.000001, giou_loss:   0.16, conf_loss:   0.04, prob_loss:   0.25, total_loss:   0.45
# epoch:99 step:    7/125, lr:0.000001, giou_loss:   0.20, conf_loss:   0.04, prob_loss:   0.24, total_loss:   0.47
# epoch:99 step:    8/125, lr:0.000001, giou_loss:   0.20, conf_loss:   0.05, prob_loss:   0.30, total_loss:   0.55
# epoch:99 step:    9/125, lr:0.000001, giou_loss:   0.54, conf_loss:   0.04, prob_loss:   0.35, total_loss:   0.92
# epoch:99 step:   10/125, lr:0.000001, giou_loss:   0.22, conf_loss:   0.04, prob_loss:   0.27, total_loss:   0.53
# epoch:99 step:   11/125, lr:0.000001, giou_loss:   0.27, conf_loss:   0.04, prob_loss:   0.38, total_loss:   0.70
# epoch:99 step:   12/125, lr:0.000001, giou_loss:   0.24, conf_loss:   0.04, prob_loss:   0.28, total_loss:   0.57
# epoch:99 step:   13/125, lr:0.000001, giou_loss:   0.13, conf_loss:   0.04, prob_loss:   0.19, total_loss:   0.36
# epoch:99 step:   14/125, lr:0.000001, giou_loss:   0.18, conf_loss:   0.04, prob_loss:   0.32, total_loss:   0.54
# epoch:99 step:   15/125, lr:0.000001, giou_loss:   0.22, conf_loss:   0.04, prob_loss:   0.41, total_loss:   0.67
# epoch:99 step:   16/125, lr:0.000001, giou_loss:   0.12, conf_loss:   0.04, prob_loss:   0.22, total_loss:   0.39
# epoch:99 step:   17/125, lr:0.000001, giou_loss:   0.30, conf_loss:   0.04, prob_loss:   0.40, total_loss:   0.75
# epoch:99 step:   18/125, lr:0.000001, giou_loss:   0.18, conf_loss:   0.04, prob_loss:   0.23, total_loss:   0.45
# epoch:99 step:   19/125, lr:0.000001, giou_loss:   0.26, conf_loss:   0.04, prob_loss:   0.37, total_loss:   0.66
# epoch:99 step:   20/125, lr:0.000001, giou_loss:   0.18, conf_loss:   0.03, prob_loss:   0.35, total_loss:   0.57
# epoch:99 step:   21/125, lr:0.000001, giou_loss:   0.26, conf_loss:   0.04, prob_loss:   0.38, total_loss:   0.67
# epoch:99 step:   22/125, lr:0.000001, giou_loss:   0.24, conf_loss:   0.03, prob_loss:   0.27, total_loss:   0.54
# epoch:99 step:   23/125, lr:0.000001, giou_loss:   0.72, conf_loss:   0.61, prob_loss:   0.56, total_loss:   1.89
# epoch:99 step:   24/125, lr:0.000001, giou_loss:   0.27, conf_loss:   0.08, prob_loss:   0.30, total_loss:   0.65
# epoch:99 step:   25/125, lr:0.000001, giou_loss:   0.21, conf_loss:   0.04, prob_loss:   0.33, total_loss:   0.58
# epoch:99 step:   26/125, lr:0.000001, giou_loss:   0.18, conf_loss:   0.04, prob_loss:   0.28, total_loss:   0.50
# epoch:99 step:   27/125, lr:0.000001, giou_loss:   0.12, conf_loss:   0.04, prob_loss:   0.22, total_loss:   0.38
# epoch:99 step:   28/125, lr:0.000001, giou_loss:   0.22, conf_loss:   0.04, prob_loss:   0.33, total_loss:   0.59
# epoch:99 step:   29/125, lr:0.000001, giou_loss:   0.15, conf_loss:   0.04, prob_loss:   0.25, total_loss:   0.44
# epoch:99 step:   30/125, lr:0.000001, giou_loss:   0.43, conf_loss:   0.05, prob_loss:   0.51, total_loss:   0.99
# epoch:99 step:   31/125, lr:0.000001, giou_loss:   0.49, conf_loss:   0.49, prob_loss:   0.37, total_loss:   1.35
# epoch:99 step:   32/125, lr:0.000001, giou_loss:   0.24, conf_loss:   0.04, prob_loss:   0.40, total_loss:   0.68
# epoch:99 step:   33/125, lr:0.000001, giou_loss:   0.35, conf_loss:   0.04, prob_loss:   0.57, total_loss:   0.96
# epoch:99 step:   34/125, lr:0.000001, giou_loss:   0.27, conf_loss:   0.04, prob_loss:   0.41, total_loss:   0.72
# epoch:99 step:   35/125, lr:0.000001, giou_loss:   0.21, conf_loss:   0.04, prob_loss:   0.33, total_loss:   0.58
# epoch:99 step:   36/125, lr:0.000001, giou_loss:   0.77, conf_loss:   0.04, prob_loss:   0.27, total_loss:   1.07
# epoch:99 step:   37/125, lr:0.000001, giou_loss:   0.41, conf_loss:   0.05, prob_loss:   0.46, total_loss:   0.92
# epoch:99 step:   38/125, lr:0.000001, giou_loss:   0.27, conf_loss:   0.04, prob_loss:   0.38, total_loss:   0.69
# epoch:99 step:   39/125, lr:0.000001, giou_loss:   0.51, conf_loss:   0.08, prob_loss:   0.59, total_loss:   1.18
# epoch:99 step:   40/125, lr:0.000001, giou_loss:   0.11, conf_loss:   0.04, prob_loss:   0.16, total_loss:   0.30
# epoch:99 step:   41/125, lr:0.000001, giou_loss:   0.22, conf_loss:   0.04, prob_loss:   0.27, total_loss:   0.53
# epoch:99 step:   42/125, lr:0.000001, giou_loss:   0.23, conf_loss:   0.04, prob_loss:   0.24, total_loss:   0.51
# epoch:99 step:   43/125, lr:0.000001, giou_loss:   0.35, conf_loss:   0.04, prob_loss:   0.39, total_loss:   0.79
# epoch:99 step:   44/125, lr:0.000001, giou_loss:   0.20, conf_loss:   0.03, prob_loss:   0.27, total_loss:   0.51
# epoch:99 step:   45/125, lr:0.000001, giou_loss:   0.30, conf_loss:   0.04, prob_loss:   0.35, total_loss:   0.70
# epoch:99 step:   46/125, lr:0.000001, giou_loss:   0.22, conf_loss:   0.04, prob_loss:   0.24, total_loss:   0.50
# epoch:99 step:   47/125, lr:0.000001, giou_loss:   0.21, conf_loss:   0.04, prob_loss:   0.29, total_loss:   0.54
# epoch:99 step:   48/125, lr:0.000001, giou_loss:   0.30, conf_loss:   0.04, prob_loss:   0.33, total_loss:   0.67
# epoch:99 step:   49/125, lr:0.000001, giou_loss:   0.18, conf_loss:   0.04, prob_loss:   0.24, total_loss:   0.45
# epoch:99 step:   50/125, lr:0.000001, giou_loss:   0.20, conf_loss:   0.04, prob_loss:   0.41, total_loss:   0.65
# epoch:99 step:   51/125, lr:0.000001, giou_loss:   0.31, conf_loss:   0.05, prob_loss:   0.41, total_loss:   0.77
# epoch:99 step:   52/125, lr:0.000001, giou_loss:   0.28, conf_loss:   0.04, prob_loss:   0.44, total_loss:   0.76
# epoch:99 step:   53/125, lr:0.000001, giou_loss:   0.15, conf_loss:   0.03, prob_loss:   0.29, total_loss:   0.47
# epoch:99 step:   54/125, lr:0.000001, giou_loss:   0.42, conf_loss:   0.07, prob_loss:   0.48, total_loss:   0.97
# epoch:99 step:   55/125, lr:0.000001, giou_loss:   0.20, conf_loss:   0.03, prob_loss:   0.37, total_loss:   0.60
# epoch:99 step:   56/125, lr:0.000001, giou_loss:   0.21, conf_loss:   0.03, prob_loss:   0.21, total_loss:   0.45
# epoch:99 step:   57/125, lr:0.000001, giou_loss:   0.27, conf_loss:   0.04, prob_loss:   0.46, total_loss:   0.77
# epoch:99 step:   58/125, lr:0.000001, giou_loss:   1.07, conf_loss:   0.04, prob_loss:   0.67, total_loss:   1.79
# epoch:99 step:   59/125, lr:0.000001, giou_loss:   0.17, conf_loss:   0.04, prob_loss:   0.16, total_loss:   0.37
# epoch:99 step:   60/125, lr:0.000001, giou_loss:   0.74, conf_loss:   0.04, prob_loss:   0.35, total_loss:   1.13
# epoch:99 step:   61/125, lr:0.000001, giou_loss:   0.25, conf_loss:   0.04, prob_loss:   0.40, total_loss:   0.70
# epoch:99 step:   62/125, lr:0.000001, giou_loss:   0.41, conf_loss:   0.05, prob_loss:   0.53, total_loss:   0.98
# epoch:99 step:   63/125, lr:0.000001, giou_loss:   0.15, conf_loss:   0.04, prob_loss:   0.29, total_loss:   0.48
# epoch:99 step:   64/125, lr:0.000001, giou_loss:   0.14, conf_loss:   0.04, prob_loss:   0.25, total_loss:   0.43
# epoch:99 step:   65/125, lr:0.000001, giou_loss:   0.30, conf_loss:   0.05, prob_loss:   0.37, total_loss:   0.71
# epoch:99 step:   66/125, lr:0.000001, giou_loss:   0.22, conf_loss:   0.04, prob_loss:   0.33, total_loss:   0.60
# epoch:99 step:   67/125, lr:0.000001, giou_loss:   0.20, conf_loss:   0.04, prob_loss:   0.34, total_loss:   0.57
# epoch:99 step:   68/125, lr:0.000001, giou_loss:   0.39, conf_loss:   0.10, prob_loss:   0.49, total_loss:   0.98
# epoch:99 step:   69/125, lr:0.000001, giou_loss:   0.40, conf_loss:   0.04, prob_loss:   0.33, total_loss:   0.78
# epoch:99 step:   70/125, lr:0.000001, giou_loss:   0.51, conf_loss:   0.04, prob_loss:   0.48, total_loss:   1.03
# epoch:99 step:   71/125, lr:0.000001, giou_loss:   0.23, conf_loss:   0.09, prob_loss:   0.27, total_loss:   0.60
# epoch:99 step:   72/125, lr:0.000001, giou_loss:   0.22, conf_loss:   0.05, prob_loss:   0.38, total_loss:   0.65
# epoch:99 step:   73/125, lr:0.000001, giou_loss:   0.28, conf_loss:   0.04, prob_loss:   0.32, total_loss:   0.64
# epoch:99 step:   74/125, lr:0.000001, giou_loss:   0.48, conf_loss:   0.05, prob_loss:   0.53, total_loss:   1.06
# epoch:99 step:   75/125, lr:0.000001, giou_loss:   0.32, conf_loss:   0.04, prob_loss:   0.33, total_loss:   0.70
# epoch:99 step:   76/125, lr:0.000001, giou_loss:   0.32, conf_loss:   0.04, prob_loss:   0.36, total_loss:   0.72
# epoch:99 step:   77/125, lr:0.000001, giou_loss:   0.61, conf_loss:   0.08, prob_loss:   0.69, total_loss:   1.38
# epoch:99 step:   78/125, lr:0.000001, giou_loss:   0.27, conf_loss:   0.04, prob_loss:   0.35, total_loss:   0.65
# epoch:99 step:   79/125, lr:0.000001, giou_loss:   0.29, conf_loss:   0.03, prob_loss:   0.38, total_loss:   0.70
# epoch:99 step:   80/125, lr:0.000001, giou_loss:   0.32, conf_loss:   0.04, prob_loss:   0.42, total_loss:   0.78
# epoch:99 step:   81/125, lr:0.000001, giou_loss:   0.42, conf_loss:   0.03, prob_loss:   0.27, total_loss:   0.73
# epoch:99 step:   82/125, lr:0.000001, giou_loss:   0.16, conf_loss:   0.03, prob_loss:   0.27, total_loss:   0.46
# epoch:99 step:   83/125, lr:0.000001, giou_loss:   0.27, conf_loss:   0.05, prob_loss:   0.35, total_loss:   0.67
# epoch:99 step:   84/125, lr:0.000001, giou_loss:   0.23, conf_loss:   0.04, prob_loss:   0.37, total_loss:   0.64
# epoch:99 step:   85/125, lr:0.000001, giou_loss:   0.28, conf_loss:   0.04, prob_loss:   0.38, total_loss:   0.70
# epoch:99 step:   86/125, lr:0.000001, giou_loss:   0.34, conf_loss:   0.04, prob_loss:   0.30, total_loss:   0.68
# epoch:99 step:   87/125, lr:0.000001, giou_loss:   0.17, conf_loss:   0.04, prob_loss:   0.22, total_loss:   0.44
# epoch:99 step:   88/125, lr:0.000001, giou_loss:   0.52, conf_loss:   0.09, prob_loss:   0.72, total_loss:   1.33
# epoch:99 step:   89/125, lr:0.000001, giou_loss:   0.29, conf_loss:   0.04, prob_loss:   0.34, total_loss:   0.67
# epoch:99 step:   90/125, lr:0.000001, giou_loss:   0.19, conf_loss:   0.04, prob_loss:   0.25, total_loss:   0.49
# epoch:99 step:   91/125, lr:0.000001, giou_loss:   0.65, conf_loss:   0.04, prob_loss:   0.37, total_loss:   1.06
# epoch:99 step:   92/125, lr:0.000001, giou_loss:   0.24, conf_loss:   0.04, prob_loss:   0.40, total_loss:   0.68
# epoch:99 step:   93/125, lr:0.000001, giou_loss:   0.41, conf_loss:   0.05, prob_loss:   0.34, total_loss:   0.80
# epoch:99 step:   94/125, lr:0.000001, giou_loss:   0.45, conf_loss:   0.05, prob_loss:   0.62, total_loss:   1.12
# epoch:99 step:   95/125, lr:0.000001, giou_loss:   0.18, conf_loss:   0.04, prob_loss:   0.26, total_loss:   0.48
# epoch:99 step:   96/125, lr:0.000001, giou_loss:   0.22, conf_loss:   0.03, prob_loss:   0.27, total_loss:   0.52
# epoch:99 step:   97/125, lr:0.000001, giou_loss:   0.80, conf_loss:   0.04, prob_loss:   0.42, total_loss:   1.26
# epoch:99 step:   98/125, lr:0.000001, giou_loss:   0.21, conf_loss:   0.04, prob_loss:   0.34, total_loss:   0.59
# epoch:99 step:   99/125, lr:0.000001, giou_loss:   0.26, conf_loss:   0.04, prob_loss:   0.38, total_loss:   0.68
# epoch:99 step:  100/125, lr:0.000001, giou_loss:   0.40, conf_loss:   0.07, prob_loss:   0.47, total_loss:   0.93
# epoch:99 step:  101/125, lr:0.000001, giou_loss:   0.47, conf_loss:   0.07, prob_loss:   0.43, total_loss:   0.97
# epoch:99 step:  102/125, lr:0.000001, giou_loss:   0.64, conf_loss:   0.04, prob_loss:   0.42, total_loss:   1.10
# epoch:99 step:  103/125, lr:0.000001, giou_loss:   0.26, conf_loss:   0.04, prob_loss:   0.21, total_loss:   0.50
# epoch:99 step:  104/125, lr:0.000001, giou_loss:   0.39, conf_loss:   0.05, prob_loss:   0.52, total_loss:   0.96
# epoch:99 step:  105/125, lr:0.000001, giou_loss:   0.20, conf_loss:   0.04, prob_loss:   0.38, total_loss:   0.62
# epoch:99 step:  106/125, lr:0.000001, giou_loss:   0.26, conf_loss:   0.04, prob_loss:   0.24, total_loss:   0.54
# epoch:99 step:  107/125, lr:0.000001, giou_loss:   0.15, conf_loss:   0.04, prob_loss:   0.21, total_loss:   0.40
# epoch:99 step:  108/125, lr:0.000001, giou_loss:   0.15, conf_loss:   0.04, prob_loss:   0.19, total_loss:   0.38
# epoch:99 step:  109/125, lr:0.000001, giou_loss:   0.43, conf_loss:   0.04, prob_loss:   0.27, total_loss:   0.74
# epoch:99 step:  110/125, lr:0.000001, giou_loss:   0.18, conf_loss:   0.04, prob_loss:   0.35, total_loss:   0.57
# epoch:99 step:  111/125, lr:0.000001, giou_loss:   0.15, conf_loss:   0.03, prob_loss:   0.27, total_loss:   0.46
# epoch:99 step:  112/125, lr:0.000001, giou_loss:   0.20, conf_loss:   0.04, prob_loss:   0.24, total_loss:   0.48
# epoch:99 step:  113/125, lr:0.000001, giou_loss:   0.46, conf_loss:   0.10, prob_loss:   0.45, total_loss:   1.00
# epoch:99 step:  114/125, lr:0.000001, giou_loss:   0.44, conf_loss:   0.07, prob_loss:   0.45, total_loss:   0.96
# epoch:99 step:  115/125, lr:0.000001, giou_loss:   0.20, conf_loss:   0.04, prob_loss:   0.36, total_loss:   0.60
# epoch:99 step:  116/125, lr:0.000001, giou_loss:   0.22, conf_loss:   0.04, prob_loss:   0.29, total_loss:   0.54
# epoch:99 step:  117/125, lr:0.000001, giou_loss:   0.12, conf_loss:   0.04, prob_loss:   0.21, total_loss:   0.36
# epoch:99 step:  118/125, lr:0.000001, giou_loss:   0.18, conf_loss:   0.04, prob_loss:   0.25, total_loss:   0.47
# epoch:99 step:  119/125, lr:0.000001, giou_loss:   0.28, conf_loss:   0.04, prob_loss:   0.26, total_loss:   0.57
# epoch:99 step:  120/125, lr:0.000001, giou_loss:   0.22, conf_loss:   0.04, prob_loss:   0.38, total_loss:   0.64
# epoch:99 step:  121/125, lr:0.000001, giou_loss:   0.15, conf_loss:   0.05, prob_loss:   0.19, total_loss:   0.38
# epoch:99 step:  122/125, lr:0.000001, giou_loss:   0.36, conf_loss:   0.04, prob_loss:   0.30, total_loss:   0.70
# epoch:99 step:  123/125, lr:0.000001, giou_loss:   0.11, conf_loss:   0.04, prob_loss:   0.24, total_loss:   0.39
# epoch:99 step:  124/125, lr:0.000001, giou_loss:   0.19, conf_loss:   0.04, prob_loss:   0.33, total_loss:   0.56
# epoch:99 step:    0/125, lr:0.000001, giou_loss:   0.30, conf_loss:   0.05, prob_loss:   0.43, total_loss:   0.78
# epoch:99 step:    1/125, lr:0.000001, giou_loss:   0.50, conf_loss:   0.09, prob_loss:   0.40, total_loss:   0.99
#
#
# giou_val_loss:   0.25, conf_val_loss:   0.05, prob_val_loss:   0.35, total_val_loss:   0.65

# %% [markdown]
# test

# %%
import os
import cv2
import numpy as np
import random
import time
import tensorflow as tf

YOLO_INPUT_SIZE = 416
input_size=YOLO_INPUT_SIZE



image_path ="C:/Users/SBAUser/Desktop/code/directory/bs.png.jpg" #image_info[0]

yolo = Create_Yolov3(input_size=input_size, CLASSES=TRAIN_CLASSES)
yolo.load_weights("yolov3_custom")



img = detect_image(yolo, image_path, "", input_size=input_size, show=True, CLASSES=TRAIN_CLASSES, rectangle_colors=(255,0,0))
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 1s 774ms/step
# []

# %%
yolo.save('my_model.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
loaded_model = tf.keras.models.load_model('my_model.h5')

loaded_model.load_weights("./checkpoints/yolov3_custom")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
#loaded_model.summary()
img = detect_image(loaded_model, image_path, "", input_size=input_size, show=True, CLASSES=TRAIN_CLASSES, rectangle_colors=(255,0,0))
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_384\2855431474.py in <module>
#       1 #loaded_model.summary()
# ----> 2 img = detect_image(loaded_model, image_path, "", input_size=input_size, show=True, CLASSES=TRAIN_CLASSES, rectangle_colors=(255,0,0))
#       3 cv2_imshow(img)
#
# NameError: name 'loaded_model' is not defined
