# %%
# Word Tokenization 

from nltk.tokenize import word_tokenize
from nltk.tokenize import WordPunctTokenizer
from tensorflow.keras.preprocessing.text import text_to_word_sequence

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
sentence = "Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop."

# %%
# 's (어퍼스트로피) 가 들어간 상황에서 Don't 하고 Jone's 토큰화 하는 방버
# >>word_tokenize : 단어 >> 토큰화

# %%
print('단어 토큰화1 :',word_tokenize("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop."))
# Out:
# 단어 토큰화1 : ['Do', "n't", 'be', 'fooled', 'by', 'the', 'dark', 'sounding', 'name', ',', 'Mr.', 'Jone', "'s", 'Orphanage', 'is', 'as', 'cheery', 'as', 'cheery', 'goes', 'for', 'a', 'pastry', 'shop', '.']

# %%
# WordPunctTokenizer : nltk 의 tokenizer 또 다른 방법
from nltk.tokenize import WordPunctTokenizer
print(WordPunctTokenizer().tokenize(sentence))

# Don't >> Don 하고 ' 하고 t로 분리
# Out:
# ['Don', "'", 't', 'be', 'fooled', 'by', 'the', 'dark', 'sounding', 'name', ',', 'Mr', '.', 'Jone', "'", 's', 'Orphanage', 'is', 'as', 'cheery', 'as', 'cheery', 'goes', 'for', 'a', 'pastry', 'shop', '.']

# %%
# TreebankWordTokenizer : NLTK 또 다른 tokenizer 방법 

from nltk.tokenize import TreebankWordTokenizer

tokenizer = TreebankWordTokenizer()

text = "Starting a home-based restaurant may be an ideal. it doesn't have a food chain or restaurant of their own."

print('트리뱅크 워드토크나이저 :',tokenizer.tokenize(text))
# Out:
# 트리뱅크 워드토크나이저 : ['Starting', 'a', 'home-based', 'restaurant', 'may', 'be', 'an', 'ideal.', 'it', 'does', "n't", 'have', 'a', 'food', 'chain', 'or', 'restaurant', 'of', 'their', 'own', '.']

# %%
en_text = "A Dog Run back corner near spare bedrooms!!!!"

# %%
from nltk.tokenize import word_tokenize 

print(word_tokenize(en_text))
# Out:
# ['A', 'Dog', 'Run', 'back', 'corner', 'near', 'spare', 'bedrooms', '!', '!', '!', '!']

# %%
en_text.split()
# Out:
# ['A', 'Dog', 'Run', 'back', 'corner', 'near', 'spare', 'bedrooms!!!!']

# %%
# 특수문자 추가 
en_text = "A Dog Run back corner near spare bedrooms .....bedrooms !!!!"

# %%
print(word_tokenize(en_text))
# Out:
# ['A', 'Dog', 'Run', 'back', 'corner', 'near', 'spare', 'bedrooms', '.....', 'bedrooms', '!', '!', '!', '!']

# %%
print(en_text.split())
# Out:
# ['A', 'Dog', 'Run', 'back', 'corner', 'near', 'spare', 'bedrooms', '.....bedrooms', '!!!!']

# %%
# 한국어 Word Toknization (KoNLPy)

kor_text = "닥터윌의 놀라운 강의능력이라는 책을 봤어. 그래서 나는 오늘 닥터윌을 보기 위해 오늘도 서울시 강동캠퍼스에 가서 인공지능 수업을 듣고 있지. 땡큐 닥터윌"
print(kor_text.split())
# Out:
# ['닥터윌의', '놀라운', '강의능력이라는', '책을', '봤어.', '그래서', '나는', '오늘', '닥터윌을', '보기', '위해', '오늘도', '서울시', '강동캠퍼스에', '가서', '인공지능', '수업을', '듣고', '있지.', '땡큐', '닥터윌']

# %%
# 에이.. '닥터윌'만 추출하고 싶은데,. 한국어는 교착어라 자꾸 조사가 붙어 나오네 
# >> 형태소로 분석해야겠다. 

# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 28.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 3.9 MB/s eta 0:00:00
# ...

# %%
# !apt-get install -y fonts-nanum
# !apt-get install -y fontconfig
# !fc-cache -fv
# !pip install Mecab
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 4 not upgraded.
# Need to get 9,599 kB of archives.
# After this operation, 29.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-nanum all 20180306-3 [9,599 kB]
# Fetched 9,599 kB in 2s (5,308 kB/s)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 122363 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20180306-3_all.deb ...
# Unpacking fonts-nanum (20180306-3) ...
# Setting up fonts-nanum (20180306-3) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fontconfig is already the newest version (2.13.1-2ubuntu3).
# fontconfig set to manually installed.
# ...

# %%
import MeCab
m = MeCab.Tagger()
output = m.parse("한글 형태소 분석기 설치 확인")
print(output)
# Out:
# 한글	NNG,*,T,한글,*,*,*,*
# 형태소	NNG,*,F,형태소,Compound,*,*,형태/NNG/*+소/NNG/*
# 분석기	NNG,*,F,분석기,Compound,*,*,분석/NNG/행위+기/NNG/*
# 설치	NNG,행위,F,설치,*,*,*,*
# 확인	NNG,행위,T,확인,*,*,*,*
# EOS

# %%
# Colab에 Mecab 설치
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 115 (delta 11), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (115/115), 1.27 MiB | 4.26 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
cd Mecab-ko-for-Google-Colab
# Out:
# /content/Mecab-ko-for-Google-Colab/Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab190912.sh
# Out:
# Installing konlpy.....
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2023-04-11 05:43:38--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::22c0:3470, 2406:da00:ff00::6b17:d1f5, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# 정상 동작 확인
from konlpy.tag import Okt, Mecab

okt = Okt()
mecab = Mecab()

# %%
from konlpy.tag import *

hannanum = Hannanum()
kkma = Kkma()
komoran = Komoran()
okt = Okt()
mecab = Mecab()


# nouns : 명사추출 
# morphs : 형태소 추출 
# pos : part of speech 품사

# %%
# 형태소 분석기 Okt

print('OKT 형태소 분석 :',okt.morphs("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('OKT 품사 태깅 :',okt.pos("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('OKT 명사 추출 :',okt.nouns("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
# Out:
# OKT 형태소 분석 : ['열심히', '코딩', '한', '당신', ',', '연휴', '에는', '여행', '을', '가봐요']
# OKT 품사 태깅 : [('열심히', 'Adverb'), ('코딩', 'Noun'), ('한', 'Josa'), ('당신', 'Noun'), (',', 'Punctuation'), ('연휴', 'Noun'), ('에는', 'Josa'), ('여행', 'Noun'), ('을', 'Josa'), ('가봐요', 'Verb')]
# OKT 명사 추출 : ['코딩', '당신', '연휴', '여행']

# %%
# 형태소 분석기 kkma
print('꼬꼬마 형태소 분석 :',kkma.morphs("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('꼬꼬마 품사 태깅 :',kkma.pos("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('꼬꼬마 명사 추출 :',kkma.nouns("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
# Out:
# 꼬꼬마 형태소 분석 : ['열심히', '코딩', '하', 'ㄴ', '당신', ',', '연휴', '에', '는', '여행', '을', '가보', '아요']
# 꼬꼬마 품사 태깅 : [('열심히', 'MAG'), ('코딩', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('당신', 'NP'), (',', 'SP'), ('연휴', 'NNG'), ('에', 'JKM'), ('는', 'JX'), ('여행', 'NNG'), ('을', 'JKO'), ('가보', 'VV'), ('아요', 'EFN')]
# 꼬꼬마 명사 추출 : ['코딩', '당신', '연휴', '여행']

# %%
# 형태소 분석기 komoran (ctrl+shift+l)
print('코모란 형태소 분석 :',komoran.morphs("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('코모란 품사 태깅 :',komoran.pos("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('코모란 명사 추출 :',komoran.nouns("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
# Out:
# 코모란 형태소 분석 : ['열심히', '코', '딩', '하', 'ㄴ', '당신', ',', '연휴', '에', '는', '여행', '을', '가', '아', '보', '아요']
# 코모란 품사 태깅 : [('열심히', 'MAG'), ('코', 'NNG'), ('딩', 'MAG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('당신', 'NNP'), (',', 'SP'), ('연휴', 'NNG'), ('에', 'JKB'), ('는', 'JX'), ('여행', 'NNG'), ('을', 'JKO'), ('가', 'VV'), ('아', 'EC'), ('보', 'VX'), ('아요', 'EC')]
# 코모란 명사 추출 : ['코', '당신', '연휴', '여행']

# %%
# 형태소 분석기 hannaum (ctrl+shift+l)
print('한나눔 형태소 분석 :',hannanum.morphs("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('한나눔 품사 태깅 :',hannanum.pos("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('한나눔 명사 추출 :',hannanum.nouns("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
# Out:
# 한나눔 형태소 분석 : ['열심히', '코딩', '하', 'ㄴ', '당신', ',', '연휴', '에는', '여행', '을', '가', '아', '보', '아']
# 한나눔 품사 태깅 : [('열심히', 'M'), ('코딩', 'N'), ('하', 'X'), ('ㄴ', 'E'), ('당신', 'N'), (',', 'S'), ('연휴', 'N'), ('에는', 'J'), ('여행', 'N'), ('을', 'J'), ('가', 'P'), ('아', 'E'), ('보', 'P'), ('아', 'E')]
# 한나눔 명사 추출 : ['코딩', '당신', '연휴', '여행']

# %%
# 형태소 분석기 mecab (ctrl+shift+l)
print('메캅 형태소 분석 :',mecab.morphs("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('메캅 품사 태깅 :',mecab.pos("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('메캅 명사 추출 :',mecab.nouns("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
# Out:
# 메캅 형태소 분석 : ['열심히', '코딩', '한', '당신', ',', '연휴', '에', '는', '여행', '을', '가', '봐요']
# 메캅 품사 태깅 : [('열심히', 'MAG'), ('코딩', 'NNG'), ('한', 'XSA+ETM'), ('당신', 'NP'), (',', 'SC'), ('연휴', 'NNG'), ('에', 'JKB'), ('는', 'JX'), ('여행', 'NNG'), ('을', 'JKO'), ('가', 'VV'), ('봐요', 'EC+VX+EC')]
# 메캅 명사 추출 : ['코딩', '당신', '연휴', '여행']

# %%
# 영어 sentence tokenization(nltk)

temp = "Gang_dong campus at sesac is a prominent academy in the AI-based technology's field in Korea. At the campus, the smart drwill who is an AI instructor is there."

# %%
print(temp.split())
# Out:
# ['Gang_dong', 'campus', 'at', 'sesac', 'is', 'a', 'prominent', 'academy', 'in', 'the', 'AI-based', "technology's", 'field', 'in', 'Korea.', 'At', 'the', 'campus,', 'the', 'smart', 'drwill', 'who', 'is', 'an', 'AI', 'instructor', 'is', 'there.']

# %%
from nltk.tokenize import sent_tokenize

print(sent_tokenize(temp))
# Out:
# ["Gang_dong campus at sesac is a prominent academy in the AI-based technology's field in Korea.", 'At the campus, the smart drwill who is an AI instructor is there.']

# %%
text = "I am actively looking for Dr.Will. Don't forget about the fact that you are Dr.Will's students"
print(sent_tokenize(text))
# Out:
# ['I am actively looking for Dr.Will.', "Don't forget about the fact that you are Dr.Will's students"]

# %%
# 한국어 sentence tokenization (kss 와 kiwi 가 있음)
# !pip install kss
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.7/77.7 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.3/131.3 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.4/26.4 MB 32.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for kss: filename=kss-4.5.1-py3-none-any.whl size=53220 sha256=ca07f1446c59006db0d6112ab5063a3adeaffdb8b957e979102929e1746676cc
#   Stored in directory: /root/.cache/pip/wheels/2f/23/d1/e9c8f5f2e8a61bb4cb8e4fdd0d0c951dab78882e3807c7f7ca
# ...
#   Created wheel for pecab: filename=pecab-1.0.8-py3-none-any.whl size=26646666 sha256=54158982109dd0bb2f4432e8020a5c9d82cbc2656449cbdab60105426efe1066
#   Stored in directory: /root/.cache/pip/wheels/5c/91/bf/14eed6eafd0a83f76eab5cf8eb50ddc0b037f059eec2bd2e4a
# Successfully built kss pecab
# ...

# %%
import kss 

text =  "닥터윌과 함께 하는 딥러닝 자연어처리 수업 너무 재미있기는 합니다. 그런데 영어보다 한국어 처리할 때 너무 어려워요."

# %%
print(kss.split_sentences(text))
# Out:
# WARNING:root:Oh! You have mecab in your environment. Kss will take this as a backend! :D
# ['닥터윌과 함께 하는 딥러닝 자연어처리 수업 너무 재미있기는 합니다.', '그런데 영어보다 한국어 처리할 때 너무 어려워요.']

# %% [markdown]
# 네이버 영화 리뷰 데이터 활용, 정수 인코딩과 패딩

# %%
import pickle 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import re 
import urllib.request 

from konlpy.tag import *

hannanum = Hannanum()
kkma = Kkma()
komoran = Komoran()
okt = Okt()
# mecab = Mecab()

from tqdm import tqdm 
from collections import Counter 
# 등장빈도수 count 하기 위함

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt", filename="ratings_train.txt")
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt", filename="ratings_test.txt")
# Out:
# ('ratings_test.txt', <http.client.HTTPMessage at 0x7ff0ddf7d5b0>)

# %%
pd.read_table('ratings_train.txt')[:10]
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# 5   5403919      막 걸음마 뗀 3세부터 초등학교 1학년생인 8살용영화.ㅋㅋㅋ...별반개도 아까움.      0
# 6   7797314                              원작의 긴장감을 제대로 살려내지못했다.      0
# 7   9443947  별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지..정말 발로해도 그것보단...      0
# 8   7156791                             액션이 없는데도 재미 있는 몇안되는 영화      1
# 9   5912145      왜케 평점이 낮은건데? 꽤 볼만한데.. 헐리우드식 화려함에만 너무 길들여져 있나?      1

# %%
train_data = pd.read_table('ratings_train.txt')
test_data = pd.read_table('ratings_test.txt')

# %%
print("훈련용 리뷰 개수:", len(train_data))
# Out:
# 훈련용 리뷰 개수: 150000

# %%
# document 열의 중복 제거 
train_data.drop_duplicates(subset=['document'], inplace=True)

# %%
print("중복제거한 훈련용 리뷰 개수:", len(train_data))
# 훈련할 총 샘플 수 >> 146183
# Out:
# 중복제거한 훈련용 리뷰 개수: 146183

# %%
train_data['label'].value_counts()
# Out:
# 0    73342
# 1    72841
# Name: label, dtype: int64

# %%
train_data['label'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
print(train_data.groupby('label').size())
# Out:
# label
# 0    73342
# 1    72841
# dtype: int64

# %%
print(train_data.groupby('label').size().reset_index(name='count'))
# Out:
#    label  count
# 0      0  73342
# 1      1  72841

# %%
train_data[:10]
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# 5   5403919      막 걸음마 뗀 3세부터 초등학교 1학년생인 8살용영화.ㅋㅋㅋ...별반개도 아까움.      0
# 6   7797314                              원작의 긴장감을 제대로 살려내지못했다.      0
# 7   9443947  별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지..정말 발로해도 그것보단...      0
# 8   7156791                             액션이 없는데도 재미 있는 몇안되는 영화      1
# 9   5912145      왜케 평점이 낮은건데? 꽤 볼만한데.. 헐리우드식 화려함에만 너무 길들여져 있나?      1

# %%
# 훈련용 데이터 중 null 값 추출 
train_data.loc[train_data.document.isnull()]
# Out:
#             id document  label
# 25857  2172111      NaN      1

# %%
train_data = train_data.dropna(how='any') 
# null 값이 존재하는 행 제거, how='any' 하나라도 있으면 제거

# %%
# 한글과 공백 제외하고 모두 제거 

train_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# Out:
# <ipython-input-21-ab9929cae33e>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# 0                                         아 더빙 진짜 짜증나네요 목소리
# 1                                흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나
# 2                                         너무재밓었다그래서보는것을추천한다
# 3                                 교도소 이야기구먼 솔직히 재미는 없다평점 조정
# 4         사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...
#                                 ...
# 149995                                      인간이 문제지 소는 뭔죄인가
# 149996                                           평점이 너무 낮아서
# 149997                        이게 뭐요 한국인은 거들먹거리고 필리핀 혼혈은 착하다
# 149998                           청춘 영화의 최고봉방황과 우울했던 날들의 자화상
# 149999                             한국 영화 최초로 수간하는 내용이 담긴 영화
# Name: document, Length: 146182, dtype: object

# %%
train_data['document'] = train_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
train_data['document'][:10]
# Out:
# <ipython-input-22-76d5fcfec62e>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['document'] = train_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# 0                                    아 더빙 진짜 짜증나네요 목소리
# 1                           흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나
# 2                                    너무재밓었다그래서보는것을추천한다
# 3                            교도소 이야기구먼 솔직히 재미는 없다평점 조정
# 4    사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...
# 5                막 걸음마 뗀 세부터 초등학교 학년생인 살용영화ㅋㅋㅋ별반개도 아까움
# 6                                 원작의 긴장감을 제대로 살려내지못했다
# 7    별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지정말 발로해도 그것보단 낫...
# 8                               액션이 없는데도 재미 있는 몇안되는 영화
# 9            왜케 평점이 낮은건데 꽤 볼만한데 헐리우드식 화려함에만 너무 길들여져 있나
# Name: document, dtype: object

# %%
train_data['document'] = train_data['document'].str.replace('^ +', "")
# white space >> empty value 로 변경
# Out:
# <ipython-input-23-03561649deb9>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['document'] = train_data['document'].str.replace('^ +', "")

# %%
train_data['document'].replace('', np.nan, inplace=True)
train_data['document'][:10]
# Out:
# 0                                    아 더빙 진짜 짜증나네요 목소리
# 1                           흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나
# 2                                    너무재밓었다그래서보는것을추천한다
# 3                            교도소 이야기구먼 솔직히 재미는 없다평점 조정
# 4    사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...
# 5                막 걸음마 뗀 세부터 초등학교 학년생인 살용영화ㅋㅋㅋ별반개도 아까움
# 6                                 원작의 긴장감을 제대로 살려내지못했다
# 7    별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지정말 발로해도 그것보단 낫...
# 8                               액션이 없는데도 재미 있는 몇안되는 영화
# 9            왜케 평점이 낮은건데 꽤 볼만한데 헐리우드식 화려함에만 너무 길들여져 있나
# Name: document, dtype: object

# %%
print(train_data.isnull().sum())
# Out:
# id            0
# document    789
# label         0
# dtype: int64

# %%
train_data.loc[train_data.document.isnull()][:5]
# Out:
#            id document  label
# 404   4221289      NaN      0
# 412   9509970      NaN      1
# 470  10147571      NaN      1
# 584   7117896      NaN      0
# 593   6478189      NaN      0

# %%
train_data = train_data.dropna(how='any')
print(len(train_data))
# Out:
# 145393

# %%
print(test_data[:10])
print()
print(len(test_data))
# Out:
#         id                                           document  label
# 0  6270596                                                굳 ㅋ      1
# 1  9274899                               GDNTOPCLASSINTHECLUB      0
# 2  8544678             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3  6825595                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4  6723715  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0
# 5  7898805                                 음악이 주가 된, 최고의 음악영화      1
# 6  6315043                                            진정한 쓰레기      0
# 7  6097171           마치 미국애니에서 튀어나온듯한 창의력없는 로봇디자인부터가,고개를 젖게한다      0
# 8  8932678  갈수록 개판되가는 중국영화 유치하고 내용없음 폼잡다 끝남 말도안되는 무기에 유치한c...      0
# 9  6242223     이별의 아픔뒤에 찾아오는 새로운 인연의 기쁨 But, 모든 사람이 그렇지는 않네..      1
#
# 50000

# %%
test_data.drop_duplicates(subset=['document'], inplace=True)
# document 열에서 중복된 내용이 있다면, 중복을 제거해줘 
test_data['document'] = test_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# 정규표현식 수행 
test_data['document'] = test_data['document'].str.replace('^ +',"")
# 공백을 empty value 변경 
test_data['document'].replace('', np.nan, inplace=True) 
# 공백을 null 값으로 변경 
test_data = test_data.dropna(how='any')
# null 값 제거 

print('전처리 후 테스트용 샘플 개수:', len(test_data))
# Out:
# 전처리 후 테스트용 샘플 개수: 48852
# <ipython-input-29-3ddd57990f52>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   test_data['document'] = test_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# <ipython-input-29-3ddd57990f52>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   test_data['document'] = test_data['document'].str.replace('^ +',"")

# %%
# 불용어_stopwords (형태소 분석기 돌리고 난 뒤에 정함)

stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
okt = Okt()

okt.morphs("와 이런 것도 영화라고 흥칫뿡")
# Out:
# ['와', '이런', '것', '도', '영화', '라고', '흥칫뿡']

# %%
mecab.morphs("와 이런 것도 영화라고 흥칫뿡")
# Out:
# ['와', '이런', '것', '도', '영화', '라고', '흥', '칫', '뿡']

# %%
x_train = []

for sentence in tqdm(train_data['document']):
  tokenized_sentence = okt.morphs(sentence) # 토큰화 
  stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
  x_train.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 145393/145393 [21:20<00:00, 113.55it/s]

# %%
x_train = []

for sentence in tqdm(train_data['document']):
  tokenized_sentence = mecab.morphs(sentence) # 토큰화 
  stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
  x_train.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 145393/145393 [00:25<00:00, 5632.35it/s]

# %%
x_test = []

for sentence in tqdm(test_data['document']):
  tokenized_sentence = okt.morphs(sentence) # 토큰화 
  stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
  x_test.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 48852/48852 [06:11<00:00, 131.44it/s]

# %%
x_test = []

for sentence in tqdm(test_data['document']):
  tokenized_sentence = mecab.morphs(sentence) # 토큰화 
  stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
  x_test.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 48852/48852 [00:13<00:00, 3618.75it/s]

# %%
word_list = []

for sent in x_train: 
  for word in sent:
    word_list.append(word)

word_counts = Counter(word_list)   
print('총 단어수:', len(word_counts))
# Out:
# 총 단어수: 49946

# %%
print(word_counts)
# key: value >> dict 형식으로 출력 {'닥터윌' : 10000, ...}
# Out:
# Counter({'영화': 57325, '다': 54467, '고': 47157, '하': 44548, '을': 29834, '보': 25456, '게': 22100, '지': 18900, '있': 16672, '없': 15783, '좋': 13651, '나': 12530, '었': 12160, '만': 11616, '는데': 11436, '너무': 10985, '봤': 10213, '적': 10087, '안': 10060, '정말': 9747, '로': 9635, '것': 9257, '음': 9223, '아': 8947, '네요': 8930, '어': 8724, '재밌': 8724, '지만': 8649, '같': 8574, '진짜': 8301, '에서': 8062, '했': 8047, '기': 7970, '네': 7830, '않': 7726, '점': 7702, '거': 7659, '았': 7611, '수': 7501, '되': 7462, '면': 7320, 'ㅋㅋ': 7172, '인': 7011, '말': 6863, '연기': 6825, '주': 6421, '최고': 6300, '내': 6246, '평점': 6228, '이런': 5989, '던': 5925, '어요': 5662, '할': 5540, '왜': 5504, '겠': 5465, '스토리': 5412, '해': 5347, 'ㅋㅋㅋ': 5340, '습니다': 5328, '듯': 5242, '아니': 5184, '드라마': 5165, '생각': 5165, '더': 5128, '그': 5103, '싶': 5041, '사람': 5036, '때': 4826, '감동': 4821, '배우': 4621, '함': 4610, '본': 4569, '까지': 4496, '뭐': 4292, '알': 4264, '만들': 4251, '내용': 4242, '볼': 4236, '보다': 4202, '감독': 4183, '라': 4166, '재미': 4070, '그냥': 4066, '시간': 3975, '지루': 3918
# ...

# %%
print('훈련 데이터에서 단어 영화의 등장 횟수:', word_counts['영화'])
print('훈련 데이터에서 단어 송강호의 등장 횟수:', word_counts['송강호'])
print('훈련 데이터에서 단어 열외의 등장 횟수:', word_counts['열외'])
# Out:
# 훈련 데이터에서 단어 영화의 등장 횟수: 57325
# 훈련 데이터에서 단어 송강호의 등장 횟수: 74
# 훈련 데이터에서 단어 열외의 등장 횟수: 1

# %%
vocab = sorted(word_counts, key=word_counts.get, reverse=True)
print('등장 빈도수 상위 10개 단어')
print(vocab[:10])
# Out:
# 등장 빈도수 상위 10개 단어
# ['영화', '다', '고', '하', '을', '보', '게', '지', '있', '없']

# %%
threshold = 3 # 임계치(기준)

total_cnt = len(word_counts) # 단어 수 
rare_cnt = 0 
# 등장 빈도수가 threshold 보다 작은 단어의 개수를 카운트 하기 위해 초기화 
total_freq = 0 
# 훈련 데이터의 전체 단어 빈도수의 총 합 구하기 위해 초기화 
rare_freq = 0 
# 등장 빈도수가 threshold 보다 작은 단어의 등장 빈도수의 총 합 초기화 

# 단어(key)와 빈도수(value) 의 쌍(pair)을 key와 value 로 받는다 

for key, value in word_counts.items(): 
   total_freq = total_freq + value

   # 단어의 등장 빈도수가 threshold 보다 작으면 
   if (value < threshold):
      rare_cnt = rare_cnt + 1 
      rare_freq = rare_freq + value

print('단어 집합(vocabulary) 크기:', total_cnt)
print('등장 빈도가 %s번 이하인 희소 단어의 수:%s'%(threshold -1, rare_cnt))
print('단어 집합에서 희소 단어의 비율:', (rare_cnt / total_cnt)*100)
print('전체 등장 빈도에서 희소 단어 등장 빈도 비율:',(rare_freq / total_freq)*100)

'''
threshold = 3 # 임계치(기준) 
>> 등장 빈도가 threshold 값이 3회 미만, 즉 2회 이하인 단어들이 단어 집합에서 
   몇 % 차지하는 지를 보고 정수 인코딩 과정에서 포함할지 , 배제할 지 정하고자 함 
   okt 로 하면 희소 단어가 67.7% 
>> 등장 빈도가 threshold 미만인 단어들을 제외한 단어를 가지고 정수 인코딩 함
  okt 분석 결과, 등장 빈도수가 2 이하인 단어를 제외하고 단어 집합을 만들겠다.
'''
# Out:
# 단어 집합(vocabulary) 크기: 49946
# 등장 빈도가 2번 이하인 희소 단어의 수:28320
# 단어 집합에서 희소 단어의 비율: 56.70123733632323
# 전체 등장 빈도에서 희소 단어 등장 빈도 비율: 1.7606779759006361
# '\nthreshold = 3 # 임계치(기준) \n>> 등장 빈도가 threshold 값이 3회 미만, 즉 2회 이하인 단어들이 단어 집합에서 \n   몇 % 차지하는 지를 보고 정수 인코딩 과정에서 포함할지 , 배제할 지 정하고자 함 \n   okt 로 하면 희소 단어가 67.7% \n>> 등장 빈도가 threshold 미만인 단어들을 제외한 단어를 가지고 정수 인코딩 함\n  okt 분석 결과, 등장 빈도수가 2 이하인 단어를 제외하고 단어 집합을 만들겠다.\n'

# %%
# 전체 단어 개수 중에서 빈도수 2이하인 단어는 단어는 제거 (등장빈도수로 정렬된 상태임)

vocab_size = total_cnt - rare_cnt 
print(vocab[:vocab_size])
# Out:
# ['영화', '다', '고', '하', '을', '보', '게', '지', '있', '없', '좋', '나', '었', '만', '는데', '너무', '봤', '적', '안', '정말', '로', '것', '음', '아', '네요', '어', '재밌', '지만', '같', '진짜', '에서', '했', '기', '네', '않', '점', '거', '았', '수', '되', '면', 'ㅋㅋ', '인', '말', '연기', '주', '최고', '내', '평점', '이런', '던', '어요', '할', '왜', '겠', '스토리', '해', 'ㅋㅋㅋ', '습니다', '듯', '아니', '드라마', '생각', '더', '그', '싶', '사람', '때', '감동', '배우', '함', '본', '까지', '뭐', '알', '만들', '내용', '볼', '보다', '감독', '라', '재미', '그냥', '시간', '지루', '중', '재미있', '였', '잼', '년', '사랑', '못', '재미없', '냐', '쓰레기', '서', '라고', '니', '면서', '다시', '번', '나오', '하나', '작품', '야', '이거', '줄', '해서', '남', '마지막', '끝', '정도', '이건', '액션', '개', '임', '건', '기대', '다는', '입니다', '라는', '완전', '참', '많', 'ㅋ', '처음', '장면', '다가', '아깝', '으면', '모르', '지금', '이렇게', '분', '돈', '이게', 'ㅠㅠ', '성', '느낌', '이야기', '일', '최악', '된', '시', '봐도', '님', '어서', '애', '편', '다고', '넘', '인데', '이해', '전', '별로', '걸', '그리고', '명작', '난', '또', '역시', '여자', '한국', '이상', '는지', '많이', '에게', '부터', '주인공', '받', '합니다', '대', '두', '우리', '만든', '길', '엔', '살', '괜찮', 
# ...

# %%
vocab = vocab[:vocab_size]
print('단어의 집합 크기:', len(vocab))
# Out:
# 단어의 집합 크기: 21626

# %%
word_to_index = {}
word_to_index['<PAD>'] = 0
word_to_index['<UNK>'] = 1 # OOV : Out of Vocabulary

# %%
for index, word in enumerate(vocab): 
  word_to_index[word] = index + 2

# %%
print(word_to_index)
# Out:
# {'<PAD>': 0, '<UNK>': 1, '영화': 2, '다': 3, '고': 4, '하': 5, '을': 6, '보': 7, '게': 8, '지': 9, '있': 10, '없': 11, '좋': 12, '나': 13, '었': 14, '만': 15, '는데': 16, '너무': 17, '봤': 18, '적': 19, '안': 20, '정말': 21, '로': 22, '것': 23, '음': 24, '아': 25, '네요': 26, '어': 27, '재밌': 28, '지만': 29, '같': 30, '진짜': 31, '에서': 32, '했': 33, '기': 34, '네': 35, '않': 36, '점': 37, '거': 38, '았': 39, '수': 40, '되': 41, '면': 42, 'ㅋㅋ': 43, '인': 44, '말': 45, '연기': 46, '주': 47, '최고': 48, '내': 49, '평점': 50, '이런': 51, '던': 52, '어요': 53, '할': 54, '왜': 55, '겠': 56, '스토리': 57, '해': 58, 'ㅋㅋㅋ': 59, '습니다': 60, '듯': 61, '아니': 62, '드라마': 63, '생각': 64, '더': 65, '그': 66, '싶': 67, '사람': 68, '때': 69, '감동': 70, '배우': 71, '함': 72, '본': 73, '까지': 74, '뭐': 75, '알': 76, '만들': 77, '내용': 78, '볼': 79, '보다': 80, '감독': 81, '라': 82, '재미': 83, '그냥': 84, '시간': 85, '지루': 86, '중': 87, '재미있': 88, '였': 89, '잼': 90, '년': 91, '사랑': 92, '못': 93, '재미없': 94, '냐': 95, '쓰레기': 96, '서': 97, '라고': 98, '니': 99, '면서': 100, '다시': 101, '번': 102, '나오': 103, '하나': 104, 
# ...

# %%
len(word_to_index)
# Out:
# 21628

# %%
vocab_size = len(word_to_index)

# %%
word_to_index['영화']
# Out:
# 2

# %%
def texts_to_sequences(tokenized_x_data, word_to_index): 
  encoded_x_data = []
  for sent in tokenized_x_data: 
    index_sequences = []
    for word in sent: 
      try: 
        index_sequences.append(word_to_index[word])
      except KeyError:
        index_sequences.append(word_to_index['<UNK>'])
    encoded_x_data.append(index_sequences)
  return encoded_x_data

# %%
encoded_x_train = texts_to_sequences(x_train, word_to_index)
print(encoded_x_train[:10])
print(encoded_x_train[0])
# Out:
# [[25, 65, 893, 31, 212, 13, 26, 697], [975, 479, 489, 634, 2, 108, 1552, 46, 862, 947, 9, 36, 362], [17, 190, 1], [8033, 141, 4132, 275, 83, 11, 3, 50, 3324], [1, 8486, 1049, 46, 2700, 52, 2, 2623, 32, 1116, 27, 324, 34, 15, 33, 52, 15309, 1, 391, 2848, 1675, 3], [625, 1, 17794, 423, 169, 1462, 659, 1590, 663, 44, 1, 2, 59, 2165, 116, 716], [235, 349, 6, 352, 1907, 49, 9, 778, 3], [230, 1342, 130, 3, 390, 703, 10357, 15310, 46, 1432, 267, 91, 231, 21, 880, 22, 319, 606, 499, 473, 544, 3, 3163, 8487, 15, 1384, 1384, 63, 280, 11, 3, 46, 93, 5, 68, 15, 1, 35], [115, 11, 16, 83, 10, 267, 20, 41, 2], [55, 610, 50, 223, 704, 529, 79, 15, 476, 1401, 594, 686, 72, 15, 17, 15311, 10, 13]]
# [25, 65, 893, 31, 212, 13, 26, 697]

# %%
encoded_x_test = texts_to_sequences(x_test, word_to_index)
print(encoded_x_test[:10])
print(encoded_x_test[0])
# Out:
# [[786, 126], [75, 106, 50, 896, 312, 36, 29, 37, 595, 3399, 62, 853], [86, 5, 9, 36, 215, 123, 326, 117, 136, 47, 4, 7, 34], [15, 62, 14, 428, 230, 2009, 116, 516, 6, 543, 55, 22, 590, 323, 19690, 790, 5, 8, 5, 274], [221, 47, 144, 48, 221, 2], [575, 96], [1043, 419, 568, 32, 13043, 61, 4703, 1589, 11, 1466, 4085, 169, 5619, 2800, 8, 184], [519, 1226, 41, 632, 2, 219, 5, 4, 78, 11, 24, 2847, 458, 3, 112, 110, 45, 20, 41, 2817, 219, 1, 25, 1330, 3, 16569, 30, 2, 114, 464, 1496, 296, 3], [2797, 1368, 580, 10808, 774, 3015, 3843, 252, 68, 306, 9, 36, 35], [180, 26, 375, 7646, 90, 1]]
# [786, 126]

# %%
index_to_word = {}
for key, value in word_to_index.items(): 
  index_to_word[value] =  key

# %%
decoded_sample = [index_to_word[word] for word in encoded_x_train[0]]
print('기존의 첫번째 샘플:', x_train[0])
print('복원 전 정수 인코딩된 첫번째 샘플', encoded_x_train[0])
print('복원된 첫번째 샘플:', decoded_sample)
# Out:
# 기존의 첫번째 샘플: ['아', '더', '빙', '진짜', '짜증', '나', '네요', '목소리']
# 복원 전 정수 인코딩된 첫번째 샘플 [25, 65, 893, 31, 212, 13, 26, 697]
# 복원된 첫번째 샘플: ['아', '더', '빙', '진짜', '짜증', '나', '네요', '목소리']

# %%
print([review for review in encoded_x_train][:5])
# Out:
# [[25, 65, 893, 31, 212, 13, 26, 697], [975, 479, 489, 634, 2, 108, 1552, 46, 862, 947, 9, 36, 362], [17, 190, 1], [8033, 141, 4132, 275, 83, 11, 3, 50, 3324], [1, 8486, 1049, 46, 2700, 52, 2, 2623, 32, 1116, 27, 324, 34, 15, 33, 52, 15309, 1, 391, 2848, 1675, 3]]

# %%
print('각 리뷰의 길이:', [len(review) for review in encoded_x_train])
print('리뷰의 최대 길이:', max([len(review) for review in encoded_x_train]))
print('리뷰의 평균 길이:',sum(map(len, encoded_x_train)) / len(encoded_x_train))

plt.hist([len(review) for review in encoded_x_train], bins=50)
plt.xlabel('length of samples') # 리뷰의 단어 길이
plt.ylabel('number of samples') # 리뷰의 단어 수
plt.show()
# Out:
# 각 리뷰의 길이: [8, 13, 3, 9, 22, 16, 9, 38, 9, 18, 1, 18, 15, 22, 22, 10, 27, 16, 17, 9, 12, 10, 48, 9, 8, 22, 5, 2, 3, 10, 22, 11, 7, 9, 4, 5, 15, 10, 8, 10, 6, 28, 7, 15, 34, 9, 48, 25, 5, 53, 20, 14, 12, 18, 2, 3, 1, 36, 2, 4, 8, 9, 10, 38, 17, 50, 27, 17, 12, 12, 9, 54, 1, 9, 4, 16, 9, 2, 20, 3, 16, 7, 22, 5, 4, 5, 3, 3, 5, 10, 7, 9, 2, 3, 6, 10, 3, 6, 8, 14, 14, 9, 12, 9, 7, 19, 2, 5, 10, 15, 11, 15, 7, 1, 21, 3, 6, 5, 12, 7, 33, 18, 10, 2, 2, 9, 5, 17, 50, 14, 2, 7, 5, 18, 7, 8, 12, 6, 12, 16, 2, 12, 49, 3, 6, 6, 42, 24, 14, 58, 9, 1, 12, 4, 3, 4, 30, 16, 7, 1, 6, 13, 6, 46, 46, 19, 3, 19, 11, 1, 36, 46, 12, 8, 4, 20, 3, 4, 14, 8, 43, 6, 44, 6, 18, 1, 9, 6, 36, 8, 4, 18, 17, 24, 23, 17, 5, 18, 15, 29, 8, 10, 6, 66, 14, 8, 11, 5, 14, 6, 4, 9, 8, 17, 4, 15, 14, 12, 13, 9, 35, 9, 22, 9, 4, 16, 3, 10, 31, 10, 30, 10, 59, 51, 6, 7, 10, 16, 12, 6, 10, 12, 10, 11, 19, 10, 11, 6, 9, 12, 19, 4, 6, 2, 18, 10, 10, 4, 14, 7, 28, 6, 16, 15, 9, 4, 34, 9, 7, 10, 2, 9, 4, 9, 6, 18, 19, 2, 1, 10, 39
# ...
