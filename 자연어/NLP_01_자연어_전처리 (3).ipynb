# %%
#word tokenization

import nltk

# %%
from nltk.tokenize import word_tokenize
from nltk.tokenize import WordPunctTokenizer
from tensorflow.keras.preprocessing.text import text_to_word_sequence

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
sentence="Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop."

# %%
# ' 어퍼스트로피가 들어간 상황에서 Don't하고 Jone's 토큰화 하는 방법
# > word

# %%
print('단어 토큰화1 :',word_tokenize("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop."))
# Out:
# 단어 토큰화1 : ['Do', "n't", 'be', 'fooled', 'by', 'the', 'dark', 'sounding', 'name', ',', 'Mr.', 'Jone', "'s", 'Orphanage', 'is', 'as', 'cheery', 'as', 'cheery', 'goes', 'for', 'a', 'pastry', 'shop', '.']

# %%
#WordPunctTokenizer : nltk 의 tokenizer 또 다른 방법
from nltk.tokenize import WordPunctTokenizer
print(WordPunctTokenizer().tokenize(sentence))
# Out:
# ['Don', "'", 't', 'be', 'fooled', 'by', 'the', 'dark', 'sounding', 'name', ',', 'Mr', '.', 'Jone', "'", 's', 'Orphanage', 'is', 'as', 'cheery', 'as', 'cheery', 'goes', 'for', 'a', 'pastry', 'shop', '.']

# %%
print('단어 토큰화2 :',WordPunctTokenizer().tokenize("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop."))
# Out:
# 단어 토큰화2 : ['Don', "'", 't', 'be', 'fooled', 'by', 'the', 'dark', 'sounding', 'name', ',', 'Mr', '.', 'Jone', "'", 's', 'Orphanage', 'is', 'as', 'cheery', 'as', 'cheery', 'goes', 'for', 'a', 'pastry', 'shop', '.']

# %%
# TreebankNLTK  또 다른 tokenizer 방법

from nltk.tokenize import TreebankWordDetokenizer
tokenizer = TreebankWordDetokenizer()
text = "Starting a home-based restaurant may be an ideal. it doesn't have a food chain or restaurant of their own."
print('트리뱅크 워드토크나이저 :',tokenizer.tokenize(text))

## 에엥에에에??? 이거 뭐야 왜 이렇게 나옴?? 아래로 보셈용 이따가 살펴보기!
# Out:
# 트리뱅크 워드토크나이저 : S t a r t i n g   a   h o m e - b a s e d   r e s t a u r a n t   m a y   b e   a n   i d e a l .   i t   d o e s n' t   h a v e   a   f o o d   c h a i n   o r   r e s t a u r a n t   o f   t h e i r   o w n.

# %%
from nltk.tokenize import TreebankWordTokenizer

tokenizer = TreebankWordTokenizer()

text = "Starting a home-based restaurant may be an ideal. it doesn't have a food chain or restaurant of their own."
print('트리뱅크 워드토크나이저 :',tokenizer.tokenize(text))
# Out:
# 트리뱅크 워드토크나이저 : ['Starting', 'a', 'home-based', 'restaurant', 'may', 'be', 'an', 'ideal.', 'it', 'does', "n't", 'have', 'a', 'food', 'chain', 'or', 'restaurant', 'of', 'their', 'own', '.']

# %% [markdown]
# 네 가지 방법으로 해보깅~

# %%
en_text = 'A Dog Run back corner near spare bedrooms!!!'

tokenizer=TreebankWordDetokenizer()
print('트리뱅크 워드토크나이저 :', tokenizer.tokenize(en_text))
# Out:
# 트리뱅크 워드토크나이저 : A   D o g   R u n   b a c k   c o r n e r   n e a r   s p a r e   b e d r o o m s!!!

# %%
tokenizer = TreebankWordTokenizer()
print('트리뱅크 워드토크나이저 :',tokenizer.tokenize(en_text))
# Out:
# 트리뱅크 워드토크나이저 : ['A', 'Dog', 'Run', 'back', 'corner', 'near', 'spare', 'bedrooms', '!', '!', '!']

# %%
print(WordPunctTokenizer().tokenize(en_text))
# Out:
# ['A', 'Dog', 'Run', 'back', 'corner', 'near', 'spare', 'bedrooms', '!!!']

# %%
print('단어 토큰화2 :',WordPunctTokenizer().tokenize(en_text))
# Out:
# 단어 토큰화2 : ['A', 'Dog', 'Run', 'back', 'corner', 'near', 'spare', 'bedrooms', '!!!']

# %%
en_text.split() #이건 리스트 형식
# Out:
# ['A', 'Dog', 'Run', 'back', 'corner', 'near', 'spare', 'bedrooms!!!']

# %%
enn_text = 'A Dog Run back corner near spare bedrooms.......... bedrooms!!!'

# %%
#특수문자 
print(word_tokenize(enn_text))
print(enn_text.split())
# Out:
# ['A', 'Dog', 'Run', 'back', 'corner', 'near', 'spare', 'bedrooms', '..........', 'bedrooms', '!', '!', '!']
# ['A', 'Dog', 'Run', 'back', 'corner', 'near', 'spare', 'bedrooms..........', 'bedrooms!!!']

# %%
#  한국어 WORD TOKENIZATION (KoNLPy)

kor_text = '강영현 전역 축하해! 이제 멋진 예빈이와 만날 날만 남았구나! 사랑한다 강영현 결혼하자 강영현'
print(kor_text.split())
# Out:
# ['강영현', '전역', '축하해!', '이제', '멋진', '예빈이와', '만날', '날만', '남았구나!', '사랑한다', '강영현', '결혼하자', '강영현']

# %%
#엥 조사가 붙어나와! 한국어는 교착어라 조사가 붙어 나왕! > 형태소 분석 해여겄웅

# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 18.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 15.3 MB/s eta 0:00:00
# ...

# %%
# 실행순서 1
# mecab
# !pip install konlpy

from konlpy.tag import Mecab
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab/
# !bash install_mecab-ko_on_colab190912.sh
# 실행 후 런타임 재실행 필요해요
# 런타임 재 실행 후에는 해당 셀은 실행하지 말아주세요

# %%
# 실행순서 2
from konlpy.tag import Kkma, Komoran, Okt, Mecab

tagger = Mecab()
okt = Okt()
kkm = Kkma()
kom = Komoran()

# %%
# 실행순서 3
# mecab test
# 형태소 
print("tagger.morphs: ", tagger.morphs('안녕하세요. 저는 딥러닝 입니다.'))

#명사
print("tagger.nouns: ", tagger.nouns('안녕하세요. 저는 딥러닝 입니다.'))

#형태소 + 품사
print("tagger.pos: ", tagger.pos('안녕하세요. 저는 딥러닝 입니다.'))

# %%
#코랩에 mecab 설치
#!git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
#%cd Mecab-ko-for-Google-Colab
#!bash install_mecab-ko_on_colab190912.sh

# %%
from eunjeon import Mecab

# %%
from konlpy.tag import *

hannanum = Hannanum()
kkma = Kkma()
komoran = Komoran()
okt = Okt()
#tagger = Mecab()
mecab = Mecab()

#nouns : 명사추출
#morphs : 형태소 추출
#pos : part of speech 품사
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/konlpy/tag/_mecab.py in __init__(self, dicpath)
#      76         try:
# ---> 77             self.tagger = Tagger('-d %s' % dicpath)
#      78             self.tagset = utils.read_json('%s/data/tagset/mecab.json' % utils.installpath)
#
# NameError: name 'Tagger' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-21-748f7471eb69> in <cell line: 8>()
#       6 okt = Okt()
#       7 #tagger = Mecab()
# ----> 8 mecab = Mecab()
#       9
#      10 #nouns : 명사추출
#
# /usr/local/lib/python3.9/dist-packages/konlpy/tag/_mecab.py in __init__(self, dicpath)
# ...

# %%
# !pip install konlpy
# !sudo apt-get install curl git
# !bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# curl is already the newest version (7.68.0-1ubuntu2.18).
# git is already the newest version (1:2.25.1-1ubuntu3.10).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# mecab-ko is already installed
# mecab-ko-dic is already installed
# Install mecab-python
# /tmp /content
# /content
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /tmp/mecab-python-0.996
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# ...

# %%
from konlpy.tag import Mecab
mecab = Mecab()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/konlpy/tag/_mecab.py in __init__(self, dicpath)
#      76         try:
# ---> 77             self.tagger = Tagger('-d %s' % dicpath)
#      78             self.tagset = utils.read_json('%s/data/tagset/mecab.json' % utils.installpath)
#
# NameError: name 'Tagger' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-93-013cfa0098c6> in <cell line: 2>()
#       1 from konlpy.tag import Mecab
# ----> 2 mecab = Mecab()
#
# /usr/local/lib/python3.9/dist-packages/konlpy/tag/_mecab.py in __init__(self, dicpath)
# ...

# %%
#형태소 분석기 okt

from konlpy.tag import Okt
from konlpy.tag import Kkma

okt = Okt()
kkma = Kkma()

print('OKT 형태소 분석 :',okt.morphs("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('OKT 품사 태깅 :',okt.pos("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('OKT 명사 추출 :',okt.nouns("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
# Out:
# OKT 형태소 분석 : ['열심히', '코딩', '한', '당신', ',', '연휴', '에는', '여행', '을', '가봐요']
# OKT 품사 태깅 : [('열심히', 'Adverb'), ('코딩', 'Noun'), ('한', 'Josa'), ('당신', 'Noun'), (',', 'Punctuation'), ('연휴', 'Noun'), ('에는', 'Josa'), ('여행', 'Noun'), ('을', 'Josa'), ('가봐요', 'Verb')]
# OKT 명사 추출 : ['코딩', '당신', '연휴', '여행']

# %%
#형태소 분석기 꼬꼬마
print('꼬꼬마 형태소 분석 :',kkma.morphs("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('꼬꼬마 품사 태깅 :',kkma.pos("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('꼬꼬마 명사 추출 :',kkma.nouns("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
# Out:
# 꼬꼬마 형태소 분석 : ['열심히', '코딩', '하', 'ㄴ', '당신', ',', '연휴', '에', '는', '여행', '을', '가보', '아요']
# 꼬꼬마 품사 태깅 : [('열심히', 'MAG'), ('코딩', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('당신', 'NP'), (',', 'SP'), ('연휴', 'NNG'), ('에', 'JKM'), ('는', 'JX'), ('여행', 'NNG'), ('을', 'JKO'), ('가보', 'VV'), ('아요', 'EFN')]
# 꼬꼬마 명사 추출 : ['코딩', '당신', '연휴', '여행']

# %%
#형태소 분석기 komoran (ctil+shift+L)
print('코모란 형태소 분석 :',komoran.morphs("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('코모란 품사 태깅 :',komoran.pos("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('코모란 명사 추출 :',komoran.nouns("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
# Out:
# 코모란 형태소 분석 : ['열심히', '코', '딩', '하', 'ㄴ', '당신', ',', '연휴', '에', '는', '여행', '을', '가', '아', '보', '아요']
# 코모란 품사 태깅 : [('열심히', 'MAG'), ('코', 'NNG'), ('딩', 'MAG'), ('하', 'XSV'), ('ㄴ', 'ETM'), ('당신', 'NNP'), (',', 'SP'), ('연휴', 'NNG'), ('에', 'JKB'), ('는', 'JX'), ('여행', 'NNG'), ('을', 'JKO'), ('가', 'VV'), ('아', 'EC'), ('보', 'VX'), ('아요', 'EC')]
# 코모란 명사 추출 : ['코', '당신', '연휴', '여행']

# %%
#형태소 분석기 hannanum (ctil+shift+L)
print('한나눔 형태소 분석 :',hannanum.morphs("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('한나눔 품사 태깅 :',hannanum.pos("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('한나눔 명사 추출 :',hannanum.nouns("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
# Out:
# 한나눔 형태소 분석 : ['열심히', '코딩', '하', 'ㄴ', '당신', ',', '연휴', '에는', '여행', '을', '가', '아', '보', '아']
# 한나눔 품사 태깅 : [('열심히', 'M'), ('코딩', 'N'), ('하', 'X'), ('ㄴ', 'E'), ('당신', 'N'), (',', 'S'), ('연휴', 'N'), ('에는', 'J'), ('여행', 'N'), ('을', 'J'), ('가', 'P'), ('아', 'E'), ('보', 'P'), ('아', 'E')]
# 한나눔 명사 추출 : ['코딩', '당신', '연휴', '여행']

# %%
mecab = Mecab()

#형태소 분석기 mecab (ctil+shift+L)
print('메캅 형태소 분석 :',mecab.morphs("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('메캅 품사 태깅 :',mecab.pos("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
print('메캅 명사 추출 :',mecab.nouns("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/konlpy/tag/_mecab.py in __init__(self, dicpath)
#      76         try:
# ---> 77             self.tagger = Tagger('-d %s' % dicpath)
#      78             self.tagset = utils.read_json('%s/data/tagset/mecab.json' % utils.installpath)
#
# NameError: name 'Tagger' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-26-6f5345cd33d2> in <cell line: 1>()
# ----> 1 mecab = Mecab()
#       2
#       3 #형태소 분석기 mecab (ctil+shift+L)
#       4 print('메캅 형태소 분석 :',mecab.morphs("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
#       5 print('메캅 품사 태깅 :',mecab.pos("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
#
# /usr/local/lib/python3.9/dist-packages/konlpy/tag/_mecab.py in __init__(self, dicpath)
# ...

# %%
#영어 sentence tokenization(nltk)

temp = 'yebin is so happy now. becease her husband is free!!!'
print(temp.split())
# Out:
# ['yebin', 'is', 'so', 'happy', 'now.', 'becease', 'her', 'husband', 'is', 'free!!!']

# %%
from nltk.tokenize import sent_tokenize
print(sent_tokenize(temp))
# Out:
# ['yebin is so happy now.', 'becease her husband is free!!', '!']

# %%
# !pip install kss
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.7/77.7 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.3/131.3 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.4/26.4 MB 41.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for kss: filename=kss-4.5.1-py3-none-any.whl size=53220 sha256=aed458174e9c896eff45de148b8c6088312a235014352fa734452eb4776d3e5e
#   Stored in directory: /root/.cache/pip/wheels/2f/23/d1/e9c8f5f2e8a61bb4cb8e4fdd0d0c951dab78882e3807c7f7ca
# ...
#   Created wheel for pecab: filename=pecab-1.0.8-py3-none-any.whl size=26646666 sha256=303b18144d660c0e4355b8f5ba5b2eb324a081a19d0da624b963ed00af55a74a
#   Stored in directory: /root/.cache/pip/wheels/5c/91/bf/14eed6eafd0a83f76eab5cf8eb50ddc0b037f059eec2bd2e4a
# Successfully built kss pecab
# ...

# %%
import kss 
text='영현아 제대 축하해 평생 사랑한다 내 가수'

# %%
print(kss.split_sentences(text))
# Out:
# WARNING:root:Oh! You have mecab in your environment. Kss will take this as a backend! :D
# ['영현아 제대 축하해 평생 사랑한다', '내 가수']

# %% [markdown]
# 네이버 영화 리뷰 데이터 활용 인코딩과 패딩

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import re
import urllib.request
from konlpy.tag import *

hannanum = Hannanum()
kkma = Kkma()
komoran = Komoran()
okt = Okt()
#tagger = Mecab()
#mecab = Mecab()

from tqdm import tqdm
from collections import Counter

# %%
import pandas as pd

# %%
# 네이버 영화 리뷰 데이터 
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt", filename="ratings_train.txt")
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt", filename="ratings_test.txt")
# Out:
# ('ratings_test.txt', <http.client.HTTPMessage at 0x7f97c5577a60>)

# %%
pd.read_table('ratings_test.txt')[:10]
# Out:
#         id                                           document  label
# 0  6270596                                                굳 ㅋ      1
# 1  9274899                               GDNTOPCLASSINTHECLUB      0
# 2  8544678             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3  6825595                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4  6723715  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0
# 5  7898805                                 음악이 주가 된, 최고의 음악영화      1
# 6  6315043                                            진정한 쓰레기      0
# 7  6097171           마치 미국애니에서 튀어나온듯한 창의력없는 로봇디자인부터가,고개를 젖게한다      0
# 8  8932678  갈수록 개판되가는 중국영화 유치하고 내용없음 폼잡다 끝남 말도안되는 무기에 유치한c...      0
# 9  6242223     이별의 아픔뒤에 찾아오는 새로운 인연의 기쁨 But, 모든 사람이 그렇지는 않네..      1

# %%
train_data=pd.read_table('ratings_train.txt')
test_data=pd.read_table('ratings_test.txt')

# %%
print('훈련용 리뷰 개수: ', len(train_data))
print('테스트용 리뷰 개수: ', len(test_data))
# Out:
# 훈련용 리뷰 개수:  150000
# 테스트용 리뷰 개수:  50000

# %%
#document 열의 중복 제거
train_data.drop_duplicates(subset=['document'], inplace=True)

# %%
print('중복제거 훈련용 리뷰 개수: ', len(train_data)) #훈련할 총 샘플 수 > 146183
# Out:
# 중복제거 훈련용 리뷰 개수:  146183

# %%
train_data['label'].value_counts()
# Out:
# 0    73342
# 1    72841
# Name: label, dtype: int64

# %%
train_data['label'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
print(train_data.groupby('label'))

# %%
#후련용 데이터 중 null값 교체
train_data.loc[train_data.document.isnull()]
# Out:
#             id document  label
# 25857  2172111      NaN      1

# %%
train_data.dropna(how='any')
# Out:
#               id                                           document  label
# 0        9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1        3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2       10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3        9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4        6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ...          ...                                                ...    ...
# 149995   6222902                                인간이 문제지.. 소는 뭔죄인가..      0
# 149996   8549745                                      평점이 너무 낮아서...      1
# 149997   9311800                    이게 뭐요? 한국인은 거들먹거리고 필리핀 혼혈은 착하다?      0
# 149998   2376369                        청춘 영화의 최고봉.방황과 우울했던 날들의 자화상      1
# 149999   9619869                           한국 영화 최초로 수간하는 내용이 담긴 영화      0
#
# [146182 rows x 3 columns]

# %%
#한글과 공백 제외하고 모두 제거 

train_data['document'].str.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣 ]','')
# Out:
# <ipython-input-65-332e484fc98c>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['document'].str.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣 ]','')
# 0                                         아 더빙 진짜 짜증나네요 목소리
# 1                                흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나
# 2                                         너무재밓었다그래서보는것을추천한다
# 3                                 교도소 이야기구먼 솔직히 재미는 없다평점 조정
# 4         사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...
#                                 ...
# 149995                                      인간이 문제지 소는 뭔죄인가
# 149996                                           평점이 너무 낮아서
# 149997                        이게 뭐요 한국인은 거들먹거리고 필리핀 혼혈은 착하다
# 149998                           청춘 영화의 최고봉방황과 우울했던 날들의 자화상
# 149999                             한국 영화 최초로 수간하는 내용이 담긴 영화
# Name: document, Length: 146183, dtype: object

# %%
train_data['document']=train_data['document'].str.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣 ]','')
# Out:
# <ipython-input-66-153f2ed4a347>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['document']=train_data['document'].str.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣 ]','')

# %%
train_data['document'][:10]
# Out:
# 0                                    아 더빙 진짜 짜증나네요 목소리
# 1                           흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나
# 2                                    너무재밓었다그래서보는것을추천한다
# 3                            교도소 이야기구먼 솔직히 재미는 없다평점 조정
# 4    사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...
# 5                막 걸음마 뗀 세부터 초등학교 학년생인 살용영화ㅋㅋㅋ별반개도 아까움
# 6                                 원작의 긴장감을 제대로 살려내지못했다
# 7    별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지정말 발로해도 그것보단 낫...
# 8                               액션이 없는데도 재미 있는 몇안되는 영화
# 9            왜케 평점이 낮은건데 꽤 볼만한데 헐리우드식 화려함에만 너무 길들여져 있나
# Name: document, dtype: object

# %%
train_data['document']=train_data['document'].str.replace('^ +','')
#white space > empty value로 변경
# Out:
# <ipython-input-71-12265c240801>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['document']=train_data['document'].str.replace('^ +','')

# %%
train_data['document'].replace('', np.nan, inplace=True)
train_data['document'][:10]
# Out:
# 0                                    아 더빙 진짜 짜증나네요 목소리
# 1                           흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나
# 2                                    너무재밓었다그래서보는것을추천한다
# 3                            교도소 이야기구먼 솔직히 재미는 없다평점 조정
# 4    사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...
# 5                막 걸음마 뗀 세부터 초등학교 학년생인 살용영화ㅋㅋㅋ별반개도 아까움
# 6                                 원작의 긴장감을 제대로 살려내지못했다
# 7    별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지정말 발로해도 그것보단 낫...
# 8                               액션이 없는데도 재미 있는 몇안되는 영화
# 9            왜케 평점이 낮은건데 꽤 볼만한데 헐리우드식 화려함에만 너무 길들여져 있나
# Name: document, dtype: object

# %%
print(train_data.isnull().sum())
# Out:
# id            0
# document    790
# label         0
# dtype: int64

# %%
train_data.loc[train_data.document.isnull()][:5]
# Out:
#            id document  label
# 404   4221289      NaN      0
# 412   9509970      NaN      1
# 470  10147571      NaN      1
# 584   7117896      NaN      0
# 593   6478189      NaN      0

# %%
train_data = train_data.dropna(how='any')
len(train_data)
# Out:
# 145393

# %%
print(train_data.isnull().sum())
# Out:
# id          0
# document    0
# label       0
# dtype: int64

# %%
#다큐먼트에 중복된 내용 있으면 제거
test_data.drop_duplicates(subset=['document'], inplace=True)
#정규표현식수행
test_data['document']= test_data['document'].str.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣 ]','')
#공간을 엠티밸류로 변경
test_data['document']=test_data['document'].str.replace('^ +','')
# Out:
# <ipython-input-82-dde54c95f961>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   test_data['document']= test_data['document'].str.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣 ]','')
# <ipython-input-82-dde54c95f961>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   test_data['document']=test_data['document'].str.replace('^ +','')

# %%
#공백을 null값으로 변경
test_data['document'].replace('', np.nan, inplace=True)
#널값 제거
test_data = test_data.dropna(how='any')

print('전처리 후 테스트용 샘플 개수: ', len(test_data))
# Out:
# 전처리 후 테스트용 샘플 개수:  48852

# %%
#불용어_stopwords (형태소 분석기 돌리고 난 뒤에 정함)

stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
okt=Okt()
okt.morphs('왕왕 짱 재밌어요!!!')
# Out:
# ['왕왕', '짱', '재밌어요', '!!!']

# %%
mecab=Mecab()
mecab.morphs('왕왕 짱 재밌어요!!!')

# %%
x_train=[]

for sentence in tqdm(train_data['document']):
    tokenized_sentence = okt.morphs(sentence) #토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] #불용어 제거
    x_train.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 143620/143620 [11:27<00:00, 208.87it/s]

# %%
x_test=[]

for sentence in tqdm(train_data['document']):
    tokenized_sentence = okt.morphs(sentence) #토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] #불용어 제거
    x_test.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 143620/143620 [11:57<00:00, 200.22it/s]

# %%
x_train=[]

for sentence in tqdm(train_data['document']):
    tokenized_sentence = mecab.morphs(sentence) #토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] #불용어 제거
    x_train.append(stopwords_removed_sentence)

# %%
x_test=[]

for sentence in tqdm(train_data['document']):
    tokenized_sentence = mecab.morphs(sentence) #토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] #불용어 제거
    x_test.append(stopwords_removed_sentence)

# %%
word_list=[]

for sent in x_train:
    for word in sent:
        word_list.append(word)

word_counts = Counter(word_list)
print('총 단어수: ', len(word_counts))
# Out:
# 총 단어수:  100004

# %%
print(word_counts)
# Out:
# Counter({'영화': 50163, '을': 23196, '너무': 11069, '다': 10076, '정말': 9661, '적': 8726, '만': 8653, '진짜': 8288, '로': 7830, '점': 7474, '에서': 6979, '연기': 6326, '것': 6276, '평점': 6245, '내': 5883, '최고': 5676, '그': 5667, '나': 5568, '안': 5492, '인': 5461, '이런': 5414, '스토리': 5329, '생각': 5312, '못': 5294, '왜': 5110, '드라마': 5024, '게': 4907, '이다': 4897, '사람': 4836, '감동': 4803, '보고': 4712, '하는': 4686, '하고': 4666, '고': 4513, '말': 4498, '더': 4353, '배우': 4283, '때': 4277, 'ㅋㅋ': 4272, '아': 4120, '감독': 4113, '거': 4077, '그냥': 4048, '본': 4026, '요': 4010, '재미': 3854, '시간': 3852, '내용': 3811, '까지': 3785, '뭐': 3729, '중': 3724, '보다': 3543, '없는': 3482, '수': 3430, '네': 3411, '쓰레기': 3391, '지': 3326, '봤는데': 3029, '작품': 2975, '사랑': 2939, '할': 2923, '하나': 2810, '다시': 2806, '없다': 2784, '볼': 2773, '마지막': 2756, '좋은': 2615, '정도': 2585, '저': 2574, '이건': 2565, '같은': 2551, '완전': 2507, '있는': 2497, 'ㅋ': 2493, '입니다': 2487, 'ㅠㅠ': 2473, '처음': 2451, 'ㅋㅋㅋ': 2447, '장면': 2425, '액션': 2394, '주인공': 2375, '이렇게': 2325, '걸': 2321, '보는': 2291, '
# ...

# %%
print('훈련 데이터에서 단어 영화의 등장 횟수 : ', word_counts['영화'])
print('훈련 데이터에서 단어 송강호의 등장 횟수 : ', word_counts['송강호'])
print('훈련 데이터에서 단어 열외의 등장 횟수 : ', word_counts['열외'])
# Out:
# 훈련 데이터에서 단어 영화의 등장 횟수 :  50163
# 훈련 데이터에서 단어 송강호의 등장 횟수 :  74
# 훈련 데이터에서 단어 열외의 등장 횟수 :  0

# %%
vocab = sorted(word_counts, key=word_counts.get, reverse=True)
print('등장 빈도수 상위 10개 단어')
print(vocab[:10])
# Out:
# 등장 빈도수 상위 10개 단어
# ['영화', '을', '너무', '다', '정말', '적', '만', '진짜', '로', '점']

# %%
threshold=3 #임계치 (기준) 등장 빈도가 3회 미만 즉 2회 이하 단어들은 전체의 몇 %인지
total_cnt=len(word_counts) #단어 수
rare_cnt=0 #등장 빈도수가 뜨레스홀드보다 작은 다언의 개수를 카운트하기 위해 초기화
total_freq=0 #훈련 데이터의 전체 단어 빈도수의 총 합 구하기 위해 초기화
rare_freq=0 #등장 빈도수의 뜨레스홀드 보다 작은 단어의 등장 빈도수의 총 합 포기화

#단어(키)와 빈도수(밸류)의 쌍(pair) 을 key와 value로 받는다
for key, value in word_counts.items():
    total_freq = total_freq + value

    #단어의 등장 빈도수가 threshold보다 작으면
    if (value<threshold):
        rare_cnt = rare_cnt +1
        rare_freq = rare_freq + value

print('단어 집합 크기: ', total_cnt)
print('등장 빈도가 %s번 이하인 희소 단어의 수:%s' %(threshold-1, rare_cnt))
print('단어 집합에서 희소 단어의 비율: ', (rare_cnt/total_cnt)*100)
print('전체 등장 빈도에서 희소 단어 등장 빈도 비율: ', (rare_freq/total_freq)*100)


'''
#임계치 (기준) 등장 빈도가 3회 미만 즉 2회 이하 단어들은 전체의 몇 % 차지는지 보고
정수 인코딩 과정에서 포함할지 배제할ㅈ ㅣ정하고자 함
okt로 하면 희소 단어가 67.7
> 등장빈도가 미만인 단어들을 제외한 단어를 가지고 정수 인코딩함
'''
# Out:
# 단어 집합 크기:  100004
# 등장 빈도가 2번 이하인 희소 단어의 수:67698
# 단어 집합에서 희소 단어의 비율:  67.69529218831248
# 전체 등장 빈도에서 희소 단어 등장 빈도 비율:  4.960087053761962
# '\n#임계치 (기준) 등장 빈도가 3회 미만 즉 2회 이하 단어들은 전체의 몇 % 차지는지 보고\n정수 인코딩 과정에서 포함할지 배제할ㅈ ㅣ정하고자 함\nokt로 하면 희소 단어가 67.7\n> 등장빈도가 미만인 단어들을 제외한 단어를 가지고 정수 인코딩함\n'

# %%
#전체 단어 개수 중에서 빈도수 2이하인 단어는 제거 등장빈도수로 정렬된상태

vocab_size = total_cnt-rare_cnt
print(vocab[:vocab_size])
# Out:
# ['영화', '을', '너무', '다', '정말', '적', '만', '진짜', '로', '점', '에서', '연기', '것', '평점', '내', '최고', '그', '나', '안', '인', '이런', '스토리', '생각', '못', '왜', '드라마', '게', '이다', '사람', '감동', '보고', '하는', '하고', '고', '말', '더', '배우', '때', 'ㅋㅋ', '아', '감독', '거', '그냥', '본', '요', '재미', '시간', '내용', '까지', '뭐', '중', '보다', '없는', '수', '네', '쓰레기', '지', '봤는데', '작품', '사랑', '할', '하나', '다시', '없다', '볼', '마지막', '좋은', '정도', '저', '이건', '같은', '완전', '있는', 'ㅋ', '입니다', 'ㅠㅠ', '처음', 'ㅋㅋㅋ', '장면', '액션', '주인공', '이렇게', '걸', '보는', '개', '하', '돈', '이야기', '지금', '최악', '봐도', '느낌', '참', '연출', '임', '라', '인데', 'ㅡㅡ', '없고', '듯', '끝', '명작', '그리고', '년', '역시', '기', '별로', '많이', '별', '서', '이해', '재밌게', '면', '난', '대', '이영화', '분', '보면', '라고', '또', '이나', '때문', '성', '여자', '부터', '일', '해서', '된', '꼭', '보기', '엔', '이고', '두', '무슨', '여', '에게', '기억', '결말', '편', '같다', 'ㅎㅎ', '랑', '야', '마음', '소재', '영', '짱', '아깝다', '인생', '넘', '애', '님', '전', '없이', '수준', '현실', '한번', '속', '해', '씨', '가장', '급', '반전', '매력', '전개', '한다', '제', '함', '라는', '한국', '남자', '가슴', '뿐', '되는', '아이', '음악', 
# ...

# %%
vocab=vocab[:vocab_size]
print('단어의 집합 크기 : ', len(vocab))
# Out:
# 단어의 집합 크기 :  32306

# %%
word_to_index={}
word_to_index['<PAD>']=0
word_to_index['<UNK>']=1 #OOV : OUT OF VOCAB

# %%
for index, word in enumerate(vocab):
    word_to_index[word]=index+2

# %%
print(word_to_index)
# Out:
# {'<PAD>': 0, '<UNK>': 1, '영화': 2, '을': 3, '너무': 4, '다': 5, '정말': 6, '적': 7, '만': 8, '진짜': 9, '로': 10, '점': 11, '에서': 12, '연기': 13, '것': 14, '평점': 15, '내': 16, '최고': 17, '그': 18, '나': 19, '안': 20, '인': 21, '이런': 22, '스토리': 23, '생각': 24, '못': 25, '왜': 26, '드라마': 27, '게': 28, '이다': 29, '사람': 30, '감동': 31, '보고': 32, '하는': 33, '하고': 34, '고': 35, '말': 36, '더': 37, '배우': 38, '때': 39, 'ㅋㅋ': 40, '아': 41, '감독': 42, '거': 43, '그냥': 44, '본': 45, '요': 46, '재미': 47, '시간': 48, '내용': 49, '까지': 50, '뭐': 51, '중': 52, '보다': 53, '없는': 54, '수': 55, '네': 56, '쓰레기': 57, '지': 58, '봤는데': 59, '작품': 60, '사랑': 61, '할': 62, '하나': 63, '다시': 64, '없다': 65, '볼': 66, '마지막': 67, '좋은': 68, '정도': 69, '저': 70, '이건': 71, '같은': 72, '완전': 73, '있는': 74, 'ㅋ': 75, '입니다': 76, 'ㅠㅠ': 77, '처음': 78, 'ㅋㅋㅋ': 79, '장면': 80, '액션': 81, '주인공': 82, '이렇게': 83, '걸': 84, '보는': 85, '개': 86, '하': 87, '돈': 88, '이야기': 89, '지금': 90, '최악': 91, '봐도': 92, '느낌': 93, '참': 94, '연출': 95, '임': 96, '라': 97, '인데': 98, 'ㅡㅡ': 99, '없고': 100, '듯': 101, '끝': 102,
# ...

# %%
len(word_to_index)
# Out:
# 32308

# %%
vocab_size=len(word_to_index)

# %%
word_to_index['영화']
# Out:
# 2

# %%
from IPython.utils.py3compat import encode
def texts_to_sequences(tokenized_x_data, word_to_index):
    encoded_x_data=[]
    for sent in tokenized_x_data:
        index_sequences=[]
        for word in sent:
            try:
                index_sequences.append(word_to_index[word])
            except KeyError:
                index_sequences.append(word_to_index['<UNK>'])
        encoded_x_data.append(index_sequences)
    return encoded_x_data

# %%
encoded_x_train = texts_to_sequences(x_train, word_to_index)
encoded_x_test = texts_to_sequences(x_test, word_to_index)
print(encoded_x_train[:10])
print(encoded_x_train[0])
# Out:
# [[41, 418, 9, 6597, 625], [922, 419, 32, 567, 2, 183, 1519, 13, 940, 6028, 25782], [356, 2811, 1, 2643, 7320, 12022, 190, 5], [8576, 89, 11206, 206, 47, 65, 15, 4336], [1006, 1, 18, 1, 13, 6407, 2, 2967, 12, 5279, 1, 441, 21839, 1, 1065, 3669, 4521], [686, 7321, 963, 25783, 394, 126, 1831, 1744, 16959, 1, 2, 79, 110, 1087, 564, 209], [182, 283, 3, 295, 1, 214], [110, 1087, 149, 303, 719, 13959, 21840, 263, 107, 1687, 339, 105, 194, 6, 773, 10, 343, 538, 472, 1, 3670, 11207, 8, 1451, 1451, 27, 244, 65, 13, 25, 33, 30, 8, 665, 1059, 56], [81, 19092, 47, 74, 339, 372, 2], [1618, 15, 1, 496, 66, 8, 361, 1508, 329, 1, 4, 25784, 1083]]
# [41, 418, 9, 6597, 625]

# %%
print(encoded_x_test[:10])
print(encoded_x_test[0])
# Out:
# [[41, 418, 9, 6597, 625], [922, 419, 32, 567, 2, 183, 1519, 13, 940, 6028, 25782], [356, 2811, 1, 2643, 7320, 12022, 190, 5], [8576, 89, 11206, 206, 47, 65, 15, 4336], [1006, 1, 18, 1, 13, 6407, 2, 2967, 12, 5279, 1, 441, 21839, 1, 1065, 3669, 4521], [686, 7321, 963, 25783, 394, 126, 1831, 1744, 16959, 1, 2, 79, 110, 1087, 564, 209], [182, 283, 3, 295, 1, 214], [110, 1087, 149, 303, 719, 13959, 21840, 263, 107, 1687, 339, 105, 194, 6, 773, 10, 343, 538, 472, 1, 3670, 11207, 8, 1451, 1451, 27, 244, 65, 13, 25, 33, 30, 8, 665, 1059, 56], [81, 19092, 47, 74, 339, 372, 2], [1618, 15, 1, 496, 66, 8, 361, 1508, 329, 1, 4, 25784, 1083]]
# [41, 418, 9, 6597, 625]

# %%
index_to_word={}
for key, value in word_to_index.items():
    index_to_word[value]=key

# %%
decoded_sample = [index_to_word[word] for word in encoded_x_train[0]]
print('기존 처1번 샘플: ', x_train[0])
print('복원 전 정수 인코딩 된 1번 샘플: ', encoded_x_train[0])
print('복원 1번 샘플: ', decoded_sample)
# Out:
# 기존 처1번 샘플:  ['아', '더빙', '진짜', '짜증나네요', '목소리']
# 복원 전 정수 인코딩 된 1번 샘플:  [41, 418, 9, 6597, 625]
# 복원 1번 샘플:  ['아', '더빙', '진짜', '짜증나네요', '목소리']

# %%
print([review for review in encoded_x_train][:5])
# Out:
# [[41, 418, 9, 6597, 625], [922, 419, 32, 567, 2, 183, 1519, 13, 940, 6028, 25782], [356, 2811, 1, 2643, 7320, 12022, 190, 5], [8576, 89, 11206, 206, 47, 65, 15, 4336], [1006, 1, 18, 1, 13, 6407, 2, 2967, 12, 5279, 1, 441, 21839, 1, 1065, 3669, 4521]]

# %%
print('각 리뷰의 길이 : ', [len(review) for review in encoded_x_train] )
print('리뷰의 최대 길이 : ', max(len(review) for review in encoded_x_train) )
print('리뷰의 최대 길이 : ', max([len(review) for review in encoded_x_train]) )
print('리뷰의 평균 길이 : ', sum(map(len, encoded_x_train))/len(encoded_x_train))
# Out:
# 각 리뷰의 길이 :  [5, 11, 8, 8, 17, 16, 6, 36, 7, 13, 6, 13, 16, 17, 21, 7, 24, 13, 14, 12, 12, 5, 40, 8, 5, 12, 4, 3, 1, 10, 17, 9, 6, 7, 5, 6, 10, 8, 6, 7, 4, 23, 4, 11, 27, 8, 40, 19, 5, 47, 17, 13, 11, 13, 1, 2, 1, 28, 2, 3, 7, 8, 8, 28, 12, 41, 25, 13, 9, 8, 7, 36, 1, 7, 4, 14, 5, 2, 17, 3, 10, 4, 16, 5, 4, 5, 2, 3, 5, 9, 7, 6, 2, 9, 5, 7, 3, 6, 6, 11, 12, 8, 9, 7, 4, 13, 1, 4, 9, 10, 9, 11, 7, 1, 16, 2, 4, 4, 10, 4, 28, 15, 7, 3, 2, 6, 6, 16, 40, 9, 2, 5, 3, 10, 6, 9, 11, 5, 12, 15, 1, 12, 45, 2, 4, 5, 37, 21, 11, 44, 8, 1, 11, 4, 3, 3, 20, 9, 5, 1, 6, 12, 5, 31, 45, 13, 3, 13, 9, 1, 26, 36, 6, 5, 4, 14, 2, 4, 13, 5, 34, 7, 34, 4, 13, 1, 4, 6, 26, 6, 4, 13, 13, 18, 17, 13, 5, 17, 12, 25, 8, 11, 6, 53, 15, 6, 10, 3, 14, 5, 4, 7, 7, 11, 3, 11, 11, 9, 12, 10, 27, 7, 17, 8, 4, 12, 4, 7, 22, 9, 30, 10, 44, 40, 6, 5, 7, 14, 9, 7, 9, 9, 10, 11, 15, 7, 9, 4, 5, 7, 13, 3, 6, 2, 11, 7, 8, 3, 12, 6, 21, 5, 16, 12, 5, 5, 28, 8, 7, 6, 2, 7, 3, 6, 6, 15, 13, 2, 1, 10, 31, 9, 15, 33, 7, 4, 18, 2, 2
# ...

# %%
plt.hist([len(review) for review in encoded_x_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
